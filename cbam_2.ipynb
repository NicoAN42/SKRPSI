# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoAN42/SKRPSI/blob/main/cbam_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mount dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.layers import Conv2D, Input, concatenate, Activation, InputLayer, Dense, Reshape, Flatten, Add, multiply, Permute, Lambda, Concatenate
from tensorflow.keras.layers import LeakyReLU,ReLU, MaxPooling2D, BatchNormalization,GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import layers
from tensorflow.keras.activations import softmax,sigmoid
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout,SpatialDropout2D,GaussianDropout
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.regularizers import l1,l2
from tensorflow.keras import backend as K
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow
import tensorflow as tf
import math
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold
import os
import random
import shutil

# %%
#from tensorflow.keras.optimizers import SGD

# %%
CLASS = 3
#sourcepath isi semua data train, folder valid kosongin datanya sisai folder classnya
sourcePath = '/content/drive/MyDrive/Colab Notebooks/Dataset 11'
train_path = '/content/drive/MyDrive/Colab Notebooks/Dataset 11/train'
valid_path = '/content/drive/MyDrive/Colab Notebooks/Dataset 11/valid'
test_path = '/content/drive/MyDrive/Colab Notebooks/Dataset 11/test'
attention_module = 'cbam_block'
#nico

# %%
classLabels =['covid','normal', 'pneumonia']

# %%
def attach_attention_module(net, attention_module):
  #if attention_module == 'se_block': # SE_block
    #net = se_block(net)
  if attention_module == 'cbam_block': # CBAM_block
    net = cbam_block(net)
  else:
    raise Exception("'{}' is not supported attention module!".format(attention_module))

  return net

# %%
def cbam_block(cbam_feature, ratio=8):
	"""Contains the implementation of Convolutional Block Attention Module(CBAM) block.
	As described in https://arxiv.org/abs/1807.06521.
	"""
	
	cbam_feature = channel_attention(cbam_feature, ratio)
	cbam_feature = spatial_attention(cbam_feature)
	return cbam_feature

# %%
def channel_attention(input_feature, ratio=8):
	
	channel_axis = 1 if K.image_data_format() == "channels_first" else -1
	channel = input_feature.shape[channel_axis]
	
	shared_layer_one = Dense(channel//ratio,
							 activation='relu',
							 kernel_initializer='he_normal',
							 use_bias=True,
							 bias_initializer='zeros')
	shared_layer_two = Dense(channel,
							 kernel_initializer='he_normal',
							 use_bias=True,
							 bias_initializer='zeros')
	
	avg_pool = GlobalAveragePooling2D()(input_feature)    
	avg_pool = Reshape((1,1,channel))(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel)
	avg_pool = shared_layer_one(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel//ratio)
	avg_pool = shared_layer_two(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel)
	
	max_pool = GlobalMaxPooling2D()(input_feature)
	max_pool = Reshape((1,1,channel))(max_pool)
	assert max_pool.shape[1:] == (1,1,channel)
	max_pool = shared_layer_one(max_pool)
	assert max_pool.shape[1:] == (1,1,channel//ratio)
	max_pool = shared_layer_two(max_pool)
	assert max_pool.shape[1:] == (1,1,channel)
	
	cbam_feature = Add()([avg_pool,max_pool])
	cbam_feature = Activation('sigmoid')(cbam_feature)
	
	if K.image_data_format() == "channels_first":
		cbam_feature = Permute((3, 1, 2))(cbam_feature)
	
	return multiply([input_feature, cbam_feature])

# %%
def spatial_attention(input_feature):
	kernel_size = 7
	
	if K.image_data_format() == "channels_first":
		channel = input_feature.shape[1]
		cbam_feature = Permute((2,3,1))(input_feature)
	else:
		channel = input_feature.shape[-1]
		cbam_feature = input_feature
	
	avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
	assert avg_pool.shape[-1] == 1
	max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
	assert max_pool.shape[-1] == 1
	concat = Concatenate(axis=3)([avg_pool, max_pool])
	assert concat.shape[-1] == 2
	cbam_feature = Conv2D(filters = 1,
					kernel_size=kernel_size,
					strides=1,
					padding='same',
					activation='sigmoid',
					kernel_initializer='he_normal',
					use_bias=False)(concat)	
	assert cbam_feature.shape[-1] == 1
	
	if K.image_data_format() == "channels_first":
		cbam_feature = Permute((3, 1, 2))(cbam_feature)
		
	return multiply([input_feature, cbam_feature])

# %%
input = Input(shape=(256,256,3))

# %%
#Layer 1
model = layers.Conv2D(32, (3,3), padding='same', name='conv_1', activation = 'relu')(input)
model = layers.BatchNormalization(name='norm_1')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides= 2)(model)
attention_module = 'cbam_block'
y = attach_attention_module(model, attention_module)
model =  tensorflow.keras.layers.add([model, y])

# %%
#Layer 2
model = layers.Conv2D(64, (3,3), padding='same', name='conv_2', activation = 'relu')(model)
model = layers.Dropout(0.1)(model)
model = layers.BatchNormalization(name='norm_2')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

attention_module = 'cbam_block'
y = attach_attention_module(model, attention_module)
model =  tensorflow.keras.layers.add([model, y])

# %%
# Layer 3
model = layers.Conv2D(64, (3,3), padding='same', name='conv_3', activation = 'relu')(model)
model = layers.BatchNormalization(name='norm_3')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

attention_module = 'cbam_block'
y = attach_attention_module(model, attention_module)
model =  tensorflow.keras.layers.add([model, y])

# %%
# Layer 4
model = layers.Conv2D(128, (3,3), padding='same', name='conv_4', activation = 'relu')(model)
model = layers.Dropout(0.2)(model)
model = layers.BatchNormalization(name='norm_4')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

attention_module = 'cbam_block'
y = attach_attention_module(model, attention_module)
model =  tensorflow.keras.layers.add([model, y])

# %%
# Layer 5
model = layers.Conv2D(256, (3,3), padding='same', name='conv_5', activation = 'relu')(model)
layer = layers.Conv2D(256, (3,3), padding='same', name='conv_5', activation = 'relu')
batch = layers.BatchNormalization(name='norm_5')
model = layers.Dropout(0.2)(model)
model = layers.BatchNormalization(name='norm_5')(model)
#model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

# %%
model = layers.Flatten()(model)
model = layers.Dense(128, activation = 'relu')(model)
model = layers.Dropout(0.2)(model)
output = layers.Dense(3,Activation('softmax'))(model)
model = Model(input, output)

# %%
#output = model.output_shape

# %%
print(input)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")

# %%
initial_learning_rate=0.0001

# %%
lr_schedule = ExponentialDecay(
   initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)

# %%
opt = Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)

# %%
model.compile(optimizer=opt, loss="sparse_categorical_crossentropy", metrics=["accuracy"] )

# %%
print(model.summary())
print(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv_1 (Conv2D)                (None, 256, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  norm_1 (BatchNormalization)    (None, 256, 256, 32  128         ['conv_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['norm_1[0][0]']
#                                 )
#
#  global_average_pooling2d (Glob  (None, 32)          0           ['max_pooling2d[0][0]']
#  alAveragePooling2D)
#
#  global_max_pooling2d (GlobalMa  (None, 32)          0           ['max_pooling2d[0][0]']
#  xPooling2D)
#
#  reshape (Reshape)              (None, 1, 1, 32)     0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  reshape_1 (Reshape)            (None, 1, 1, 32)     0           ['global_max_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 1, 1, 4)      132         ['reshape[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  dense_1 (Dense)                (None, 1, 1, 32)     160         ['dense[0][0]',
#                                                                   'dense[1][0]']
#
#  add (Add)                      (None, 1, 1, 32)     0           ['dense_1[0][0]',
#                                                                   'dense_1[1][0]']
#
#  activation (Activation)        (None, 1, 1, 32)     0           ['add[0][0]']
#
#  multiply (Multiply)            (None, 128, 128, 32  0           ['max_pooling2d[0][0]',
#                                 )                                 'activation[0][0]']
#
#  lambda (Lambda)                (None, 128, 128, 1)  0           ['multiply[0][0]']
#
#  lambda_1 (Lambda)              (None, 128, 128, 1)  0           ['multiply[0][0]']
#
#  concatenate (Concatenate)      (None, 128, 128, 2)  0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  conv2d (Conv2D)                (None, 128, 128, 1)  98          ['concatenate[0][0]']
#
#  multiply_1 (Multiply)          (None, 128, 128, 32  0           ['multiply[0][0]',
#                                 )                                 'conv2d[0][0]']
#
#  add_1 (Add)                    (None, 128, 128, 32  0           ['max_pooling2d[0][0]',
#                                 )                                 'multiply_1[0][0]']
#
#  conv_2 (Conv2D)                (None, 128, 128, 64  18496       ['add_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 64  0           ['conv_2[0][0]']
#                                 )
#
#  norm_2 (BatchNormalization)    (None, 128, 128, 64  256         ['dropout[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['norm_2[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 64)          0           ['max_pooling2d_1[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_1 (Global  (None, 64)          0           ['max_pooling2d_1[0][0]']
#  MaxPooling2D)
#
#  reshape_2 (Reshape)            (None, 1, 1, 64)     0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  reshape_3 (Reshape)            (None, 1, 1, 64)     0           ['global_max_pooling2d_1[0][0]']
#
#  dense_2 (Dense)                (None, 1, 1, 8)      520         ['reshape_2[0][0]',
#                                                                   'reshape_3[0][0]']
#
#  dense_3 (Dense)                (None, 1, 1, 64)     576         ['dense_2[0][0]',
#                                                                   'dense_2[1][0]']
#
#  add_2 (Add)                    (None, 1, 1, 64)     0           ['dense_3[0][0]',
#                                                                   'dense_3[1][0]']
#
#  activation_1 (Activation)      (None, 1, 1, 64)     0           ['add_2[0][0]']
#
#  multiply_2 (Multiply)          (None, 64, 64, 64)   0           ['max_pooling2d_1[0][0]',
#                                                                   'activation_1[0][0]']
#
#  lambda_2 (Lambda)              (None, 64, 64, 1)    0           ['multiply_2[0][0]']
#
#  lambda_3 (Lambda)              (None, 64, 64, 1)    0           ['multiply_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 2)    0           ['lambda_2[0][0]',
#                                                                   'lambda_3[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 1)    98          ['concatenate_1[0][0]']
#
#  multiply_3 (Multiply)          (None, 64, 64, 64)   0           ['multiply_2[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  add_3 (Add)                    (None, 64, 64, 64)   0           ['max_pooling2d_1[0][0]',
#                                                                   'multiply_3[0][0]']
#
#  conv_3 (Conv2D)                (None, 64, 64, 64)   36928       ['add_3[0][0]']
#
#  norm_3 (BatchNormalization)    (None, 64, 64, 64)   256         ['conv_3[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)  0           ['norm_3[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 64)          0           ['max_pooling2d_2[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_2 (Global  (None, 64)          0           ['max_pooling2d_2[0][0]']
#  MaxPooling2D)
#
#  reshape_4 (Reshape)            (None, 1, 1, 64)     0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  reshape_5 (Reshape)            (None, 1, 1, 64)     0           ['global_max_pooling2d_2[0][0]']
#
#  dense_4 (Dense)                (None, 1, 1, 8)      520         ['reshape_4[0][0]',
#                                                                   'reshape_5[0][0]']
#
#  dense_5 (Dense)                (None, 1, 1, 64)     576         ['dense_4[0][0]',
#                                                                   'dense_4[1][0]']
#
#  add_4 (Add)                    (None, 1, 1, 64)     0           ['dense_5[0][0]',
#                                                                   'dense_5[1][0]']
#
#  activation_2 (Activation)      (None, 1, 1, 64)     0           ['add_4[0][0]']
#
#  multiply_4 (Multiply)          (None, 32, 32, 64)   0           ['max_pooling2d_2[0][0]',
#                                                                   'activation_2[0][0]']
#
#  lambda_4 (Lambda)              (None, 32, 32, 1)    0           ['multiply_4[0][0]']
#
#  lambda_5 (Lambda)              (None, 32, 32, 1)    0           ['multiply_4[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 2)    0           ['lambda_4[0][0]',
#                                                                   'lambda_5[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 1)    98          ['concatenate_2[0][0]']
#
#  multiply_5 (Multiply)          (None, 32, 32, 64)   0           ['multiply_4[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  add_5 (Add)                    (None, 32, 32, 64)   0           ['max_pooling2d_2[0][0]',
#                                                                   'multiply_5[0][0]']
#
#  conv_4 (Conv2D)                (None, 32, 32, 128)  73856       ['add_5[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 128)  0           ['conv_4[0][0]']
#
#  norm_4 (BatchNormalization)    (None, 32, 32, 128)  512         ['dropout_1[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0          ['norm_4[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 128)         0           ['max_pooling2d_3[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_3 (Global  (None, 128)         0           ['max_pooling2d_3[0][0]']
#  MaxPooling2D)
#
#  reshape_6 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  reshape_7 (Reshape)            (None, 1, 1, 128)    0           ['global_max_pooling2d_3[0][0]']
#
#  dense_6 (Dense)                (None, 1, 1, 16)     2064        ['reshape_6[0][0]',
#                                                                   'reshape_7[0][0]']
#
#  dense_7 (Dense)                (None, 1, 1, 128)    2176        ['dense_6[0][0]',
#                                                                   'dense_6[1][0]']
#
#  add_6 (Add)                    (None, 1, 1, 128)    0           ['dense_7[0][0]',
#                                                                   'dense_7[1][0]']
#
#  activation_3 (Activation)      (None, 1, 1, 128)    0           ['add_6[0][0]']
#
#  multiply_6 (Multiply)          (None, 16, 16, 128)  0           ['max_pooling2d_3[0][0]',
#                                                                   'activation_3[0][0]']
#
#  lambda_6 (Lambda)              (None, 16, 16, 1)    0           ['multiply_6[0][0]']
#
#  lambda_7 (Lambda)              (None, 16, 16, 1)    0           ['multiply_6[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 16, 16, 2)    0           ['lambda_6[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 1)    98          ['concatenate_3[0][0]']
#
#  multiply_7 (Multiply)          (None, 16, 16, 128)  0           ['multiply_6[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  add_7 (Add)                    (None, 16, 16, 128)  0           ['max_pooling2d_3[0][0]',
#                                                                   'multiply_7[0][0]']
#
#  conv_5 (Conv2D)                (None, 16, 16, 256)  295168      ['add_7[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 256)  0           ['conv_5[0][0]']
#
#  norm_5 (BatchNormalization)    (None, 16, 16, 256)  1024        ['dropout_2[0][0]']
#
#  flatten (Flatten)              (None, 65536)        0           ['norm_5[0][0]']
#
#  dense_8 (Dense)                (None, 128)          8388736     ['flatten[0][0]']
#
#  dropout_3 (Dropout)            (None, 128)          0           ['dense_8[0][0]']
#
#  dense_9 (Dense)                (None, 3)            387         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 8,823,759
# Trainable params: 8,822,671
# Non-trainable params: 1,088
# __________________________________________________________________________________________________
# None
# <keras.engine.functional.Functional object at 0x7fb8b0318650>

# %%
X = []
Y = []
def transferBetweenFolders(source, dest, splitRate): 
    global sourceFiles
    sourceFiles=os.listdir(source)
    if(len(sourceFiles)!=0):
        transferFileNumbers=int(len(sourceFiles)*splitRate)
        transferIndex=random.sample(range(0, len(sourceFiles)), transferFileNumbers)
        for eachIndex in transferIndex:
            shutil.move(source+str(sourceFiles[eachIndex]), dest+str(sourceFiles[eachIndex]))
    else:
        print("No file moved. Source empty!")

# %%
def transferAllClassBetweenFolders(source, dest, splitRate):
    for label in classLabels:
        transferBetweenFolders(sourcePath+'/'+source+'/'+label+'/', 
                               sourcePath+'/'+dest+'/'+label+'/', 
                               splitRate)
#First cut all images from validation to train (if any exists)
transferAllClassBetweenFolders('valid', 'train', 1.0)
#no valid
transferAllClassBetweenFolders('test', 'train', 1.0)
# Out:
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!

# %%
def prepareNameWithLabels(folderName):
    sourceFiles=os.listdir(sourcePath+'/train/'+folderName)
    for val in sourceFiles:
        X.append(val)
        for i in range(len(classLabels)):
          if(folderName==classLabels[i]):
              Y.append(i)
# Organize file names and class labels in X and Y variables
for i in range(len(classLabels)):
  prepareNameWithLabels(classLabels[i])

def my_metrics(y_true, y_pred):
    accuracy=accuracy_score(y_true, y_pred)
    precision=precision_score(y_true, y_pred,average='weighted')
    f1Score=f1_score(y_true, y_pred, average='weighted') 
    print("Accuracy  : {}".format(accuracy))
    print("Precision : {}".format(precision))
    print("f1Score : {}".format(f1Score))
    cm=confusion_matrix(y_true, y_pred)
    print(cm)
    return accuracy, precision, f1Score

# %%
transferAllClassBetweenFolders('valid', 'train', 1.0)
transferAllClassBetweenFolders('test', 'train', 1.0)
X=np.asarray(X)
Y=np.asarray(Y)

print(X)
print(Y)

skf = StratifiedKFold(n_splits=5
                      , shuffle=True)
skf.get_n_splits(X, Y)
print(skf)
print(skf.get_n_splits(X,Y))
print(skf.split(X,Y))
foldNum=0
overAllAcc = 0
# Out:
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# ['COVID(51).png' 'COVID(24).png' 'COVID(28).png' ...
#  'person119_virus_225.jpeg' 'person110_virus_205.jpeg'
#  'person101_virus_188.jpeg']
# [0 0 0 ... 2 2 2]
# StratifiedKFold(n_splits=5, random_state=None, shuffle=True)
# 5
# <generator object _BaseKFold.split at 0x7fb8b02c8450>

# %%
for train_index, val_index in skf.split(X, Y):
    print("trn_indx: %s test_indx: %s" % (len(train_index), len(val_index)))
    #First cut all images from validation to train (if any exists)
    transferAllClassBetweenFolders('valid', 'train', 1.0)
    #no valid
    transferAllClassBetweenFolders('test', 'train', 1.0)
    foldNum+=1
    print("Results for fold",foldNum)
    X_train, X_val = X[train_index], X[val_index]
    Y_train, Y_val = Y[train_index], Y[val_index]
    print(len(X_train))
    print(len(X_val))
    # Move validation images of this fold from train folder to the validation folder
    for eachIndex in range(len(X_val)):
        classLabel=''
        for i in range(len(classLabels)):
          if(Y_val[eachIndex]==i):
              classLabel=classLabels[i]
        #Then, copy the validation images to the validation folder
        shutil.move(sourcePath+'/train/'+classLabel+'/'+X_val[eachIndex], 
                    #sourcePath+'/valid/'+classLabel+'/'+X_val[eachIndex])
        #without valid
                    sourcePath+'/test/'+classLabel+'/'+X_val[eachIndex])
        
    train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 32, shuffle=True)
    #without valid
    #valid_batches = ImageDataGenerator().flow_from_directory(valid_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 32, shuffle=True)
    test_batches = ImageDataGenerator().flow_from_directory(test_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 32, shuffle=False)

    history = model.fit(train_batches, 
                    #steps_per_epoch=sp_epoch, 
                    #without valid
                    #validation_data=valid_batches, 
                    #validation_steps=10, 
                    epochs=100, 
                    verbose=2)
    
    
    
    plt.plot(history.history['accuracy'])
    #plt.plot(history.history['val_accuracy'])
    plt.title('Final Cbam model accuracy')
    plt.ylim(0,1.1)
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    #plt.legend(['train', 'valid'], loc='upper left')
    #without valid
    plt.legend(['train'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    #plt.plot(history.history['val_loss'])
    plt.title('Final Cbam model loss')
    plt.ylim(0,1.1)
    plt.ylabel('loss')
    plt.xlabel('epoch')
    #plt.legend(['train', 'valid'], loc='upper left')
    #without valid
    plt.legend(['train'], loc='upper left')
    plt.show()
    test_batches.reset()
    Y_pred = model.predict(test_batches)
    classes = test_batches.classes[test_batches.index_array]
    y_pred = np.argmax(Y_pred, axis=-1)
    print(sum(y_pred==classes)/10000)
    confusion_matrix(test_batches.classes[test_batches.index_array],y_pred)
    #predictions = model.predict(test_batches, verbose=1)
    #yPredictions = np.argmax(predictions, axis=1)
    #print(yPredictions)
    #true_classes = test_batches.classes
    # evaluate validation performance
    print("***Performance on Test Data***")    
    #valAcc, valPrec, valFScore = my_metrics(true_classes, yPredictions)
    valAcc, valPrec, valFScore = my_metrics(classes, y_pred)
    #valAcc, valPrec, valFScore = my_metrics(classes, y_pred)
    overAllAcc = overAllAcc+valAcc
    
    model.evaluate(test_batches)
print("Overall Accuracy: ",  overAllAcc/foldNum)
# Out:
# trn_indx: 2160 test_indx: 540
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# Results for fold 1
# 2160
# 540
# Found 2160 images belonging to 3 classes.
# Found 540 images belonging to 3 classes.
# Epoch 1/100
# 68/68 - 518s - loss: 0.6998 - accuracy: 0.8704 - 518s/epoch - 8s/step
# Epoch 2/100
# 68/68 - 22s - loss: 0.2124 - accuracy: 0.9426 - 22s/epoch - 327ms/step
# Epoch 3/100
# 68/68 - 22s - loss: 0.2269 - accuracy: 0.9500 - 22s/epoch - 330ms/step
# Epoch 4/100
# 68/68 - 22s - loss: 0.1689 - accuracy: 0.9565 - 22s/epoch - 326ms/step
# Epoch 5/100
# 68/68 - 22s - loss: 0.1266 - accuracy: 0.9639 - 22s/epoch - 322ms/step
# Epoch 6/100
# 68/68 - 22s - loss: 0.0545 - accuracy: 0.9838 - 22s/epoch - 322ms/step
# Epoch 7/100
# 68/68 - 22s - loss: 0.0569 - accuracy: 0.9847 - 22s/epoch - 325ms/step
# Epoch 8/100
# 68/68 - 22s - loss: 0.0687 - accuracy: 0.9801 - 22s/epoch - 329ms/step
# Epoch 9/100
# 68/68 - 22s - loss: 0.0360 - accuracy: 0.9870 - 22s/epoch - 324ms/step
# Epoch 10/100
# 68/68 - 23s - loss: 0.0274 - accuracy: 0.9926 - 23s/epoch - 331ms/step
# Epoch 11/100
# 68/68 - 22s - loss: 0.0444 - accuracy: 0.9861 - 22s/epoch - 329ms/step
# Epoch 12/100
# 68/68 - 23s - loss: 0.0641 - accuracy: 0.9843 - 23s/epoch - 334ms/step
# Epoch 13/100
# 68/68 - 22s - loss: 0.0352 - accuracy: 0.9903 - 22s/epoch - 325ms/step
# Epoch 14/100
# 68/68 - 22s - loss: 0.0122 - accuracy: 0.9963 - 22s/epoch - 331ms/step
# Epoch 15/100
# 68/68 - 22s - loss: 0.0112 - accuracy: 0.9954 - 22s/epoch - 331ms/step
# Epoch 16/100
# 68/68 - 22s - loss: 0.0139 - accuracy: 0.9972 - 22s/epoch - 325ms/step
# Epoch 17/100
# 68/68 - 23s - loss: 0.0101 - accuracy: 0.9949 - 23s/epoch - 332ms/step
# Epoch 18/100
# 68/68 - 22s - loss: 0.0243 - accuracy: 0.9921 - 22s/epoch - 329ms/step
# Epoch 19/100
# 68/68 - 23s - loss: 0.0101 - accuracy: 0.9963 - 23s/epoch - 334ms/step
# Epoch 20/100
# 68/68 - 22s - loss: 0.0075 - accuracy: 0.9981 - 22s/epoch - 329ms/step
# Epoch 21/100
# 68/68 - 23s - loss: 0.0061 - accuracy: 0.9977 - 23s/epoch - 332ms/step
# Epoch 22/100
# 68/68 - 23s - loss: 0.0415 - accuracy: 0.9889 - 23s/epoch - 331ms/step
# Epoch 23/100
# 68/68 - 22s - loss: 0.0596 - accuracy: 0.9852 - 22s/epoch - 326ms/step
# Epoch 24/100
# 68/68 - 22s - loss: 0.1349 - accuracy: 0.9750 - 22s/epoch - 326ms/step
# Epoch 25/100
# 68/68 - 22s - loss: 3.4864 - accuracy: 0.8662 - 22s/epoch - 326ms/step
# Epoch 26/100
# 68/68 - 22s - loss: 0.2544 - accuracy: 0.9208 - 22s/epoch - 327ms/step
# Epoch 27/100
# 68/68 - 22s - loss: 0.1761 - accuracy: 0.9458 - 22s/epoch - 324ms/step
# Epoch 28/100
# 68/68 - 22s - loss: 0.1186 - accuracy: 0.9602 - 22s/epoch - 326ms/step
# Epoch 29/100
# 68/68 - 22s - loss: 0.1162 - accuracy: 0.9644 - 22s/epoch - 328ms/step
# Epoch 30/100
# 68/68 - 22s - loss: 0.0707 - accuracy: 0.9764 - 22s/epoch - 324ms/step
# Epoch 31/100
# 68/68 - 22s - loss: 0.0651 - accuracy: 0.9745 - 22s/epoch - 325ms/step
# Epoch 32/100
# 68/68 - 22s - loss: 0.0567 - accuracy: 0.9824 - 22s/epoch - 324ms/step
# Epoch 33/100
# 68/68 - 23s - loss: 0.0686 - accuracy: 0.9796 - 23s/epoch - 335ms/step
# Epoch 34/100
# 68/68 - 22s - loss: 0.0554 - accuracy: 0.9810 - 22s/epoch - 328ms/step
# Epoch 35/100
# 68/68 - 22s - loss: 0.0612 - accuracy: 0.9810 - 22s/epoch - 327ms/step
# Epoch 36/100
# 68/68 - 22s - loss: 0.0405 - accuracy: 0.9861 - 22s/epoch - 330ms/step
# Epoch 37/100
# 68/68 - 22s - loss: 0.0419 - accuracy: 0.9856 - 22s/epoch - 324ms/step
# Epoch 38/100
# 68/68 - 22s - loss: 0.0371 - accuracy: 0.9856 - 22s/epoch - 325ms/step
# Epoch 39/100
# 68/68 - 22s - loss: 0.0458 - accuracy: 0.9856 - 22s/epoch - 324ms/step
# Epoch 40/100
# 68/68 - 22s - loss: 0.0378 - accuracy: 0.9856 - 22s/epoch - 330ms/step
# Epoch 41/100
# 68/68 - 22s - loss: 0.0355 - accuracy: 0.9880 - 22s/epoch - 327ms/step
# Epoch 42/100
# 68/68 - 22s - loss: 0.0435 - accuracy: 0.9847 - 22s/epoch - 323ms/step
# Epoch 43/100
# 68/68 - 23s - loss: 0.0238 - accuracy: 0.9912 - 23s/epoch - 331ms/step
# Epoch 44/100
# 68/68 - 22s - loss: 0.0472 - accuracy: 0.9856 - 22s/epoch - 327ms/step
# Epoch 45/100
# 68/68 - 22s - loss: 0.0276 - accuracy: 0.9870 - 22s/epoch - 329ms/step
# Epoch 46/100
# 68/68 - 22s - loss: 0.0164 - accuracy: 0.9944 - 22s/epoch - 328ms/step
# Epoch 47/100
# 68/68 - 23s - loss: 0.0340 - accuracy: 0.9898 - 23s/epoch - 331ms/step
# Epoch 48/100
# 68/68 - 22s - loss: 0.0250 - accuracy: 0.9894 - 22s/epoch - 327ms/step
# Epoch 49/100
# 68/68 - 22s - loss: 0.0522 - accuracy: 0.9875 - 22s/epoch - 324ms/step
# Epoch 50/100
# 68/68 - 22s - loss: 0.0315 - accuracy: 0.9875 - 22s/epoch - 326ms/step
# Epoch 51/100
# 68/68 - 22s - loss: 0.1396 - accuracy: 0.9843 - 22s/epoch - 325ms/step
# Epoch 52/100
# 68/68 - 22s - loss: 0.1128 - accuracy: 0.9644 - 22s/epoch - 331ms/step
# Epoch 53/100
# 68/68 - 22s - loss: 0.0550 - accuracy: 0.9810 - 22s/epoch - 330ms/step
# Epoch 54/100
# 68/68 - 23s - loss: 0.0595 - accuracy: 0.9833 - 23s/epoch - 334ms/step
# Epoch 55/100
# 68/68 - 22s - loss: 0.0437 - accuracy: 0.9843 - 22s/epoch - 328ms/step
# Epoch 56/100
# 68/68 - 22s - loss: 0.0336 - accuracy: 0.9898 - 22s/epoch - 327ms/step
# Epoch 57/100
# 68/68 - 23s - loss: 0.0228 - accuracy: 0.9917 - 23s/epoch - 332ms/step
# Epoch 58/100
# 68/68 - 22s - loss: 0.0178 - accuracy: 0.9935 - 22s/epoch - 329ms/step
# Epoch 59/100
# 68/68 - 22s - loss: 0.0177 - accuracy: 0.9931 - 22s/epoch - 328ms/step
# Epoch 60/100
# 68/68 - 22s - loss: 0.0192 - accuracy: 0.9926 - 22s/epoch - 320ms/step
# Epoch 61/100
# 68/68 - 22s - loss: 0.0146 - accuracy: 0.9944 - 22s/epoch - 330ms/step
# Epoch 62/100
# 68/68 - 22s - loss: 0.0133 - accuracy: 0.9963 - 22s/epoch - 327ms/step
# Epoch 63/100
# 68/68 - 23s - loss: 0.0150 - accuracy: 0.9968 - 23s/epoch - 331ms/step
# Epoch 64/100
# 68/68 - 22s - loss: 0.0208 - accuracy: 0.9940 - 22s/epoch - 328ms/step
# Epoch 65/100
# 68/68 - 23s - loss: 0.0133 - accuracy: 0.9954 - 23s/epoch - 333ms/step
# Epoch 66/100
# 68/68 - 22s - loss: 0.0180 - accuracy: 0.9944 - 22s/epoch - 330ms/step
# Epoch 67/100
# 68/68 - 22s - loss: 0.0231 - accuracy: 0.9935 - 22s/epoch - 324ms/step
# Epoch 68/100
# 68/68 - 22s - loss: 0.0232 - accuracy: 0.9931 - 22s/epoch - 325ms/step
# Epoch 69/100
# 68/68 - 22s - loss: 0.0106 - accuracy: 0.9977 - 22s/epoch - 324ms/step
# Epoch 70/100
# 68/68 - 22s - loss: 0.0185 - accuracy: 0.9963 - 22s/epoch - 323ms/step
# Epoch 71/100
# 68/68 - 22s - loss: 0.0379 - accuracy: 0.9875 - 22s/epoch - 326ms/step
# Epoch 72/100
# 68/68 - 22s - loss: 0.0509 - accuracy: 0.9861 - 22s/epoch - 322ms/step
# Epoch 73/100
# 68/68 - 22s - loss: 0.0300 - accuracy: 0.9921 - 22s/epoch - 329ms/step
# Epoch 74/100
# 68/68 - 22s - loss: 0.0338 - accuracy: 0.9907 - 22s/epoch - 323ms/step
# Epoch 75/100
# 68/68 - 22s - loss: 0.0212 - accuracy: 0.9898 - 22s/epoch - 329ms/step
# Epoch 76/100
# 68/68 - 22s - loss: 0.0267 - accuracy: 0.9940 - 22s/epoch - 327ms/step
# Epoch 77/100
# 68/68 - 22s - loss: 0.0109 - accuracy: 0.9963 - 22s/epoch - 328ms/step
# Epoch 78/100
# 68/68 - 22s - loss: 0.0154 - accuracy: 0.9958 - 22s/epoch - 323ms/step
# Epoch 79/100
# 68/68 - 22s - loss: 0.0097 - accuracy: 0.9972 - 22s/epoch - 321ms/step
# Epoch 80/100
# 68/68 - 22s - loss: 0.0093 - accuracy: 0.9972 - 22s/epoch - 324ms/step
# Epoch 81/100
# 68/68 - 22s - loss: 0.0184 - accuracy: 0.9954 - 22s/epoch - 324ms/step
# Epoch 82/100
# 68/68 - 22s - loss: 0.0067 - accuracy: 0.9986 - 22s/epoch - 323ms/step
# Epoch 83/100
# 68/68 - 22s - loss: 0.0144 - accuracy: 0.9968 - 22s/epoch - 328ms/step
# Epoch 84/100
# 68/68 - 23s - loss: 0.0094 - accuracy: 0.9968 - 23s/epoch - 334ms/step
# Epoch 85/100
# 68/68 - 22s - loss: 0.0236 - accuracy: 0.9921 - 22s/epoch - 331ms/step
# Epoch 86/100
# 68/68 - 22s - loss: 0.0224 - accuracy: 0.9917 - 22s/epoch - 329ms/step
# Epoch 87/100
# 68/68 - 22s - loss: 0.0118 - accuracy: 0.9963 - 22s/epoch - 328ms/step
# Epoch 88/100
# 68/68 - 22s - loss: 0.0155 - accuracy: 0.9940 - 22s/epoch - 327ms/step
# Epoch 89/100
# 68/68 - 22s - loss: 0.0114 - accuracy: 0.9968 - 22s/epoch - 326ms/step
# Epoch 90/100
# 68/68 - 22s - loss: 0.0078 - accuracy: 0.9968 - 22s/epoch - 326ms/step
# Epoch 91/100
# 68/68 - 22s - loss: 0.0176 - accuracy: 0.9954 - 22s/epoch - 326ms/step
# Epoch 92/100
# 68/68 - 22s - loss: 0.0115 - accuracy: 0.9968 - 22s/epoch - 323ms/step
# Epoch 93/100
# 68/68 - 22s - loss: 0.0387 - accuracy: 0.9931 - 22s/epoch - 326ms/step
# Epoch 94/100
# 68/68 - 22s - loss: 0.0802 - accuracy: 0.9741 - 22s/epoch - 329ms/step
# Epoch 95/100
# 68/68 - 22s - loss: 0.0470 - accuracy: 0.9898 - 22s/epoch - 327ms/step
# Epoch 96/100
# 68/68 - 22s - loss: 0.0319 - accuracy: 0.9926 - 22s/epoch - 326ms/step
# Epoch 97/100
# 68/68 - 22s - loss: 0.0223 - accuracy: 0.9907 - 22s/epoch - 327ms/step
# Epoch 98/100
# 68/68 - 22s - loss: 0.0157 - accuracy: 0.9954 - 22s/epoch - 330ms/step
# Epoch 99/100
# 68/68 - 23s - loss: 0.0100 - accuracy: 0.9963 - 23s/epoch - 336ms/step
# Epoch 100/100
# 68/68 - 22s - loss: 0.0234 - accuracy: 0.9949 - 22s/epoch - 325ms/step
# 0.052
# ***Performance on Test Data***
# Accuracy  : 0.9629629629629629
# Precision : 0.9638332004143407
# f1Score : 0.963010468584239
# [[176   1   3]
#  [  3 169   8]
#  [  5   0 175]]
# 17/17 [==============================] - 6s 359ms/step - loss: 0.5097 - accuracy: 0.9630
# trn_indx: 2160 test_indx: 540
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# Results for fold 2
# 2160
# 540
# Found 2160 images belonging to 3 classes.
# Found 540 images belonging to 3 classes.
# Epoch 1/100
# 68/68 - 23s - loss: 0.1513 - accuracy: 0.9764 - 23s/epoch - 336ms/step
# Epoch 2/100
# 68/68 - 23s - loss: 0.0758 - accuracy: 0.9796 - 23s/epoch - 331ms/step
# Epoch 3/100
# 68/68 - 23s - loss: 0.0450 - accuracy: 0.9861 - 23s/epoch - 334ms/step
# Epoch 4/100
# 68/68 - 23s - loss: 0.0526 - accuracy: 0.9889 - 23s/epoch - 335ms/step
# Epoch 5/100
# 68/68 - 22s - loss: 0.0282 - accuracy: 0.9903 - 22s/epoch - 326ms/step
# Epoch 6/100
# 68/68 - 22s - loss: 0.0149 - accuracy: 0.9944 - 22s/epoch - 329ms/step
# Epoch 7/100
# 68/68 - 22s - loss: 0.0249 - accuracy: 0.9917 - 22s/epoch - 328ms/step
# Epoch 8/100
# 68/68 - 23s - loss: 0.0210 - accuracy: 0.9944 - 23s/epoch - 333ms/step
# Epoch 9/100
# 68/68 - 22s - loss: 0.0078 - accuracy: 0.9968 - 22s/epoch - 324ms/step
# Epoch 10/100
# 68/68 - 23s - loss: 0.0058 - accuracy: 0.9977 - 23s/epoch - 333ms/step
# Epoch 11/100
# 68/68 - 22s - loss: 0.0209 - accuracy: 0.9931 - 22s/epoch - 329ms/step
# Epoch 12/100
# 68/68 - 22s - loss: 0.0115 - accuracy: 0.9958 - 22s/epoch - 326ms/step
# Epoch 13/100
# 68/68 - 22s - loss: 0.0064 - accuracy: 0.9977 - 22s/epoch - 331ms/step
# Epoch 14/100
# 68/68 - 22s - loss: 0.0120 - accuracy: 0.9944 - 22s/epoch - 328ms/step
# Epoch 15/100
# 68/68 - 23s - loss: 0.0167 - accuracy: 0.9954 - 23s/epoch - 335ms/step
# Epoch 16/100
# 68/68 - 22s - loss: 0.0085 - accuracy: 0.9968 - 22s/epoch - 327ms/step
# Epoch 17/100
# 68/68 - 22s - loss: 0.0049 - accuracy: 0.9986 - 22s/epoch - 331ms/step
# Epoch 18/100
# 68/68 - 23s - loss: 0.0149 - accuracy: 0.9958 - 23s/epoch - 331ms/step
# Epoch 19/100
# 68/68 - 22s - loss: 0.0248 - accuracy: 0.9917 - 22s/epoch - 330ms/step
# Epoch 20/100
# 68/68 - 22s - loss: 0.0208 - accuracy: 0.9963 - 22s/epoch - 327ms/step
# Epoch 21/100
# 68/68 - 22s - loss: 0.0137 - accuracy: 0.9977 - 22s/epoch - 330ms/step
# Epoch 22/100
# 68/68 - 22s - loss: 0.0129 - accuracy: 0.9958 - 22s/epoch - 328ms/step
# Epoch 23/100
# 68/68 - 22s - loss: 0.0082 - accuracy: 0.9972 - 22s/epoch - 328ms/step
# Epoch 24/100
# 68/68 - 22s - loss: 0.0185 - accuracy: 0.9963 - 22s/epoch - 329ms/step
# Epoch 25/100
# 68/68 - 22s - loss: 0.0236 - accuracy: 0.9954 - 22s/epoch - 328ms/step
# Epoch 26/100
# 68/68 - 23s - loss: 0.0093 - accuracy: 0.9981 - 23s/epoch - 331ms/step
# Epoch 27/100
# 68/68 - 22s - loss: 0.0039 - accuracy: 0.9986 - 22s/epoch - 330ms/step
# Epoch 28/100
# 68/68 - 23s - loss: 0.0012 - accuracy: 0.9995 - 23s/epoch - 333ms/step
# Epoch 29/100
# 68/68 - 22s - loss: 0.0039 - accuracy: 0.9981 - 22s/epoch - 330ms/step
# Epoch 30/100
# 68/68 - 22s - loss: 0.0119 - accuracy: 0.9972 - 22s/epoch - 330ms/step
# Epoch 31/100
# 68/68 - 22s - loss: 0.0412 - accuracy: 0.9907 - 22s/epoch - 327ms/step
# Epoch 32/100
# 68/68 - 23s - loss: 0.0425 - accuracy: 0.9884 - 23s/epoch - 336ms/step
# Epoch 33/100
# 68/68 - 22s - loss: 0.0404 - accuracy: 0.9894 - 22s/epoch - 327ms/step
# Epoch 34/100
# 68/68 - 22s - loss: 0.0162 - accuracy: 0.9944 - 22s/epoch - 327ms/step
# Epoch 35/100
# 68/68 - 22s - loss: 0.0121 - accuracy: 0.9968 - 22s/epoch - 330ms/step
# Epoch 36/100
# 68/68 - 22s - loss: 0.0080 - accuracy: 0.9972 - 22s/epoch - 327ms/step
# Epoch 37/100
# 68/68 - 22s - loss: 0.0100 - accuracy: 0.9949 - 22s/epoch - 328ms/step
# Epoch 38/100
# 68/68 - 23s - loss: 0.0102 - accuracy: 0.9958 - 23s/epoch - 331ms/step
# Epoch 39/100
# 68/68 - 22s - loss: 0.0091 - accuracy: 0.9981 - 22s/epoch - 331ms/step
# Epoch 40/100
# 68/68 - 22s - loss: 0.0094 - accuracy: 0.9958 - 22s/epoch - 328ms/step
# Epoch 41/100
# 68/68 - 22s - loss: 0.0227 - accuracy: 0.9963 - 22s/epoch - 325ms/step
# Epoch 42/100
# 68/68 - 22s - loss: 0.0317 - accuracy: 0.9931 - 22s/epoch - 325ms/step
# Epoch 43/100
# 68/68 - 22s - loss: 0.0076 - accuracy: 0.9968 - 22s/epoch - 330ms/step
# Epoch 44/100
# 68/68 - 22s - loss: 0.0168 - accuracy: 0.9963 - 22s/epoch - 327ms/step
# Epoch 45/100
# 68/68 - 23s - loss: 0.0111 - accuracy: 0.9968 - 23s/epoch - 334ms/step
# Epoch 46/100
# 68/68 - 23s - loss: 0.0065 - accuracy: 0.9986 - 23s/epoch - 342ms/step
# Epoch 47/100
# 68/68 - 23s - loss: 0.0040 - accuracy: 0.9986 - 23s/epoch - 333ms/step
# Epoch 48/100
# 68/68 - 22s - loss: 0.0048 - accuracy: 0.9991 - 22s/epoch - 326ms/step
# Epoch 49/100
# 68/68 - 22s - loss: 0.0034 - accuracy: 0.9991 - 22s/epoch - 327ms/step
# Epoch 50/100
# 68/68 - 22s - loss: 0.0030 - accuracy: 0.9991 - 22s/epoch - 329ms/step
# Epoch 51/100
# 68/68 - 22s - loss: 0.0025 - accuracy: 0.9991 - 22s/epoch - 329ms/step
# Epoch 52/100
# 68/68 - 22s - loss: 0.0035 - accuracy: 0.9986 - 22s/epoch - 330ms/step
# Epoch 53/100
# 68/68 - 22s - loss: 0.0083 - accuracy: 0.9972 - 22s/epoch - 328ms/step
# Epoch 54/100
# 68/68 - 22s - loss: 0.0058 - accuracy: 0.9986 - 22s/epoch - 328ms/step
# Epoch 55/100
# 68/68 - 22s - loss: 0.0079 - accuracy: 0.9977 - 22s/epoch - 329ms/step
# Epoch 56/100
# 68/68 - 23s - loss: 0.0089 - accuracy: 0.9972 - 23s/epoch - 331ms/step
# Epoch 57/100
# 68/68 - 22s - loss: 0.0085 - accuracy: 0.9981 - 22s/epoch - 329ms/step
# Epoch 58/100
# 68/68 - 23s - loss: 0.0467 - accuracy: 0.9949 - 23s/epoch - 332ms/step
# Epoch 59/100
# 68/68 - 22s - loss: 0.0908 - accuracy: 0.9866 - 22s/epoch - 328ms/step
# Epoch 60/100
# 68/68 - 23s - loss: 0.0466 - accuracy: 0.9935 - 23s/epoch - 331ms/step
# Epoch 61/100
# 68/68 - 22s - loss: 0.0347 - accuracy: 0.9912 - 22s/epoch - 328ms/step
# Epoch 62/100
# 68/68 - 22s - loss: 0.0186 - accuracy: 0.9921 - 22s/epoch - 326ms/step
# Epoch 63/100
# 68/68 - 22s - loss: 0.0258 - accuracy: 0.9912 - 22s/epoch - 327ms/step
# Epoch 64/100
# 68/68 - 22s - loss: 0.0093 - accuracy: 0.9977 - 22s/epoch - 329ms/step
# Epoch 65/100
# 68/68 - 22s - loss: 0.0087 - accuracy: 0.9981 - 22s/epoch - 326ms/step
# Epoch 66/100
# 68/68 - 22s - loss: 0.0050 - accuracy: 0.9986 - 22s/epoch - 326ms/step
# Epoch 67/100
# 68/68 - 22s - loss: 0.0045 - accuracy: 0.9981 - 22s/epoch - 328ms/step
# Epoch 68/100
# 68/68 - 23s - loss: 0.0140 - accuracy: 0.9958 - 23s/epoch - 331ms/step
# Epoch 69/100
# 68/68 - 22s - loss: 0.0223 - accuracy: 0.9949 - 22s/epoch - 325ms/step
# Epoch 70/100
# 68/68 - 23s - loss: 0.0282 - accuracy: 0.9954 - 23s/epoch - 332ms/step
# Epoch 71/100
# 68/68 - 22s - loss: 0.0117 - accuracy: 0.9963 - 22s/epoch - 329ms/step
# Epoch 72/100
# 68/68 - 22s - loss: 0.0196 - accuracy: 0.9958 - 22s/epoch - 331ms/step
# Epoch 73/100
# 68/68 - 23s - loss: 0.0220 - accuracy: 0.9954 - 23s/epoch - 340ms/step
# Epoch 74/100
# 68/68 - 22s - loss: 0.0069 - accuracy: 0.9972 - 22s/epoch - 330ms/step
# Epoch 75/100
# 68/68 - 22s - loss: 0.0063 - accuracy: 0.9981 - 22s/epoch - 330ms/step
# Epoch 76/100
# 68/68 - 23s - loss: 0.0037 - accuracy: 0.9986 - 23s/epoch - 331ms/step
# Epoch 77/100
# 68/68 - 22s - loss: 0.0021 - accuracy: 0.9995 - 22s/epoch - 323ms/step
# Epoch 78/100
# 68/68 - 22s - loss: 0.0024 - accuracy: 0.9991 - 22s/epoch - 322ms/step
# Epoch 79/100
# 68/68 - 22s - loss: 0.0118 - accuracy: 0.9981 - 22s/epoch - 323ms/step
# Epoch 80/100
# 68/68 - 22s - loss: 0.0066 - accuracy: 0.9986 - 22s/epoch - 323ms/step
# Epoch 81/100
# 68/68 - 22s - loss: 0.0066 - accuracy: 0.9972 - 22s/epoch - 322ms/step
# Epoch 82/100
# 68/68 - 22s - loss: 0.0063 - accuracy: 0.9991 - 22s/epoch - 322ms/step
# Epoch 83/100
# 68/68 - 22s - loss: 0.0050 - accuracy: 0.9981 - 22s/epoch - 323ms/step
# Epoch 84/100
# 68/68 - 22s - loss: 0.0315 - accuracy: 0.9931 - 22s/epoch - 322ms/step
# Epoch 85/100
# 68/68 - 22s - loss: 0.0027 - accuracy: 0.9995 - 22s/epoch - 324ms/step
# Epoch 86/100
# 68/68 - 22s - loss: 0.0084 - accuracy: 0.9986 - 22s/epoch - 325ms/step
# Epoch 87/100
# 68/68 - 22s - loss: 0.0025 - accuracy: 0.9991 - 22s/epoch - 322ms/step
# Epoch 88/100
# 68/68 - 22s - loss: 0.0164 - accuracy: 0.9972 - 22s/epoch - 324ms/step
# Epoch 89/100
# 68/68 - 22s - loss: 0.0250 - accuracy: 0.9935 - 22s/epoch - 322ms/step
# Epoch 90/100
# 68/68 - 22s - loss: 0.0214 - accuracy: 0.9940 - 22s/epoch - 323ms/step
# Epoch 91/100
# 68/68 - 22s - loss: 0.0256 - accuracy: 0.9968 - 22s/epoch - 322ms/step
# Epoch 92/100
# 68/68 - 22s - loss: 0.0105 - accuracy: 0.9968 - 22s/epoch - 322ms/step
# Epoch 93/100
# 68/68 - 22s - loss: 0.0113 - accuracy: 0.9954 - 22s/epoch - 323ms/step
# Epoch 94/100
# 68/68 - 22s - loss: 0.0063 - accuracy: 0.9981 - 22s/epoch - 323ms/step
# Epoch 95/100
# 68/68 - 22s - loss: 0.0028 - accuracy: 0.9986 - 22s/epoch - 324ms/step
# Epoch 96/100
# 68/68 - 22s - loss: 0.0019 - accuracy: 0.9991 - 22s/epoch - 322ms/step
# Epoch 97/100
# 68/68 - 22s - loss: 0.0063 - accuracy: 0.9977 - 22s/epoch - 323ms/step
# Epoch 98/100
# 68/68 - 22s - loss: 0.0103 - accuracy: 0.9972 - 22s/epoch - 324ms/step
# Epoch 99/100
# 68/68 - 22s - loss: 0.0188 - accuracy: 0.9963 - 22s/epoch - 324ms/step
# Epoch 100/100
# 68/68 - 22s - loss: 0.0131 - accuracy: 0.9949 - 22s/epoch - 325ms/step
# 0.0527
# ***Performance on Test Data***
# Accuracy  : 0.975925925925926
# Precision : 0.9763122491080192
# f1Score : 0.9759261192819723
# [[179   0   1]
#  [  4 175   1]
#  [  4   3 173]]
# 17/17 [==============================] - 5s 330ms/step - loss: 0.1419 - accuracy: 0.9759
# trn_indx: 2160 test_indx: 540
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# Results for fold 3
# 2160
# 540
# Found 2160 images belonging to 3 classes.
# Found 540 images belonging to 3 classes.
# Epoch 1/100
# 68/68 - 22s - loss: 0.0406 - accuracy: 0.9894 - 22s/epoch - 324ms/step
# Epoch 2/100
# 68/68 - 22s - loss: 0.0147 - accuracy: 0.9949 - 22s/epoch - 326ms/step
# Epoch 3/100
# 68/68 - 22s - loss: 0.0151 - accuracy: 0.9968 - 22s/epoch - 330ms/step
# Epoch 4/100
# 68/68 - 22s - loss: 0.0116 - accuracy: 0.9968 - 22s/epoch - 329ms/step
# Epoch 5/100
# 68/68 - 22s - loss: 0.0122 - accuracy: 0.9949 - 22s/epoch - 330ms/step
# Epoch 6/100
# 68/68 - 22s - loss: 0.0156 - accuracy: 0.9949 - 22s/epoch - 326ms/step
# Epoch 7/100
# 68/68 - 22s - loss: 0.0437 - accuracy: 0.9954 - 22s/epoch - 325ms/step
# Epoch 8/100
# 68/68 - 22s - loss: 0.0269 - accuracy: 0.9935 - 22s/epoch - 325ms/step
# Epoch 9/100
# 68/68 - 22s - loss: 0.0440 - accuracy: 0.9889 - 22s/epoch - 328ms/step
# Epoch 10/100
# 68/68 - 22s - loss: 0.0474 - accuracy: 0.9880 - 22s/epoch - 327ms/step
# Epoch 11/100
# 68/68 - 22s - loss: 0.0340 - accuracy: 0.9926 - 22s/epoch - 329ms/step
# Epoch 12/100
# 68/68 - 22s - loss: 0.0228 - accuracy: 0.9921 - 22s/epoch - 329ms/step
# Epoch 13/100
# 68/68 - 22s - loss: 0.0080 - accuracy: 0.9963 - 22s/epoch - 331ms/step
# Epoch 14/100
# 68/68 - 22s - loss: 0.0202 - accuracy: 0.9954 - 22s/epoch - 328ms/step
# Epoch 15/100
# 68/68 - 22s - loss: 0.0082 - accuracy: 0.9977 - 22s/epoch - 328ms/step
# Epoch 16/100
# 68/68 - 22s - loss: 0.0093 - accuracy: 0.9981 - 22s/epoch - 327ms/step
# Epoch 17/100
# 68/68 - 22s - loss: 0.0109 - accuracy: 0.9949 - 22s/epoch - 327ms/step
# Epoch 18/100
# 68/68 - 22s - loss: 0.0034 - accuracy: 0.9991 - 22s/epoch - 328ms/step
# Epoch 19/100
# 68/68 - 22s - loss: 0.0024 - accuracy: 0.9995 - 22s/epoch - 325ms/step
# Epoch 20/100
# 68/68 - 22s - loss: 0.0038 - accuracy: 0.9981 - 22s/epoch - 327ms/step
# Epoch 21/100
# 68/68 - 22s - loss: 0.0060 - accuracy: 0.9981 - 22s/epoch - 327ms/step
# Epoch 22/100
# 68/68 - 22s - loss: 0.0022 - accuracy: 1.0000 - 22s/epoch - 329ms/step
# Epoch 23/100
# 68/68 - 22s - loss: 0.0018 - accuracy: 0.9995 - 22s/epoch - 327ms/step
# Epoch 24/100
# 68/68 - 22s - loss: 0.0042 - accuracy: 0.9986 - 22s/epoch - 328ms/step
# Epoch 25/100
# 68/68 - 22s - loss: 0.0037 - accuracy: 0.9986 - 22s/epoch - 328ms/step
# Epoch 26/100
# 68/68 - 22s - loss: 0.0049 - accuracy: 0.9981 - 22s/epoch - 327ms/step
# Epoch 27/100
# 68/68 - 22s - loss: 0.0177 - accuracy: 0.9972 - 22s/epoch - 330ms/step
# Epoch 28/100
# 68/68 - 22s - loss: 0.0030 - accuracy: 0.9991 - 22s/epoch - 330ms/step
# Epoch 29/100
# 68/68 - 22s - loss: 0.0046 - accuracy: 0.9986 - 22s/epoch - 329ms/step
# Epoch 30/100
# 68/68 - 22s - loss: 0.0089 - accuracy: 0.9981 - 22s/epoch - 330ms/step
# Epoch 31/100
# 68/68 - 22s - loss: 0.0058 - accuracy: 0.9981 - 22s/epoch - 328ms/step
# Epoch 32/100
# 68/68 - 22s - loss: 0.0082 - accuracy: 0.9968 - 22s/epoch - 329ms/step
# Epoch 33/100
# 68/68 - 22s - loss: 0.0229 - accuracy: 0.9954 - 22s/epoch - 329ms/step
# Epoch 34/100
# 68/68 - 22s - loss: 0.0383 - accuracy: 0.9921 - 22s/epoch - 330ms/step
# Epoch 35/100
# 68/68 - 22s - loss: 0.0406 - accuracy: 0.9949 - 22s/epoch - 328ms/step
# Epoch 36/100
# 68/68 - 22s - loss: 0.0238 - accuracy: 0.9958 - 22s/epoch - 328ms/step
# Epoch 37/100
# 68/68 - 22s - loss: 0.0084 - accuracy: 0.9963 - 22s/epoch - 328ms/step
# Epoch 38/100
# 68/68 - 22s - loss: 0.0110 - accuracy: 0.9963 - 22s/epoch - 329ms/step
# Epoch 39/100
# 68/68 - 22s - loss: 0.0084 - accuracy: 0.9968 - 22s/epoch - 328ms/step
# Epoch 40/100
# 68/68 - 22s - loss: 0.0061 - accuracy: 0.9981 - 22s/epoch - 328ms/step
# Epoch 41/100
# 68/68 - 23s - loss: 0.0019 - accuracy: 0.9995 - 23s/epoch - 331ms/step
# Epoch 42/100
# 68/68 - 22s - loss: 0.0033 - accuracy: 0.9995 - 22s/epoch - 328ms/step
# Epoch 43/100
# 68/68 - 22s - loss: 0.0097 - accuracy: 0.9963 - 22s/epoch - 328ms/step
# Epoch 44/100
# 68/68 - 22s - loss: 0.0052 - accuracy: 0.9972 - 22s/epoch - 327ms/step
# Epoch 45/100
# 68/68 - 22s - loss: 0.0058 - accuracy: 0.9977 - 22s/epoch - 329ms/step
# Epoch 46/100
# 68/68 - 22s - loss: 0.0054 - accuracy: 0.9981 - 22s/epoch - 327ms/step
# Epoch 47/100
# 68/68 - 22s - loss: 0.0030 - accuracy: 0.9986 - 22s/epoch - 326ms/step
# Epoch 48/100
# 68/68 - 22s - loss: 0.0029 - accuracy: 0.9991 - 22s/epoch - 329ms/step
# Epoch 49/100
# 68/68 - 22s - loss: 0.0097 - accuracy: 0.9986 - 22s/epoch - 330ms/step
# Epoch 50/100
# 68/68 - 22s - loss: 0.0203 - accuracy: 0.9949 - 22s/epoch - 327ms/step
# Epoch 51/100
# 68/68 - 22s - loss: 0.0159 - accuracy: 0.9968 - 22s/epoch - 324ms/step
# Epoch 52/100
# 68/68 - 22s - loss: 0.0053 - accuracy: 0.9981 - 22s/epoch - 329ms/step
# Epoch 53/100
# 68/68 - 22s - loss: 0.0024 - accuracy: 0.9995 - 22s/epoch - 329ms/step
# Epoch 54/100
# 68/68 - 22s - loss: 0.0024 - accuracy: 0.9995 - 22s/epoch - 329ms/step
# Epoch 55/100
# 68/68 - 22s - loss: 0.0130 - accuracy: 0.9972 - 22s/epoch - 331ms/step
# Epoch 56/100
# 68/68 - 23s - loss: 0.0019 - accuracy: 1.0000 - 23s/epoch - 332ms/step
# Epoch 57/100
# 68/68 - 22s - loss: 0.0043 - accuracy: 0.9981 - 22s/epoch - 331ms/step
# Epoch 58/100
# 68/68 - 22s - loss: 0.0036 - accuracy: 0.9991 - 22s/epoch - 328ms/step
# Epoch 59/100
# 68/68 - 22s - loss: 0.0016 - accuracy: 0.9995 - 22s/epoch - 327ms/step
# Epoch 60/100
# 68/68 - 23s - loss: 0.0015 - accuracy: 0.9995 - 23s/epoch - 333ms/step
# Epoch 61/100
# 68/68 - 22s - loss: 0.0146 - accuracy: 0.9986 - 22s/epoch - 329ms/step
# Epoch 62/100
# 68/68 - 22s - loss: 0.0152 - accuracy: 0.9949 - 22s/epoch - 324ms/step
# Epoch 63/100
# 68/68 - 22s - loss: 0.0129 - accuracy: 0.9968 - 22s/epoch - 327ms/step
# Epoch 64/100
# 68/68 - 22s - loss: 0.0548 - accuracy: 0.9931 - 22s/epoch - 328ms/step
# Epoch 65/100
# 68/68 - 22s - loss: 0.0613 - accuracy: 0.9917 - 22s/epoch - 331ms/step
# Epoch 66/100
# 68/68 - 22s - loss: 0.0074 - accuracy: 0.9972 - 22s/epoch - 326ms/step
# Epoch 67/100
# 68/68 - 22s - loss: 0.0040 - accuracy: 0.9991 - 22s/epoch - 327ms/step
# Epoch 68/100
# 68/68 - 22s - loss: 0.0026 - accuracy: 0.9991 - 22s/epoch - 326ms/step
# Epoch 69/100
# 68/68 - 22s - loss: 0.0106 - accuracy: 0.9968 - 22s/epoch - 330ms/step
# Epoch 70/100
# 68/68 - 22s - loss: 0.0050 - accuracy: 0.9981 - 22s/epoch - 327ms/step
# Epoch 71/100
# 68/68 - 22s - loss: 0.0012 - accuracy: 1.0000 - 22s/epoch - 329ms/step
# Epoch 72/100
# 68/68 - 22s - loss: 0.0033 - accuracy: 0.9981 - 22s/epoch - 329ms/step
# Epoch 73/100
# 68/68 - 22s - loss: 0.0017 - accuracy: 0.9995 - 22s/epoch - 326ms/step
# Epoch 74/100
# 68/68 - 22s - loss: 0.0020 - accuracy: 0.9995 - 22s/epoch - 325ms/step
# Epoch 75/100
# 68/68 - 22s - loss: 0.0057 - accuracy: 0.9981 - 22s/epoch - 327ms/step
# Epoch 76/100
# 68/68 - 22s - loss: 0.0029 - accuracy: 0.9991 - 22s/epoch - 326ms/step
# Epoch 77/100
# 68/68 - 22s - loss: 0.0033 - accuracy: 0.9986 - 22s/epoch - 325ms/step
# Epoch 78/100
# 68/68 - 22s - loss: 0.0089 - accuracy: 0.9977 - 22s/epoch - 327ms/step
# Epoch 79/100
# 68/68 - 22s - loss: 0.0014 - accuracy: 1.0000 - 22s/epoch - 329ms/step
# Epoch 80/100
# 68/68 - 22s - loss: 0.0016 - accuracy: 0.9995 - 22s/epoch - 328ms/step
# Epoch 81/100
# 68/68 - 23s - loss: 0.0033 - accuracy: 0.9995 - 23s/epoch - 335ms/step
# Epoch 82/100
# 68/68 - 23s - loss: 0.0017 - accuracy: 0.9991 - 23s/epoch - 332ms/step
# Epoch 83/100
# 68/68 - 23s - loss: 0.0060 - accuracy: 0.9981 - 23s/epoch - 333ms/step
# Epoch 84/100
# 68/68 - 23s - loss: 8.7788e-04 - accuracy: 1.0000 - 23s/epoch - 333ms/step
# Epoch 85/100
# 68/68 - 22s - loss: 3.8665e-04 - accuracy: 1.0000 - 22s/epoch - 328ms/step
# Epoch 86/100
# 68/68 - 22s - loss: 0.0011 - accuracy: 1.0000 - 22s/epoch - 327ms/step
# Epoch 87/100
# 68/68 - 22s - loss: 2.4988e-04 - accuracy: 1.0000 - 22s/epoch - 328ms/step
# Epoch 88/100
# 68/68 - 22s - loss: 0.0067 - accuracy: 0.9995 - 22s/epoch - 329ms/step
# Epoch 89/100
# 68/68 - 22s - loss: 0.0155 - accuracy: 0.9972 - 22s/epoch - 326ms/step
# Epoch 90/100
# 68/68 - 22s - loss: 0.1213 - accuracy: 0.9940 - 22s/epoch - 328ms/step
# Epoch 91/100
# 68/68 - 22s - loss: 0.0395 - accuracy: 0.9898 - 22s/epoch - 327ms/step
# Epoch 92/100
# 68/68 - 22s - loss: 0.0236 - accuracy: 0.9944 - 22s/epoch - 329ms/step
# Epoch 93/100
# 68/68 - 22s - loss: 0.0046 - accuracy: 0.9991 - 22s/epoch - 326ms/step
# Epoch 94/100
# 68/68 - 22s - loss: 0.0068 - accuracy: 0.9981 - 22s/epoch - 327ms/step
# Epoch 95/100
# 68/68 - 22s - loss: 0.0158 - accuracy: 0.9963 - 22s/epoch - 325ms/step
# Epoch 96/100
# 68/68 - 22s - loss: 0.0074 - accuracy: 0.9986 - 22s/epoch - 329ms/step
# Epoch 97/100
# 68/68 - 22s - loss: 0.0034 - accuracy: 0.9991 - 22s/epoch - 328ms/step
# Epoch 98/100
# 68/68 - 22s - loss: 0.0052 - accuracy: 0.9986 - 22s/epoch - 326ms/step
# Epoch 99/100
# 68/68 - 22s - loss: 0.0030 - accuracy: 0.9991 - 22s/epoch - 327ms/step
# Epoch 100/100
# 68/68 - 22s - loss: 0.0030 - accuracy: 0.9991 - 22s/epoch - 327ms/step
# 0.0537
# ***Performance on Test Data***
# Accuracy  : 0.9944444444444445
# Precision : 0.9944545613547744
# f1Score : 0.9944444015771725
# [[180   0   0]
#  [  0 179   1]
#  [  0   2 178]]
# 17/17 [==============================] - 5s 335ms/step - loss: 0.0132 - accuracy: 0.9944
# trn_indx: 2160 test_indx: 540
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# Results for fold 4
# 2160
# 540
# Found 2160 images belonging to 3 classes.
# Found 540 images belonging to 3 classes.
# Epoch 1/100
# 68/68 - 22s - loss: 0.0114 - accuracy: 0.9968 - 22s/epoch - 329ms/step
# Epoch 2/100
# 68/68 - 22s - loss: 0.0066 - accuracy: 0.9972 - 22s/epoch - 330ms/step
# Epoch 3/100
# 68/68 - 23s - loss: 0.0187 - accuracy: 0.9981 - 23s/epoch - 332ms/step
# Epoch 4/100
# 68/68 - 23s - loss: 0.0255 - accuracy: 0.9935 - 23s/epoch - 332ms/step
# Epoch 5/100
# 68/68 - 23s - loss: 0.0061 - accuracy: 0.9972 - 23s/epoch - 331ms/step
# Epoch 6/100
# 68/68 - 22s - loss: 0.0094 - accuracy: 0.9972 - 22s/epoch - 330ms/step
# Epoch 7/100
# 68/68 - 22s - loss: 0.0016 - accuracy: 0.9995 - 22s/epoch - 329ms/step
# Epoch 8/100
# 68/68 - 23s - loss: 7.0995e-04 - accuracy: 1.0000 - 23s/epoch - 331ms/step
# Epoch 9/100
# 68/68 - 23s - loss: 0.0101 - accuracy: 0.9972 - 23s/epoch - 336ms/step
# Epoch 10/100
# 68/68 - 23s - loss: 0.0068 - accuracy: 0.9977 - 23s/epoch - 331ms/step
# Epoch 11/100
# 68/68 - 23s - loss: 0.0192 - accuracy: 0.9968 - 23s/epoch - 333ms/step
# Epoch 12/100
# 68/68 - 22s - loss: 0.0469 - accuracy: 0.9931 - 22s/epoch - 331ms/step
# Epoch 13/100
# 68/68 - 23s - loss: 0.0095 - accuracy: 0.9981 - 23s/epoch - 333ms/step
# Epoch 14/100
# 68/68 - 22s - loss: 0.0061 - accuracy: 0.9977 - 22s/epoch - 330ms/step
# Epoch 15/100
# 68/68 - 22s - loss: 0.0017 - accuracy: 1.0000 - 22s/epoch - 331ms/step
# Epoch 16/100
# 68/68 - 23s - loss: 0.0097 - accuracy: 0.9963 - 23s/epoch - 332ms/step
# Epoch 17/100
# 68/68 - 23s - loss: 0.0023 - accuracy: 0.9995 - 23s/epoch - 334ms/step
# Epoch 18/100
# 68/68 - 23s - loss: 0.0044 - accuracy: 0.9986 - 23s/epoch - 334ms/step
# Epoch 19/100
# 68/68 - 23s - loss: 0.0032 - accuracy: 0.9986 - 23s/epoch - 334ms/step
# Epoch 20/100
# 68/68 - 22s - loss: 0.0126 - accuracy: 0.9986 - 22s/epoch - 330ms/step
# Epoch 21/100
# 68/68 - 23s - loss: 0.0469 - accuracy: 0.9931 - 23s/epoch - 336ms/step
# Epoch 22/100
# 68/68 - 23s - loss: 0.0307 - accuracy: 0.9907 - 23s/epoch - 334ms/step
# Epoch 23/100
# 68/68 - 23s - loss: 0.0337 - accuracy: 0.9949 - 23s/epoch - 335ms/step
# Epoch 24/100
# 68/68 - 23s - loss: 0.0169 - accuracy: 0.9949 - 23s/epoch - 337ms/step
# Epoch 25/100
# 68/68 - 23s - loss: 0.0050 - accuracy: 0.9986 - 23s/epoch - 333ms/step
# Epoch 26/100
# 68/68 - 22s - loss: 0.0077 - accuracy: 0.9986 - 22s/epoch - 328ms/step
# Epoch 27/100
# 68/68 - 23s - loss: 0.0030 - accuracy: 0.9991 - 23s/epoch - 332ms/step
# Epoch 28/100
# 68/68 - 23s - loss: 0.0060 - accuracy: 0.9986 - 23s/epoch - 335ms/step
# Epoch 29/100
# 68/68 - 23s - loss: 0.0280 - accuracy: 0.9968 - 23s/epoch - 332ms/step
# Epoch 30/100
# 68/68 - 23s - loss: 0.0227 - accuracy: 0.9949 - 23s/epoch - 332ms/step
# Epoch 31/100
# 68/68 - 23s - loss: 0.0048 - accuracy: 0.9981 - 23s/epoch - 333ms/step
# Epoch 32/100
# 68/68 - 22s - loss: 0.0028 - accuracy: 0.9995 - 22s/epoch - 329ms/step
# Epoch 33/100
# 68/68 - 23s - loss: 0.0024 - accuracy: 0.9991 - 23s/epoch - 334ms/step
# Epoch 34/100
# 68/68 - 23s - loss: 0.0022 - accuracy: 0.9995 - 23s/epoch - 336ms/step
# Epoch 35/100
# 68/68 - 23s - loss: 0.0054 - accuracy: 0.9991 - 23s/epoch - 337ms/step
# Epoch 36/100
# 68/68 - 23s - loss: 0.0037 - accuracy: 0.9986 - 23s/epoch - 337ms/step
# Epoch 37/100
# 68/68 - 23s - loss: 0.0040 - accuracy: 0.9991 - 23s/epoch - 338ms/step
# Epoch 38/100
# 68/68 - 23s - loss: 0.0026 - accuracy: 0.9991 - 23s/epoch - 337ms/step
# Epoch 39/100
# 68/68 - 23s - loss: 0.0032 - accuracy: 0.9991 - 23s/epoch - 334ms/step
# Epoch 40/100
# 68/68 - 23s - loss: 0.0012 - accuracy: 1.0000 - 23s/epoch - 337ms/step
# Epoch 41/100
# 68/68 - 23s - loss: 0.0020 - accuracy: 0.9991 - 23s/epoch - 337ms/step
# Epoch 42/100
# 68/68 - 23s - loss: 0.0104 - accuracy: 0.9991 - 23s/epoch - 340ms/step
# Epoch 43/100
# 68/68 - 23s - loss: 0.0128 - accuracy: 0.9986 - 23s/epoch - 340ms/step
# Epoch 44/100
# 68/68 - 23s - loss: 0.0023 - accuracy: 0.9995 - 23s/epoch - 342ms/step
# Epoch 45/100
# 68/68 - 23s - loss: 0.0034 - accuracy: 0.9986 - 23s/epoch - 339ms/step
# Epoch 46/100
# 68/68 - 23s - loss: 0.0034 - accuracy: 0.9986 - 23s/epoch - 336ms/step
# Epoch 47/100
# 68/68 - 23s - loss: 0.0016 - accuracy: 0.9995 - 23s/epoch - 335ms/step
# Epoch 48/100
# 68/68 - 23s - loss: 0.0074 - accuracy: 0.9981 - 23s/epoch - 337ms/step
# Epoch 49/100
# 68/68 - 23s - loss: 0.0570 - accuracy: 0.9958 - 23s/epoch - 338ms/step
# Epoch 50/100
# 68/68 - 23s - loss: 0.0110 - accuracy: 0.9972 - 23s/epoch - 342ms/step
# Epoch 51/100
# 68/68 - 23s - loss: 0.0146 - accuracy: 0.9958 - 23s/epoch - 337ms/step
# Epoch 52/100
# 68/68 - 23s - loss: 0.0165 - accuracy: 0.9972 - 23s/epoch - 336ms/step
# Epoch 53/100
# 68/68 - 22s - loss: 0.0159 - accuracy: 0.9977 - 22s/epoch - 331ms/step
# Epoch 54/100
# 68/68 - 22s - loss: 0.0049 - accuracy: 0.9981 - 22s/epoch - 330ms/step
# Epoch 55/100
# 68/68 - 22s - loss: 0.0033 - accuracy: 0.9986 - 22s/epoch - 331ms/step
# Epoch 56/100
# 68/68 - 23s - loss: 0.0059 - accuracy: 0.9972 - 23s/epoch - 333ms/step
# Epoch 57/100
# 68/68 - 23s - loss: 0.0013 - accuracy: 1.0000 - 23s/epoch - 335ms/step
# Epoch 58/100
# 68/68 - 23s - loss: 0.0017 - accuracy: 0.9991 - 23s/epoch - 333ms/step
# Epoch 59/100
# 68/68 - 23s - loss: 0.0029 - accuracy: 0.9991 - 23s/epoch - 333ms/step
# Epoch 60/100
# 68/68 - 23s - loss: 0.0026 - accuracy: 0.9991 - 23s/epoch - 335ms/step
# Epoch 61/100
# 68/68 - 23s - loss: 8.8917e-04 - accuracy: 1.0000 - 23s/epoch - 341ms/step
# Epoch 62/100
# 68/68 - 23s - loss: 0.0015 - accuracy: 0.9995 - 23s/epoch - 343ms/step
# Epoch 63/100
# 68/68 - 23s - loss: 0.0011 - accuracy: 0.9995 - 23s/epoch - 340ms/step
# Epoch 64/100
# 68/68 - 23s - loss: 0.0013 - accuracy: 0.9995 - 23s/epoch - 343ms/step
# Epoch 65/100
# 68/68 - 23s - loss: 0.0043 - accuracy: 0.9986 - 23s/epoch - 336ms/step
# Epoch 66/100
# 68/68 - 23s - loss: 0.0026 - accuracy: 0.9986 - 23s/epoch - 341ms/step
# Epoch 67/100
# 68/68 - 24s - loss: 5.1998e-04 - accuracy: 1.0000 - 24s/epoch - 346ms/step
# Epoch 68/100
# 68/68 - 24s - loss: 0.0015 - accuracy: 0.9995 - 24s/epoch - 347ms/step
# Epoch 69/100
# 68/68 - 24s - loss: 0.0011 - accuracy: 0.9995 - 24s/epoch - 348ms/step
# Epoch 70/100
# 68/68 - 24s - loss: 0.0112 - accuracy: 0.9977 - 24s/epoch - 351ms/step
# Epoch 71/100
# 68/68 - 24s - loss: 0.0015 - accuracy: 1.0000 - 24s/epoch - 346ms/step
# Epoch 72/100
# 68/68 - 24s - loss: 0.0042 - accuracy: 0.9995 - 24s/epoch - 347ms/step
# Epoch 73/100
# 68/68 - 24s - loss: 0.0045 - accuracy: 0.9986 - 24s/epoch - 346ms/step
# Epoch 74/100
# 68/68 - 23s - loss: 9.6810e-04 - accuracy: 1.0000 - 23s/epoch - 344ms/step
# Epoch 75/100
# 68/68 - 23s - loss: 0.0011 - accuracy: 0.9995 - 23s/epoch - 344ms/step
# Epoch 76/100
# 68/68 - 24s - loss: 0.0019 - accuracy: 0.9986 - 24s/epoch - 348ms/step
# Epoch 77/100
# 68/68 - 24s - loss: 0.0014 - accuracy: 0.9995 - 24s/epoch - 347ms/step
# Epoch 78/100
# 68/68 - 24s - loss: 0.0031 - accuracy: 0.9986 - 24s/epoch - 347ms/step
# Epoch 79/100
# 68/68 - 23s - loss: 0.0012 - accuracy: 0.9995 - 23s/epoch - 345ms/step
# Epoch 80/100
# 68/68 - 23s - loss: 5.4337e-04 - accuracy: 1.0000 - 23s/epoch - 344ms/step
# Epoch 81/100
# 68/68 - 23s - loss: 0.0069 - accuracy: 0.9991 - 23s/epoch - 344ms/step
# Epoch 82/100
# 68/68 - 23s - loss: 2.8716e-04 - accuracy: 1.0000 - 23s/epoch - 343ms/step
# Epoch 83/100
# 68/68 - 23s - loss: 5.9934e-04 - accuracy: 1.0000 - 23s/epoch - 340ms/step
# Epoch 84/100
# 68/68 - 23s - loss: 0.0031 - accuracy: 0.9986 - 23s/epoch - 340ms/step
# Epoch 85/100
# 68/68 - 23s - loss: 0.0012 - accuracy: 0.9995 - 23s/epoch - 335ms/step
# Epoch 86/100
# 68/68 - 23s - loss: 3.3754e-04 - accuracy: 1.0000 - 23s/epoch - 335ms/step
# Epoch 87/100
# 68/68 - 23s - loss: 3.7763e-04 - accuracy: 1.0000 - 23s/epoch - 336ms/step
# Epoch 88/100
# 68/68 - 23s - loss: 6.5309e-04 - accuracy: 1.0000 - 23s/epoch - 338ms/step
# Epoch 89/100
# 68/68 - 23s - loss: 8.4032e-04 - accuracy: 1.0000 - 23s/epoch - 332ms/step
# Epoch 90/100
# 68/68 - 23s - loss: 0.0072 - accuracy: 0.9977 - 23s/epoch - 338ms/step
# Epoch 91/100
# 68/68 - 23s - loss: 0.0199 - accuracy: 0.9935 - 23s/epoch - 340ms/step
# Epoch 92/100
# 68/68 - 23s - loss: 0.0152 - accuracy: 0.9977 - 23s/epoch - 332ms/step
# Epoch 93/100
# 68/68 - 23s - loss: 0.0030 - accuracy: 0.9986 - 23s/epoch - 334ms/step
# Epoch 94/100
# 68/68 - 23s - loss: 0.0018 - accuracy: 0.9991 - 23s/epoch - 334ms/step
# Epoch 95/100
# 68/68 - 23s - loss: 9.2603e-04 - accuracy: 0.9995 - 23s/epoch - 335ms/step
# Epoch 96/100
# 68/68 - 23s - loss: 0.0162 - accuracy: 0.9981 - 23s/epoch - 340ms/step
# Epoch 97/100
# 68/68 - 23s - loss: 0.0073 - accuracy: 0.9986 - 23s/epoch - 337ms/step
# Epoch 98/100
# 68/68 - 23s - loss: 0.0244 - accuracy: 0.9940 - 23s/epoch - 338ms/step
# Epoch 99/100
# 68/68 - 23s - loss: 0.0299 - accuracy: 0.9935 - 23s/epoch - 335ms/step
# Epoch 100/100
# 68/68 - 23s - loss: 0.0381 - accuracy: 0.9963 - 23s/epoch - 332ms/step
# 0.0461
# ***Performance on Test Data***
# Accuracy  : 0.8537037037037037
# Precision : 0.8983268983268984
# f1Score : 0.8495803349491079
# [[174   0   6]
#  [  0 107  73]
#  [  0   0 180]]
# 17/17 [==============================] - 5s 326ms/step - loss: 0.4990 - accuracy: 0.8537
# trn_indx: 2160 test_indx: 540
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# Results for fold 5
# 2160
# 540
# Found 2160 images belonging to 3 classes.
# Found 540 images belonging to 3 classes.
# Epoch 1/100
# 68/68 - 22s - loss: 0.0106 - accuracy: 0.9968 - 22s/epoch - 331ms/step
# Epoch 2/100
# 68/68 - 22s - loss: 0.0492 - accuracy: 0.9912 - 22s/epoch - 330ms/step
# Epoch 3/100
# 68/68 - 22s - loss: 0.0242 - accuracy: 0.9944 - 22s/epoch - 330ms/step
# Epoch 4/100
# 68/68 - 22s - loss: 0.0060 - accuracy: 0.9981 - 22s/epoch - 331ms/step
# Epoch 5/100
# 68/68 - 22s - loss: 0.0064 - accuracy: 0.9991 - 22s/epoch - 329ms/step
# Epoch 6/100
# 68/68 - 23s - loss: 0.0037 - accuracy: 0.9986 - 23s/epoch - 331ms/step
# Epoch 7/100
# 68/68 - 23s - loss: 0.0024 - accuracy: 0.9991 - 23s/epoch - 331ms/step
# Epoch 8/100
# 68/68 - 23s - loss: 0.0174 - accuracy: 0.9968 - 23s/epoch - 337ms/step
# Epoch 9/100
# 68/68 - 23s - loss: 0.0218 - accuracy: 0.9912 - 23s/epoch - 333ms/step
# Epoch 10/100
# 68/68 - 23s - loss: 0.0128 - accuracy: 0.9972 - 23s/epoch - 333ms/step
# Epoch 11/100
# 68/68 - 23s - loss: 0.0257 - accuracy: 0.9963 - 23s/epoch - 335ms/step
# Epoch 12/100
# 68/68 - 22s - loss: 0.0045 - accuracy: 0.9981 - 22s/epoch - 328ms/step
# Epoch 13/100
# 68/68 - 23s - loss: 8.3343e-04 - accuracy: 1.0000 - 23s/epoch - 334ms/step
# Epoch 14/100
# 68/68 - 22s - loss: 0.0049 - accuracy: 0.9991 - 22s/epoch - 330ms/step
# Epoch 15/100
# 68/68 - 23s - loss: 5.9078e-04 - accuracy: 1.0000 - 23s/epoch - 333ms/step
# Epoch 16/100
# 68/68 - 23s - loss: 0.0037 - accuracy: 0.9995 - 23s/epoch - 331ms/step
# Epoch 17/100
# 68/68 - 23s - loss: 0.0214 - accuracy: 0.9944 - 23s/epoch - 336ms/step
# Epoch 18/100
# 68/68 - 23s - loss: 0.0070 - accuracy: 0.9968 - 23s/epoch - 332ms/step
# Epoch 19/100
# 68/68 - 23s - loss: 0.0228 - accuracy: 0.9968 - 23s/epoch - 331ms/step
# Epoch 20/100
# 68/68 - 23s - loss: 0.0204 - accuracy: 0.9949 - 23s/epoch - 331ms/step
# Epoch 21/100
# 68/68 - 23s - loss: 0.0297 - accuracy: 0.9963 - 23s/epoch - 334ms/step
# Epoch 22/100
# 68/68 - 23s - loss: 0.0021 - accuracy: 0.9995 - 23s/epoch - 334ms/step
# Epoch 23/100
# 68/68 - 23s - loss: 6.3072e-04 - accuracy: 1.0000 - 23s/epoch - 341ms/step
# Epoch 24/100
# 68/68 - 23s - loss: 0.0028 - accuracy: 0.9995 - 23s/epoch - 332ms/step
# Epoch 25/100
# 68/68 - 22s - loss: 4.0059e-04 - accuracy: 1.0000 - 22s/epoch - 328ms/step
# Epoch 26/100
# 68/68 - 22s - loss: 0.0597 - accuracy: 0.9954 - 22s/epoch - 330ms/step
# Epoch 27/100
# 68/68 - 22s - loss: 0.0172 - accuracy: 0.9954 - 22s/epoch - 327ms/step
# Epoch 28/100
# 68/68 - 22s - loss: 0.0154 - accuracy: 0.9954 - 22s/epoch - 329ms/step
# Epoch 29/100
# 68/68 - 22s - loss: 0.0081 - accuracy: 0.9981 - 22s/epoch - 327ms/step
# Epoch 30/100
# 68/68 - 22s - loss: 0.0033 - accuracy: 0.9981 - 22s/epoch - 330ms/step
# Epoch 31/100
# 68/68 - 23s - loss: 0.0091 - accuracy: 0.9972 - 23s/epoch - 332ms/step
# Epoch 32/100
# 68/68 - 22s - loss: 0.0128 - accuracy: 0.9977 - 22s/epoch - 330ms/step
# Epoch 33/100
# 68/68 - 22s - loss: 0.0047 - accuracy: 0.9981 - 22s/epoch - 330ms/step
# Epoch 34/100
# 68/68 - 22s - loss: 0.0014 - accuracy: 0.9995 - 22s/epoch - 330ms/step
# Epoch 35/100
# 68/68 - 22s - loss: 0.0028 - accuracy: 0.9991 - 22s/epoch - 330ms/step
# Epoch 36/100
# 68/68 - 23s - loss: 0.0035 - accuracy: 0.9991 - 23s/epoch - 331ms/step
# Epoch 37/100
# 68/68 - 23s - loss: 0.0036 - accuracy: 0.9995 - 23s/epoch - 332ms/step
# Epoch 38/100
# 68/68 - 22s - loss: 8.2990e-04 - accuracy: 0.9995 - 22s/epoch - 330ms/step
# Epoch 39/100
# 68/68 - 22s - loss: 0.0013 - accuracy: 1.0000 - 22s/epoch - 330ms/step
# Epoch 40/100
# 68/68 - 22s - loss: 0.0014 - accuracy: 0.9995 - 22s/epoch - 331ms/step
# Epoch 41/100
# 68/68 - 22s - loss: 0.0014 - accuracy: 0.9995 - 22s/epoch - 330ms/step
# Epoch 42/100
# 68/68 - 22s - loss: 7.4142e-04 - accuracy: 1.0000 - 22s/epoch - 330ms/step
# Epoch 43/100
# 68/68 - 23s - loss: 0.0049 - accuracy: 0.9981 - 23s/epoch - 331ms/step
# Epoch 44/100
# 68/68 - 22s - loss: 0.0225 - accuracy: 0.9972 - 22s/epoch - 330ms/step
# Epoch 45/100
# 68/68 - 23s - loss: 0.0597 - accuracy: 0.9949 - 23s/epoch - 331ms/step
# Epoch 46/100
# 68/68 - 22s - loss: 0.0049 - accuracy: 0.9981 - 22s/epoch - 329ms/step
# Epoch 47/100
# 68/68 - 23s - loss: 7.6685e-04 - accuracy: 1.0000 - 23s/epoch - 333ms/step
# Epoch 48/100
# 68/68 - 22s - loss: 0.0016 - accuracy: 0.9995 - 22s/epoch - 329ms/step
# Epoch 49/100
# 68/68 - 22s - loss: 0.0011 - accuracy: 1.0000 - 22s/epoch - 330ms/step
# Epoch 50/100
# 68/68 - 22s - loss: 0.0064 - accuracy: 0.9991 - 22s/epoch - 330ms/step
# Epoch 51/100
# 68/68 - 22s - loss: 0.0014 - accuracy: 0.9995 - 22s/epoch - 330ms/step
# Epoch 52/100
# 68/68 - 23s - loss: 0.0330 - accuracy: 0.9981 - 23s/epoch - 332ms/step
# Epoch 53/100
# 68/68 - 22s - loss: 0.0050 - accuracy: 0.9981 - 22s/epoch - 331ms/step
# Epoch 54/100
# 68/68 - 22s - loss: 0.0033 - accuracy: 0.9991 - 22s/epoch - 326ms/step
# Epoch 55/100
# 68/68 - 23s - loss: 7.9043e-04 - accuracy: 1.0000 - 23s/epoch - 332ms/step
# Epoch 56/100
# 68/68 - 22s - loss: 0.0138 - accuracy: 0.9991 - 22s/epoch - 327ms/step
# Epoch 57/100
# 68/68 - 23s - loss: 0.0028 - accuracy: 0.9986 - 23s/epoch - 331ms/step
# Epoch 58/100
# 68/68 - 23s - loss: 0.0019 - accuracy: 0.9995 - 23s/epoch - 332ms/step
# Epoch 59/100
# 68/68 - 23s - loss: 9.6841e-04 - accuracy: 0.9995 - 23s/epoch - 333ms/step
# Epoch 60/100
# 68/68 - 22s - loss: 2.8142e-04 - accuracy: 1.0000 - 22s/epoch - 330ms/step
# Epoch 61/100
# 68/68 - 22s - loss: 0.0024 - accuracy: 0.9991 - 22s/epoch - 329ms/step
# Epoch 62/100
# 68/68 - 23s - loss: 9.5176e-04 - accuracy: 1.0000 - 23s/epoch - 333ms/step
# Epoch 63/100
# 68/68 - 23s - loss: 0.0017 - accuracy: 0.9995 - 23s/epoch - 333ms/step
# Epoch 64/100
# 68/68 - 23s - loss: 8.2225e-04 - accuracy: 1.0000 - 23s/epoch - 332ms/step
# Epoch 65/100
# 68/68 - 22s - loss: 0.0015 - accuracy: 0.9995 - 22s/epoch - 331ms/step
# Epoch 66/100
# 68/68 - 23s - loss: 0.0017 - accuracy: 0.9995 - 23s/epoch - 335ms/step
# Epoch 67/100
# 68/68 - 22s - loss: 0.0059 - accuracy: 0.9981 - 22s/epoch - 328ms/step
# Epoch 68/100
# 68/68 - 22s - loss: 0.0011 - accuracy: 0.9995 - 22s/epoch - 330ms/step
# Epoch 69/100
# 68/68 - 22s - loss: 2.7017e-04 - accuracy: 1.0000 - 22s/epoch - 330ms/step
# Epoch 70/100
# 68/68 - 22s - loss: 1.5928e-04 - accuracy: 1.0000 - 22s/epoch - 329ms/step
# Epoch 71/100
# 68/68 - 22s - loss: 5.1538e-04 - accuracy: 1.0000 - 22s/epoch - 329ms/step
# Epoch 72/100
# 68/68 - 23s - loss: 0.0020 - accuracy: 0.9991 - 23s/epoch - 334ms/step
# Epoch 73/100
# 68/68 - 23s - loss: 8.6782e-04 - accuracy: 0.9995 - 23s/epoch - 334ms/step
# Epoch 74/100
# 68/68 - 22s - loss: 2.7755e-04 - accuracy: 1.0000 - 22s/epoch - 329ms/step
# Epoch 75/100
# 68/68 - 23s - loss: 0.0011 - accuracy: 0.9995 - 23s/epoch - 336ms/step
# Epoch 76/100
# 68/68 - 23s - loss: 1.3734e-04 - accuracy: 1.0000 - 23s/epoch - 336ms/step
# Epoch 77/100
# 68/68 - 22s - loss: 2.6237e-04 - accuracy: 1.0000 - 22s/epoch - 329ms/step
# Epoch 78/100
# 68/68 - 22s - loss: 0.0049 - accuracy: 0.9991 - 22s/epoch - 328ms/step
# Epoch 79/100
# 68/68 - 22s - loss: 2.7702e-04 - accuracy: 1.0000 - 22s/epoch - 330ms/step
# Epoch 80/100
# 68/68 - 23s - loss: 4.9737e-04 - accuracy: 1.0000 - 23s/epoch - 332ms/step
# Epoch 81/100
# 68/68 - 22s - loss: 0.0015 - accuracy: 0.9995 - 22s/epoch - 326ms/step
# Epoch 82/100
# 68/68 - 23s - loss: 0.0030 - accuracy: 0.9991 - 23s/epoch - 331ms/step
# Epoch 83/100
# 68/68 - 22s - loss: 0.0122 - accuracy: 0.9981 - 22s/epoch - 330ms/step
# Epoch 84/100
# 68/68 - 23s - loss: 0.0146 - accuracy: 0.9977 - 23s/epoch - 333ms/step
# Epoch 85/100
# 68/68 - 22s - loss: 0.0063 - accuracy: 0.9981 - 22s/epoch - 327ms/step
# Epoch 86/100
# 68/68 - 22s - loss: 0.0020 - accuracy: 0.9995 - 22s/epoch - 331ms/step
# Epoch 87/100
# 68/68 - 23s - loss: 8.4276e-04 - accuracy: 1.0000 - 23s/epoch - 332ms/step
# Epoch 88/100
# 68/68 - 22s - loss: 0.0108 - accuracy: 0.9972 - 22s/epoch - 328ms/step
# Epoch 89/100
# 68/68 - 23s - loss: 0.0161 - accuracy: 0.9977 - 23s/epoch - 334ms/step
# Epoch 90/100
# 68/68 - 22s - loss: 0.0489 - accuracy: 0.9963 - 22s/epoch - 331ms/step
# Epoch 91/100
# 68/68 - 23s - loss: 0.0210 - accuracy: 0.9940 - 23s/epoch - 332ms/step
# Epoch 92/100
# 68/68 - 22s - loss: 0.0278 - accuracy: 0.9963 - 22s/epoch - 329ms/step
# Epoch 93/100
# 68/68 - 23s - loss: 0.0075 - accuracy: 0.9977 - 23s/epoch - 333ms/step
# Epoch 94/100
# 68/68 - 23s - loss: 0.0041 - accuracy: 0.9977 - 23s/epoch - 336ms/step
# Epoch 95/100
# 68/68 - 23s - loss: 0.0012 - accuracy: 0.9995 - 23s/epoch - 333ms/step
# Epoch 96/100
# 68/68 - 22s - loss: 0.0103 - accuracy: 0.9986 - 22s/epoch - 329ms/step
# Epoch 97/100
# 68/68 - 22s - loss: 0.0023 - accuracy: 0.9991 - 22s/epoch - 331ms/step
# Epoch 98/100
# 68/68 - 23s - loss: 0.0058 - accuracy: 0.9991 - 23s/epoch - 336ms/step
# Epoch 99/100
# 68/68 - 22s - loss: 0.0169 - accuracy: 0.9981 - 22s/epoch - 330ms/step
# Epoch 100/100
# 68/68 - 23s - loss: 0.0579 - accuracy: 0.9958 - 23s/epoch - 337ms/step
# 0.0503
# ***Performance on Test Data***
# Accuracy  : 0.9314814814814815
# Precision : 0.9403330731199584
# f1Score : 0.9310002572721504
# [[179   0   1]
#  [  1 147  32]
#  [  3   0 177]]
# 17/17 [==============================] - 6s 336ms/step - loss: 0.3247 - accuracy: 0.9315
# Overall Accuracy:  0.9437037037037037
