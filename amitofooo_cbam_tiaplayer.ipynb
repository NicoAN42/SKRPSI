# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoAN42/SKRPSI/blob/main/amitofooo_cbam_tiaplayer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mount dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow.keras.layers import Conv2D, Input, concatenate, Activation, InputLayer, Dense, Reshape, Flatten, Add, multiply, Permute, Lambda, Concatenate
from tensorflow.keras.layers import LeakyReLU,ReLU, MaxPooling2D, BatchNormalization,GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import layers
from tensorflow.keras.activations import softmax,sigmoid
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout,SpatialDropout2D,GaussianDropout
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.regularizers import l1,l2
from tensorflow.keras import backend as K
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow
import tensorflow as tf
import math
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold
import os
import random
import shutil

# %%
from tensorflow.keras.optimizers import SGD

# %%
CLASS = 3
#sourcepath isi semua data train, folder valid kosongin datanya sisai folder classnya
sourcePath = '/content/drive/MyDrive/Colab Notebooks/Dataset'
train_path = '/content/drive/MyDrive/Colab Notebooks/Dataset/train'
valid_path = '/content/drive/MyDrive/Colab Notebooks/Dataset/valid'
test_path = '/content/drive/MyDrive/Colab Notebooks/Dataset/test'

#nico

# %%
classLabels =['covid','normal', 'pneumonia']

# %%
def attach_attention_module(net, attention_module):
  #if attention_module == 'se_block': # SE_block
    #net = se_block(net)
  if attention_module == 'cbam_block': # CBAM_block
    net = cbam_block(net)
  else:
    raise Exception("'{}' is not supported attention module!".format(attention_module))

  return net

# %%
def cbam_block(cbam_feature, ratio=8):
	"""Contains the implementation of Convolutional Block Attention Module(CBAM) block.
	As described in https://arxiv.org/abs/1807.06521.
	"""
	
	cbam_feature = channel_attention(cbam_feature, ratio)
	cbam_feature = spatial_attention(cbam_feature)
	return cbam_feature

# %%
def channel_attention(input_feature, ratio=8):
	
	channel_axis = 1 if K.image_data_format() == "channels_first" else -1
	channel = input_feature.shape[channel_axis]
	
	shared_layer_one = Dense(channel//ratio,
							 activation='relu',
							 kernel_initializer='he_normal',
							 use_bias=True,
							 bias_initializer='zeros')
	shared_layer_two = Dense(channel,
							 kernel_initializer='he_normal',
							 use_bias=True,
							 bias_initializer='zeros')
	
	avg_pool = GlobalAveragePooling2D()(input_feature)    
	avg_pool = Reshape((1,1,channel))(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel)
	avg_pool = shared_layer_one(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel//ratio)
	avg_pool = shared_layer_two(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel)
	
	max_pool = GlobalMaxPooling2D()(input_feature)
	max_pool = Reshape((1,1,channel))(max_pool)
	assert max_pool.shape[1:] == (1,1,channel)
	max_pool = shared_layer_one(max_pool)
	assert max_pool.shape[1:] == (1,1,channel//ratio)
	max_pool = shared_layer_two(max_pool)
	assert max_pool.shape[1:] == (1,1,channel)
	
	cbam_feature = Add()([avg_pool,max_pool])
	cbam_feature = Activation('sigmoid')(cbam_feature)
	
	if K.image_data_format() == "channels_first":
		cbam_feature = Permute((3, 1, 2))(cbam_feature)
	
	return multiply([input_feature, cbam_feature])

# %%
def spatial_attention(input_feature):
	kernel_size = 7
	
	if K.image_data_format() == "channels_first":
		channel = input_feature.shape[1]
		cbam_feature = Permute((2,3,1))(input_feature)
	else:
		channel = input_feature.shape[-1]
		cbam_feature = input_feature
	
	avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
	assert avg_pool.shape[-1] == 1
	max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
	assert max_pool.shape[-1] == 1
	concat = Concatenate(axis=3)([avg_pool, max_pool])
	assert concat.shape[-1] == 2
	cbam_feature = Conv2D(filters = 1,
					kernel_size=kernel_size,
					strides=1,
					padding='same',
					activation='sigmoid',
					kernel_initializer='he_normal',
					use_bias=False)(concat)	
	assert cbam_feature.shape[-1] == 1
	
	if K.image_data_format() == "channels_first":
		cbam_feature = Permute((3, 1, 2))(cbam_feature)
		
	return multiply([input_feature, cbam_feature])

# %%
input = Input(shape=(256,256,3))

# %%
#Layer 1
model = layers.Conv2D(32, (3,3), padding='same', name='conv_1', activation = 'relu')(input)
model = layers.BatchNormalization(name='norm_1')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides= 2)(model)
attention_module = 'cbam_block'
y = attach_attention_module(model, attention_module)
model =  tensorflow.keras.layers.add([model, y])

# %%
#Layer 2
model = layers.Conv2D(64, (3,3), padding='same', name='conv_2', activation = 'relu')(model)
model = layers.Dropout(0.1)(model)
model = layers.BatchNormalization(name='norm_2')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)
attention_module = 'cbam_block'
y = attach_attention_module(model, attention_module)
model =  tensorflow.keras.layers.add([model, y])

# %%
# Layer 3
model = layers.Conv2D(64, (3,3), padding='same', name='conv_3', activation = 'relu')(model)
model = layers.BatchNormalization(name='norm_3')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)
attention_module = 'cbam_block'
y = attach_attention_module(model, attention_module)
model =  tensorflow.keras.layers.add([model, y])

# %%
# Layer 4
model = layers.Conv2D(128, (3,3), padding='same', name='conv_4', activation = 'relu')(model)
model = layers.Dropout(0.2)(model)
model = layers.BatchNormalization(name='norm_4')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)
attention_module = 'cbam_block'
y = attach_attention_module(model, attention_module)
model =  tensorflow.keras.layers.add([model, y])

# %%
# Layer 5
model = layers.Conv2D(256, (3,3), padding='same', name='conv_5', activation = 'relu')(model)
layer = layers.Conv2D(256, (3,3), padding='same', name='conv_5', activation = 'relu')
batch = layers.BatchNormalization(name='norm_5')
model = layers.Dropout(0.2)(model)
model = layers.BatchNormalization(name='norm_5')(model)
#model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

# %%
model = layers.Flatten()(model)
model = layers.Dense(128, activation = 'relu')(model)
model = layers.Dropout(0.2)(model)
output = layers.Dense(3,Activation('softmax'))(model)
model = Model(input, output)

# %%
#output = model.output_shape

# %%
print(input)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'")

# %%
initial_learning_rate=0.0001

# %%
lr_schedule = ExponentialDecay(
   initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)

# %%
opt = Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)

# %%
model.compile(optimizer=opt, loss="sparse_categorical_crossentropy", metrics=["accuracy"] )

# %%
print(model.summary())
print(model)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv_1 (Conv2D)                (None, 256, 256, 32  896         ['input_2[0][0]']
#                                 )
#
#  norm_1 (BatchNormalization)    (None, 256, 256, 32  128         ['conv_1[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 32  0          ['norm_1[0][0]']
#                                 )
#
#  global_average_pooling2d_4 (Gl  (None, 32)          0           ['max_pooling2d_4[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_4 (Global  (None, 32)          0           ['max_pooling2d_4[0][0]']
#  MaxPooling2D)
#
#  reshape_8 (Reshape)            (None, 1, 1, 32)     0           ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  reshape_9 (Reshape)            (None, 1, 1, 32)     0           ['global_max_pooling2d_4[0][0]']
#
#  dense_10 (Dense)               (None, 1, 1, 4)      132         ['reshape_8[0][0]',
#                                                                   'reshape_9[0][0]']
#
#  dense_11 (Dense)               (None, 1, 1, 32)     160         ['dense_10[0][0]',
#                                                                   'dense_10[1][0]']
#
#  add_8 (Add)                    (None, 1, 1, 32)     0           ['dense_11[0][0]',
#                                                                   'dense_11[1][0]']
#
#  activation_5 (Activation)      (None, 1, 1, 32)     0           ['add_8[0][0]']
#
#  multiply_8 (Multiply)          (None, 128, 128, 32  0           ['max_pooling2d_4[0][0]',
#                                 )                                 'activation_5[0][0]']
#
#  lambda_8 (Lambda)              (None, 128, 128, 1)  0           ['multiply_8[0][0]']
#
#  lambda_9 (Lambda)              (None, 128, 128, 1)  0           ['multiply_8[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 128, 128, 2)  0           ['lambda_8[0][0]',
#                                                                   'lambda_9[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 1)  98          ['concatenate_4[0][0]']
#
#  multiply_9 (Multiply)          (None, 128, 128, 32  0           ['multiply_8[0][0]',
#                                 )                                 'conv2d_4[0][0]']
#
#  add_9 (Add)                    (None, 128, 128, 32  0           ['max_pooling2d_4[0][0]',
#                                 )                                 'multiply_9[0][0]']
#
#  conv_2 (Conv2D)                (None, 128, 128, 64  18496       ['add_9[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 128, 128, 64  0           ['conv_2[0][0]']
#                                 )
#
#  norm_2 (BatchNormalization)    (None, 128, 128, 64  256         ['dropout_4[0][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 64)  0           ['norm_2[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 64)          0           ['max_pooling2d_5[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_5 (Global  (None, 64)          0           ['max_pooling2d_5[0][0]']
#  MaxPooling2D)
#
#  reshape_10 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  reshape_11 (Reshape)           (None, 1, 1, 64)     0           ['global_max_pooling2d_5[0][0]']
#
#  dense_12 (Dense)               (None, 1, 1, 8)      520         ['reshape_10[0][0]',
#                                                                   'reshape_11[0][0]']
#
#  dense_13 (Dense)               (None, 1, 1, 64)     576         ['dense_12[0][0]',
#                                                                   'dense_12[1][0]']
#
#  add_10 (Add)                   (None, 1, 1, 64)     0           ['dense_13[0][0]',
#                                                                   'dense_13[1][0]']
#
#  activation_6 (Activation)      (None, 1, 1, 64)     0           ['add_10[0][0]']
#
#  multiply_10 (Multiply)         (None, 64, 64, 64)   0           ['max_pooling2d_5[0][0]',
#                                                                   'activation_6[0][0]']
#
#  lambda_10 (Lambda)             (None, 64, 64, 1)    0           ['multiply_10[0][0]']
#
#  lambda_11 (Lambda)             (None, 64, 64, 1)    0           ['multiply_10[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 2)    0           ['lambda_10[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 1)    98          ['concatenate_5[0][0]']
#
#  multiply_11 (Multiply)         (None, 64, 64, 64)   0           ['multiply_10[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  add_11 (Add)                   (None, 64, 64, 64)   0           ['max_pooling2d_5[0][0]',
#                                                                   'multiply_11[0][0]']
#
#  conv_3 (Conv2D)                (None, 64, 64, 64)   36928       ['add_11[0][0]']
#
#  norm_3 (BatchNormalization)    (None, 64, 64, 64)   256         ['conv_3[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 64)  0           ['norm_3[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 64)          0           ['max_pooling2d_6[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_6 (Global  (None, 64)          0           ['max_pooling2d_6[0][0]']
#  MaxPooling2D)
#
#  reshape_12 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  reshape_13 (Reshape)           (None, 1, 1, 64)     0           ['global_max_pooling2d_6[0][0]']
#
#  dense_14 (Dense)               (None, 1, 1, 8)      520         ['reshape_12[0][0]',
#                                                                   'reshape_13[0][0]']
#
#  dense_15 (Dense)               (None, 1, 1, 64)     576         ['dense_14[0][0]',
#                                                                   'dense_14[1][0]']
#
#  add_12 (Add)                   (None, 1, 1, 64)     0           ['dense_15[0][0]',
#                                                                   'dense_15[1][0]']
#
#  activation_7 (Activation)      (None, 1, 1, 64)     0           ['add_12[0][0]']
#
#  multiply_12 (Multiply)         (None, 32, 32, 64)   0           ['max_pooling2d_6[0][0]',
#                                                                   'activation_7[0][0]']
#
#  lambda_12 (Lambda)             (None, 32, 32, 1)    0           ['multiply_12[0][0]']
#
#  lambda_13 (Lambda)             (None, 32, 32, 1)    0           ['multiply_12[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 32, 32, 2)    0           ['lambda_12[0][0]',
#                                                                   'lambda_13[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 1)    98          ['concatenate_6[0][0]']
#
#  multiply_13 (Multiply)         (None, 32, 32, 64)   0           ['multiply_12[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  add_13 (Add)                   (None, 32, 32, 64)   0           ['max_pooling2d_6[0][0]',
#                                                                   'multiply_13[0][0]']
#
#  conv_4 (Conv2D)                (None, 32, 32, 128)  73856       ['add_13[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 128)  0           ['conv_4[0][0]']
#
#  norm_4 (BatchNormalization)    (None, 32, 32, 128)  512         ['dropout_5[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 128)  0          ['norm_4[0][0]']
#
#  global_average_pooling2d_7 (Gl  (None, 128)         0           ['max_pooling2d_7[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_7 (Global  (None, 128)         0           ['max_pooling2d_7[0][0]']
#  MaxPooling2D)
#
#  reshape_14 (Reshape)           (None, 1, 1, 128)    0           ['global_average_pooling2d_7[0][0
#                                                                  ]']
#
#  reshape_15 (Reshape)           (None, 1, 1, 128)    0           ['global_max_pooling2d_7[0][0]']
#
#  dense_16 (Dense)               (None, 1, 1, 16)     2064        ['reshape_14[0][0]',
#                                                                   'reshape_15[0][0]']
#
#  dense_17 (Dense)               (None, 1, 1, 128)    2176        ['dense_16[0][0]',
#                                                                   'dense_16[1][0]']
#
#  add_14 (Add)                   (None, 1, 1, 128)    0           ['dense_17[0][0]',
#                                                                   'dense_17[1][0]']
#
#  activation_8 (Activation)      (None, 1, 1, 128)    0           ['add_14[0][0]']
#
#  multiply_14 (Multiply)         (None, 16, 16, 128)  0           ['max_pooling2d_7[0][0]',
#                                                                   'activation_8[0][0]']
#
#  lambda_14 (Lambda)             (None, 16, 16, 1)    0           ['multiply_14[0][0]']
#
#  lambda_15 (Lambda)             (None, 16, 16, 1)    0           ['multiply_14[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 16, 16, 2)    0           ['lambda_14[0][0]',
#                                                                   'lambda_15[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 1)    98          ['concatenate_7[0][0]']
#
#  multiply_15 (Multiply)         (None, 16, 16, 128)  0           ['multiply_14[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  add_15 (Add)                   (None, 16, 16, 128)  0           ['max_pooling2d_7[0][0]',
#                                                                   'multiply_15[0][0]']
#
#  conv_5 (Conv2D)                (None, 16, 16, 256)  295168      ['add_15[0][0]']
#
#  dropout_6 (Dropout)            (None, 16, 16, 256)  0           ['conv_5[0][0]']
#
#  norm_5 (BatchNormalization)    (None, 16, 16, 256)  1024        ['dropout_6[0][0]']
#
#  flatten_1 (Flatten)            (None, 65536)        0           ['norm_5[0][0]']
#
#  dense_18 (Dense)               (None, 128)          8388736     ['flatten_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 128)          0           ['dense_18[0][0]']
#
#  dense_19 (Dense)               (None, 3)            387         ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 8,823,759
# Trainable params: 8,822,671
# Non-trainable params: 1,088
# __________________________________________________________________________________________________
# None
# <keras.engine.functional.Functional object at 0x7f759297eb50>

# %%
X = []
Y = []
def transferBetweenFolders(source, dest, splitRate): 
    global sourceFiles
    sourceFiles=os.listdir(source)
    if(len(sourceFiles)!=0):
        transferFileNumbers=int(len(sourceFiles)*splitRate)
        transferIndex=random.sample(range(0, len(sourceFiles)), transferFileNumbers)
        for eachIndex in transferIndex:
            shutil.move(source+str(sourceFiles[eachIndex]), dest+str(sourceFiles[eachIndex]))
    else:
        print("No file moved. Source empty!")

# %%
def transferAllClassBetweenFolders(source, dest, splitRate):
    for label in classLabels:
        transferBetweenFolders(sourcePath+'/'+source+'/'+label+'/', 
                               sourcePath+'/'+dest+'/'+label+'/', 
                               splitRate)

# %%
def prepareNameWithLabels(folderName):
    sourceFiles=os.listdir(sourcePath+'/train/'+folderName)
    for val in sourceFiles:
        X.append(val)
        for i in range(len(classLabels)):
          if(folderName==classLabels[i]):
              Y.append(i)
# Organize file names and class labels in X and Y variables
for i in range(len(classLabels)):
  prepareNameWithLabels(classLabels[i])

def my_metrics(y_true, y_pred):
    accuracy=accuracy_score(y_true, y_pred)
    precision=precision_score(y_true, y_pred,average='weighted')
    f1Score=f1_score(y_true, y_pred, average='weighted') 
    print("Accuracy  : {}".format(accuracy))
    print("Precision : {}".format(precision))
    print("f1Score : {}".format(f1Score))
    cm=confusion_matrix(y_true, y_pred)
    print(cm)
    return accuracy, precision, f1Score

# %%
X=np.asarray(X)
Y=np.asarray(Y)

print(X)
print(Y)

skf = StratifiedKFold(n_splits=4
                      , shuffle=True)
skf.get_n_splits(X, Y)
foldNum=0
# Out:
# ['COVID(329).png' 'COVID(378).png' 'COVID(377).png' ...
#  'person984_bacteria_2911.jpeg' 'person987_bacteria_2914.jpeg'
#  'person985_bacteria_2912.jpeg']
# [0 0 0 ... 2 2 2]

# %%
for train_index, val_index in skf.split(X, Y):
    #First cut all images from validation to train (if any exists)
    transferAllClassBetweenFolders('valid', 'train', 1.0)
    foldNum+=1
    print("Results for fold",foldNum)
    X_train, X_val = X[train_index], X[val_index]
    Y_train, Y_val = Y[train_index], Y[val_index]
    # Move validation images of this fold from train folder to the validation folder
    for eachIndex in range(len(X_val)):
        classLabel=''
        for i in range(len(classLabels)):
          if(Y_val[eachIndex]==i):
              classLabel=classLabels[i]
        #Then, copy the validation images to the validation folder
        shutil.move(sourcePath+'/train/'+classLabel+'/'+X_val[eachIndex], 
                    sourcePath+'/valid/'+classLabel+'/'+X_val[eachIndex])
        
    train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 64, shuffle=True)
    valid_batches = ImageDataGenerator().flow_from_directory(valid_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 64, shuffle=True)
    test_batches = ImageDataGenerator().flow_from_directory(test_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 64, shuffle=False)

    history = model.fit(train_batches, 
                    #steps_per_epoch=sp_epoch, 
                    validation_data=valid_batches, 
                    #validation_steps=10, 
                    epochs=100, 
                    verbose=2)
    
    
    
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Final Cbam model accuracy')
    plt.ylim(0,1.1)
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Final Cbam model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.show()
    test_batches.reset()
    Y_pred = model.predict(test_batches)
    classes = test_batches.classes[test_batches.index_array]
    y_pred = np.argmax(Y_pred, axis=-1)
    print(sum(y_pred==classes)/10000)
    confusion_matrix(test_batches.classes[test_batches.index_array],y_pred)
    #predictions = model.predict(test_batches, verbose=1)
    #yPredictions = np.argmax(predictions, axis=1)
    #print(yPredictions)
    #true_classes = test_batches.classes
    # evaluate validation performance
    print("***Performance on Test Data***")    
    #valAcc, valPrec, valFScore = my_metrics(true_classes, yPredictions)
    valAcc, valPrec, valFScore = my_metrics(classes, y_pred)

    model.evaluate(test_batches)
# Out:
# Results for fold 1
# Found 1822 images belonging to 3 classes.
# Found 473 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.
# Epoch 1/100
# 29/29 - 440s - loss: 0.8689 - accuracy: 0.8793 - val_loss: 14.2621 - val_accuracy: 0.3658 - 440s/epoch - 15s/step
# Epoch 2/100
# 29/29 - 24s - loss: 0.1301 - accuracy: 0.9594 - val_loss: 0.4606 - val_accuracy: 0.8816 - 24s/epoch - 824ms/step
# Epoch 3/100
# 29/29 - 24s - loss: 0.1051 - accuracy: 0.9649 - val_loss: 2.1329 - val_accuracy: 0.7844 - 24s/epoch - 829ms/step
# Epoch 4/100
# 29/29 - 24s - loss: 0.0953 - accuracy: 0.9775 - val_loss: 0.2796 - val_accuracy: 0.8858 - 24s/epoch - 828ms/step
# Epoch 5/100
# 29/29 - 24s - loss: 0.0342 - accuracy: 0.9863 - val_loss: 0.2723 - val_accuracy: 0.8753 - 24s/epoch - 826ms/step
# Epoch 6/100
# 29/29 - 24s - loss: 0.0183 - accuracy: 0.9929 - val_loss: 0.1271 - val_accuracy: 0.9662 - 24s/epoch - 821ms/step
# Epoch 7/100
# 29/29 - 24s - loss: 0.0375 - accuracy: 0.9907 - val_loss: 0.1270 - val_accuracy: 0.9556 - 24s/epoch - 815ms/step
# Epoch 8/100
# 29/29 - 24s - loss: 1.0613 - accuracy: 0.9177 - val_loss: 5.8426 - val_accuracy: 0.9091 - 24s/epoch - 830ms/step
# Epoch 9/100
# 29/29 - 24s - loss: 0.3334 - accuracy: 0.9276 - val_loss: 0.9807 - val_accuracy: 0.9197 - 24s/epoch - 825ms/step
# Epoch 10/100
# 29/29 - 24s - loss: 0.1394 - accuracy: 0.9501 - val_loss: 0.2934 - val_accuracy: 0.9471 - 24s/epoch - 828ms/step
# Epoch 11/100
# 29/29 - 24s - loss: 0.0759 - accuracy: 0.9737 - val_loss: 0.2571 - val_accuracy: 0.9556 - 24s/epoch - 835ms/step
# Epoch 12/100
# 29/29 - 24s - loss: 0.0472 - accuracy: 0.9846 - val_loss: 0.3769 - val_accuracy: 0.8837 - 24s/epoch - 837ms/step
# Epoch 13/100
# 29/29 - 24s - loss: 0.0350 - accuracy: 0.9896 - val_loss: 0.7100 - val_accuracy: 0.8266 - 24s/epoch - 831ms/step
# Epoch 14/100
# 29/29 - 24s - loss: 0.0226 - accuracy: 0.9912 - val_loss: 0.2365 - val_accuracy: 0.9302 - 24s/epoch - 823ms/step
# Epoch 15/100
# 29/29 - 24s - loss: 0.0197 - accuracy: 0.9929 - val_loss: 0.1841 - val_accuracy: 0.9641 - 24s/epoch - 824ms/step
# Epoch 16/100
# 29/29 - 24s - loss: 0.0214 - accuracy: 0.9934 - val_loss: 0.3931 - val_accuracy: 0.8795 - 24s/epoch - 832ms/step
# Epoch 17/100
# 29/29 - 24s - loss: 0.0174 - accuracy: 0.9973 - val_loss: 0.5006 - val_accuracy: 0.9175 - 24s/epoch - 834ms/step
# Epoch 18/100
# 29/29 - 24s - loss: 0.0353 - accuracy: 0.9907 - val_loss: 0.4754 - val_accuracy: 0.9133 - 24s/epoch - 839ms/step
# Epoch 19/100
# 29/29 - 24s - loss: 0.0286 - accuracy: 0.9929 - val_loss: 0.3523 - val_accuracy: 0.9450 - 24s/epoch - 833ms/step
# Epoch 20/100
# 29/29 - 24s - loss: 0.0286 - accuracy: 0.9907 - val_loss: 0.2338 - val_accuracy: 0.9683 - 24s/epoch - 838ms/step
# Epoch 21/100
# 29/29 - 24s - loss: 0.0111 - accuracy: 0.9951 - val_loss: 0.1932 - val_accuracy: 0.9725 - 24s/epoch - 829ms/step
# Epoch 22/100
# 29/29 - 24s - loss: 0.0081 - accuracy: 0.9956 - val_loss: 0.2106 - val_accuracy: 0.9641 - 24s/epoch - 833ms/step
# Epoch 23/100
# 29/29 - 24s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9577 - 24s/epoch - 837ms/step
# Epoch 24/100
# 29/29 - 24s - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.4614 - val_accuracy: 0.8985 - 24s/epoch - 834ms/step
# Epoch 25/100
# 29/29 - 24s - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.5329 - val_accuracy: 0.8922 - 24s/epoch - 829ms/step
# Epoch 26/100
# 29/29 - 24s - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.2268 - val_accuracy: 0.9683 - 24s/epoch - 830ms/step
# Epoch 27/100
# 29/29 - 24s - loss: 0.0067 - accuracy: 0.9984 - val_loss: 0.1777 - val_accuracy: 0.9767 - 24s/epoch - 824ms/step
# Epoch 28/100
# 29/29 - 24s - loss: 0.0056 - accuracy: 0.9973 - val_loss: 19.8299 - val_accuracy: 0.4968 - 24s/epoch - 835ms/step
# Epoch 29/100
# 29/29 - 24s - loss: 0.0040 - accuracy: 0.9984 - val_loss: 0.4403 - val_accuracy: 0.9387 - 24s/epoch - 832ms/step
# Epoch 30/100
# 29/29 - 24s - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.3170 - val_accuracy: 0.9408 - 24s/epoch - 830ms/step
# Epoch 31/100
# 29/29 - 24s - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.1851 - val_accuracy: 0.9704 - 24s/epoch - 837ms/step
# Epoch 32/100
# 29/29 - 24s - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.1984 - val_accuracy: 0.9662 - 24s/epoch - 837ms/step
# Epoch 33/100
# 29/29 - 24s - loss: 0.0091 - accuracy: 0.9984 - val_loss: 0.4439 - val_accuracy: 0.9577 - 24s/epoch - 839ms/step
# Epoch 34/100
# 29/29 - 24s - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.3580 - val_accuracy: 0.9704 - 24s/epoch - 825ms/step
# Epoch 35/100
# 29/29 - 24s - loss: 0.0065 - accuracy: 0.9973 - val_loss: 0.5442 - val_accuracy: 0.9493 - 24s/epoch - 838ms/step
# Epoch 36/100
# 29/29 - 24s - loss: 0.0211 - accuracy: 0.9945 - val_loss: 0.5071 - val_accuracy: 0.9619 - 24s/epoch - 836ms/step
# Epoch 37/100
# 29/29 - 24s - loss: 0.0077 - accuracy: 0.9967 - val_loss: 0.9664 - val_accuracy: 0.9070 - 24s/epoch - 830ms/step
# Epoch 38/100
# 29/29 - 24s - loss: 0.0407 - accuracy: 0.9918 - val_loss: 3.4391 - val_accuracy: 0.7505 - 24s/epoch - 828ms/step
# Epoch 39/100
# 29/29 - 24s - loss: 0.0088 - accuracy: 0.9962 - val_loss: 0.8421 - val_accuracy: 0.9133 - 24s/epoch - 832ms/step
# Epoch 40/100
# 29/29 - 24s - loss: 0.0250 - accuracy: 0.9918 - val_loss: 2.2180 - val_accuracy: 0.7400 - 24s/epoch - 834ms/step
# Epoch 41/100
# 29/29 - 24s - loss: 0.0268 - accuracy: 0.9923 - val_loss: 0.9131 - val_accuracy: 0.9197 - 24s/epoch - 830ms/step
# Epoch 42/100
# 29/29 - 24s - loss: 0.0132 - accuracy: 0.9967 - val_loss: 0.4159 - val_accuracy: 0.9493 - 24s/epoch - 828ms/step
# Epoch 43/100
# 29/29 - 24s - loss: 0.0192 - accuracy: 0.9945 - val_loss: 0.3228 - val_accuracy: 0.9260 - 24s/epoch - 822ms/step
# Epoch 44/100
# 29/29 - 24s - loss: 0.0429 - accuracy: 0.9868 - val_loss: 0.9056 - val_accuracy: 0.8943 - 24s/epoch - 832ms/step
# Epoch 45/100
# 29/29 - 24s - loss: 0.0185 - accuracy: 0.9918 - val_loss: 0.5647 - val_accuracy: 0.8922 - 24s/epoch - 830ms/step
# Epoch 46/100
# 29/29 - 24s - loss: 0.0327 - accuracy: 0.9929 - val_loss: 0.5231 - val_accuracy: 0.9577 - 24s/epoch - 833ms/step
# Epoch 47/100
# 29/29 - 24s - loss: 0.0133 - accuracy: 0.9956 - val_loss: 0.2170 - val_accuracy: 0.9704 - 24s/epoch - 829ms/step
# Epoch 48/100
# 29/29 - 24s - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.5608 - val_accuracy: 0.9239 - 24s/epoch - 831ms/step
# Epoch 49/100
# 29/29 - 24s - loss: 0.0102 - accuracy: 0.9973 - val_loss: 0.3538 - val_accuracy: 0.9577 - 24s/epoch - 835ms/step
# Epoch 50/100
# 29/29 - 24s - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.5117 - val_accuracy: 0.9154 - 24s/epoch - 831ms/step
# Epoch 51/100
# 29/29 - 24s - loss: 0.0340 - accuracy: 0.9929 - val_loss: 1.2804 - val_accuracy: 0.8478 - 24s/epoch - 825ms/step
# Epoch 52/100
# 29/29 - 24s - loss: 0.1049 - accuracy: 0.9819 - val_loss: 0.6690 - val_accuracy: 0.9387 - 24s/epoch - 826ms/step
# Epoch 53/100
# 29/29 - 24s - loss: 0.0324 - accuracy: 0.9929 - val_loss: 0.5089 - val_accuracy: 0.9514 - 24s/epoch - 830ms/step
# Epoch 54/100
# 29/29 - 24s - loss: 0.0248 - accuracy: 0.9956 - val_loss: 0.8512 - val_accuracy: 0.8816 - 24s/epoch - 826ms/step
# Epoch 55/100
# 29/29 - 24s - loss: 0.0329 - accuracy: 0.9929 - val_loss: 1.0415 - val_accuracy: 0.8922 - 24s/epoch - 842ms/step
# Epoch 56/100
# 29/29 - 24s - loss: 0.0326 - accuracy: 0.9923 - val_loss: 0.7996 - val_accuracy: 0.9091 - 24s/epoch - 830ms/step
# Epoch 57/100
# 29/29 - 24s - loss: 0.0750 - accuracy: 0.9929 - val_loss: 0.7977 - val_accuracy: 0.9239 - 24s/epoch - 823ms/step
# Epoch 58/100
# 29/29 - 24s - loss: 0.0205 - accuracy: 0.9934 - val_loss: 0.4855 - val_accuracy: 0.9408 - 24s/epoch - 830ms/step
# Epoch 59/100
# 29/29 - 24s - loss: 0.0187 - accuracy: 0.9962 - val_loss: 0.4845 - val_accuracy: 0.9302 - 24s/epoch - 834ms/step
# Epoch 60/100
# 29/29 - 24s - loss: 0.0357 - accuracy: 0.9951 - val_loss: 0.5700 - val_accuracy: 0.9408 - 24s/epoch - 833ms/step
# Epoch 61/100
# 29/29 - 24s - loss: 0.0134 - accuracy: 0.9962 - val_loss: 1.6958 - val_accuracy: 0.8943 - 24s/epoch - 827ms/step
# Epoch 62/100
# 29/29 - 24s - loss: 0.0166 - accuracy: 0.9951 - val_loss: 2.7672 - val_accuracy: 0.8288 - 24s/epoch - 818ms/step
# Epoch 63/100
# 29/29 - 24s - loss: 0.0048 - accuracy: 0.9984 - val_loss: 1.4663 - val_accuracy: 0.8901 - 24s/epoch - 826ms/step
# Epoch 64/100
# 29/29 - 24s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.5832 - val_accuracy: 0.9514 - 24s/epoch - 825ms/step
# Epoch 65/100
# 29/29 - 24s - loss: 0.0054 - accuracy: 0.9989 - val_loss: 2.3194 - val_accuracy: 0.8858 - 24s/epoch - 826ms/step
# Epoch 66/100
# 29/29 - 24s - loss: 0.0025 - accuracy: 0.9989 - val_loss: 0.8106 - val_accuracy: 0.9619 - 24s/epoch - 832ms/step
# Epoch 67/100
# 29/29 - 24s - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.6631 - val_accuracy: 0.9535 - 24s/epoch - 839ms/step
# Epoch 68/100
# 29/29 - 25s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.6124 - val_accuracy: 0.9535 - 25s/epoch - 845ms/step
# Epoch 69/100
# 29/29 - 24s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.3318 - val_accuracy: 0.9746 - 24s/epoch - 836ms/step
# Epoch 70/100
# 29/29 - 24s - loss: 0.0050 - accuracy: 0.9978 - val_loss: 0.2214 - val_accuracy: 0.9746 - 24s/epoch - 824ms/step
# Epoch 71/100
# 29/29 - 24s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2157 - val_accuracy: 0.9746 - 24s/epoch - 821ms/step
# Epoch 72/100
# 29/29 - 24s - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.1978 - val_accuracy: 0.9789 - 24s/epoch - 826ms/step
# Epoch 73/100
# 29/29 - 24s - loss: 0.0018 - accuracy: 0.9989 - val_loss: 0.2000 - val_accuracy: 0.9789 - 24s/epoch - 834ms/step
# Epoch 74/100
# 29/29 - 24s - loss: 7.4057e-04 - accuracy: 0.9995 - val_loss: 0.1811 - val_accuracy: 0.9767 - 24s/epoch - 828ms/step
# Epoch 75/100
# 29/29 - 24s - loss: 3.7304e-04 - accuracy: 1.0000 - val_loss: 0.1833 - val_accuracy: 0.9789 - 24s/epoch - 827ms/step
# Epoch 76/100
# 29/29 - 24s - loss: 2.0032e-04 - accuracy: 1.0000 - val_loss: 0.2031 - val_accuracy: 0.9767 - 24s/epoch - 824ms/step
# Epoch 77/100
# 29/29 - 24s - loss: 5.0451e-04 - accuracy: 1.0000 - val_loss: 0.1955 - val_accuracy: 0.9789 - 24s/epoch - 830ms/step
# Epoch 78/100
# 29/29 - 24s - loss: 2.7184e-04 - accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9789 - 24s/epoch - 832ms/step
# Epoch 79/100
# 29/29 - 24s - loss: 1.2257e-04 - accuracy: 1.0000 - val_loss: 0.2259 - val_accuracy: 0.9789 - 24s/epoch - 840ms/step
# Epoch 80/100
# 29/29 - 24s - loss: 2.9173e-04 - accuracy: 1.0000 - val_loss: 0.2144 - val_accuracy: 0.9789 - 24s/epoch - 840ms/step
# Epoch 81/100
# 29/29 - 24s - loss: 6.5794e-04 - accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9789 - 24s/epoch - 833ms/step
# Epoch 82/100
# 29/29 - 24s - loss: 8.5778e-04 - accuracy: 0.9995 - val_loss: 0.2639 - val_accuracy: 0.9789 - 24s/epoch - 833ms/step
# Epoch 83/100
# 29/29 - 24s - loss: 1.2778e-04 - accuracy: 1.0000 - val_loss: 0.2500 - val_accuracy: 0.9789 - 24s/epoch - 838ms/step
# Epoch 84/100
# 29/29 - 24s - loss: 6.0651e-04 - accuracy: 1.0000 - val_loss: 0.2872 - val_accuracy: 0.9789 - 24s/epoch - 839ms/step
# Epoch 85/100
# 29/29 - 25s - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.2953 - val_accuracy: 0.9789 - 25s/epoch - 848ms/step
# Epoch 86/100
# 29/29 - 24s - loss: 3.0012e-04 - accuracy: 1.0000 - val_loss: 0.2623 - val_accuracy: 0.9810 - 24s/epoch - 831ms/step
# Epoch 87/100
# 29/29 - 24s - loss: 9.2316e-05 - accuracy: 1.0000 - val_loss: 0.2357 - val_accuracy: 0.9810 - 24s/epoch - 823ms/step
# Epoch 88/100
# 29/29 - 24s - loss: 2.8091e-05 - accuracy: 1.0000 - val_loss: 0.2306 - val_accuracy: 0.9810 - 24s/epoch - 831ms/step
# Epoch 89/100
# 29/29 - 24s - loss: 2.3162e-04 - accuracy: 1.0000 - val_loss: 0.2179 - val_accuracy: 0.9810 - 24s/epoch - 830ms/step
# Epoch 90/100
# 29/29 - 24s - loss: 3.7950e-05 - accuracy: 1.0000 - val_loss: 0.2022 - val_accuracy: 0.9831 - 24s/epoch - 839ms/step
# Epoch 91/100
# 29/29 - 24s - loss: 2.9773e-05 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9831 - 24s/epoch - 838ms/step
# Epoch 92/100
# 29/29 - 24s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.4902 - val_accuracy: 0.9387 - 24s/epoch - 835ms/step
# Epoch 93/100
# 29/29 - 25s - loss: 0.0289 - accuracy: 0.9951 - val_loss: 0.6688 - val_accuracy: 0.9450 - 25s/epoch - 845ms/step
# Epoch 94/100
# 29/29 - 24s - loss: 0.0760 - accuracy: 0.9824 - val_loss: 0.7841 - val_accuracy: 0.9197 - 24s/epoch - 836ms/step
# Epoch 95/100
# 29/29 - 24s - loss: 0.0420 - accuracy: 0.9874 - val_loss: 2.3389 - val_accuracy: 0.8372 - 24s/epoch - 834ms/step
# Epoch 96/100
# 29/29 - 24s - loss: 0.0238 - accuracy: 0.9940 - val_loss: 0.2308 - val_accuracy: 0.9725 - 24s/epoch - 828ms/step
# Epoch 97/100
# 29/29 - 24s - loss: 0.0182 - accuracy: 0.9940 - val_loss: 0.2111 - val_accuracy: 0.9767 - 24s/epoch - 842ms/step
# Epoch 98/100
# 29/29 - 24s - loss: 0.1058 - accuracy: 0.9813 - val_loss: 0.6805 - val_accuracy: 0.9429 - 24s/epoch - 842ms/step
# Epoch 99/100
# 29/29 - 24s - loss: 0.1366 - accuracy: 0.9824 - val_loss: 0.8760 - val_accuracy: 0.9049 - 24s/epoch - 833ms/step
# Epoch 100/100
# 29/29 - 24s - loss: 0.0652 - accuracy: 0.9890 - val_loss: 0.2362 - val_accuracy: 0.9535 - 24s/epoch - 843ms/step
# 0.0382
# ***Performance on Test Data***
# Accuracy  : 0.9432098765432099
# Precision : 0.9435550806499268
# f1Score : 0.9433238779074654
# [[133   0   2]
#  [  0 124  11]
#  [  1   9 125]]
# 7/7 [==============================] - 4s 626ms/step - loss: 0.3395 - accuracy: 0.9432
# Results for fold 2
# Found 1822 images belonging to 3 classes.
# Found 473 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.
# Epoch 1/100
# 29/29 - 25s - loss: 0.0844 - accuracy: 0.9863 - val_loss: 0.1658 - val_accuracy: 0.9387 - 25s/epoch - 866ms/step
# Epoch 2/100
# 29/29 - 24s - loss: 0.0304 - accuracy: 0.9907 - val_loss: 0.1815 - val_accuracy: 0.9366 - 24s/epoch - 832ms/step
# Epoch 3/100
# 29/29 - 24s - loss: 0.0307 - accuracy: 0.9890 - val_loss: 0.1993 - val_accuracy: 0.9091 - 24s/epoch - 839ms/step
# Epoch 4/100
# 29/29 - 24s - loss: 0.0146 - accuracy: 0.9956 - val_loss: 0.6853 - val_accuracy: 0.7104 - 24s/epoch - 835ms/step
# Epoch 5/100
# 29/29 - 24s - loss: 0.0112 - accuracy: 0.9984 - val_loss: 0.9826 - val_accuracy: 0.7125 - 24s/epoch - 826ms/step
# Epoch 6/100
# 29/29 - 24s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 1.1992 - val_accuracy: 0.6913 - 24s/epoch - 822ms/step
# Epoch 7/100
# 29/29 - 24s - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.4864 - val_accuracy: 0.8140 - 24s/epoch - 829ms/step
# Epoch 8/100
# 29/29 - 24s - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.7909 - val_accuracy: 0.7463 - 24s/epoch - 826ms/step
# Epoch 9/100
# 29/29 - 24s - loss: 0.0122 - accuracy: 0.9945 - val_loss: 0.2035 - val_accuracy: 0.9091 - 24s/epoch - 821ms/step
# Epoch 10/100
# 29/29 - 24s - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.5956 - val_accuracy: 0.7632 - 24s/epoch - 815ms/step
# Epoch 11/100
# 29/29 - 24s - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.6343 - val_accuracy: 0.8013 - 24s/epoch - 819ms/step
# Epoch 12/100
# 29/29 - 24s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5422 - val_accuracy: 0.8288 - 24s/epoch - 822ms/step
# Epoch 13/100
# 29/29 - 24s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.6135 - val_accuracy: 0.8309 - 24s/epoch - 830ms/step
# Epoch 14/100
# 29/29 - 24s - loss: 0.0020 - accuracy: 0.9989 - val_loss: 0.4292 - val_accuracy: 0.8732 - 24s/epoch - 837ms/step
# Epoch 15/100
# 29/29 - 24s - loss: 4.1074e-04 - accuracy: 1.0000 - val_loss: 0.4349 - val_accuracy: 0.8710 - 24s/epoch - 841ms/step
# Epoch 16/100
# 29/29 - 24s - loss: 2.2733e-04 - accuracy: 1.0000 - val_loss: 0.3779 - val_accuracy: 0.8837 - 24s/epoch - 832ms/step
# Epoch 17/100
# 29/29 - 24s - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.6603 - val_accuracy: 0.8372 - 24s/epoch - 832ms/step
# Epoch 18/100
# 29/29 - 24s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.5800 - val_accuracy: 0.8499 - 24s/epoch - 832ms/step
# Epoch 19/100
# 29/29 - 24s - loss: 0.0021 - accuracy: 0.9989 - val_loss: 0.3839 - val_accuracy: 0.8879 - 24s/epoch - 818ms/step
# Epoch 20/100
# 29/29 - 24s - loss: 0.0011 - accuracy: 0.9989 - val_loss: 0.0497 - val_accuracy: 0.9852 - 24s/epoch - 830ms/step
# Epoch 21/100
# 29/29 - 24s - loss: 0.0088 - accuracy: 0.9984 - val_loss: 0.1687 - val_accuracy: 0.9514 - 24s/epoch - 837ms/step
# Epoch 22/100
# 29/29 - 24s - loss: 0.0102 - accuracy: 0.9973 - val_loss: 0.0922 - val_accuracy: 0.9810 - 24s/epoch - 838ms/step
# Epoch 23/100
# 29/29 - 24s - loss: 0.0047 - accuracy: 0.9995 - val_loss: 0.0144 - val_accuracy: 0.9937 - 24s/epoch - 845ms/step
# Epoch 24/100
# 29/29 - 24s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2316 - val_accuracy: 0.9366 - 24s/epoch - 829ms/step
# Epoch 25/100
# 29/29 - 24s - loss: 0.0018 - accuracy: 0.9989 - val_loss: 0.0054 - val_accuracy: 0.9979 - 24s/epoch - 824ms/step
# Epoch 26/100
# 29/29 - 24s - loss: 0.0129 - accuracy: 0.9951 - val_loss: 1.0962 - val_accuracy: 0.9323 - 24s/epoch - 815ms/step
# Epoch 27/100
# 29/29 - 24s - loss: 0.0036 - accuracy: 0.9989 - val_loss: 3.2334 - val_accuracy: 0.8647 - 24s/epoch - 826ms/step
# Epoch 28/100
# 29/29 - 24s - loss: 0.0088 - accuracy: 0.9967 - val_loss: 1.1398 - val_accuracy: 0.9387 - 24s/epoch - 822ms/step
# Epoch 29/100
# 29/29 - 24s - loss: 0.0089 - accuracy: 0.9967 - val_loss: 0.1782 - val_accuracy: 0.9789 - 24s/epoch - 824ms/step
# Epoch 30/100
# 29/29 - 24s - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0228 - val_accuracy: 0.9937 - 24s/epoch - 823ms/step
# Epoch 31/100
# 29/29 - 24s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 0.9979 - 24s/epoch - 823ms/step
# Epoch 32/100
# 29/29 - 24s - loss: 5.0040e-04 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 0.9979 - 24s/epoch - 826ms/step
# Epoch 33/100
# 29/29 - 24s - loss: 3.1449e-04 - accuracy: 1.0000 - val_loss: 0.0159 - val_accuracy: 0.9979 - 24s/epoch - 822ms/step
# Epoch 34/100
# 29/29 - 24s - loss: 8.3504e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9958 - 24s/epoch - 830ms/step
# Epoch 35/100
# 29/29 - 24s - loss: 7.9158e-04 - accuracy: 0.9995 - val_loss: 0.0130 - val_accuracy: 0.9979 - 24s/epoch - 830ms/step
# Epoch 36/100
# 29/29 - 24s - loss: 0.0028 - accuracy: 0.9984 - val_loss: 3.6434 - val_accuracy: 0.8689 - 24s/epoch - 821ms/step
# Epoch 37/100
# 29/29 - 24s - loss: 0.0013 - accuracy: 0.9989 - val_loss: 0.0324 - val_accuracy: 0.9894 - 24s/epoch - 831ms/step
# Epoch 38/100
# 29/29 - 24s - loss: 0.0074 - accuracy: 0.9984 - val_loss: 0.0218 - val_accuracy: 0.9894 - 24s/epoch - 831ms/step
# Epoch 39/100
# 29/29 - 24s - loss: 0.0044 - accuracy: 0.9984 - val_loss: 0.1136 - val_accuracy: 0.9831 - 24s/epoch - 827ms/step
# Epoch 40/100
# 29/29 - 24s - loss: 0.0036 - accuracy: 0.9973 - val_loss: 0.0667 - val_accuracy: 0.9852 - 24s/epoch - 836ms/step
# Epoch 41/100
# 29/29 - 24s - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0071 - val_accuracy: 0.9958 - 24s/epoch - 825ms/step
# Epoch 42/100
# 29/29 - 24s - loss: 0.0057 - accuracy: 0.9995 - val_loss: 0.0109 - val_accuracy: 0.9937 - 24s/epoch - 828ms/step
# Epoch 43/100
# 29/29 - 24s - loss: 0.0057 - accuracy: 0.9989 - val_loss: 2.6582 - val_accuracy: 0.9006 - 24s/epoch - 818ms/step
# Epoch 44/100
# 29/29 - 24s - loss: 0.0159 - accuracy: 0.9978 - val_loss: 0.0957 - val_accuracy: 0.9831 - 24s/epoch - 827ms/step
# Epoch 45/100
# 29/29 - 24s - loss: 0.0457 - accuracy: 0.9929 - val_loss: 2.6488 - val_accuracy: 0.8330 - 24s/epoch - 821ms/step
# Epoch 46/100
# 29/29 - 24s - loss: 0.0539 - accuracy: 0.9896 - val_loss: 0.9583 - val_accuracy: 0.8626 - 24s/epoch - 826ms/step
# Epoch 47/100
# 29/29 - 24s - loss: 0.0769 - accuracy: 0.9863 - val_loss: 0.1997 - val_accuracy: 0.9683 - 24s/epoch - 825ms/step
# Epoch 48/100
# 29/29 - 24s - loss: 0.0189 - accuracy: 0.9945 - val_loss: 0.1313 - val_accuracy: 0.9852 - 24s/epoch - 824ms/step
# Epoch 49/100
# 29/29 - 24s - loss: 0.0128 - accuracy: 0.9967 - val_loss: 0.0830 - val_accuracy: 0.9810 - 24s/epoch - 818ms/step
# Epoch 50/100
# 29/29 - 24s - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.0264 - val_accuracy: 0.9958 - 24s/epoch - 818ms/step
# Epoch 51/100
# 29/29 - 23s - loss: 0.0172 - accuracy: 0.9951 - val_loss: 1.7924 - val_accuracy: 0.9345 - 23s/epoch - 808ms/step
# Epoch 52/100
# 29/29 - 24s - loss: 0.0147 - accuracy: 0.9967 - val_loss: 0.0124 - val_accuracy: 0.9937 - 24s/epoch - 818ms/step
# Epoch 53/100
# 29/29 - 24s - loss: 0.0080 - accuracy: 0.9984 - val_loss: 0.1691 - val_accuracy: 0.9810 - 24s/epoch - 824ms/step
# Epoch 54/100
# 29/29 - 24s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1128 - val_accuracy: 0.9767 - 24s/epoch - 827ms/step
# Epoch 55/100
# 29/29 - 24s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9852 - 24s/epoch - 823ms/step
# Epoch 56/100
# 29/29 - 24s - loss: 1.8860e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9810 - 24s/epoch - 821ms/step
# Epoch 57/100
# 29/29 - 24s - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0481 - val_accuracy: 0.9894 - 24s/epoch - 822ms/step
# Epoch 58/100
# 29/29 - 24s - loss: 4.4970e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9915 - 24s/epoch - 819ms/step
# Epoch 59/100
# 29/29 - 24s - loss: 5.4949e-04 - accuracy: 1.0000 - val_loss: 0.1073 - val_accuracy: 0.9810 - 24s/epoch - 822ms/step
# Epoch 60/100
# 29/29 - 24s - loss: 6.3130e-04 - accuracy: 1.0000 - val_loss: 0.1597 - val_accuracy: 0.9662 - 24s/epoch - 815ms/step
# Epoch 61/100
# 29/29 - 23s - loss: 0.0028 - accuracy: 0.9995 - val_loss: 0.2667 - val_accuracy: 0.9154 - 23s/epoch - 809ms/step
# Epoch 62/100
# 29/29 - 24s - loss: 2.3820e-04 - accuracy: 1.0000 - val_loss: 0.2445 - val_accuracy: 0.9366 - 24s/epoch - 835ms/step
# Epoch 63/100
# 29/29 - 24s - loss: 0.0037 - accuracy: 0.9989 - val_loss: 1.0881 - val_accuracy: 0.9577 - 24s/epoch - 819ms/step
# Epoch 64/100
# 29/29 - 24s - loss: 0.0070 - accuracy: 0.9989 - val_loss: 10.3205 - val_accuracy: 0.7484 - 24s/epoch - 820ms/step
# Epoch 65/100
# 29/29 - 24s - loss: 0.0109 - accuracy: 0.9956 - val_loss: 0.1913 - val_accuracy: 0.9683 - 24s/epoch - 822ms/step
# Epoch 66/100
# 29/29 - 24s - loss: 0.0036 - accuracy: 0.9995 - val_loss: 1.7949 - val_accuracy: 0.7780 - 24s/epoch - 825ms/step
# Epoch 67/100
# 29/29 - 24s - loss: 0.0042 - accuracy: 0.9978 - val_loss: 0.4795 - val_accuracy: 0.9260 - 24s/epoch - 821ms/step
# Epoch 68/100
# 29/29 - 24s - loss: 0.0224 - accuracy: 0.9967 - val_loss: 0.7197 - val_accuracy: 0.9027 - 24s/epoch - 820ms/step
# Epoch 69/100
# 29/29 - 24s - loss: 0.0118 - accuracy: 0.9973 - val_loss: 0.5052 - val_accuracy: 0.9218 - 24s/epoch - 821ms/step
# Epoch 70/100
# 29/29 - 23s - loss: 0.0230 - accuracy: 0.9973 - val_loss: 0.3975 - val_accuracy: 0.9323 - 23s/epoch - 809ms/step
# Epoch 71/100
# 29/29 - 24s - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.7357 - val_accuracy: 0.8837 - 24s/epoch - 819ms/step
# Epoch 72/100
# 29/29 - 24s - loss: 0.0054 - accuracy: 0.9989 - val_loss: 1.3550 - val_accuracy: 0.8076 - 24s/epoch - 819ms/step
# Epoch 73/100
# 29/29 - 24s - loss: 0.0032 - accuracy: 0.9978 - val_loss: 0.6744 - val_accuracy: 0.8605 - 24s/epoch - 822ms/step
# Epoch 74/100
# 29/29 - 24s - loss: 9.0367e-04 - accuracy: 0.9995 - val_loss: 1.2151 - val_accuracy: 0.7992 - 24s/epoch - 813ms/step
# Epoch 75/100
# 29/29 - 24s - loss: 4.9925e-04 - accuracy: 1.0000 - val_loss: 1.3066 - val_accuracy: 0.8013 - 24s/epoch - 821ms/step
# Epoch 76/100
# 29/29 - 24s - loss: 0.0075 - accuracy: 0.9989 - val_loss: 0.7650 - val_accuracy: 0.8753 - 24s/epoch - 820ms/step
# Epoch 77/100
# 29/29 - 24s - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.3170 - val_accuracy: 0.9577 - 24s/epoch - 823ms/step
# Epoch 78/100
# 29/29 - 24s - loss: 0.0114 - accuracy: 0.9978 - val_loss: 0.8581 - val_accuracy: 0.8964 - 24s/epoch - 827ms/step
# Epoch 79/100
# 29/29 - 24s - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.2828 - val_accuracy: 0.9577 - 24s/epoch - 827ms/step
# Epoch 80/100
# 29/29 - 24s - loss: 0.0023 - accuracy: 0.9989 - val_loss: 0.2830 - val_accuracy: 0.9408 - 24s/epoch - 832ms/step
# Epoch 81/100
# 29/29 - 24s - loss: 0.0155 - accuracy: 0.9978 - val_loss: 0.3744 - val_accuracy: 0.9345 - 24s/epoch - 835ms/step
# Epoch 82/100
# 29/29 - 24s - loss: 0.0435 - accuracy: 0.9956 - val_loss: 1.0867 - val_accuracy: 0.8922 - 24s/epoch - 827ms/step
# Epoch 83/100
# 29/29 - 24s - loss: 0.0089 - accuracy: 0.9984 - val_loss: 0.4420 - val_accuracy: 0.9133 - 24s/epoch - 826ms/step
# Epoch 84/100
# 29/29 - 24s - loss: 0.0020 - accuracy: 0.9989 - val_loss: 0.5190 - val_accuracy: 0.9154 - 24s/epoch - 826ms/step
# Epoch 85/100
# 29/29 - 24s - loss: 0.0068 - accuracy: 0.9967 - val_loss: 0.7054 - val_accuracy: 0.8795 - 24s/epoch - 828ms/step
# Epoch 86/100
# 29/29 - 24s - loss: 0.0150 - accuracy: 0.9978 - val_loss: 0.4362 - val_accuracy: 0.9049 - 24s/epoch - 825ms/step
# Epoch 87/100
# 29/29 - 24s - loss: 0.0308 - accuracy: 0.9945 - val_loss: 35.5461 - val_accuracy: 0.4820 - 24s/epoch - 830ms/step
# Epoch 88/100
# 29/29 - 24s - loss: 0.0395 - accuracy: 0.9945 - val_loss: 36.9281 - val_accuracy: 0.4905 - 24s/epoch - 823ms/step
# Epoch 89/100
# 29/29 - 24s - loss: 0.0290 - accuracy: 0.9962 - val_loss: 6.0489 - val_accuracy: 0.7717 - 24s/epoch - 827ms/step
# Epoch 90/100
# 29/29 - 24s - loss: 0.0124 - accuracy: 0.9962 - val_loss: 0.1260 - val_accuracy: 0.9831 - 24s/epoch - 818ms/step
# Epoch 91/100
# 29/29 - 24s - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.1352 - val_accuracy: 0.9789 - 24s/epoch - 831ms/step
# Epoch 92/100
# 29/29 - 24s - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.0967 - val_accuracy: 0.9831 - 24s/epoch - 825ms/step
# Epoch 93/100
# 29/29 - 24s - loss: 0.0264 - accuracy: 0.9967 - val_loss: 0.0931 - val_accuracy: 0.9831 - 24s/epoch - 831ms/step
# Epoch 94/100
# 29/29 - 24s - loss: 0.0115 - accuracy: 0.9973 - val_loss: 0.0789 - val_accuracy: 0.9894 - 24s/epoch - 822ms/step
# Epoch 95/100
# 29/29 - 24s - loss: 0.0036 - accuracy: 0.9995 - val_loss: 0.1403 - val_accuracy: 0.9852 - 24s/epoch - 825ms/step
# Epoch 96/100
# 29/29 - 24s - loss: 0.0020 - accuracy: 0.9989 - val_loss: 0.2052 - val_accuracy: 0.9641 - 24s/epoch - 829ms/step
# Epoch 97/100
# 29/29 - 24s - loss: 0.0150 - accuracy: 0.9978 - val_loss: 2.1712 - val_accuracy: 0.8964 - 24s/epoch - 836ms/step
# Epoch 98/100
# 29/29 - 24s - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.1778 - val_accuracy: 0.9831 - 24s/epoch - 834ms/step
# Epoch 99/100
# 29/29 - 24s - loss: 3.1771e-04 - accuracy: 1.0000 - val_loss: 0.0468 - val_accuracy: 0.9979 - 24s/epoch - 814ms/step
# Epoch 100/100
# 29/29 - 24s - loss: 2.0742e-04 - accuracy: 1.0000 - val_loss: 0.0565 - val_accuracy: 0.9958 - 24s/epoch - 813ms/step
# 0.0387
# ***Performance on Test Data***
# Accuracy  : 0.9555555555555556
# Precision : 0.9559459582879397
# f1Score : 0.9552520867617803
# [[132   0   3]
#  [  0 133   2]
#  [  4   9 122]]
# 7/7 [==============================] - 4s 613ms/step - loss: 0.4671 - accuracy: 0.9556
# Results for fold 3
# Found 1823 images belonging to 3 classes.
# Found 472 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.
# Epoch 1/100
# 29/29 - 25s - loss: 0.0190 - accuracy: 0.9978 - val_loss: 0.0713 - val_accuracy: 0.9703 - 25s/epoch - 865ms/step
# Epoch 2/100
# 29/29 - 24s - loss: 0.0087 - accuracy: 0.9967 - val_loss: 0.0779 - val_accuracy: 0.9703 - 24s/epoch - 829ms/step
# Epoch 3/100
# 29/29 - 24s - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.0059 - val_accuracy: 0.9979 - 24s/epoch - 829ms/step
# Epoch 4/100
# 29/29 - 24s - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0224 - val_accuracy: 0.9852 - 24s/epoch - 844ms/step
# Epoch 5/100
# 29/29 - 24s - loss: 0.0138 - accuracy: 0.9973 - val_loss: 2.6936e-04 - val_accuracy: 1.0000 - 24s/epoch - 836ms/step
# Epoch 6/100
# 29/29 - 24s - loss: 0.0070 - accuracy: 0.9973 - val_loss: 0.0017 - val_accuracy: 1.0000 - 24s/epoch - 822ms/step
# Epoch 7/100
# 29/29 - 24s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0028 - val_accuracy: 1.0000 - 24s/epoch - 821ms/step
# Epoch 8/100
# 29/29 - 24s - loss: 0.0022 - accuracy: 0.9989 - val_loss: 6.0646e-04 - val_accuracy: 1.0000 - 24s/epoch - 814ms/step
# Epoch 9/100
# 29/29 - 24s - loss: 0.0013 - accuracy: 0.9989 - val_loss: 0.0034 - val_accuracy: 0.9979 - 24s/epoch - 829ms/step
# Epoch 10/100
# 29/29 - 24s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 3.9254e-05 - val_accuracy: 1.0000 - 24s/epoch - 823ms/step
# Epoch 11/100
# 29/29 - 24s - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0015 - val_accuracy: 1.0000 - 24s/epoch - 840ms/step
# Epoch 12/100
# 29/29 - 24s - loss: 0.0019 - accuracy: 0.9984 - val_loss: 0.0218 - val_accuracy: 0.9915 - 24s/epoch - 834ms/step
# Epoch 13/100
# 29/29 - 24s - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.2059 - val_accuracy: 0.9301 - 24s/epoch - 830ms/step
# Epoch 14/100
# 29/29 - 24s - loss: 2.9829e-04 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9619 - 24s/epoch - 821ms/step
# Epoch 15/100
# 29/29 - 24s - loss: 1.6134e-04 - accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 0.9873 - 24s/epoch - 816ms/step
# Epoch 16/100
# 29/29 - 24s - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.1226 - val_accuracy: 0.9682 - 24s/epoch - 821ms/step
# Epoch 17/100
# 29/29 - 24s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0018 - val_accuracy: 1.0000 - 24s/epoch - 828ms/step
# Epoch 18/100
# 29/29 - 24s - loss: 6.7343e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000 - 24s/epoch - 826ms/step
# Epoch 19/100
# 29/29 - 24s - loss: 2.1808e-04 - accuracy: 1.0000 - val_loss: 9.2788e-04 - val_accuracy: 1.0000 - 24s/epoch - 827ms/step
# Epoch 20/100
# 29/29 - 24s - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0331 - val_accuracy: 0.9852 - 24s/epoch - 820ms/step
# Epoch 21/100
# 29/29 - 24s - loss: 1.9423e-04 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9915 - 24s/epoch - 828ms/step
# Epoch 22/100
# 29/29 - 24s - loss: 8.9243e-04 - accuracy: 0.9995 - val_loss: 0.0012 - val_accuracy: 1.0000 - 24s/epoch - 832ms/step
# Epoch 23/100
# 29/29 - 24s - loss: 2.2771e-04 - accuracy: 1.0000 - val_loss: 7.5062e-06 - val_accuracy: 1.0000 - 24s/epoch - 827ms/step
# Epoch 24/100
# 29/29 - 24s - loss: 8.9036e-05 - accuracy: 1.0000 - val_loss: 7.1918e-06 - val_accuracy: 1.0000 - 24s/epoch - 817ms/step
# Epoch 25/100
# 29/29 - 24s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0072 - val_accuracy: 0.9979 - 24s/epoch - 819ms/step
# Epoch 26/100
# 29/29 - 24s - loss: 5.5263e-05 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 0.9979 - 24s/epoch - 825ms/step
# Epoch 27/100
# 29/29 - 24s - loss: 3.7002e-04 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9958 - 24s/epoch - 824ms/step
# Epoch 28/100
# 29/29 - 24s - loss: 2.3897e-04 - accuracy: 1.0000 - val_loss: 8.2889e-04 - val_accuracy: 1.0000 - 24s/epoch - 828ms/step
# Epoch 29/100
# 29/29 - 24s - loss: 2.9589e-05 - accuracy: 1.0000 - val_loss: 2.8146e-04 - val_accuracy: 1.0000 - 24s/epoch - 833ms/step
# Epoch 30/100
# 29/29 - 24s - loss: 5.0118e-04 - accuracy: 1.0000 - val_loss: 4.2126e-05 - val_accuracy: 1.0000 - 24s/epoch - 841ms/step
# Epoch 31/100
# 29/29 - 24s - loss: 2.9487e-06 - accuracy: 1.0000 - val_loss: 1.3209e-05 - val_accuracy: 1.0000 - 24s/epoch - 834ms/step
# Epoch 32/100
# 29/29 - 24s - loss: 1.6793e-05 - accuracy: 1.0000 - val_loss: 4.6281e-06 - val_accuracy: 1.0000 - 24s/epoch - 822ms/step
# Epoch 33/100
# 29/29 - 24s - loss: 2.3166e-04 - accuracy: 1.0000 - val_loss: 1.6002e-05 - val_accuracy: 1.0000 - 24s/epoch - 815ms/step
# Epoch 34/100
# 29/29 - 24s - loss: 9.8601e-05 - accuracy: 1.0000 - val_loss: 1.4491e-04 - val_accuracy: 1.0000 - 24s/epoch - 827ms/step
# Epoch 35/100
# 29/29 - 24s - loss: 9.7321e-05 - accuracy: 1.0000 - val_loss: 2.3980e-05 - val_accuracy: 1.0000 - 24s/epoch - 826ms/step
# Epoch 36/100
# 29/29 - 24s - loss: 2.5627e-06 - accuracy: 1.0000 - val_loss: 8.5594e-06 - val_accuracy: 1.0000 - 24s/epoch - 829ms/step
# Epoch 37/100
# 29/29 - 24s - loss: 3.4573e-04 - accuracy: 1.0000 - val_loss: 5.4095e-06 - val_accuracy: 1.0000 - 24s/epoch - 833ms/step
# Epoch 38/100
# 29/29 - 24s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.7926 - val_accuracy: 0.9492 - 24s/epoch - 838ms/step
# Epoch 39/100
# 29/29 - 24s - loss: 0.0062 - accuracy: 0.9995 - val_loss: 1.3444e-04 - val_accuracy: 1.0000 - 24s/epoch - 832ms/step
# Epoch 40/100
# 29/29 - 24s - loss: 0.0161 - accuracy: 0.9978 - val_loss: 0.0247 - val_accuracy: 0.9958 - 24s/epoch - 826ms/step
# Epoch 41/100
# 29/29 - 24s - loss: 0.0400 - accuracy: 0.9973 - val_loss: 70.5446 - val_accuracy: 0.5424 - 24s/epoch - 827ms/step
# Epoch 42/100
# 29/29 - 24s - loss: 0.0301 - accuracy: 0.9945 - val_loss: 7.7108 - val_accuracy: 0.8369 - 24s/epoch - 829ms/step
# Epoch 43/100
# 29/29 - 24s - loss: 0.0781 - accuracy: 0.9890 - val_loss: 19.4084 - val_accuracy: 0.5636 - 24s/epoch - 835ms/step
# Epoch 44/100
# 29/29 - 24s - loss: 0.0665 - accuracy: 0.9929 - val_loss: 0.6564 - val_accuracy: 0.9534 - 24s/epoch - 832ms/step
# Epoch 45/100
# 29/29 - 24s - loss: 0.0429 - accuracy: 0.9929 - val_loss: 0.4557 - val_accuracy: 0.9174 - 24s/epoch - 827ms/step
# Epoch 46/100
# 29/29 - 24s - loss: 0.0142 - accuracy: 0.9973 - val_loss: 0.2557 - val_accuracy: 0.9004 - 24s/epoch - 832ms/step
# Epoch 47/100
# 29/29 - 24s - loss: 0.0045 - accuracy: 0.9984 - val_loss: 0.2125 - val_accuracy: 0.9089 - 24s/epoch - 824ms/step
# Epoch 48/100
# 29/29 - 24s - loss: 0.0056 - accuracy: 0.9973 - val_loss: 0.1636 - val_accuracy: 0.9492 - 24s/epoch - 831ms/step
# Epoch 49/100
# 29/29 - 24s - loss: 0.0191 - accuracy: 0.9973 - val_loss: 0.2287 - val_accuracy: 0.9364 - 24s/epoch - 830ms/step
# Epoch 50/100
# 29/29 - 24s - loss: 0.0036 - accuracy: 0.9984 - val_loss: 0.1425 - val_accuracy: 0.9555 - 24s/epoch - 827ms/step
# Epoch 51/100
# 29/29 - 24s - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0994 - val_accuracy: 0.9640 - 24s/epoch - 831ms/step
# Epoch 52/100
# 29/29 - 24s - loss: 2.3751e-04 - accuracy: 1.0000 - val_loss: 0.0590 - val_accuracy: 0.9788 - 24s/epoch - 826ms/step
# Epoch 53/100
# 29/29 - 24s - loss: 0.0023 - accuracy: 0.9989 - val_loss: 0.0464 - val_accuracy: 0.9831 - 24s/epoch - 821ms/step
# Epoch 54/100
# 29/29 - 24s - loss: 0.0082 - accuracy: 0.9978 - val_loss: 0.1065 - val_accuracy: 0.9682 - 24s/epoch - 825ms/step
# Epoch 55/100
# 29/29 - 24s - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.0067 - val_accuracy: 0.9958 - 24s/epoch - 828ms/step
# Epoch 56/100
# 29/29 - 24s - loss: 0.0040 - accuracy: 0.9973 - val_loss: 0.0047 - val_accuracy: 0.9979 - 24s/epoch - 834ms/step
# Epoch 57/100
# 29/29 - 24s - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0320 - val_accuracy: 0.9894 - 24s/epoch - 820ms/step
# Epoch 58/100
# 29/29 - 24s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0336 - val_accuracy: 0.9852 - 24s/epoch - 834ms/step
# Epoch 59/100
# 29/29 - 24s - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.0088 - val_accuracy: 0.9936 - 24s/epoch - 828ms/step
# Epoch 60/100
# 29/29 - 24s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9979 - 24s/epoch - 822ms/step
# Epoch 61/100
# 29/29 - 24s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 0.9979 - 24s/epoch - 828ms/step
# Epoch 62/100
# 29/29 - 24s - loss: 0.0131 - accuracy: 0.9967 - val_loss: 0.0049 - val_accuracy: 0.9979 - 24s/epoch - 828ms/step
# Epoch 63/100
# 29/29 - 24s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - 24s/epoch - 825ms/step
# Epoch 64/100
# 29/29 - 24s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0082 - val_accuracy: 0.9958 - 24s/epoch - 826ms/step
# Epoch 65/100
# 29/29 - 24s - loss: 0.0026 - accuracy: 0.9984 - val_loss: 0.0645 - val_accuracy: 0.9746 - 24s/epoch - 834ms/step
# Epoch 66/100
# 29/29 - 24s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000 - 24s/epoch - 824ms/step
# Epoch 67/100
# 29/29 - 24s - loss: 3.6096e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - 24s/epoch - 819ms/step
# Epoch 68/100
# 29/29 - 24s - loss: 2.9169e-04 - accuracy: 1.0000 - val_loss: 9.9363e-04 - val_accuracy: 1.0000 - 24s/epoch - 828ms/step
# Epoch 69/100
# 29/29 - 24s - loss: 9.5888e-04 - accuracy: 0.9995 - val_loss: 0.0045 - val_accuracy: 0.9979 - 24s/epoch - 826ms/step
# Epoch 70/100
# 29/29 - 24s - loss: 0.0017 - accuracy: 0.9989 - val_loss: 0.1152 - val_accuracy: 0.9661 - 24s/epoch - 822ms/step
# Epoch 71/100
# 29/29 - 24s - loss: 0.0017 - accuracy: 0.9989 - val_loss: 0.0034 - val_accuracy: 0.9979 - 24s/epoch - 812ms/step
# Epoch 72/100
# 29/29 - 24s - loss: 5.5066e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000 - 24s/epoch - 817ms/step
# Epoch 73/100
# 29/29 - 24s - loss: 2.0285e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - 24s/epoch - 820ms/step
# Epoch 74/100
# 29/29 - 24s - loss: 0.0093 - accuracy: 0.9978 - val_loss: 0.0131 - val_accuracy: 0.9958 - 24s/epoch - 815ms/step
# Epoch 75/100
# 29/29 - 24s - loss: 0.0061 - accuracy: 0.9995 - val_loss: 0.3879 - val_accuracy: 0.9343 - 24s/epoch - 826ms/step
# Epoch 76/100
# 29/29 - 25s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.1938 - val_accuracy: 0.9640 - 25s/epoch - 863ms/step
# Epoch 77/100
# 29/29 - 25s - loss: 0.0061 - accuracy: 0.9995 - val_loss: 0.0331 - val_accuracy: 0.9894 - 25s/epoch - 864ms/step
# Epoch 78/100
# 29/29 - 25s - loss: 3.0467e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - 25s/epoch - 877ms/step
# Epoch 79/100
# 29/29 - 25s - loss: 7.0106e-04 - accuracy: 1.0000 - val_loss: 6.8210e-04 - val_accuracy: 1.0000 - 25s/epoch - 864ms/step
# Epoch 80/100
# 29/29 - 25s - loss: 6.0948e-05 - accuracy: 1.0000 - val_loss: 3.9559e-04 - val_accuracy: 1.0000 - 25s/epoch - 869ms/step
# Epoch 81/100
# 29/29 - 25s - loss: 0.0037 - accuracy: 0.9995 - val_loss: 1.6273e-04 - val_accuracy: 1.0000 - 25s/epoch - 859ms/step
# Epoch 82/100
# 29/29 - 25s - loss: 5.3531e-05 - accuracy: 1.0000 - val_loss: 1.9093e-04 - val_accuracy: 1.0000 - 25s/epoch - 868ms/step
# Epoch 83/100
# 29/29 - 25s - loss: 3.6995e-05 - accuracy: 1.0000 - val_loss: 2.2137e-04 - val_accuracy: 1.0000 - 25s/epoch - 859ms/step
# Epoch 84/100
# 29/29 - 25s - loss: 5.1545e-05 - accuracy: 1.0000 - val_loss: 1.4259e-04 - val_accuracy: 1.0000 - 25s/epoch - 862ms/step
# Epoch 85/100
# 29/29 - 25s - loss: 2.4781e-04 - accuracy: 1.0000 - val_loss: 2.8357e-05 - val_accuracy: 1.0000 - 25s/epoch - 860ms/step
# Epoch 86/100
# 29/29 - 25s - loss: 6.7461e-04 - accuracy: 0.9995 - val_loss: 5.6974e-05 - val_accuracy: 1.0000 - 25s/epoch - 871ms/step
# Epoch 87/100
# 29/29 - 25s - loss: 7.4532e-04 - accuracy: 0.9995 - val_loss: 4.2631e-05 - val_accuracy: 1.0000 - 25s/epoch - 853ms/step
# Epoch 88/100
# 29/29 - 25s - loss: 4.1904e-05 - accuracy: 1.0000 - val_loss: 2.6909e-05 - val_accuracy: 1.0000 - 25s/epoch - 866ms/step
# Epoch 89/100
# 29/29 - 25s - loss: 1.4321e-04 - accuracy: 1.0000 - val_loss: 2.8253e-05 - val_accuracy: 1.0000 - 25s/epoch - 863ms/step
# Epoch 90/100
# 29/29 - 25s - loss: 4.5361e-04 - accuracy: 1.0000 - val_loss: 1.6116e-04 - val_accuracy: 1.0000 - 25s/epoch - 866ms/step
# Epoch 91/100
# 29/29 - 25s - loss: 5.2036e-04 - accuracy: 0.9995 - val_loss: 2.2830e-04 - val_accuracy: 1.0000 - 25s/epoch - 860ms/step
# Epoch 92/100
# 29/29 - 25s - loss: 3.6135e-04 - accuracy: 1.0000 - val_loss: 1.3701e-04 - val_accuracy: 1.0000 - 25s/epoch - 868ms/step
# Epoch 93/100
# 29/29 - 25s - loss: 1.7362e-05 - accuracy: 1.0000 - val_loss: 1.0440e-04 - val_accuracy: 1.0000 - 25s/epoch - 854ms/step
# Epoch 94/100
# 29/29 - 25s - loss: 4.4987e-04 - accuracy: 0.9995 - val_loss: 0.0027 - val_accuracy: 0.9979 - 25s/epoch - 871ms/step
# Epoch 95/100
# 29/29 - 25s - loss: 1.2409e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9979 - 25s/epoch - 858ms/step
# Epoch 96/100
# 29/29 - 25s - loss: 7.9782e-05 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9979 - 25s/epoch - 857ms/step
# Epoch 97/100
# 29/29 - 25s - loss: 6.5388e-06 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 0.9979 - 25s/epoch - 858ms/step
# Epoch 98/100
# 29/29 - 25s - loss: 4.1001e-05 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 0.9979 - 25s/epoch - 851ms/step
# Epoch 99/100
# 29/29 - 25s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0026 - val_accuracy: 0.9979 - 25s/epoch - 864ms/step
# Epoch 100/100
# 29/29 - 25s - loss: 6.4239e-05 - accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 0.9936 - 25s/epoch - 856ms/step
# 0.0378
# ***Performance on Test Data***
# Accuracy  : 0.9333333333333333
# Precision : 0.9393302508056606
# f1Score : 0.933644561581184
# [[127   4   4]
#  [  0 134   1]
#  [  0  18 117]]
# 7/7 [==============================] - 4s 642ms/step - loss: 1.0497 - accuracy: 0.9333
# Results for fold 4
# Found 1823 images belonging to 3 classes.
# Found 472 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.
# Epoch 1/100
# 29/29 - 26s - loss: 2.4775e-04 - accuracy: 1.0000 - val_loss: 2.3404e-06 - val_accuracy: 1.0000 - 26s/epoch - 892ms/step
# Epoch 2/100
# 29/29 - 24s - loss: 3.0252e-04 - accuracy: 1.0000 - val_loss: 1.2754e-07 - val_accuracy: 1.0000 - 24s/epoch - 836ms/step
# Epoch 3/100
# 29/29 - 24s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 2.3683e-05 - val_accuracy: 1.0000 - 24s/epoch - 832ms/step
# Epoch 4/100
# 29/29 - 24s - loss: 1.8122e-05 - accuracy: 1.0000 - val_loss: 2.9302e-06 - val_accuracy: 1.0000 - 24s/epoch - 839ms/step
# Epoch 5/100
# 29/29 - 24s - loss: 1.3507e-04 - accuracy: 1.0000 - val_loss: 2.7709e-06 - val_accuracy: 1.0000 - 24s/epoch - 831ms/step
# Epoch 6/100
# 29/29 - 24s - loss: 8.0853e-04 - accuracy: 0.9995 - val_loss: 7.8351e-06 - val_accuracy: 1.0000 - 24s/epoch - 835ms/step
# Epoch 7/100
# 29/29 - 24s - loss: 0.0058 - accuracy: 0.9989 - val_loss: 0.6727 - val_accuracy: 0.9047 - 24s/epoch - 828ms/step
# Epoch 8/100
# 29/29 - 24s - loss: 0.0052 - accuracy: 0.9984 - val_loss: 8.5253 - val_accuracy: 0.8390 - 24s/epoch - 834ms/step
# Epoch 9/100
# 29/29 - 24s - loss: 0.0192 - accuracy: 0.9973 - val_loss: 4.0370e-04 - val_accuracy: 1.0000 - 24s/epoch - 828ms/step
# Epoch 10/100
# 29/29 - 24s - loss: 0.0114 - accuracy: 0.9978 - val_loss: 0.2078 - val_accuracy: 0.9725 - 24s/epoch - 824ms/step
# Epoch 11/100
# 29/29 - 24s - loss: 0.0130 - accuracy: 0.9962 - val_loss: 5.5534e-04 - val_accuracy: 1.0000 - 24s/epoch - 832ms/step
# Epoch 12/100
# 29/29 - 24s - loss: 0.1505 - accuracy: 0.9907 - val_loss: 1.7191 - val_accuracy: 0.9068 - 24s/epoch - 825ms/step
# Epoch 13/100
# 29/29 - 24s - loss: 0.1211 - accuracy: 0.9901 - val_loss: 0.2413 - val_accuracy: 0.9746 - 24s/epoch - 825ms/step
# Epoch 14/100
# 29/29 - 24s - loss: 0.0285 - accuracy: 0.9923 - val_loss: 0.8855 - val_accuracy: 0.9068 - 24s/epoch - 840ms/step
# Epoch 15/100
# 29/29 - 24s - loss: 0.0545 - accuracy: 0.9934 - val_loss: 0.8542 - val_accuracy: 0.9153 - 24s/epoch - 831ms/step
# Epoch 16/100
# 29/29 - 24s - loss: 0.0225 - accuracy: 0.9945 - val_loss: 0.0873 - val_accuracy: 0.9852 - 24s/epoch - 829ms/step
# Epoch 17/100
# 29/29 - 24s - loss: 0.0094 - accuracy: 0.9984 - val_loss: 0.1136 - val_accuracy: 0.9703 - 24s/epoch - 833ms/step
# Epoch 18/100
# 29/29 - 24s - loss: 0.0090 - accuracy: 0.9978 - val_loss: 0.5135 - val_accuracy: 0.9153 - 24s/epoch - 835ms/step
# Epoch 19/100
# 29/29 - 24s - loss: 0.0049 - accuracy: 0.9989 - val_loss: 0.0372 - val_accuracy: 0.9915 - 24s/epoch - 839ms/step
# Epoch 20/100
# 29/29 - 24s - loss: 0.0476 - accuracy: 0.9973 - val_loss: 0.1223 - val_accuracy: 0.9619 - 24s/epoch - 830ms/step
# Epoch 21/100
# 29/29 - 24s - loss: 0.0130 - accuracy: 0.9967 - val_loss: 0.2976 - val_accuracy: 0.9407 - 24s/epoch - 825ms/step
# Epoch 22/100
# 29/29 - 24s - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.1524 - val_accuracy: 0.9619 - 24s/epoch - 828ms/step
# Epoch 23/100
# 29/29 - 24s - loss: 0.0047 - accuracy: 0.9973 - val_loss: 0.0971 - val_accuracy: 0.9767 - 24s/epoch - 825ms/step
# Epoch 24/100
# 29/29 - 24s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9936 - 24s/epoch - 838ms/step
# Epoch 25/100
# 29/29 - 24s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1467 - val_accuracy: 0.9682 - 24s/epoch - 832ms/step
# Epoch 26/100
# 29/29 - 24s - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0556 - val_accuracy: 0.9873 - 24s/epoch - 832ms/step
# Epoch 27/100
# 29/29 - 24s - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0286 - val_accuracy: 0.9958 - 24s/epoch - 829ms/step
# Epoch 28/100
# 29/29 - 24s - loss: 8.0861e-04 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9958 - 24s/epoch - 829ms/step
# Epoch 29/100
# 29/29 - 24s - loss: 0.0028 - accuracy: 0.9995 - val_loss: 0.1643 - val_accuracy: 0.9746 - 24s/epoch - 835ms/step
# Epoch 30/100
# 29/29 - 24s - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.1465 - val_accuracy: 0.9746 - 24s/epoch - 832ms/step
# Epoch 31/100
# 29/29 - 24s - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.1755 - val_accuracy: 0.9703 - 24s/epoch - 827ms/step
# Epoch 32/100
# 29/29 - 24s - loss: 0.0023 - accuracy: 0.9989 - val_loss: 0.0267 - val_accuracy: 0.9936 - 24s/epoch - 832ms/step
# Epoch 33/100
# 29/29 - 24s - loss: 6.9161e-04 - accuracy: 0.9995 - val_loss: 0.0351 - val_accuracy: 0.9958 - 24s/epoch - 830ms/step
# Epoch 34/100
# 29/29 - 24s - loss: 6.2204e-04 - accuracy: 0.9995 - val_loss: 0.0093 - val_accuracy: 0.9958 - 24s/epoch - 828ms/step
# Epoch 35/100
# 29/29 - 24s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.4354 - val_accuracy: 0.9852 - 24s/epoch - 834ms/step
# Epoch 36/100
# 29/29 - 24s - loss: 0.0101 - accuracy: 0.9995 - val_loss: 0.0357 - val_accuracy: 0.9958 - 24s/epoch - 824ms/step
# Epoch 37/100
# 29/29 - 24s - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0261 - val_accuracy: 0.9958 - 24s/epoch - 825ms/step
# Epoch 38/100
# 29/29 - 24s - loss: 2.4884e-04 - accuracy: 1.0000 - val_loss: 0.0200 - val_accuracy: 0.9979 - 24s/epoch - 832ms/step
# Epoch 39/100
# 29/29 - 24s - loss: 4.5828e-04 - accuracy: 1.0000 - val_loss: 0.0363 - val_accuracy: 0.9936 - 24s/epoch - 827ms/step
# Epoch 40/100
# 29/29 - 24s - loss: 0.0073 - accuracy: 0.9995 - val_loss: 0.1344 - val_accuracy: 0.9746 - 24s/epoch - 839ms/step
# Epoch 41/100
# 29/29 - 24s - loss: 1.7342e-04 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 0.9788 - 24s/epoch - 838ms/step
# Epoch 42/100
# 29/29 - 24s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0545 - val_accuracy: 0.9894 - 24s/epoch - 832ms/step
# Epoch 43/100
# 29/29 - 24s - loss: 0.0100 - accuracy: 0.9995 - val_loss: 0.0325 - val_accuracy: 0.9894 - 24s/epoch - 836ms/step
# Epoch 44/100
# 29/29 - 24s - loss: 0.0073 - accuracy: 0.9984 - val_loss: 0.1701 - val_accuracy: 0.9831 - 24s/epoch - 832ms/step
# Epoch 45/100
# 29/29 - 24s - loss: 0.0125 - accuracy: 0.9989 - val_loss: 0.0487 - val_accuracy: 0.9958 - 24s/epoch - 841ms/step
# Epoch 46/100
# 29/29 - 24s - loss: 0.0079 - accuracy: 0.9984 - val_loss: 0.1184 - val_accuracy: 0.9725 - 24s/epoch - 828ms/step
# Epoch 47/100
# 29/29 - 24s - loss: 0.0317 - accuracy: 0.9978 - val_loss: 0.3585 - val_accuracy: 0.9746 - 24s/epoch - 832ms/step
# Epoch 48/100
# 29/29 - 24s - loss: 0.0254 - accuracy: 0.9956 - val_loss: 0.0844 - val_accuracy: 0.9894 - 24s/epoch - 840ms/step
# Epoch 49/100
# 29/29 - 24s - loss: 0.0105 - accuracy: 0.9978 - val_loss: 0.0122 - val_accuracy: 0.9958 - 24s/epoch - 826ms/step
# Epoch 50/100
# 29/29 - 24s - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0043 - val_accuracy: 0.9979 - 24s/epoch - 836ms/step
# Epoch 51/100
# 29/29 - 24s - loss: 0.0088 - accuracy: 0.9978 - val_loss: 0.0605 - val_accuracy: 0.9894 - 24s/epoch - 839ms/step
# Epoch 52/100
# 29/29 - 24s - loss: 0.0059 - accuracy: 0.9989 - val_loss: 0.0680 - val_accuracy: 0.9831 - 24s/epoch - 830ms/step
# Epoch 53/100
# 29/29 - 24s - loss: 0.0068 - accuracy: 0.9995 - val_loss: 0.0956 - val_accuracy: 0.9894 - 24s/epoch - 817ms/step
# Epoch 54/100
# 29/29 - 24s - loss: 3.7756e-04 - accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 0.9915 - 24s/epoch - 823ms/step
# Epoch 55/100
# 29/29 - 24s - loss: 5.9431e-04 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 0.9958 - 24s/epoch - 823ms/step
# Epoch 56/100
# 29/29 - 24s - loss: 0.0092 - accuracy: 0.9989 - val_loss: 0.0023 - val_accuracy: 1.0000 - 24s/epoch - 836ms/step
# Epoch 57/100
# 29/29 - 24s - loss: 0.0096 - accuracy: 0.9984 - val_loss: 0.3877 - val_accuracy: 0.9492 - 24s/epoch - 841ms/step
# Epoch 58/100
# 29/29 - 24s - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.2316 - val_accuracy: 0.9619 - 24s/epoch - 830ms/step
# Epoch 59/100
# 29/29 - 24s - loss: 0.0057 - accuracy: 0.9989 - val_loss: 0.7527 - val_accuracy: 0.9174 - 24s/epoch - 825ms/step
# Epoch 60/100
# 29/29 - 25s - loss: 0.0023 - accuracy: 0.9989 - val_loss: 0.7845 - val_accuracy: 0.9174 - 25s/epoch - 849ms/step
# Epoch 61/100
# 29/29 - 24s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.9399 - val_accuracy: 0.8983 - 24s/epoch - 825ms/step
# Epoch 62/100
# 29/29 - 24s - loss: 0.0094 - accuracy: 0.9984 - val_loss: 0.3310 - val_accuracy: 0.9661 - 24s/epoch - 831ms/step
# Epoch 63/100
# 29/29 - 24s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.2809 - val_accuracy: 0.9682 - 24s/epoch - 828ms/step
# Epoch 64/100
# 29/29 - 24s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.2769 - val_accuracy: 0.9746 - 24s/epoch - 813ms/step
# Epoch 65/100
# 29/29 - 24s - loss: 0.0222 - accuracy: 0.9984 - val_loss: 1.0760 - val_accuracy: 0.9047 - 24s/epoch - 816ms/step
# Epoch 66/100
# 29/29 - 24s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0146 - val_accuracy: 0.9958 - 24s/epoch - 815ms/step
# Epoch 67/100
# 29/29 - 23s - loss: 0.0080 - accuracy: 0.9978 - val_loss: 0.4749 - val_accuracy: 0.9343 - 23s/epoch - 809ms/step
# Epoch 68/100
# 29/29 - 23s - loss: 0.0372 - accuracy: 0.9967 - val_loss: 0.1749 - val_accuracy: 0.9852 - 23s/epoch - 807ms/step
# Epoch 69/100
# 29/29 - 23s - loss: 0.0140 - accuracy: 0.9973 - val_loss: 0.2549 - val_accuracy: 0.9746 - 23s/epoch - 805ms/step
# Epoch 70/100
# 29/29 - 24s - loss: 8.4594e-04 - accuracy: 0.9995 - val_loss: 0.1961 - val_accuracy: 0.9852 - 24s/epoch - 814ms/step
# Epoch 71/100
# 29/29 - 23s - loss: 0.0045 - accuracy: 0.9995 - val_loss: 0.3654 - val_accuracy: 0.9492 - 23s/epoch - 810ms/step
# Epoch 72/100
# 29/29 - 23s - loss: 0.0114 - accuracy: 0.9973 - val_loss: 0.0807 - val_accuracy: 0.9852 - 23s/epoch - 808ms/step
# Epoch 73/100
# 29/29 - 23s - loss: 0.0021 - accuracy: 0.9989 - val_loss: 0.5497 - val_accuracy: 0.9513 - 23s/epoch - 809ms/step
# Epoch 74/100
# 29/29 - 23s - loss: 1.9653e-04 - accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 0.9936 - 23s/epoch - 805ms/step
# Epoch 75/100
# 29/29 - 23s - loss: 2.1459e-04 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9979 - 23s/epoch - 805ms/step
# Epoch 76/100
# 29/29 - 23s - loss: 9.3031e-05 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 0.9979 - 23s/epoch - 807ms/step
# Epoch 77/100
# 29/29 - 23s - loss: 1.4765e-04 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9958 - 23s/epoch - 805ms/step
# Epoch 78/100
# 29/29 - 23s - loss: 2.0337e-04 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9958 - 23s/epoch - 805ms/step
# Epoch 79/100
# 29/29 - 23s - loss: 3.8319e-05 - accuracy: 1.0000 - val_loss: 0.0455 - val_accuracy: 0.9958 - 23s/epoch - 809ms/step
# Epoch 80/100
# 29/29 - 24s - loss: 2.6372e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9958 - 24s/epoch - 811ms/step
# Epoch 81/100
# 29/29 - 24s - loss: 9.4485e-05 - accuracy: 1.0000 - val_loss: 0.0354 - val_accuracy: 0.9979 - 24s/epoch - 811ms/step
# Epoch 82/100
# 29/29 - 23s - loss: 5.7216e-04 - accuracy: 0.9995 - val_loss: 0.0359 - val_accuracy: 0.9979 - 23s/epoch - 808ms/step
# Epoch 83/100
# 29/29 - 23s - loss: 6.8325e-04 - accuracy: 0.9995 - val_loss: 0.0362 - val_accuracy: 0.9979 - 23s/epoch - 807ms/step
# Epoch 84/100
# 29/29 - 24s - loss: 6.7543e-06 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 0.9979 - 24s/epoch - 814ms/step
# Epoch 85/100
# 29/29 - 24s - loss: 0.0423 - accuracy: 0.9989 - val_loss: 0.0484 - val_accuracy: 0.9936 - 24s/epoch - 816ms/step
# Epoch 86/100
# 29/29 - 24s - loss: 0.0049 - accuracy: 0.9995 - val_loss: 0.2316 - val_accuracy: 0.9809 - 24s/epoch - 813ms/step
# Epoch 87/100
# 29/29 - 24s - loss: 6.2130e-04 - accuracy: 1.0000 - val_loss: 0.0527 - val_accuracy: 0.9958 - 24s/epoch - 822ms/step
# Epoch 88/100
# 29/29 - 24s - loss: 1.4061e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 0.9979 - 24s/epoch - 811ms/step
# Epoch 89/100
# 29/29 - 24s - loss: 0.0115 - accuracy: 0.9984 - val_loss: 0.0849 - val_accuracy: 0.9915 - 24s/epoch - 811ms/step
# Epoch 90/100
# 29/29 - 24s - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1538 - val_accuracy: 0.9831 - 24s/epoch - 821ms/step
# Epoch 91/100
# 29/29 - 24s - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.1545 - val_accuracy: 0.9852 - 24s/epoch - 818ms/step
# Epoch 92/100
# 29/29 - 24s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.1512 - val_accuracy: 0.9809 - 24s/epoch - 820ms/step
# Epoch 93/100
# 29/29 - 24s - loss: 4.3083e-04 - accuracy: 1.0000 - val_loss: 0.2425 - val_accuracy: 0.9746 - 24s/epoch - 814ms/step
# Epoch 94/100
# 29/29 - 24s - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.1521 - val_accuracy: 0.9852 - 24s/epoch - 811ms/step
# Epoch 95/100
# 29/29 - 24s - loss: 7.2658e-05 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 0.9873 - 24s/epoch - 811ms/step
# Epoch 96/100
# 29/29 - 24s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0698 - val_accuracy: 0.9936 - 24s/epoch - 813ms/step
# Epoch 97/100
# 29/29 - 24s - loss: 5.4486e-04 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9979 - 24s/epoch - 819ms/step
# Epoch 98/100
# 29/29 - 24s - loss: 2.2733e-05 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9979 - 24s/epoch - 814ms/step
# Epoch 99/100
# 29/29 - 24s - loss: 6.4092e-04 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9958 - 24s/epoch - 812ms/step
# Epoch 100/100
# 29/29 - 24s - loss: 6.6990e-05 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9958 - 24s/epoch - 817ms/step
# 0.0386
# ***Performance on Test Data***
# Accuracy  : 0.9530864197530864
# Precision : 0.9529696097502476
# f1Score : 0.952993203915065
# [[132   0   3]
#  [  1 129   5]
#  [  4   6 125]]
# 7/7 [==============================] - 4s 605ms/step - loss: 0.7971 - accuracy: 0.9531
