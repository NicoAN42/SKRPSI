# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoAN42/SKRPSI/blob/main/amitofooo_cbam_1layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mount dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow.keras.layers import Conv2D, Input, concatenate, Activation, InputLayer, Dense, Reshape, Flatten, Add, multiply, Permute, Lambda, Concatenate
from tensorflow.keras.layers import LeakyReLU,ReLU, MaxPooling2D, BatchNormalization,GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import layers
from tensorflow.keras.activations import softmax,sigmoid
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout,SpatialDropout2D,GaussianDropout
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.regularizers import l1,l2
from tensorflow.keras import backend as K
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow
import tensorflow as tf
import math
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold
import os
import random
import shutil

# %%
from tensorflow.keras.optimizers import SGD

# %%
CLASS = 3
#sourcepath isi semua data train, folder valid kosongin datanya sisai folder classnya
sourcePath = '/content/drive/MyDrive/Colab Notebooks/Dataset 007'
train_path = '/content/drive/MyDrive/Colab Notebooks/Dataset 007/train'
valid_path = '/content/drive/MyDrive/Colab Notebooks/Dataset 007/valid'
test_path = '/content/drive/MyDrive/Colab Notebooks/Dataset 007/test'

#nico

# %%
classLabels =['covid','normal', 'pneumonia']

# %%
def attach_attention_module(net, attention_module):
  #if attention_module == 'se_block': # SE_block
    #net = se_block(net)
  if attention_module == 'cbam_block': # CBAM_block
    net = cbam_block(net)
  else:
    raise Exception("'{}' is not supported attention module!".format(attention_module))

  return net

# %%
def cbam_block(cbam_feature, ratio=8):
	"""Contains the implementation of Convolutional Block Attention Module(CBAM) block.
	As described in https://arxiv.org/abs/1807.06521.
	"""
	
	cbam_feature = channel_attention(cbam_feature, ratio)
	cbam_feature = spatial_attention(cbam_feature)
	return cbam_feature

# %%
def channel_attention(input_feature, ratio=8):
	
	channel_axis = 1 if K.image_data_format() == "channels_first" else -1
	channel = input_feature.shape[channel_axis]
	
	shared_layer_one = Dense(channel//ratio,
							 activation='relu',
							 kernel_initializer='he_normal',
							 use_bias=True,
							 bias_initializer='zeros')
	shared_layer_two = Dense(channel,
							 kernel_initializer='he_normal',
							 use_bias=True,
							 bias_initializer='zeros')
	
	avg_pool = GlobalAveragePooling2D()(input_feature)    
	avg_pool = Reshape((1,1,channel))(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel)
	avg_pool = shared_layer_one(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel//ratio)
	avg_pool = shared_layer_two(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel)
	
	max_pool = GlobalMaxPooling2D()(input_feature)
	max_pool = Reshape((1,1,channel))(max_pool)
	assert max_pool.shape[1:] == (1,1,channel)
	max_pool = shared_layer_one(max_pool)
	assert max_pool.shape[1:] == (1,1,channel//ratio)
	max_pool = shared_layer_two(max_pool)
	assert max_pool.shape[1:] == (1,1,channel)
	
	cbam_feature = Add()([avg_pool,max_pool])
	cbam_feature = Activation('sigmoid')(cbam_feature)
	
	if K.image_data_format() == "channels_first":
		cbam_feature = Permute((3, 1, 2))(cbam_feature)
	
	return multiply([input_feature, cbam_feature])

# %%
def spatial_attention(input_feature):
	kernel_size = 7
	
	if K.image_data_format() == "channels_first":
		channel = input_feature.shape[1]
		cbam_feature = Permute((2,3,1))(input_feature)
	else:
		channel = input_feature.shape[-1]
		cbam_feature = input_feature
	
	avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
	assert avg_pool.shape[-1] == 1
	max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
	assert max_pool.shape[-1] == 1
	concat = Concatenate(axis=3)([avg_pool, max_pool])
	assert concat.shape[-1] == 2
	cbam_feature = Conv2D(filters = 1,
					kernel_size=kernel_size,
					strides=1,
					padding='same',
					activation='sigmoid',
					kernel_initializer='he_normal',
					use_bias=False)(concat)	
	assert cbam_feature.shape[-1] == 1
	
	if K.image_data_format() == "channels_first":
		cbam_feature = Permute((3, 1, 2))(cbam_feature)
		
	return multiply([input_feature, cbam_feature])

# %%
input = Input(shape=(256,256,3))

# %%
#Layer 1
model = layers.Conv2D(32, (3,3), padding='same', name='conv_1', activation = 'relu')(input)
model = layers.BatchNormalization(name='norm_1')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides= 2)(model)
attention_module = 'cbam_block'
y = attach_attention_module(model, attention_module)
model =  tensorflow.keras.layers.add([model, y])

# %%
#Layer 2
model = layers.Conv2D(64, (3,3), padding='same', name='conv_2', activation = 'relu')(model)
model = layers.Dropout(0.1)(model)
model = layers.BatchNormalization(name='norm_2')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

# %%
# Layer 3
model = layers.Conv2D(64, (3,3), padding='same', name='conv_3', activation = 'relu')(model)
model = layers.BatchNormalization(name='norm_3')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

# %%
# Layer 4
model = layers.Conv2D(128, (3,3), padding='same', name='conv_4', activation = 'relu')(model)
model = layers.Dropout(0.2)(model)
model = layers.BatchNormalization(name='norm_4')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

# %%
# Layer 5
model = layers.Conv2D(256, (3,3), padding='same', name='conv_5', activation = 'relu')(model)
layer = layers.Conv2D(256, (3,3), padding='same', name='conv_5', activation = 'relu')
batch = layers.BatchNormalization(name='norm_5')
model = layers.Dropout(0.2)(model)
model = layers.BatchNormalization(name='norm_5')(model)
#model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

# %%
model = layers.Flatten()(model)
model = layers.Dense(128, activation = 'relu')(model)
model = layers.Dropout(0.2)(model)
output = layers.Dense(3,Activation('softmax'))(model)
model = Model(input, output)

# %%
#output = model.output_shape

# %%
print(input)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='input_3'), name='input_3', description="created by layer 'input_3'")

# %%
initial_learning_rate=0.0001

# %%
lr_schedule = ExponentialDecay(
   initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)

# %%
opt = Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)

# %%
model.compile(optimizer=opt, loss="sparse_categorical_crossentropy", metrics=["accuracy"] )

# %%
print(model.summary())
print(model)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv_1 (Conv2D)                (None, 256, 256, 32  896         ['input_3[0][0]']
#                                 )
#
#  norm_1 (BatchNormalization)    (None, 256, 256, 32  128         ['conv_1[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 128, 128, 32  0          ['norm_1[0][0]']
#                                 )
#
#  global_average_pooling2d_8 (Gl  (None, 32)          0           ['max_pooling2d_8[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_8 (Global  (None, 32)          0           ['max_pooling2d_8[0][0]']
#  MaxPooling2D)
#
#  reshape_16 (Reshape)           (None, 1, 1, 32)     0           ['global_average_pooling2d_8[0][0
#                                                                  ]']
#
#  reshape_17 (Reshape)           (None, 1, 1, 32)     0           ['global_max_pooling2d_8[0][0]']
#
#  dense_20 (Dense)               (None, 1, 1, 4)      132         ['reshape_16[0][0]',
#                                                                   'reshape_17[0][0]']
#
#  dense_21 (Dense)               (None, 1, 1, 32)     160         ['dense_20[0][0]',
#                                                                   'dense_20[1][0]']
#
#  add_16 (Add)                   (None, 1, 1, 32)     0           ['dense_21[0][0]',
#                                                                   'dense_21[1][0]']
#
#  activation_10 (Activation)     (None, 1, 1, 32)     0           ['add_16[0][0]']
#
#  multiply_16 (Multiply)         (None, 128, 128, 32  0           ['max_pooling2d_8[0][0]',
#                                 )                                 'activation_10[0][0]']
#
#  lambda_16 (Lambda)             (None, 128, 128, 1)  0           ['multiply_16[0][0]']
#
#  lambda_17 (Lambda)             (None, 128, 128, 1)  0           ['multiply_16[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 128, 128, 2)  0           ['lambda_16[0][0]',
#                                                                   'lambda_17[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 128, 128, 1)  98          ['concatenate_8[0][0]']
#
#  multiply_17 (Multiply)         (None, 128, 128, 32  0           ['multiply_16[0][0]',
#                                 )                                 'conv2d_8[0][0]']
#
#  add_17 (Add)                   (None, 128, 128, 32  0           ['max_pooling2d_8[0][0]',
#                                 )                                 'multiply_17[0][0]']
#
#  conv_2 (Conv2D)                (None, 128, 128, 64  18496       ['add_17[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 128, 128, 64  0           ['conv_2[0][0]']
#                                 )
#
#  norm_2 (BatchNormalization)    (None, 128, 128, 64  256         ['dropout_8[0][0]']
#                                 )
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 64, 64, 64)  0           ['norm_2[0][0]']
#
#  conv_3 (Conv2D)                (None, 64, 64, 64)   36928       ['max_pooling2d_9[0][0]']
#
#  norm_3 (BatchNormalization)    (None, 64, 64, 64)   256         ['conv_3[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 32, 32, 64)  0           ['norm_3[0][0]']
#  )
#
#  conv_4 (Conv2D)                (None, 32, 32, 128)  73856       ['max_pooling2d_10[0][0]']
#
#  dropout_9 (Dropout)            (None, 32, 32, 128)  0           ['conv_4[0][0]']
#
#  norm_4 (BatchNormalization)    (None, 32, 32, 128)  512         ['dropout_9[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 16, 16, 128)  0          ['norm_4[0][0]']
#  )
#
#  conv_5 (Conv2D)                (None, 16, 16, 256)  295168      ['max_pooling2d_11[0][0]']
#
#  dropout_10 (Dropout)           (None, 16, 16, 256)  0           ['conv_5[0][0]']
#
#  norm_5 (BatchNormalization)    (None, 16, 16, 256)  1024        ['dropout_10[0][0]']
#
#  flatten_2 (Flatten)            (None, 65536)        0           ['norm_5[0][0]']
#
#  dense_22 (Dense)               (None, 128)          8388736     ['flatten_2[0][0]']
#
#  dropout_11 (Dropout)           (None, 128)          0           ['dense_22[0][0]']
#
#  dense_23 (Dense)               (None, 3)            387         ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 8,817,033
# Trainable params: 8,815,945
# Non-trainable params: 1,088
# __________________________________________________________________________________________________
# None
# <keras.engine.functional.Functional object at 0x7f74b0ebfb10>

# %%
X = []
Y = []
def transferBetweenFolders(source, dest, splitRate): 
    global sourceFiles
    sourceFiles=os.listdir(source)
    if(len(sourceFiles)!=0):
        transferFileNumbers=int(len(sourceFiles)*splitRate)
        transferIndex=random.sample(range(0, len(sourceFiles)), transferFileNumbers)
        for eachIndex in transferIndex:
            shutil.move(source+str(sourceFiles[eachIndex]), dest+str(sourceFiles[eachIndex]))
    else:
        print("No file moved. Source empty!")

# %%
def transferAllClassBetweenFolders(source, dest, splitRate):
    for label in classLabels:
        transferBetweenFolders(sourcePath+'/'+source+'/'+label+'/', 
                               sourcePath+'/'+dest+'/'+label+'/', 
                               splitRate)

# %%
def prepareNameWithLabels(folderName):
    sourceFiles=os.listdir(sourcePath+'/train/'+folderName)
    for val in sourceFiles:
        X.append(val)
        for i in range(len(classLabels)):
          if(folderName==classLabels[i]):
              Y.append(i)
# Organize file names and class labels in X and Y variables
for i in range(len(classLabels)):
  prepareNameWithLabels(classLabels[i])

def my_metrics(y_true, y_pred):
    accuracy=accuracy_score(y_true, y_pred)
    precision=precision_score(y_true, y_pred,average='weighted')
    f1Score=f1_score(y_true, y_pred, average='weighted') 
    print("Accuracy  : {}".format(accuracy))
    print("Precision : {}".format(precision))
    print("f1Score : {}".format(f1Score))
    cm=confusion_matrix(y_true, y_pred)
    print(cm)
    return accuracy, precision, f1Score

# %%
X=np.asarray(X)
Y=np.asarray(Y)

print(X)
print(Y)

skf = StratifiedKFold(n_splits=4
                      , shuffle=True)
skf.get_n_splits(X, Y)
foldNum=0
# Out:
# ['COVID(326).png' 'COVID(377).png' 'COVID(347).png' ...
#  'person975_virus_1650.jpeg' 'person976_bacteria_2901.jpeg'
#  'person974_bacteria_2899.jpeg']
# [0 0 0 ... 2 2 2]

# %%
for train_index, val_index in skf.split(X, Y):
    #First cut all images from validation to train (if any exists)
    transferAllClassBetweenFolders('valid', 'train', 1.0)
    foldNum+=1
    print("Results for fold",foldNum)
    X_train, X_val = X[train_index], X[val_index]
    Y_train, Y_val = Y[train_index], Y[val_index]
    # Move validation images of this fold from train folder to the validation folder
    for eachIndex in range(len(X_val)):
        classLabel=''
        for i in range(len(classLabels)):
          if(Y_val[eachIndex]==i):
              classLabel=classLabels[i]
        #Then, copy the validation images to the validation folder
        shutil.move(sourcePath+'/train/'+classLabel+'/'+X_val[eachIndex], 
                    sourcePath+'/valid/'+classLabel+'/'+X_val[eachIndex])
        
    train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 64, shuffle=True)
    valid_batches = ImageDataGenerator().flow_from_directory(valid_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 64, shuffle=True)
    test_batches = ImageDataGenerator().flow_from_directory(test_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 64, shuffle=False)

    history = model.fit(train_batches, 
                    #steps_per_epoch=sp_epoch, 
                    validation_data=valid_batches, 
                    #validation_steps=10, 
                    epochs=100, 
                    verbose=2)
    
    
    
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Final Cbam model accuracy')
    plt.ylim(0,1.1)
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Final Cbam model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.show()
    test_batches.reset()
    Y_pred = model.predict(test_batches)
    classes = test_batches.classes[test_batches.index_array]
    y_pred = np.argmax(Y_pred, axis=-1)
    print(sum(y_pred==classes)/10000)
    confusion_matrix(test_batches.classes[test_batches.index_array],y_pred)
    #predictions = model.predict(test_batches, verbose=1)
    #yPredictions = np.argmax(predictions, axis=1)
    #print(yPredictions)
    #true_classes = test_batches.classes
    # evaluate validation performance
    print("***Performance on Test Data***")    
    #valAcc, valPrec, valFScore = my_metrics(true_classes, yPredictions)
    valAcc, valPrec, valFScore = my_metrics(classes, y_pred)

    model.evaluate(test_batches)
# Out:
# Results for fold 1
# Found 1822 images belonging to 3 classes.
# Found 473 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.
# Epoch 1/100
# 29/29 - 431s - loss: 1.3197 - accuracy: 0.8502 - val_loss: 26.6236 - val_accuracy: 0.6448 - 431s/epoch - 15s/step
# Epoch 2/100
# 29/29 - 24s - loss: 0.1509 - accuracy: 0.9544 - val_loss: 3.0998 - val_accuracy: 0.7548 - 24s/epoch - 818ms/step
# Epoch 3/100
# 29/29 - 24s - loss: 0.1077 - accuracy: 0.9671 - val_loss: 0.5134 - val_accuracy: 0.8224 - 24s/epoch - 843ms/step
# Epoch 4/100
# 29/29 - 24s - loss: 0.0829 - accuracy: 0.9759 - val_loss: 0.1957 - val_accuracy: 0.9429 - 24s/epoch - 840ms/step
# Epoch 5/100
# 29/29 - 24s - loss: 0.0406 - accuracy: 0.9885 - val_loss: 0.1366 - val_accuracy: 0.9556 - 24s/epoch - 820ms/step
# Epoch 6/100
# 29/29 - 24s - loss: 0.0410 - accuracy: 0.9819 - val_loss: 0.3236 - val_accuracy: 0.8964 - 24s/epoch - 818ms/step
# Epoch 7/100
# 29/29 - 24s - loss: 0.0264 - accuracy: 0.9923 - val_loss: 0.3225 - val_accuracy: 0.8943 - 24s/epoch - 815ms/step
# Epoch 8/100
# 29/29 - 23s - loss: 0.0440 - accuracy: 0.9835 - val_loss: 0.1509 - val_accuracy: 0.9387 - 23s/epoch - 805ms/step
# Epoch 9/100
# 29/29 - 23s - loss: 0.0489 - accuracy: 0.9890 - val_loss: 0.1464 - val_accuracy: 0.9683 - 23s/epoch - 805ms/step
# Epoch 10/100
# 29/29 - 23s - loss: 0.0249 - accuracy: 0.9934 - val_loss: 0.1501 - val_accuracy: 0.9767 - 23s/epoch - 801ms/step
# Epoch 11/100
# 29/29 - 23s - loss: 0.0302 - accuracy: 0.9901 - val_loss: 0.1338 - val_accuracy: 0.9641 - 23s/epoch - 804ms/step
# Epoch 12/100
# 29/29 - 23s - loss: 0.0299 - accuracy: 0.9934 - val_loss: 0.2199 - val_accuracy: 0.9408 - 23s/epoch - 804ms/step
# Epoch 13/100
# 29/29 - 23s - loss: 0.0360 - accuracy: 0.9879 - val_loss: 0.1049 - val_accuracy: 0.9873 - 23s/epoch - 805ms/step
# Epoch 14/100
# 29/29 - 23s - loss: 0.0096 - accuracy: 0.9962 - val_loss: 0.1341 - val_accuracy: 0.9767 - 23s/epoch - 801ms/step
# Epoch 15/100
# 29/29 - 23s - loss: 0.0256 - accuracy: 0.9945 - val_loss: 0.3483 - val_accuracy: 0.9366 - 23s/epoch - 799ms/step
# Epoch 16/100
# 29/29 - 24s - loss: 0.1096 - accuracy: 0.9802 - val_loss: 10.0193 - val_accuracy: 0.5476 - 24s/epoch - 812ms/step
# Epoch 17/100
# 29/29 - 23s - loss: 0.1488 - accuracy: 0.9676 - val_loss: 0.4804 - val_accuracy: 0.9493 - 23s/epoch - 810ms/step
# Epoch 18/100
# 29/29 - 23s - loss: 0.0985 - accuracy: 0.9813 - val_loss: 0.9433 - val_accuracy: 0.8901 - 23s/epoch - 805ms/step
# Epoch 19/100
# 29/29 - 23s - loss: 0.0256 - accuracy: 0.9929 - val_loss: 0.1585 - val_accuracy: 0.9683 - 23s/epoch - 802ms/step
# Epoch 20/100
# 29/29 - 23s - loss: 0.0410 - accuracy: 0.9868 - val_loss: 0.1168 - val_accuracy: 0.9831 - 23s/epoch - 800ms/step
# Epoch 21/100
# 29/29 - 23s - loss: 0.0436 - accuracy: 0.9885 - val_loss: 0.1493 - val_accuracy: 0.9767 - 23s/epoch - 807ms/step
# Epoch 22/100
# 29/29 - 23s - loss: 0.0088 - accuracy: 0.9967 - val_loss: 0.4171 - val_accuracy: 0.9387 - 23s/epoch - 805ms/step
# Epoch 23/100
# 29/29 - 23s - loss: 0.0145 - accuracy: 0.9962 - val_loss: 0.2471 - val_accuracy: 0.9387 - 23s/epoch - 808ms/step
# Epoch 24/100
# 29/29 - 23s - loss: 0.0079 - accuracy: 0.9967 - val_loss: 0.0920 - val_accuracy: 0.9789 - 23s/epoch - 803ms/step
# Epoch 25/100
# 29/29 - 23s - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.1174 - val_accuracy: 0.9767 - 23s/epoch - 808ms/step
# Epoch 26/100
# 29/29 - 24s - loss: 0.0031 - accuracy: 0.9984 - val_loss: 0.2155 - val_accuracy: 0.9598 - 24s/epoch - 821ms/step
# Epoch 27/100
# 29/29 - 23s - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.1283 - val_accuracy: 0.9789 - 23s/epoch - 808ms/step
# Epoch 28/100
# 29/29 - 23s - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.2106 - val_accuracy: 0.9767 - 23s/epoch - 800ms/step
# Epoch 29/100
# 29/29 - 23s - loss: 8.2750e-04 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9831 - 23s/epoch - 806ms/step
# Epoch 30/100
# 29/29 - 24s - loss: 0.0024 - accuracy: 0.9989 - val_loss: 0.0906 - val_accuracy: 0.9852 - 24s/epoch - 817ms/step
# Epoch 31/100
# 29/29 - 23s - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.1341 - val_accuracy: 0.9810 - 23s/epoch - 806ms/step
# Epoch 32/100
# 29/29 - 23s - loss: 8.9173e-04 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9810 - 23s/epoch - 807ms/step
# Epoch 33/100
# 29/29 - 23s - loss: 1.6288e-04 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9810 - 23s/epoch - 805ms/step
# Epoch 34/100
# 29/29 - 24s - loss: 3.8158e-04 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9810 - 24s/epoch - 813ms/step
# Epoch 35/100
# 29/29 - 23s - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.1879 - val_accuracy: 0.9704 - 23s/epoch - 801ms/step
# Epoch 36/100
# 29/29 - 23s - loss: 0.0218 - accuracy: 0.9929 - val_loss: 2.0728 - val_accuracy: 0.8161 - 23s/epoch - 809ms/step
# Epoch 37/100
# 29/29 - 23s - loss: 0.0478 - accuracy: 0.9907 - val_loss: 0.2379 - val_accuracy: 0.9704 - 23s/epoch - 805ms/step
# Epoch 38/100
# 29/29 - 23s - loss: 0.0292 - accuracy: 0.9923 - val_loss: 0.8503 - val_accuracy: 0.9006 - 23s/epoch - 805ms/step
# Epoch 39/100
# 29/29 - 23s - loss: 0.0272 - accuracy: 0.9918 - val_loss: 2.2196 - val_accuracy: 0.5624 - 23s/epoch - 804ms/step
# Epoch 40/100
# 29/29 - 23s - loss: 0.1090 - accuracy: 0.9764 - val_loss: 0.4761 - val_accuracy: 0.9598 - 23s/epoch - 809ms/step
# Epoch 41/100
# 29/29 - 23s - loss: 0.0130 - accuracy: 0.9956 - val_loss: 0.4240 - val_accuracy: 0.9683 - 23s/epoch - 810ms/step
# Epoch 42/100
# 29/29 - 23s - loss: 0.0728 - accuracy: 0.9918 - val_loss: 0.4202 - val_accuracy: 0.9514 - 23s/epoch - 808ms/step
# Epoch 43/100
# 29/29 - 24s - loss: 1.0990 - accuracy: 0.9072 - val_loss: 4.2219 - val_accuracy: 0.9154 - 24s/epoch - 838ms/step
# Epoch 44/100
# 29/29 - 24s - loss: 0.1547 - accuracy: 0.9649 - val_loss: 12.3166 - val_accuracy: 0.8224 - 24s/epoch - 835ms/step
# Epoch 45/100
# 29/29 - 24s - loss: 0.0971 - accuracy: 0.9715 - val_loss: 2.5549 - val_accuracy: 0.8879 - 24s/epoch - 812ms/step
# Epoch 46/100
# 29/29 - 24s - loss: 0.0675 - accuracy: 0.9846 - val_loss: 0.5448 - val_accuracy: 0.9471 - 24s/epoch - 823ms/step
# Epoch 47/100
# 29/29 - 24s - loss: 0.0237 - accuracy: 0.9912 - val_loss: 0.3868 - val_accuracy: 0.9704 - 24s/epoch - 816ms/step
# Epoch 48/100
# 29/29 - 23s - loss: 0.0121 - accuracy: 0.9951 - val_loss: 0.4028 - val_accuracy: 0.9725 - 23s/epoch - 804ms/step
# Epoch 49/100
# 29/29 - 23s - loss: 0.0127 - accuracy: 0.9951 - val_loss: 0.3318 - val_accuracy: 0.9683 - 23s/epoch - 806ms/step
# Epoch 50/100
# 29/29 - 23s - loss: 0.0125 - accuracy: 0.9962 - val_loss: 0.3644 - val_accuracy: 0.9746 - 23s/epoch - 806ms/step
# Epoch 51/100
# 29/29 - 23s - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.3886 - val_accuracy: 0.9767 - 23s/epoch - 804ms/step
# Epoch 52/100
# 29/29 - 24s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.3920 - val_accuracy: 0.9767 - 24s/epoch - 811ms/step
# Epoch 53/100
# 29/29 - 23s - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.3929 - val_accuracy: 0.9725 - 23s/epoch - 801ms/step
# Epoch 54/100
# 29/29 - 23s - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.4133 - val_accuracy: 0.9725 - 23s/epoch - 803ms/step
# Epoch 55/100
# 29/29 - 23s - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.3916 - val_accuracy: 0.9746 - 23s/epoch - 798ms/step
# Epoch 56/100
# 29/29 - 23s - loss: 0.0049 - accuracy: 0.9978 - val_loss: 0.3802 - val_accuracy: 0.9767 - 23s/epoch - 810ms/step
# Epoch 57/100
# 29/29 - 23s - loss: 0.0064 - accuracy: 0.9989 - val_loss: 0.4024 - val_accuracy: 0.9725 - 23s/epoch - 806ms/step
# Epoch 58/100
# 29/29 - 23s - loss: 0.0094 - accuracy: 0.9967 - val_loss: 0.3174 - val_accuracy: 0.9683 - 23s/epoch - 803ms/step
# Epoch 59/100
# 29/29 - 23s - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.3403 - val_accuracy: 0.9725 - 23s/epoch - 798ms/step
# Epoch 60/100
# 29/29 - 23s - loss: 0.0089 - accuracy: 0.9967 - val_loss: 0.4792 - val_accuracy: 0.9704 - 23s/epoch - 804ms/step
# Epoch 61/100
# 29/29 - 23s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.3917 - val_accuracy: 0.9704 - 23s/epoch - 802ms/step
# Epoch 62/100
# 29/29 - 23s - loss: 0.0023 - accuracy: 0.9989 - val_loss: 0.3994 - val_accuracy: 0.9725 - 23s/epoch - 799ms/step
# Epoch 63/100
# 29/29 - 23s - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.3529 - val_accuracy: 0.9725 - 23s/epoch - 801ms/step
# Epoch 64/100
# 29/29 - 23s - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.3901 - val_accuracy: 0.9704 - 23s/epoch - 802ms/step
# Epoch 65/100
# 29/29 - 23s - loss: 0.0033 - accuracy: 0.9984 - val_loss: 0.2663 - val_accuracy: 0.9789 - 23s/epoch - 798ms/step
# Epoch 66/100
# 29/29 - 23s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2774 - val_accuracy: 0.9746 - 23s/epoch - 797ms/step
# Epoch 67/100
# 29/29 - 23s - loss: 7.2456e-04 - accuracy: 1.0000 - val_loss: 0.3498 - val_accuracy: 0.9683 - 23s/epoch - 804ms/step
# Epoch 68/100
# 29/29 - 23s - loss: 0.0130 - accuracy: 0.9967 - val_loss: 0.3410 - val_accuracy: 0.9746 - 23s/epoch - 801ms/step
# Epoch 69/100
# 29/29 - 23s - loss: 0.0037 - accuracy: 0.9978 - val_loss: 0.2970 - val_accuracy: 0.9789 - 23s/epoch - 805ms/step
# Epoch 70/100
# 29/29 - 23s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.2817 - val_accuracy: 0.9810 - 23s/epoch - 806ms/step
# Epoch 71/100
# 29/29 - 23s - loss: 0.0044 - accuracy: 0.9973 - val_loss: 0.3748 - val_accuracy: 0.9641 - 23s/epoch - 801ms/step
# Epoch 72/100
# 29/29 - 23s - loss: 6.6872e-04 - accuracy: 1.0000 - val_loss: 0.3237 - val_accuracy: 0.9746 - 23s/epoch - 803ms/step
# Epoch 73/100
# 29/29 - 23s - loss: 0.0020 - accuracy: 0.9984 - val_loss: 0.3376 - val_accuracy: 0.9704 - 23s/epoch - 803ms/step
# Epoch 74/100
# 29/29 - 23s - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.2626 - val_accuracy: 0.9767 - 23s/epoch - 803ms/step
# Epoch 75/100
# 29/29 - 23s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.2820 - val_accuracy: 0.9789 - 23s/epoch - 802ms/step
# Epoch 76/100
# 29/29 - 23s - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.3097 - val_accuracy: 0.9810 - 23s/epoch - 800ms/step
# Epoch 77/100
# 29/29 - 23s - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.3254 - val_accuracy: 0.9810 - 23s/epoch - 803ms/step
# Epoch 78/100
# 29/29 - 23s - loss: 0.0050 - accuracy: 0.9978 - val_loss: 0.3472 - val_accuracy: 0.9767 - 23s/epoch - 799ms/step
# Epoch 79/100
# 29/29 - 23s - loss: 0.0015 - accuracy: 0.9989 - val_loss: 0.3055 - val_accuracy: 0.9767 - 23s/epoch - 800ms/step
# Epoch 80/100
# 29/29 - 23s - loss: 0.0044 - accuracy: 0.9995 - val_loss: 0.4373 - val_accuracy: 0.9767 - 23s/epoch - 804ms/step
# Epoch 81/100
# 29/29 - 23s - loss: 0.0095 - accuracy: 0.9973 - val_loss: 0.4131 - val_accuracy: 0.9767 - 23s/epoch - 803ms/step
# Epoch 82/100
# 29/29 - 23s - loss: 0.0042 - accuracy: 0.9978 - val_loss: 0.3471 - val_accuracy: 0.9810 - 23s/epoch - 801ms/step
# Epoch 83/100
# 29/29 - 23s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.3568 - val_accuracy: 0.9789 - 23s/epoch - 809ms/step
# Epoch 84/100
# 29/29 - 23s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.4197 - val_accuracy: 0.9725 - 23s/epoch - 803ms/step
# Epoch 85/100
# 29/29 - 23s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.3301 - val_accuracy: 0.9789 - 23s/epoch - 807ms/step
# Epoch 86/100
# 29/29 - 24s - loss: 0.0042 - accuracy: 0.9984 - val_loss: 0.3952 - val_accuracy: 0.9704 - 24s/epoch - 811ms/step
# Epoch 87/100
# 29/29 - 23s - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.3730 - val_accuracy: 0.9789 - 23s/epoch - 802ms/step
# Epoch 88/100
# 29/29 - 23s - loss: 0.0031 - accuracy: 0.9978 - val_loss: 0.3604 - val_accuracy: 0.9789 - 23s/epoch - 806ms/step
# Epoch 89/100
# 29/29 - 23s - loss: 0.0255 - accuracy: 0.9978 - val_loss: 0.2976 - val_accuracy: 0.9810 - 23s/epoch - 801ms/step
# Epoch 90/100
# 29/29 - 23s - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.3538 - val_accuracy: 0.9704 - 23s/epoch - 799ms/step
# Epoch 91/100
# 29/29 - 23s - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.3647 - val_accuracy: 0.9789 - 23s/epoch - 800ms/step
# Epoch 92/100
# 29/29 - 23s - loss: 9.7921e-04 - accuracy: 0.9995 - val_loss: 0.3770 - val_accuracy: 0.9767 - 23s/epoch - 802ms/step
# Epoch 93/100
# 29/29 - 23s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.3651 - val_accuracy: 0.9810 - 23s/epoch - 800ms/step
# Epoch 94/100
# 29/29 - 23s - loss: 2.5982e-04 - accuracy: 1.0000 - val_loss: 0.3602 - val_accuracy: 0.9789 - 23s/epoch - 797ms/step
# Epoch 95/100
# 29/29 - 23s - loss: 3.4648e-04 - accuracy: 1.0000 - val_loss: 0.3673 - val_accuracy: 0.9810 - 23s/epoch - 803ms/step
# Epoch 96/100
# 29/29 - 23s - loss: 6.0270e-04 - accuracy: 1.0000 - val_loss: 0.3507 - val_accuracy: 0.9810 - 23s/epoch - 807ms/step
# Epoch 97/100
# 29/29 - 23s - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.3541 - val_accuracy: 0.9831 - 23s/epoch - 801ms/step
# Epoch 98/100
# 29/29 - 24s - loss: 3.9194e-04 - accuracy: 1.0000 - val_loss: 0.3606 - val_accuracy: 0.9810 - 24s/epoch - 812ms/step
# Epoch 99/100
# 29/29 - 23s - loss: 9.6144e-05 - accuracy: 1.0000 - val_loss: 0.3668 - val_accuracy: 0.9810 - 23s/epoch - 808ms/step
# Epoch 100/100
# 29/29 - 23s - loss: 8.0841e-04 - accuracy: 1.0000 - val_loss: 0.3927 - val_accuracy: 0.9831 - 23s/epoch - 800ms/step
# 0.0384
# ***Performance on Test Data***
# Accuracy  : 0.9481481481481482
# Precision : 0.9481844888804817
# f1Score : 0.9480291699782031
# [[131   0   4]
#  [  1 130   4]
#  [  3   9 123]]
# 7/7 [==============================] - 4s 601ms/step - loss: 0.6346 - accuracy: 0.9481
# Results for fold 2
# Found 1822 images belonging to 3 classes.
# Found 473 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.
# Epoch 1/100
# 29/29 - 25s - loss: 0.1834 - accuracy: 0.9874 - val_loss: 0.0867 - val_accuracy: 0.9746 - 25s/epoch - 846ms/step
# Epoch 2/100
# 29/29 - 23s - loss: 0.0492 - accuracy: 0.9868 - val_loss: 0.0394 - val_accuracy: 0.9831 - 23s/epoch - 808ms/step
# Epoch 3/100
# 29/29 - 23s - loss: 0.0283 - accuracy: 0.9885 - val_loss: 0.1331 - val_accuracy: 0.9662 - 23s/epoch - 807ms/step
# Epoch 4/100
# 29/29 - 24s - loss: 0.0103 - accuracy: 0.9956 - val_loss: 0.2323 - val_accuracy: 0.9598 - 24s/epoch - 813ms/step
# Epoch 5/100
# 29/29 - 24s - loss: 0.0033 - accuracy: 0.9984 - val_loss: 0.1037 - val_accuracy: 0.9683 - 24s/epoch - 820ms/step
# Epoch 6/100
# 29/29 - 23s - loss: 0.0145 - accuracy: 0.9945 - val_loss: 0.0575 - val_accuracy: 0.9789 - 23s/epoch - 803ms/step
# Epoch 7/100
# 29/29 - 23s - loss: 0.0085 - accuracy: 0.9967 - val_loss: 0.0915 - val_accuracy: 0.9683 - 23s/epoch - 809ms/step
# Epoch 8/100
# 29/29 - 23s - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0449 - val_accuracy: 0.9873 - 23s/epoch - 809ms/step
# Epoch 9/100
# 29/29 - 24s - loss: 0.0033 - accuracy: 0.9984 - val_loss: 0.1998 - val_accuracy: 0.9810 - 24s/epoch - 811ms/step
# Epoch 10/100
# 29/29 - 23s - loss: 0.0019 - accuracy: 0.9989 - val_loss: 0.0962 - val_accuracy: 0.9683 - 23s/epoch - 809ms/step
# Epoch 11/100
# 29/29 - 23s - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.1579 - val_accuracy: 0.9493 - 23s/epoch - 804ms/step
# Epoch 12/100
# 29/29 - 24s - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.1245 - val_accuracy: 0.9619 - 24s/epoch - 811ms/step
# Epoch 13/100
# 29/29 - 23s - loss: 0.0081 - accuracy: 0.9984 - val_loss: 0.0829 - val_accuracy: 0.9746 - 23s/epoch - 803ms/step
# Epoch 14/100
# 29/29 - 24s - loss: 0.0045 - accuracy: 0.9984 - val_loss: 0.4211 - val_accuracy: 0.9767 - 24s/epoch - 812ms/step
# Epoch 15/100
# 29/29 - 23s - loss: 0.0082 - accuracy: 0.9978 - val_loss: 0.0057 - val_accuracy: 1.0000 - 23s/epoch - 809ms/step
# Epoch 16/100
# 29/29 - 23s - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0141 - val_accuracy: 0.9958 - 23s/epoch - 797ms/step
# Epoch 17/100
# 29/29 - 23s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0051 - val_accuracy: 1.0000 - 23s/epoch - 802ms/step
# Epoch 18/100
# 29/29 - 24s - loss: 0.0022 - accuracy: 0.9989 - val_loss: 0.1383 - val_accuracy: 0.9662 - 24s/epoch - 813ms/step
# Epoch 19/100
# 29/29 - 23s - loss: 2.9504e-04 - accuracy: 1.0000 - val_loss: 0.1186 - val_accuracy: 0.9683 - 23s/epoch - 805ms/step
# Epoch 20/100
# 29/29 - 23s - loss: 6.8340e-04 - accuracy: 0.9995 - val_loss: 0.0570 - val_accuracy: 0.9810 - 23s/epoch - 804ms/step
# Epoch 21/100
# 29/29 - 23s - loss: 0.0019 - accuracy: 0.9989 - val_loss: 0.0500 - val_accuracy: 0.9852 - 23s/epoch - 802ms/step
# Epoch 22/100
# 29/29 - 23s - loss: 1.5041e-04 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9852 - 23s/epoch - 804ms/step
# Epoch 23/100
# 29/29 - 23s - loss: 3.1753e-04 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9873 - 23s/epoch - 799ms/step
# Epoch 24/100
# 29/29 - 24s - loss: 3.6878e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000 - 24s/epoch - 813ms/step
# Epoch 25/100
# 29/29 - 23s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0162 - val_accuracy: 0.9937 - 23s/epoch - 804ms/step
# Epoch 26/100
# 29/29 - 23s - loss: 3.7035e-04 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000 - 23s/epoch - 807ms/step
# Epoch 27/100
# 29/29 - 24s - loss: 0.0059 - accuracy: 0.9967 - val_loss: 1.2047 - val_accuracy: 0.8436 - 24s/epoch - 834ms/step
# Epoch 28/100
# 29/29 - 25s - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.1849 - val_accuracy: 0.9577 - 25s/epoch - 849ms/step
# Epoch 29/100
# 29/29 - 24s - loss: 0.0031 - accuracy: 0.9984 - val_loss: 0.2176 - val_accuracy: 0.9281 - 24s/epoch - 824ms/step
# Epoch 30/100
# 29/29 - 24s - loss: 0.0016 - accuracy: 0.9989 - val_loss: 0.1728 - val_accuracy: 0.9345 - 24s/epoch - 812ms/step
# Epoch 31/100
# 29/29 - 25s - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.1877 - val_accuracy: 0.9366 - 25s/epoch - 851ms/step
# Epoch 32/100
# 29/29 - 24s - loss: 9.8639e-04 - accuracy: 0.9995 - val_loss: 0.2311 - val_accuracy: 0.9323 - 24s/epoch - 826ms/step
# Epoch 33/100
# 29/29 - 25s - loss: 6.4305e-04 - accuracy: 1.0000 - val_loss: 0.1754 - val_accuracy: 0.9556 - 25s/epoch - 849ms/step
# Epoch 34/100
# 29/29 - 24s - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.0605 - val_accuracy: 0.9852 - 24s/epoch - 841ms/step
# Epoch 35/100
# 29/29 - 24s - loss: 0.0026 - accuracy: 0.9984 - val_loss: 0.2257 - val_accuracy: 0.9619 - 24s/epoch - 828ms/step
# Epoch 36/100
# 29/29 - 24s - loss: 0.0023 - accuracy: 0.9989 - val_loss: 5.9726 - val_accuracy: 0.7886 - 24s/epoch - 833ms/step
# Epoch 37/100
# 29/29 - 24s - loss: 0.0265 - accuracy: 0.9962 - val_loss: 0.0995 - val_accuracy: 0.9831 - 24s/epoch - 838ms/step
# Epoch 38/100
# 29/29 - 25s - loss: 0.0047 - accuracy: 0.9978 - val_loss: 1.7900 - val_accuracy: 0.8626 - 25s/epoch - 848ms/step
# Epoch 39/100
# 29/29 - 24s - loss: 0.0102 - accuracy: 0.9978 - val_loss: 7.1432 - val_accuracy: 0.7738 - 24s/epoch - 828ms/step
# Epoch 40/100
# 29/29 - 24s - loss: 0.0099 - accuracy: 0.9967 - val_loss: 0.1871 - val_accuracy: 0.9767 - 24s/epoch - 822ms/step
# Epoch 41/100
# 29/29 - 24s - loss: 0.0063 - accuracy: 0.9989 - val_loss: 0.0886 - val_accuracy: 0.9789 - 24s/epoch - 825ms/step
# Epoch 42/100
# 29/29 - 24s - loss: 0.0035 - accuracy: 0.9978 - val_loss: 0.1035 - val_accuracy: 0.9746 - 24s/epoch - 842ms/step
# Epoch 43/100
# 29/29 - 24s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9641 - 24s/epoch - 820ms/step
# Epoch 44/100
# 29/29 - 24s - loss: 0.0152 - accuracy: 0.9984 - val_loss: 0.1173 - val_accuracy: 0.9662 - 24s/epoch - 814ms/step
# Epoch 45/100
# 29/29 - 24s - loss: 8.5306e-04 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9725 - 24s/epoch - 812ms/step
# Epoch 46/100
# 29/29 - 23s - loss: 2.1485e-04 - accuracy: 1.0000 - val_loss: 0.2539 - val_accuracy: 0.9556 - 23s/epoch - 810ms/step
# Epoch 47/100
# 29/29 - 24s - loss: 2.7611e-04 - accuracy: 1.0000 - val_loss: 0.2832 - val_accuracy: 0.9514 - 24s/epoch - 814ms/step
# Epoch 48/100
# 29/29 - 24s - loss: 0.0012 - accuracy: 0.9989 - val_loss: 0.0563 - val_accuracy: 0.9873 - 24s/epoch - 813ms/step
# Epoch 49/100
# 29/29 - 24s - loss: 7.2002e-04 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9725 - 24s/epoch - 835ms/step
# Epoch 50/100
# 29/29 - 24s - loss: 0.0016 - accuracy: 0.9989 - val_loss: 0.3115 - val_accuracy: 0.9598 - 24s/epoch - 814ms/step
# Epoch 51/100
# 29/29 - 23s - loss: 0.0051 - accuracy: 0.9978 - val_loss: 0.0929 - val_accuracy: 0.9704 - 23s/epoch - 807ms/step
# Epoch 52/100
# 29/29 - 24s - loss: 0.0162 - accuracy: 0.9945 - val_loss: 0.0348 - val_accuracy: 0.9852 - 24s/epoch - 835ms/step
# Epoch 53/100
# 29/29 - 23s - loss: 0.0025 - accuracy: 0.9984 - val_loss: 0.0435 - val_accuracy: 0.9873 - 23s/epoch - 804ms/step
# Epoch 54/100
# 29/29 - 24s - loss: 5.7680e-04 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9937 - 24s/epoch - 811ms/step
# Epoch 55/100
# 29/29 - 24s - loss: 0.0017 - accuracy: 0.9989 - val_loss: 0.0823 - val_accuracy: 0.9767 - 24s/epoch - 811ms/step
# Epoch 56/100
# 29/29 - 24s - loss: 1.8345e-04 - accuracy: 1.0000 - val_loss: 0.0772 - val_accuracy: 0.9789 - 24s/epoch - 828ms/step
# Epoch 57/100
# 29/29 - 24s - loss: 1.1284e-04 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 0.9831 - 24s/epoch - 833ms/step
# Epoch 58/100
# 29/29 - 24s - loss: 2.6482e-05 - accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 0.9873 - 24s/epoch - 826ms/step
# Epoch 59/100
# 29/29 - 24s - loss: 7.4331e-05 - accuracy: 1.0000 - val_loss: 0.0454 - val_accuracy: 0.9873 - 24s/epoch - 824ms/step
# Epoch 60/100
# 29/29 - 24s - loss: 1.8315e-04 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9852 - 24s/epoch - 821ms/step
# Epoch 61/100
# 29/29 - 23s - loss: 9.9659e-05 - accuracy: 1.0000 - val_loss: 0.0678 - val_accuracy: 0.9810 - 23s/epoch - 809ms/step
# Epoch 62/100
# 29/29 - 23s - loss: 4.9973e-04 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9767 - 23s/epoch - 803ms/step
# Epoch 63/100
# 29/29 - 23s - loss: 6.7416e-04 - accuracy: 0.9995 - val_loss: 0.0641 - val_accuracy: 0.9937 - 23s/epoch - 806ms/step
# Epoch 64/100
# 29/29 - 23s - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0500 - val_accuracy: 0.9937 - 23s/epoch - 809ms/step
# Epoch 65/100
# 29/29 - 23s - loss: 1.8338e-04 - accuracy: 1.0000 - val_loss: 0.0357 - val_accuracy: 0.9915 - 23s/epoch - 808ms/step
# Epoch 66/100
# 29/29 - 23s - loss: 2.2536e-04 - accuracy: 1.0000 - val_loss: 0.0496 - val_accuracy: 0.9915 - 23s/epoch - 805ms/step
# Epoch 67/100
# 29/29 - 23s - loss: 1.5349e-04 - accuracy: 1.0000 - val_loss: 0.0561 - val_accuracy: 0.9915 - 23s/epoch - 807ms/step
# Epoch 68/100
# 29/29 - 24s - loss: 5.1437e-04 - accuracy: 1.0000 - val_loss: 0.0681 - val_accuracy: 0.9937 - 24s/epoch - 813ms/step
# Epoch 69/100
# 29/29 - 23s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 2.0121 - val_accuracy: 0.9133 - 23s/epoch - 809ms/step
# Epoch 70/100
# 29/29 - 24s - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.3668 - val_accuracy: 0.9429 - 24s/epoch - 817ms/step
# Epoch 71/100
# 29/29 - 23s - loss: 0.0139 - accuracy: 0.9967 - val_loss: 0.0847 - val_accuracy: 0.9873 - 23s/epoch - 810ms/step
# Epoch 72/100
# 29/29 - 24s - loss: 0.0060 - accuracy: 0.9973 - val_loss: 0.9349 - val_accuracy: 0.9070 - 24s/epoch - 811ms/step
# Epoch 73/100
# 29/29 - 23s - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.2229 - val_accuracy: 0.9683 - 23s/epoch - 806ms/step
# Epoch 74/100
# 29/29 - 23s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.1083 - val_accuracy: 0.9831 - 23s/epoch - 807ms/step
# Epoch 75/100
# 29/29 - 23s - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0242 - val_accuracy: 0.9937 - 23s/epoch - 808ms/step
# Epoch 76/100
# 29/29 - 23s - loss: 0.0278 - accuracy: 0.9978 - val_loss: 0.0851 - val_accuracy: 0.9873 - 23s/epoch - 805ms/step
# Epoch 77/100
# 29/29 - 23s - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0867 - val_accuracy: 0.9873 - 23s/epoch - 807ms/step
# Epoch 78/100
# 29/29 - 24s - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.1980 - val_accuracy: 0.9619 - 24s/epoch - 814ms/step
# Epoch 79/100
# 29/29 - 24s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0694 - val_accuracy: 0.9789 - 24s/epoch - 828ms/step
# Epoch 80/100
# 29/29 - 24s - loss: 0.0321 - accuracy: 0.9945 - val_loss: 0.1980 - val_accuracy: 0.9662 - 24s/epoch - 829ms/step
# Epoch 81/100
# 29/29 - 24s - loss: 0.0270 - accuracy: 0.9934 - val_loss: 1.0602 - val_accuracy: 0.9112 - 24s/epoch - 829ms/step
# Epoch 82/100
# 29/29 - 24s - loss: 0.0278 - accuracy: 0.9945 - val_loss: 1.5224 - val_accuracy: 0.8753 - 24s/epoch - 822ms/step
# Epoch 83/100
# 29/29 - 24s - loss: 0.0320 - accuracy: 0.9934 - val_loss: 0.1709 - val_accuracy: 0.9662 - 24s/epoch - 828ms/step
# Epoch 84/100
# 29/29 - 24s - loss: 0.0306 - accuracy: 0.9934 - val_loss: 0.8823 - val_accuracy: 0.9281 - 24s/epoch - 820ms/step
# Epoch 85/100
# 29/29 - 24s - loss: 0.0135 - accuracy: 0.9967 - val_loss: 0.2242 - val_accuracy: 0.9598 - 24s/epoch - 811ms/step
# Epoch 86/100
# 29/29 - 23s - loss: 0.0018 - accuracy: 0.9989 - val_loss: 0.2186 - val_accuracy: 0.9704 - 23s/epoch - 806ms/step
# Epoch 87/100
# 29/29 - 23s - loss: 0.0143 - accuracy: 0.9962 - val_loss: 0.1121 - val_accuracy: 0.9641 - 23s/epoch - 803ms/step
# Epoch 88/100
# 29/29 - 23s - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.2592 - val_accuracy: 0.9683 - 23s/epoch - 808ms/step
# Epoch 89/100
# 29/29 - 23s - loss: 0.0228 - accuracy: 0.9951 - val_loss: 0.6123 - val_accuracy: 0.9514 - 23s/epoch - 805ms/step
# Epoch 90/100
# 29/29 - 24s - loss: 0.0139 - accuracy: 0.9984 - val_loss: 0.1346 - val_accuracy: 0.9789 - 24s/epoch - 811ms/step
# Epoch 91/100
# 29/29 - 23s - loss: 0.0247 - accuracy: 0.9967 - val_loss: 0.2041 - val_accuracy: 0.9746 - 23s/epoch - 810ms/step
# Epoch 92/100
# 29/29 - 23s - loss: 0.0046 - accuracy: 0.9978 - val_loss: 0.2971 - val_accuracy: 0.9662 - 23s/epoch - 807ms/step
# Epoch 93/100
# 29/29 - 24s - loss: 0.0107 - accuracy: 0.9978 - val_loss: 0.1788 - val_accuracy: 0.9767 - 24s/epoch - 811ms/step
# Epoch 94/100
# 29/29 - 23s - loss: 0.0168 - accuracy: 0.9967 - val_loss: 0.5367 - val_accuracy: 0.7611 - 23s/epoch - 810ms/step
# Epoch 95/100
# 29/29 - 24s - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.1999 - val_accuracy: 0.9197 - 24s/epoch - 811ms/step
# Epoch 96/100
# 29/29 - 24s - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.1112 - val_accuracy: 0.9471 - 24s/epoch - 811ms/step
# Epoch 97/100
# 29/29 - 24s - loss: 5.4372e-04 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9725 - 24s/epoch - 820ms/step
# Epoch 98/100
# 29/29 - 24s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 0.9725 - 24s/epoch - 811ms/step
# Epoch 99/100
# 29/29 - 24s - loss: 0.0096 - accuracy: 0.9984 - val_loss: 0.1643 - val_accuracy: 0.9852 - 24s/epoch - 816ms/step
# Epoch 100/100
# 29/29 - 23s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.1581 - val_accuracy: 0.9767 - 23s/epoch - 807ms/step
# 0.0383
# ***Performance on Test Data***
# Accuracy  : 0.945679012345679
# Precision : 0.9478433402346446
# f1Score : 0.9450894815100072
# [[133   0   2]
#  [  1 133   1]
#  [  4  14 117]]
# 7/7 [==============================] - 4s 625ms/step - loss: 0.6151 - accuracy: 0.9457
# Results for fold 3
# Found 1823 images belonging to 3 classes.
# Found 472 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.
# Epoch 1/100
# 29/29 - 25s - loss: 0.0611 - accuracy: 0.9923 - val_loss: 0.0341 - val_accuracy: 0.9873 - 25s/epoch - 862ms/step
# Epoch 2/100
# 29/29 - 24s - loss: 0.0089 - accuracy: 0.9962 - val_loss: 0.0977 - val_accuracy: 0.9640 - 24s/epoch - 838ms/step
# Epoch 3/100
# 29/29 - 24s - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.1292 - val_accuracy: 0.9449 - 24s/epoch - 818ms/step
# Epoch 4/100
# 29/29 - 24s - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0361 - val_accuracy: 0.9894 - 24s/epoch - 818ms/step
# Epoch 5/100
# 29/29 - 24s - loss: 0.0341 - accuracy: 0.9934 - val_loss: 0.0391 - val_accuracy: 0.9873 - 24s/epoch - 813ms/step
# Epoch 6/100
# 29/29 - 24s - loss: 0.0274 - accuracy: 0.9923 - val_loss: 0.1240 - val_accuracy: 0.9492 - 24s/epoch - 811ms/step
# Epoch 7/100
# 29/29 - 24s - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.0046 - val_accuracy: 1.0000 - 24s/epoch - 810ms/step
# Epoch 8/100
# 29/29 - 24s - loss: 0.0145 - accuracy: 0.9978 - val_loss: 0.0097 - val_accuracy: 0.9958 - 24s/epoch - 813ms/step
# Epoch 9/100
# 29/29 - 24s - loss: 0.0084 - accuracy: 0.9978 - val_loss: 0.0036 - val_accuracy: 1.0000 - 24s/epoch - 824ms/step
# Epoch 10/100
# 29/29 - 24s - loss: 0.0038 - accuracy: 0.9989 - val_loss: 3.3068e-04 - val_accuracy: 1.0000 - 24s/epoch - 814ms/step
# Epoch 11/100
# 29/29 - 24s - loss: 9.4925e-04 - accuracy: 0.9995 - val_loss: 7.2301e-05 - val_accuracy: 1.0000 - 24s/epoch - 819ms/step
# Epoch 12/100
# 29/29 - 24s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 2.4591e-04 - val_accuracy: 1.0000 - 24s/epoch - 815ms/step
# Epoch 13/100
# 29/29 - 24s - loss: 9.9860e-04 - accuracy: 0.9995 - val_loss: 5.1356e-05 - val_accuracy: 1.0000 - 24s/epoch - 812ms/step
# Epoch 14/100
# 29/29 - 24s - loss: 3.0184e-04 - accuracy: 1.0000 - val_loss: 3.0010e-05 - val_accuracy: 1.0000 - 24s/epoch - 814ms/step
# Epoch 15/100
# 29/29 - 24s - loss: 7.6486e-05 - accuracy: 1.0000 - val_loss: 2.4534e-05 - val_accuracy: 1.0000 - 24s/epoch - 815ms/step
# Epoch 16/100
# 29/29 - 24s - loss: 0.0030 - accuracy: 0.9984 - val_loss: 7.6696e-05 - val_accuracy: 1.0000 - 24s/epoch - 819ms/step
# Epoch 17/100
# 29/29 - 23s - loss: 0.0120 - accuracy: 0.9973 - val_loss: 0.0070 - val_accuracy: 0.9979 - 23s/epoch - 810ms/step
# Epoch 18/100
# 29/29 - 24s - loss: 0.0481 - accuracy: 0.9967 - val_loss: 0.2071 - val_accuracy: 0.9788 - 24s/epoch - 822ms/step
# Epoch 19/100
# 29/29 - 24s - loss: 0.0486 - accuracy: 0.9912 - val_loss: 0.6565 - val_accuracy: 0.7839 - 24s/epoch - 812ms/step
# Epoch 20/100
# 29/29 - 24s - loss: 0.0179 - accuracy: 0.9923 - val_loss: 0.6616 - val_accuracy: 0.8390 - 24s/epoch - 816ms/step
# Epoch 21/100
# 29/29 - 24s - loss: 0.0255 - accuracy: 0.9929 - val_loss: 0.3045 - val_accuracy: 0.9047 - 24s/epoch - 814ms/step
# Epoch 22/100
# 29/29 - 24s - loss: 0.0145 - accuracy: 0.9967 - val_loss: 0.4129 - val_accuracy: 0.8559 - 24s/epoch - 816ms/step
# Epoch 23/100
# 29/29 - 24s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.4870 - val_accuracy: 0.8835 - 24s/epoch - 818ms/step
# Epoch 24/100
# 29/29 - 24s - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.0821 - val_accuracy: 0.9640 - 24s/epoch - 812ms/step
# Epoch 25/100
# 29/29 - 24s - loss: 0.0142 - accuracy: 0.9978 - val_loss: 0.3606 - val_accuracy: 0.8496 - 24s/epoch - 813ms/step
# Epoch 26/100
# 29/29 - 24s - loss: 0.0137 - accuracy: 0.9962 - val_loss: 0.3807 - val_accuracy: 0.8708 - 24s/epoch - 813ms/step
# Epoch 27/100
# 29/29 - 24s - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.1164 - val_accuracy: 0.9640 - 24s/epoch - 811ms/step
# Epoch 28/100
# 29/29 - 24s - loss: 0.0134 - accuracy: 0.9984 - val_loss: 0.1818 - val_accuracy: 0.9576 - 24s/epoch - 813ms/step
# Epoch 29/100
# 29/29 - 24s - loss: 0.0594 - accuracy: 0.9984 - val_loss: 9.3710 - val_accuracy: 0.6653 - 24s/epoch - 822ms/step
# Epoch 30/100
# 29/29 - 24s - loss: 0.0931 - accuracy: 0.9945 - val_loss: 5.4199 - val_accuracy: 0.8644 - 24s/epoch - 833ms/step
# Epoch 31/100
# 29/29 - 24s - loss: 0.1889 - accuracy: 0.9841 - val_loss: 10.6573 - val_accuracy: 0.7987 - 24s/epoch - 821ms/step
# Epoch 32/100
# 29/29 - 24s - loss: 0.1140 - accuracy: 0.9824 - val_loss: 1.0095 - val_accuracy: 0.9280 - 24s/epoch - 814ms/step
# Epoch 33/100
# 29/29 - 24s - loss: 0.0327 - accuracy: 0.9918 - val_loss: 0.1138 - val_accuracy: 0.9746 - 24s/epoch - 819ms/step
# Epoch 34/100
# 29/29 - 24s - loss: 0.0148 - accuracy: 0.9956 - val_loss: 0.0245 - val_accuracy: 0.9873 - 24s/epoch - 812ms/step
# Epoch 35/100
# 29/29 - 24s - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0156 - val_accuracy: 0.9936 - 24s/epoch - 816ms/step
# Epoch 36/100
# 29/29 - 24s - loss: 0.0097 - accuracy: 0.9978 - val_loss: 0.0276 - val_accuracy: 0.9873 - 24s/epoch - 821ms/step
# Epoch 37/100
# 29/29 - 24s - loss: 0.0055 - accuracy: 0.9973 - val_loss: 0.0945 - val_accuracy: 0.9682 - 24s/epoch - 811ms/step
# Epoch 38/100
# 29/29 - 23s - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.1754 - val_accuracy: 0.9661 - 23s/epoch - 809ms/step
# Epoch 39/100
# 29/29 - 24s - loss: 0.0017 - accuracy: 0.9989 - val_loss: 0.0958 - val_accuracy: 0.9788 - 24s/epoch - 815ms/step
# Epoch 40/100
# 29/29 - 24s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9831 - 24s/epoch - 812ms/step
# Epoch 41/100
# 29/29 - 23s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0872 - val_accuracy: 0.9873 - 23s/epoch - 808ms/step
# Epoch 42/100
# 29/29 - 24s - loss: 4.2047e-04 - accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 0.9873 - 24s/epoch - 825ms/step
# Epoch 43/100
# 29/29 - 24s - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.0557 - val_accuracy: 0.9894 - 24s/epoch - 831ms/step
# Epoch 44/100
# 29/29 - 24s - loss: 0.0077 - accuracy: 0.9995 - val_loss: 0.0518 - val_accuracy: 0.9915 - 24s/epoch - 824ms/step
# Epoch 45/100
# 29/29 - 24s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0099 - val_accuracy: 0.9958 - 24s/epoch - 814ms/step
# Epoch 46/100
# 29/29 - 24s - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0036 - val_accuracy: 0.9979 - 24s/epoch - 824ms/step
# Epoch 47/100
# 29/29 - 24s - loss: 2.6866e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - 24s/epoch - 831ms/step
# Epoch 48/100
# 29/29 - 24s - loss: 5.2199e-04 - accuracy: 1.0000 - val_loss: 9.2684e-04 - val_accuracy: 1.0000 - 24s/epoch - 829ms/step
# Epoch 49/100
# 29/29 - 24s - loss: 0.0014 - accuracy: 0.9989 - val_loss: 0.0016 - val_accuracy: 1.0000 - 24s/epoch - 840ms/step
# Epoch 50/100
# 29/29 - 24s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 5.2161e-05 - val_accuracy: 1.0000 - 24s/epoch - 834ms/step
# Epoch 51/100
# 29/29 - 24s - loss: 0.0077 - accuracy: 0.9989 - val_loss: 0.1000 - val_accuracy: 0.9894 - 24s/epoch - 834ms/step
# Epoch 52/100
# 29/29 - 24s - loss: 0.0063 - accuracy: 0.9989 - val_loss: 0.0323 - val_accuracy: 0.9936 - 24s/epoch - 829ms/step
# Epoch 53/100
# 29/29 - 24s - loss: 0.0025 - accuracy: 0.9989 - val_loss: 0.0067 - val_accuracy: 0.9979 - 24s/epoch - 840ms/step
# Epoch 54/100
# 29/29 - 24s - loss: 0.0037 - accuracy: 0.9995 - val_loss: 8.9251e-04 - val_accuracy: 1.0000 - 24s/epoch - 831ms/step
# Epoch 55/100
# 29/29 - 24s - loss: 7.1513e-04 - accuracy: 1.0000 - val_loss: 4.5345e-05 - val_accuracy: 1.0000 - 24s/epoch - 835ms/step
# Epoch 56/100
# 29/29 - 24s - loss: 1.3462e-04 - accuracy: 1.0000 - val_loss: 1.9199e-05 - val_accuracy: 1.0000 - 24s/epoch - 838ms/step
# Epoch 57/100
# 29/29 - 25s - loss: 6.6415e-04 - accuracy: 1.0000 - val_loss: 1.2493e-05 - val_accuracy: 1.0000 - 25s/epoch - 868ms/step
# Epoch 58/100
# 29/29 - 25s - loss: 3.4067e-04 - accuracy: 1.0000 - val_loss: 9.9457e-05 - val_accuracy: 1.0000 - 25s/epoch - 847ms/step
# Epoch 59/100
# 29/29 - 25s - loss: 1.5232e-04 - accuracy: 1.0000 - val_loss: 1.0290e-04 - val_accuracy: 1.0000 - 25s/epoch - 848ms/step
# Epoch 60/100
# 29/29 - 25s - loss: 7.2016e-04 - accuracy: 0.9995 - val_loss: 8.4004e-05 - val_accuracy: 1.0000 - 25s/epoch - 845ms/step
# Epoch 61/100
# 29/29 - 24s - loss: 4.6589e-05 - accuracy: 1.0000 - val_loss: 6.6448e-05 - val_accuracy: 1.0000 - 24s/epoch - 835ms/step
# Epoch 62/100
# 29/29 - 24s - loss: 9.5772e-04 - accuracy: 0.9995 - val_loss: 0.0413 - val_accuracy: 0.9809 - 24s/epoch - 828ms/step
# Epoch 63/100
# 29/29 - 24s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.1715 - val_accuracy: 0.9809 - 24s/epoch - 825ms/step
# Epoch 64/100
# 29/29 - 24s - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.0328 - val_accuracy: 0.9958 - 24s/epoch - 825ms/step
# Epoch 65/100
# 29/29 - 24s - loss: 7.8558e-05 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 0.9979 - 24s/epoch - 826ms/step
# Epoch 66/100
# 29/29 - 24s - loss: 8.7782e-04 - accuracy: 0.9995 - val_loss: 2.2652e-04 - val_accuracy: 1.0000 - 24s/epoch - 825ms/step
# Epoch 67/100
# 29/29 - 24s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 2.1545e-04 - val_accuracy: 1.0000 - 24s/epoch - 829ms/step
# Epoch 68/100
# 29/29 - 24s - loss: 2.0451e-04 - accuracy: 1.0000 - val_loss: 1.0228e-04 - val_accuracy: 1.0000 - 24s/epoch - 826ms/step
# Epoch 69/100
# 29/29 - 24s - loss: 7.4931e-05 - accuracy: 1.0000 - val_loss: 8.6489e-05 - val_accuracy: 1.0000 - 24s/epoch - 826ms/step
# Epoch 70/100
# 29/29 - 24s - loss: 3.8625e-05 - accuracy: 1.0000 - val_loss: 6.6198e-05 - val_accuracy: 1.0000 - 24s/epoch - 829ms/step
# Epoch 71/100
# 29/29 - 24s - loss: 1.2817e-04 - accuracy: 1.0000 - val_loss: 6.3580e-05 - val_accuracy: 1.0000 - 24s/epoch - 828ms/step
# Epoch 72/100
# 29/29 - 24s - loss: 1.8406e-04 - accuracy: 1.0000 - val_loss: 5.0020e-05 - val_accuracy: 1.0000 - 24s/epoch - 823ms/step
# Epoch 73/100
# 29/29 - 24s - loss: 3.1064e-04 - accuracy: 1.0000 - val_loss: 1.1302e-04 - val_accuracy: 1.0000 - 24s/epoch - 824ms/step
# Epoch 74/100
# 29/29 - 24s - loss: 6.8136e-04 - accuracy: 0.9995 - val_loss: 0.0351 - val_accuracy: 0.9958 - 24s/epoch - 835ms/step
# Epoch 75/100
# 29/29 - 24s - loss: 4.3939e-05 - accuracy: 1.0000 - val_loss: 0.0885 - val_accuracy: 0.9831 - 24s/epoch - 834ms/step
# Epoch 76/100
# 29/29 - 24s - loss: 9.9131e-06 - accuracy: 1.0000 - val_loss: 0.0689 - val_accuracy: 0.9894 - 24s/epoch - 823ms/step
# Epoch 77/100
# 29/29 - 24s - loss: 5.4908e-04 - accuracy: 1.0000 - val_loss: 1.6121e-04 - val_accuracy: 1.0000 - 24s/epoch - 827ms/step
# Epoch 78/100
# 29/29 - 24s - loss: 3.5099e-05 - accuracy: 1.0000 - val_loss: 2.7256e-04 - val_accuracy: 1.0000 - 24s/epoch - 823ms/step
# Epoch 79/100
# 29/29 - 24s - loss: 1.6584e-04 - accuracy: 1.0000 - val_loss: 1.4607e-04 - val_accuracy: 1.0000 - 24s/epoch - 824ms/step
# Epoch 80/100
# 29/29 - 24s - loss: 1.2316e-04 - accuracy: 1.0000 - val_loss: 2.9245e-04 - val_accuracy: 1.0000 - 24s/epoch - 826ms/step
# Epoch 81/100
# 29/29 - 24s - loss: 4.0077e-04 - accuracy: 1.0000 - val_loss: 4.0588e-04 - val_accuracy: 1.0000 - 24s/epoch - 824ms/step
# Epoch 82/100
# 29/29 - 24s - loss: 6.7502e-04 - accuracy: 0.9995 - val_loss: 2.9852e-04 - val_accuracy: 1.0000 - 24s/epoch - 823ms/step
# Epoch 83/100
# 29/29 - 24s - loss: 7.3085e-04 - accuracy: 0.9995 - val_loss: 1.3025e-04 - val_accuracy: 1.0000 - 24s/epoch - 832ms/step
# Epoch 84/100
# 29/29 - 24s - loss: 2.1115e-04 - accuracy: 1.0000 - val_loss: 2.9879e-05 - val_accuracy: 1.0000 - 24s/epoch - 825ms/step
# Epoch 85/100
# 29/29 - 24s - loss: 7.1925e-04 - accuracy: 0.9995 - val_loss: 4.7742e-04 - val_accuracy: 1.0000 - 24s/epoch - 829ms/step
# Epoch 86/100
# 29/29 - 24s - loss: 8.5653e-04 - accuracy: 0.9995 - val_loss: 0.0019 - val_accuracy: 0.9979 - 24s/epoch - 825ms/step
# Epoch 87/100
# 29/29 - 24s - loss: 3.3968e-05 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 0.9979 - 24s/epoch - 833ms/step
# Epoch 88/100
# 29/29 - 24s - loss: 0.0020 - accuracy: 0.9989 - val_loss: 5.3560e-05 - val_accuracy: 1.0000 - 24s/epoch - 828ms/step
# Epoch 89/100
# 29/29 - 24s - loss: 0.0026 - accuracy: 0.9995 - val_loss: 5.9191e-04 - val_accuracy: 1.0000 - 24s/epoch - 823ms/step
# Epoch 90/100
# 29/29 - 24s - loss: 4.1668e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000 - 24s/epoch - 833ms/step
# Epoch 91/100
# 29/29 - 24s - loss: 0.0015 - accuracy: 0.9989 - val_loss: 0.0030 - val_accuracy: 0.9979 - 24s/epoch - 826ms/step
# Epoch 92/100
# 29/29 - 24s - loss: 9.8765e-05 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 0.9979 - 24s/epoch - 823ms/step
# Epoch 93/100
# 29/29 - 24s - loss: 8.0765e-05 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 0.9979 - 24s/epoch - 824ms/step
# Epoch 94/100
# 29/29 - 24s - loss: 6.5357e-04 - accuracy: 0.9995 - val_loss: 0.0064 - val_accuracy: 0.9979 - 24s/epoch - 828ms/step
# Epoch 95/100
# 29/29 - 24s - loss: 5.5896e-04 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9958 - 24s/epoch - 826ms/step
# Epoch 96/100
# 29/29 - 24s - loss: 2.9854e-05 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9958 - 24s/epoch - 826ms/step
# Epoch 97/100
# 29/29 - 24s - loss: 7.6002e-05 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 0.9979 - 24s/epoch - 825ms/step
# Epoch 98/100
# 29/29 - 24s - loss: 6.4578e-06 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 0.9979 - 24s/epoch - 828ms/step
# Epoch 99/100
# 29/29 - 24s - loss: 0.0028 - accuracy: 0.9995 - val_loss: 2.7653e-05 - val_accuracy: 1.0000 - 24s/epoch - 825ms/step
# Epoch 100/100
# 29/29 - 24s - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.2833 - val_accuracy: 0.9809 - 24s/epoch - 836ms/step
# 0.0371
# ***Performance on Test Data***
# Accuracy  : 0.9160493827160494
# Precision : 0.9254963143852033
# f1Score : 0.9163667324586865
# [[125   6   4]
#  [  0 134   1]
#  [  1  22 112]]
# 7/7 [==============================] - 4s 615ms/step - loss: 2.0939 - accuracy: 0.9160
# Results for fold 4
# Found 1823 images belonging to 3 classes.
# Found 472 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.
# Epoch 1/100
# 29/29 - 25s - loss: 0.0179 - accuracy: 0.9978 - val_loss: 0.4719 - val_accuracy: 0.9047 - 25s/epoch - 854ms/step
# Epoch 2/100
# 29/29 - 24s - loss: 0.0393 - accuracy: 0.9901 - val_loss: 0.1022 - val_accuracy: 0.9788 - 24s/epoch - 835ms/step
# Epoch 3/100
# 29/29 - 24s - loss: 0.0212 - accuracy: 0.9962 - val_loss: 0.0227 - val_accuracy: 0.9958 - 24s/epoch - 834ms/step
# Epoch 4/100
# 29/29 - 24s - loss: 0.0156 - accuracy: 0.9956 - val_loss: 0.0016 - val_accuracy: 1.0000 - 24s/epoch - 839ms/step
# Epoch 5/100
# 29/29 - 24s - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.0127 - val_accuracy: 0.9958 - 24s/epoch - 820ms/step
# Epoch 6/100
# 29/29 - 24s - loss: 0.0371 - accuracy: 0.9984 - val_loss: 0.0402 - val_accuracy: 0.9831 - 24s/epoch - 816ms/step
# Epoch 7/100
# 29/29 - 24s - loss: 0.0190 - accuracy: 0.9956 - val_loss: 0.0127 - val_accuracy: 0.9936 - 24s/epoch - 812ms/step
# Epoch 8/100
# 29/29 - 23s - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.0012 - val_accuracy: 1.0000 - 23s/epoch - 809ms/step
# Epoch 9/100
# 29/29 - 23s - loss: 0.0168 - accuracy: 0.9962 - val_loss: 0.0260 - val_accuracy: 0.9936 - 23s/epoch - 810ms/step
# Epoch 10/100
# 29/29 - 24s - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.0375 - val_accuracy: 0.9979 - 24s/epoch - 812ms/step
# Epoch 11/100
# 29/29 - 24s - loss: 0.0146 - accuracy: 0.9989 - val_loss: 0.0605 - val_accuracy: 0.9915 - 24s/epoch - 811ms/step
# Epoch 12/100
# 29/29 - 24s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0921 - val_accuracy: 0.9831 - 24s/epoch - 813ms/step
# Epoch 13/100
# 29/29 - 24s - loss: 9.8147e-04 - accuracy: 0.9995 - val_loss: 0.0842 - val_accuracy: 0.9831 - 24s/epoch - 818ms/step
# Epoch 14/100
# 29/29 - 24s - loss: 2.0562e-04 - accuracy: 1.0000 - val_loss: 0.0806 - val_accuracy: 0.9852 - 24s/epoch - 812ms/step
# Epoch 15/100
# 29/29 - 24s - loss: 2.5756e-04 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 0.9852 - 24s/epoch - 816ms/step
# Epoch 16/100
# 29/29 - 24s - loss: 5.3499e-04 - accuracy: 1.0000 - val_loss: 0.0702 - val_accuracy: 0.9852 - 24s/epoch - 824ms/step
# Epoch 17/100
# 29/29 - 24s - loss: 3.3615e-04 - accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 0.9894 - 24s/epoch - 813ms/step
# Epoch 18/100
# 29/29 - 24s - loss: 5.3873e-04 - accuracy: 1.0000 - val_loss: 0.0518 - val_accuracy: 0.9936 - 24s/epoch - 822ms/step
# Epoch 19/100
# 29/29 - 24s - loss: 3.6005e-04 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9788 - 24s/epoch - 821ms/step
# Epoch 20/100
# 29/29 - 24s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0506 - val_accuracy: 0.9915 - 24s/epoch - 819ms/step
# Epoch 21/100
# 29/29 - 23s - loss: 6.1624e-04 - accuracy: 0.9995 - val_loss: 0.0385 - val_accuracy: 0.9958 - 23s/epoch - 809ms/step
# Epoch 22/100
# 29/29 - 24s - loss: 4.6887e-05 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9958 - 24s/epoch - 811ms/step
# Epoch 23/100
# 29/29 - 23s - loss: 2.1022e-04 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 0.9958 - 23s/epoch - 810ms/step
# Epoch 24/100
# 29/29 - 24s - loss: 1.9933e-04 - accuracy: 1.0000 - val_loss: 0.0353 - val_accuracy: 0.9958 - 24s/epoch - 811ms/step
# Epoch 25/100
# 29/29 - 24s - loss: 5.0003e-04 - accuracy: 0.9995 - val_loss: 0.0658 - val_accuracy: 0.9936 - 24s/epoch - 824ms/step
# Epoch 26/100
# 29/29 - 24s - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0642 - val_accuracy: 0.9936 - 24s/epoch - 826ms/step
# Epoch 27/100
# 29/29 - 24s - loss: 2.9683e-04 - accuracy: 1.0000 - val_loss: 0.0521 - val_accuracy: 0.9936 - 24s/epoch - 823ms/step
# Epoch 28/100
# 29/29 - 24s - loss: 1.6299e-04 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9936 - 24s/epoch - 815ms/step
# Epoch 29/100
# 29/29 - 24s - loss: 1.5566e-05 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9958 - 24s/epoch - 824ms/step
# Epoch 30/100
# 29/29 - 24s - loss: 1.0500e-04 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 0.9958 - 24s/epoch - 821ms/step
# Epoch 31/100
# 29/29 - 24s - loss: 4.4198e-05 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9979 - 24s/epoch - 811ms/step
# Epoch 32/100
# 29/29 - 24s - loss: 7.7475e-05 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9979 - 24s/epoch - 814ms/step
# Epoch 33/100
# 29/29 - 24s - loss: 4.0505e-04 - accuracy: 0.9995 - val_loss: 0.0111 - val_accuracy: 0.9979 - 24s/epoch - 816ms/step
# Epoch 34/100
# 29/29 - 23s - loss: 8.2153e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9979 - 23s/epoch - 810ms/step
# Epoch 35/100
# 29/29 - 24s - loss: 1.2946e-04 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 0.9979 - 24s/epoch - 822ms/step
# Epoch 36/100
# 29/29 - 24s - loss: 8.0097e-05 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 0.9979 - 24s/epoch - 815ms/step
# Epoch 37/100
# 29/29 - 23s - loss: 3.5149e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 0.9979 - 23s/epoch - 807ms/step
# Epoch 38/100
# 29/29 - 24s - loss: 1.1923e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000 - 24s/epoch - 811ms/step
# Epoch 39/100
# 29/29 - 24s - loss: 1.9177e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000 - 24s/epoch - 818ms/step
# Epoch 40/100
# 29/29 - 24s - loss: 1.5424e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 0.9979 - 24s/epoch - 813ms/step
# Epoch 41/100
# 29/29 - 23s - loss: 4.0393e-04 - accuracy: 1.0000 - val_loss: 4.9118e-04 - val_accuracy: 1.0000 - 23s/epoch - 806ms/step
# Epoch 42/100
# 29/29 - 23s - loss: 0.0055 - accuracy: 0.9995 - val_loss: 0.0113 - val_accuracy: 0.9979 - 23s/epoch - 805ms/step
# Epoch 43/100
# 29/29 - 23s - loss: 0.0082 - accuracy: 0.9984 - val_loss: 0.0774 - val_accuracy: 0.9894 - 23s/epoch - 808ms/step
# Epoch 44/100
# 29/29 - 24s - loss: 7.3556e-04 - accuracy: 0.9995 - val_loss: 0.0665 - val_accuracy: 0.9915 - 24s/epoch - 815ms/step
# Epoch 45/100
# 29/29 - 24s - loss: 0.0070 - accuracy: 0.9989 - val_loss: 0.1010 - val_accuracy: 0.9894 - 24s/epoch - 815ms/step
# Epoch 46/100
# 29/29 - 24s - loss: 0.0148 - accuracy: 0.9967 - val_loss: 0.1634 - val_accuracy: 0.9682 - 24s/epoch - 811ms/step
# Epoch 47/100
# 29/29 - 24s - loss: 0.1141 - accuracy: 0.9907 - val_loss: 0.4522 - val_accuracy: 0.9407 - 24s/epoch - 811ms/step
# Epoch 48/100
# 29/29 - 24s - loss: 0.0508 - accuracy: 0.9945 - val_loss: 0.3802 - val_accuracy: 0.9449 - 24s/epoch - 815ms/step
# Epoch 49/100
# 29/29 - 23s - loss: 0.0242 - accuracy: 0.9973 - val_loss: 0.2822 - val_accuracy: 0.9746 - 23s/epoch - 810ms/step
# Epoch 50/100
# 29/29 - 24s - loss: 0.0328 - accuracy: 0.9951 - val_loss: 0.4333 - val_accuracy: 0.9576 - 24s/epoch - 811ms/step
# Epoch 51/100
# 29/29 - 24s - loss: 0.0248 - accuracy: 0.9978 - val_loss: 0.2544 - val_accuracy: 0.9597 - 24s/epoch - 825ms/step
# Epoch 52/100
# 29/29 - 25s - loss: 0.0475 - accuracy: 0.9934 - val_loss: 0.1569 - val_accuracy: 0.9725 - 25s/epoch - 849ms/step
# Epoch 53/100
# 29/29 - 24s - loss: 0.0023 - accuracy: 0.9989 - val_loss: 0.0283 - val_accuracy: 0.9915 - 24s/epoch - 812ms/step
# Epoch 54/100
# 29/29 - 24s - loss: 0.0127 - accuracy: 0.9984 - val_loss: 0.0121 - val_accuracy: 0.9979 - 24s/epoch - 820ms/step
# Epoch 55/100
# 29/29 - 24s - loss: 0.0079 - accuracy: 0.9984 - val_loss: 0.1193 - val_accuracy: 0.9852 - 24s/epoch - 812ms/step
# Epoch 56/100
# 29/29 - 24s - loss: 0.0173 - accuracy: 0.9973 - val_loss: 0.0740 - val_accuracy: 0.9767 - 24s/epoch - 813ms/step
# Epoch 57/100
# 29/29 - 24s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0763 - val_accuracy: 0.9746 - 24s/epoch - 814ms/step
# Epoch 58/100
# 29/29 - 24s - loss: 0.0085 - accuracy: 0.9967 - val_loss: 0.1153 - val_accuracy: 0.9852 - 24s/epoch - 813ms/step
# Epoch 59/100
# 29/29 - 24s - loss: 0.0132 - accuracy: 0.9978 - val_loss: 0.1565 - val_accuracy: 0.9555 - 24s/epoch - 813ms/step
# Epoch 60/100
# 29/29 - 24s - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.8056 - val_accuracy: 0.8242 - 24s/epoch - 815ms/step
# Epoch 61/100
# 29/29 - 24s - loss: 0.0068 - accuracy: 0.9984 - val_loss: 0.2428 - val_accuracy: 0.9153 - 24s/epoch - 814ms/step
# Epoch 62/100
# 29/29 - 24s - loss: 9.5936e-05 - accuracy: 1.0000 - val_loss: 0.0968 - val_accuracy: 0.9661 - 24s/epoch - 814ms/step
# Epoch 63/100
# 29/29 - 23s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0576 - val_accuracy: 0.9809 - 23s/epoch - 810ms/step
# Epoch 64/100
# 29/29 - 24s - loss: 2.3338e-04 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9873 - 24s/epoch - 816ms/step
# Epoch 65/100
# 29/29 - 24s - loss: 5.9887e-04 - accuracy: 0.9995 - val_loss: 0.0218 - val_accuracy: 0.9958 - 24s/epoch - 823ms/step
# Epoch 66/100
# 29/29 - 24s - loss: 4.5529e-04 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 0.9936 - 24s/epoch - 812ms/step
# Epoch 67/100
# 29/29 - 24s - loss: 9.3948e-04 - accuracy: 0.9995 - val_loss: 0.0309 - val_accuracy: 0.9915 - 24s/epoch - 817ms/step
# Epoch 68/100
# 29/29 - 24s - loss: 9.4375e-04 - accuracy: 1.0000 - val_loss: 0.0372 - val_accuracy: 0.9915 - 24s/epoch - 817ms/step
# Epoch 69/100
# 29/29 - 24s - loss: 0.0015 - accuracy: 0.9989 - val_loss: 0.0215 - val_accuracy: 0.9873 - 24s/epoch - 817ms/step
# Epoch 70/100
# 29/29 - 24s - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.0060 - val_accuracy: 0.9958 - 24s/epoch - 815ms/step
# Epoch 71/100
# 29/29 - 24s - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.0614 - val_accuracy: 0.9894 - 24s/epoch - 819ms/step
# Epoch 72/100
# 29/29 - 24s - loss: 0.0141 - accuracy: 0.9989 - val_loss: 0.0331 - val_accuracy: 0.9894 - 24s/epoch - 816ms/step
# Epoch 73/100
# 29/29 - 24s - loss: 2.3434e-04 - accuracy: 1.0000 - val_loss: 0.0270 - val_accuracy: 0.9915 - 24s/epoch - 820ms/step
# Epoch 74/100
# 29/29 - 24s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0102 - val_accuracy: 0.9958 - 24s/epoch - 815ms/step
# Epoch 75/100
# 29/29 - 24s - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.0076 - val_accuracy: 0.9958 - 24s/epoch - 815ms/step
# Epoch 76/100
# 29/29 - 24s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0068 - val_accuracy: 0.9979 - 24s/epoch - 813ms/step
# Epoch 77/100
# 29/29 - 24s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0179 - val_accuracy: 0.9979 - 24s/epoch - 816ms/step
# Epoch 78/100
# 29/29 - 24s - loss: 0.0096 - accuracy: 0.9978 - val_loss: 0.0238 - val_accuracy: 0.9936 - 24s/epoch - 822ms/step
# Epoch 79/100
# 29/29 - 24s - loss: 0.0054 - accuracy: 0.9995 - val_loss: 0.1046 - val_accuracy: 0.9873 - 24s/epoch - 812ms/step
# Epoch 80/100
# 29/29 - 24s - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1838 - val_accuracy: 0.9576 - 24s/epoch - 811ms/step
# Epoch 81/100
# 29/29 - 24s - loss: 6.5051e-04 - accuracy: 1.0000 - val_loss: 0.1853 - val_accuracy: 0.9640 - 24s/epoch - 813ms/step
# Epoch 82/100
# 29/29 - 24s - loss: 0.0099 - accuracy: 0.9989 - val_loss: 0.0896 - val_accuracy: 0.9894 - 24s/epoch - 825ms/step
# Epoch 83/100
# 29/29 - 24s - loss: 7.1036e-04 - accuracy: 0.9995 - val_loss: 0.0553 - val_accuracy: 0.9915 - 24s/epoch - 817ms/step
# Epoch 84/100
# 29/29 - 24s - loss: 1.4106e-04 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9936 - 24s/epoch - 836ms/step
# Epoch 85/100
# 29/29 - 24s - loss: 9.2231e-05 - accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 0.9936 - 24s/epoch - 817ms/step
# Epoch 86/100
# 29/29 - 24s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0145 - val_accuracy: 0.9958 - 24s/epoch - 820ms/step
# Epoch 87/100
# 29/29 - 24s - loss: 1.2308e-06 - accuracy: 1.0000 - val_loss: 0.0156 - val_accuracy: 0.9958 - 24s/epoch - 825ms/step
# Epoch 88/100
# 29/29 - 24s - loss: 6.4631e-06 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 0.9958 - 24s/epoch - 824ms/step
# Epoch 89/100
# 29/29 - 24s - loss: 5.6956e-06 - accuracy: 1.0000 - val_loss: 0.0159 - val_accuracy: 0.9936 - 24s/epoch - 823ms/step
# Epoch 90/100
# 29/29 - 24s - loss: 2.2029e-05 - accuracy: 1.0000 - val_loss: 0.0172 - val_accuracy: 0.9936 - 24s/epoch - 831ms/step
# Epoch 91/100
# 29/29 - 24s - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.0985 - val_accuracy: 0.9788 - 24s/epoch - 833ms/step
# Epoch 92/100
# 29/29 - 24s - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.0811 - val_accuracy: 0.9831 - 24s/epoch - 813ms/step
# Epoch 93/100
# 29/29 - 24s - loss: 5.4918e-05 - accuracy: 1.0000 - val_loss: 0.0157 - val_accuracy: 0.9936 - 24s/epoch - 813ms/step
# Epoch 94/100
# 29/29 - 24s - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0011 - val_accuracy: 1.0000 - 24s/epoch - 811ms/step
# Epoch 95/100
# 29/29 - 24s - loss: 1.8394e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - 24s/epoch - 814ms/step
# Epoch 96/100
# 29/29 - 24s - loss: 4.1030e-05 - accuracy: 1.0000 - val_loss: 7.7431e-04 - val_accuracy: 1.0000 - 24s/epoch - 817ms/step
# Epoch 97/100
# 29/29 - 24s - loss: 1.0172e-04 - accuracy: 1.0000 - val_loss: 6.2712e-04 - val_accuracy: 1.0000 - 24s/epoch - 825ms/step
# Epoch 98/100
# 29/29 - 24s - loss: 2.3997e-05 - accuracy: 1.0000 - val_loss: 5.8624e-04 - val_accuracy: 1.0000 - 24s/epoch - 825ms/step
# Epoch 99/100
# 29/29 - 24s - loss: 1.6987e-04 - accuracy: 1.0000 - val_loss: 3.4498e-04 - val_accuracy: 1.0000 - 24s/epoch - 843ms/step
# Epoch 100/100
# 29/29 - 24s - loss: 1.3361e-04 - accuracy: 1.0000 - val_loss: 2.1272e-04 - val_accuracy: 1.0000 - 24s/epoch - 831ms/step
# 0.039
# ***Performance on Test Data***
# Accuracy  : 0.9629629629629629
# Precision : 0.964002711725711
# f1Score : 0.9628503338679655
# [[132   0   3]
#  [  1 134   0]
#  [  1  10 124]]
# 7/7 [==============================] - 4s 620ms/step - loss: 0.7796 - accuracy: 0.9630
