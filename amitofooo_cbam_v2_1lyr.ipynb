# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoAN42/SKRPSI/blob/main/amitofooo_cbam_v2_1lyr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mount dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.layers import Conv2D, Input, concatenate, Activation, InputLayer, Dense, Reshape, Flatten, Add, multiply, Permute, Lambda, Concatenate
from tensorflow.keras.layers import LeakyReLU,ReLU, MaxPooling2D, BatchNormalization,GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import layers
from tensorflow.keras.activations import softmax,sigmoid
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout,SpatialDropout2D,GaussianDropout
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.regularizers import l1,l2
from tensorflow.keras import backend as K
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow
import tensorflow as tf
import math
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold
import os
import random
import shutil

# %%
from tensorflow.keras.optimizers import SGD

# %%
CLASS = 3
#sourcepath isi semua data train, folder valid kosongin datanya sisai folder classnya
sourcePath = '/content/drive/MyDrive/Colab Notebooks/Dataset 10'
train_path = '/content/drive/MyDrive/Colab Notebooks/Dataset 10/train'
valid_path = '/content/drive/MyDrive/Colab Notebooks/Dataset 10/valid'
test_path = '/content/drive/MyDrive/Colab Notebooks/Dataset 10/test'

#nico

# %%
classLabels =['covid','normal', 'pneumonia']

# %%
def attach_attention_module(net, attention_module):
  #if attention_module == 'se_block': # SE_block
    #net = se_block(net)
  if attention_module == 'cbam_block': # CBAM_block
    net = cbam_block(net)
  else:
    raise Exception("'{}' is not supported attention module!".format(attention_module))

  return net

# %%
def cbam_block(cbam_feature, ratio=8):
	"""Contains the implementation of Convolutional Block Attention Module(CBAM) block.
	As described in https://arxiv.org/abs/1807.06521.
	"""
	
	cbam_feature = channel_attention(cbam_feature, ratio)
	cbam_feature = spatial_attention(cbam_feature)
	return cbam_feature

# %%
def channel_attention(input_feature, ratio=8):
	
	channel_axis = 1 if K.image_data_format() == "channels_first" else -1
	channel = input_feature.shape[channel_axis]
	
	shared_layer_one = Dense(channel//ratio,
							 activation='relu',
							 kernel_initializer='he_normal',
							 use_bias=True,
							 bias_initializer='zeros')
	shared_layer_two = Dense(channel,
							 kernel_initializer='he_normal',
							 use_bias=True,
							 bias_initializer='zeros')
	
	avg_pool = GlobalAveragePooling2D()(input_feature)    
	avg_pool = Reshape((1,1,channel))(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel)
	avg_pool = shared_layer_one(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel//ratio)
	avg_pool = shared_layer_two(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel)
	
	max_pool = GlobalMaxPooling2D()(input_feature)
	max_pool = Reshape((1,1,channel))(max_pool)
	assert max_pool.shape[1:] == (1,1,channel)
	max_pool = shared_layer_one(max_pool)
	assert max_pool.shape[1:] == (1,1,channel//ratio)
	max_pool = shared_layer_two(max_pool)
	assert max_pool.shape[1:] == (1,1,channel)
	
	cbam_feature = Add()([avg_pool,max_pool])
	cbam_feature = Activation('sigmoid')(cbam_feature)
	
	if K.image_data_format() == "channels_first":
		cbam_feature = Permute((3, 1, 2))(cbam_feature)
	
	return multiply([input_feature, cbam_feature])

# %%
def spatial_attention(input_feature):
	kernel_size = 7
	
	if K.image_data_format() == "channels_first":
		channel = input_feature.shape[1]
		cbam_feature = Permute((2,3,1))(input_feature)
	else:
		channel = input_feature.shape[-1]
		cbam_feature = input_feature
	
	avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
	assert avg_pool.shape[-1] == 1
	max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
	assert max_pool.shape[-1] == 1
	concat = Concatenate(axis=3)([avg_pool, max_pool])
	assert concat.shape[-1] == 2
	cbam_feature = Conv2D(filters = 1,
					kernel_size=kernel_size,
					strides=1,
					padding='same',
					activation='sigmoid',
					kernel_initializer='he_normal',
					use_bias=False)(concat)	
	assert cbam_feature.shape[-1] == 1
	
	if K.image_data_format() == "channels_first":
		cbam_feature = Permute((3, 1, 2))(cbam_feature)
		
	return multiply([input_feature, cbam_feature])

# %%
input = Input(shape=(256,256,3))

# %%
#Layer 1
model = layers.Conv2D(32, (3,3), padding='same', name='conv_1', activation = 'relu')(input)
model = layers.BatchNormalization(name='norm_1')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides= 2)(model)
attention_module = 'cbam_block'
y = attach_attention_module(model, attention_module)
model =  tensorflow.keras.layers.add([model, y])

# %%
#Layer 2
model = layers.Conv2D(64, (3,3), padding='same', name='conv_2', activation = 'relu')(model)
model = layers.Dropout(0.1)(model)
model = layers.BatchNormalization(name='norm_2')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

# %%
# Layer 3
model = layers.Conv2D(64, (3,3), padding='same', name='conv_3', activation = 'relu')(model)
model = layers.BatchNormalization(name='norm_3')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

# %%
# Layer 4
model = layers.Conv2D(128, (3,3), padding='same', name='conv_4', activation = 'relu')(model)
model = layers.Dropout(0.2)(model)
model = layers.BatchNormalization(name='norm_4')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

# %%
# Layer 5
model = layers.Conv2D(256, (3,3), padding='same', name='conv_5', activation = 'relu')(model)
layer = layers.Conv2D(256, (3,3), padding='same', name='conv_5', activation = 'relu')
batch = layers.BatchNormalization(name='norm_5')
model = layers.Dropout(0.2)(model)
model = layers.BatchNormalization(name='norm_5')(model)
#model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

# %%
model = layers.Flatten()(model)
model = layers.Dense(128, activation = 'relu')(model)
model = layers.Dropout(0.2)(model)
output = layers.Dense(3,Activation('softmax'))(model)
model = Model(input, output)

# %%
#output = model.output_shape

# %%
print(input)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")

# %%
initial_learning_rate=0.0001

# %%
lr_schedule = ExponentialDecay(
   initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)

# %%
opt = Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)

# %%
model.compile(optimizer=opt, loss="sparse_categorical_crossentropy", metrics=["accuracy"] )

# %%
print(model.summary())
print(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv_1 (Conv2D)                (None, 256, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  norm_1 (BatchNormalization)    (None, 256, 256, 32  128         ['conv_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['norm_1[0][0]']
#                                 )
#
#  global_average_pooling2d (Glob  (None, 32)          0           ['max_pooling2d[0][0]']
#  alAveragePooling2D)
#
#  global_max_pooling2d (GlobalMa  (None, 32)          0           ['max_pooling2d[0][0]']
#  xPooling2D)
#
#  reshape (Reshape)              (None, 1, 1, 32)     0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  reshape_1 (Reshape)            (None, 1, 1, 32)     0           ['global_max_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 1, 1, 4)      132         ['reshape[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  dense_1 (Dense)                (None, 1, 1, 32)     160         ['dense[0][0]',
#                                                                   'dense[1][0]']
#
#  add (Add)                      (None, 1, 1, 32)     0           ['dense_1[0][0]',
#                                                                   'dense_1[1][0]']
#
#  activation (Activation)        (None, 1, 1, 32)     0           ['add[0][0]']
#
#  multiply (Multiply)            (None, 128, 128, 32  0           ['max_pooling2d[0][0]',
#                                 )                                 'activation[0][0]']
#
#  lambda (Lambda)                (None, 128, 128, 1)  0           ['multiply[0][0]']
#
#  lambda_1 (Lambda)              (None, 128, 128, 1)  0           ['multiply[0][0]']
#
#  concatenate (Concatenate)      (None, 128, 128, 2)  0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  conv2d (Conv2D)                (None, 128, 128, 1)  98          ['concatenate[0][0]']
#
#  multiply_1 (Multiply)          (None, 128, 128, 32  0           ['multiply[0][0]',
#                                 )                                 'conv2d[0][0]']
#
#  add_1 (Add)                    (None, 128, 128, 32  0           ['max_pooling2d[0][0]',
#                                 )                                 'multiply_1[0][0]']
#
#  conv_2 (Conv2D)                (None, 128, 128, 64  18496       ['add_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 64  0           ['conv_2[0][0]']
#                                 )
#
#  norm_2 (BatchNormalization)    (None, 128, 128, 64  256         ['dropout[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['norm_2[0][0]']
#
#  conv_3 (Conv2D)                (None, 64, 64, 64)   36928       ['max_pooling2d_1[0][0]']
#
#  norm_3 (BatchNormalization)    (None, 64, 64, 64)   256         ['conv_3[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)  0           ['norm_3[0][0]']
#
#  conv_4 (Conv2D)                (None, 32, 32, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 128)  0           ['conv_4[0][0]']
#
#  norm_4 (BatchNormalization)    (None, 32, 32, 128)  512         ['dropout_1[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0          ['norm_4[0][0]']
#
#  conv_5 (Conv2D)                (None, 16, 16, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 256)  0           ['conv_5[0][0]']
#
#  norm_5 (BatchNormalization)    (None, 16, 16, 256)  1024        ['dropout_2[0][0]']
#
#  flatten (Flatten)              (None, 65536)        0           ['norm_5[0][0]']
#
#  dense_2 (Dense)                (None, 128)          8388736     ['flatten[0][0]']
#
#  dropout_3 (Dropout)            (None, 128)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 3)            387         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 8,817,033
# Trainable params: 8,815,945
# Non-trainable params: 1,088
# __________________________________________________________________________________________________
# None
# <keras.engine.functional.Functional object at 0x7f0c84547810>

# %%
X = []
Y = []
def transferBetweenFolders(source, dest, splitRate): 
    global sourceFiles
    sourceFiles=os.listdir(source)
    if(len(sourceFiles)!=0):
        transferFileNumbers=int(len(sourceFiles)*splitRate)
        transferIndex=random.sample(range(0, len(sourceFiles)), transferFileNumbers)
        for eachIndex in transferIndex:
            shutil.move(source+str(sourceFiles[eachIndex]), dest+str(sourceFiles[eachIndex]))
    else:
        print("No file moved. Source empty!")

# %%
def transferAllClassBetweenFolders(source, dest, splitRate):
    for label in classLabels:
        transferBetweenFolders(sourcePath+'/'+source+'/'+label+'/', 
                               sourcePath+'/'+dest+'/'+label+'/', 
                               splitRate)
#First cut all images from validation to train (if any exists)
transferAllClassBetweenFolders('valid', 'train', 1.0)
#no valid
#transferAllClassBetweenFolders('test', 'train', 1.0)

# %%
def prepareNameWithLabels(folderName):
    sourceFiles=os.listdir(sourcePath+'/train/'+folderName)
    for val in sourceFiles:
        X.append(val)
        for i in range(len(classLabels)):
          if(folderName==classLabels[i]):
              Y.append(i)
# Organize file names and class labels in X and Y variables
for i in range(len(classLabels)):
  prepareNameWithLabels(classLabels[i])

def my_metrics(y_true, y_pred):
    accuracy=accuracy_score(y_true, y_pred)
    precision=precision_score(y_true, y_pred,average='weighted')
    f1Score=f1_score(y_true, y_pred, average='weighted') 
    print("Accuracy  : {}".format(accuracy))
    print("Precision : {}".format(precision))
    print("f1Score : {}".format(f1Score))
    cm=confusion_matrix(y_true, y_pred)
    print(cm)
    return accuracy, precision, f1Score

# %%
transferAllClassBetweenFolders('valid', 'train', 1.0)
#transferAllClassBetweenFolders('test', 'train', 1.0)
X=np.asarray(X)
Y=np.asarray(Y)

print(X)
print(Y)

skf = StratifiedKFold(n_splits=5
                      , shuffle=True)
skf.get_n_splits(X, Y)
foldNum=0
overAllAcc = 0
# Out:
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# ['COVID(57).png' 'COVID(91).png' 'COVID(66).png' ...
#  'person1369_virus_2356.jpeg' 'person1385_virus_2380.jpeg'
#  'person1179_virus_2006.jpeg']
# [0 0 0 ... 2 2 2]

# %%
for train_index, val_index in skf.split(X, Y):
    #First cut all images from validation to train (if any exists)
    transferAllClassBetweenFolders('valid', 'train', 1.0)
    #no valid
    #transferAllClassBetweenFolders('test', 'train', 1.0)
    foldNum+=1
    print("Results for fold",foldNum)
    X_train, X_val = X[train_index], X[val_index]
    Y_train, Y_val = Y[train_index], Y[val_index]
    # Move validation images of this fold from train folder to the validation folder
    for eachIndex in range(len(X_val)):
        classLabel=''
        for i in range(len(classLabels)):
          if(Y_val[eachIndex]==i):
              classLabel=classLabels[i]
        #Then, copy the validation images to the validation folder
        shutil.move(sourcePath+'/train/'+classLabel+'/'+X_val[eachIndex], 
                    sourcePath+'/valid/'+classLabel+'/'+X_val[eachIndex])
        
    train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 64, shuffle=True)
    valid_batches = ImageDataGenerator().flow_from_directory(valid_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 64, shuffle=True)
    test_batches = ImageDataGenerator().flow_from_directory(test_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 64, shuffle=False)

    history = model.fit(train_batches, 
                    #steps_per_epoch=sp_epoch, 
                    validation_data=valid_batches, 
                    #validation_steps=10, 
                    epochs=100, 
                    verbose=2)
    
    
    
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Final Cbam model accuracy')
    plt.ylim(0,1.1)
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Final Cbam model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.show()
    test_batches.reset()
    Y_pred = model.predict(test_batches)
    classes = test_batches.classes[test_batches.index_array]
    y_pred = np.argmax(Y_pred, axis=-1)
    print(sum(y_pred==classes)/10000)
    confusion_matrix(test_batches.classes[test_batches.index_array],y_pred)
    #predictions = model.predict(test_batches, verbose=1)
    #yPredictions = np.argmax(predictions, axis=1)
    #print(yPredictions)
    #true_classes = test_batches.classes
    # evaluate validation performance
    print("***Performance on Test Data***")    
    #valAcc, valPrec, valFScore = my_metrics(true_classes, yPredictions)
    valAcc, valPrec, valFScore = my_metrics(classes, y_pred)
    overAllAcc = overAllAcc+valAcc
    
    model.evaluate(test_batches)
print("Overall Accuracy: ",  overAllAcc/foldNum)
# Out:
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# Results for fold 1
# Found 1836 images belonging to 3 classes.
# Found 459 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.
# Epoch 1/100
# 29/29 - 1045s - loss: 1.3456 - accuracy: 0.8655 - val_loss: 13.2259 - val_accuracy: 0.5839 - 1045s/epoch - 36s/step
# Epoch 2/100
# 29/29 - 28s - loss: 0.1422 - accuracy: 0.9575 - val_loss: 4.3616 - val_accuracy: 0.5991 - 28s/epoch - 957ms/step
# Epoch 3/100
# 29/29 - 28s - loss: 0.0847 - accuracy: 0.9744 - val_loss: 5.9959 - val_accuracy: 0.5861 - 28s/epoch - 950ms/step
# Epoch 4/100
# 29/29 - 28s - loss: 0.1146 - accuracy: 0.9684 - val_loss: 3.5962 - val_accuracy: 0.6601 - 28s/epoch - 958ms/step
# Epoch 5/100
# 29/29 - 27s - loss: 0.0389 - accuracy: 0.9842 - val_loss: 0.3072 - val_accuracy: 0.9129 - 27s/epoch - 934ms/step
# Epoch 6/100
# 29/29 - 27s - loss: 0.0412 - accuracy: 0.9891 - val_loss: 0.1080 - val_accuracy: 0.9717 - 27s/epoch - 922ms/step
# Epoch 7/100
# 29/29 - 27s - loss: 0.0279 - accuracy: 0.9924 - val_loss: 0.1751 - val_accuracy: 0.9434 - 27s/epoch - 928ms/step
# Epoch 8/100
# 29/29 - 27s - loss: 0.0115 - accuracy: 0.9956 - val_loss: 0.0791 - val_accuracy: 0.9847 - 27s/epoch - 920ms/step
# Epoch 9/100
# 29/29 - 27s - loss: 0.0140 - accuracy: 0.9956 - val_loss: 0.1137 - val_accuracy: 0.9739 - 27s/epoch - 922ms/step
# Epoch 10/100
# 29/29 - 27s - loss: 0.0080 - accuracy: 0.9978 - val_loss: 0.1080 - val_accuracy: 0.9739 - 27s/epoch - 918ms/step
# Epoch 11/100
# 29/29 - 27s - loss: 0.0120 - accuracy: 0.9967 - val_loss: 0.2371 - val_accuracy: 0.9564 - 27s/epoch - 918ms/step
# Epoch 12/100
# 29/29 - 27s - loss: 0.0190 - accuracy: 0.9956 - val_loss: 0.1417 - val_accuracy: 0.9717 - 27s/epoch - 921ms/step
# Epoch 13/100
# 29/29 - 27s - loss: 0.0291 - accuracy: 0.9913 - val_loss: 0.3219 - val_accuracy: 0.9542 - 27s/epoch - 916ms/step
# Epoch 14/100
# 29/29 - 26s - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.1379 - val_accuracy: 0.9760 - 26s/epoch - 912ms/step
# Epoch 15/100
# 29/29 - 26s - loss: 1.5282 - accuracy: 0.8998 - val_loss: 7.1107 - val_accuracy: 0.8824 - 26s/epoch - 913ms/step
# Epoch 16/100
# 29/29 - 27s - loss: 0.2844 - accuracy: 0.9450 - val_loss: 0.9425 - val_accuracy: 0.9390 - 27s/epoch - 920ms/step
# Epoch 17/100
# 29/29 - 27s - loss: 0.0794 - accuracy: 0.9766 - val_loss: 0.6229 - val_accuracy: 0.8366 - 27s/epoch - 915ms/step
# Epoch 18/100
# 29/29 - 27s - loss: 0.1076 - accuracy: 0.9853 - val_loss: 0.1664 - val_accuracy: 0.9608 - 27s/epoch - 914ms/step
# Epoch 19/100
# 29/29 - 26s - loss: 0.0303 - accuracy: 0.9891 - val_loss: 0.1437 - val_accuracy: 0.9695 - 26s/epoch - 912ms/step
# Epoch 20/100
# 29/29 - 26s - loss: 0.0217 - accuracy: 0.9918 - val_loss: 0.4380 - val_accuracy: 0.8736 - 26s/epoch - 912ms/step
# Epoch 21/100
# 29/29 - 27s - loss: 0.0189 - accuracy: 0.9918 - val_loss: 0.2376 - val_accuracy: 0.9717 - 27s/epoch - 925ms/step
# Epoch 22/100
# 29/29 - 27s - loss: 0.0150 - accuracy: 0.9935 - val_loss: 0.6891 - val_accuracy: 0.8344 - 27s/epoch - 914ms/step
# Epoch 23/100
# 29/29 - 27s - loss: 0.0175 - accuracy: 0.9924 - val_loss: 0.9476 - val_accuracy: 0.7908 - 27s/epoch - 917ms/step
# Epoch 24/100
# 29/29 - 27s - loss: 0.0206 - accuracy: 0.9935 - val_loss: 1.1895 - val_accuracy: 0.7691 - 27s/epoch - 916ms/step
# Epoch 25/100
# 29/29 - 27s - loss: 0.0065 - accuracy: 0.9984 - val_loss: 0.7173 - val_accuracy: 0.8410 - 27s/epoch - 914ms/step
# Epoch 26/100
# 29/29 - 26s - loss: 0.0160 - accuracy: 0.9973 - val_loss: 10.8769 - val_accuracy: 0.7495 - 26s/epoch - 907ms/step
# Epoch 27/100
# 29/29 - 28s - loss: 0.0246 - accuracy: 0.9929 - val_loss: 0.3517 - val_accuracy: 0.9129 - 28s/epoch - 956ms/step
# Epoch 28/100
# 29/29 - 27s - loss: 0.0095 - accuracy: 0.9973 - val_loss: 1.9946 - val_accuracy: 0.7473 - 27s/epoch - 914ms/step
# Epoch 29/100
# 29/29 - 26s - loss: 0.0088 - accuracy: 0.9978 - val_loss: 0.3161 - val_accuracy: 0.9216 - 26s/epoch - 911ms/step
# Epoch 30/100
# 29/29 - 26s - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.2474 - val_accuracy: 0.9390 - 26s/epoch - 912ms/step
# Epoch 31/100
# 29/29 - 26s - loss: 0.0034 - accuracy: 0.9984 - val_loss: 0.2176 - val_accuracy: 0.9586 - 26s/epoch - 912ms/step
# Epoch 32/100
# 29/29 - 26s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2028 - val_accuracy: 0.9608 - 26s/epoch - 912ms/step
# Epoch 33/100
# 29/29 - 26s - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.2091 - val_accuracy: 0.9499 - 26s/epoch - 909ms/step
# Epoch 34/100
# 29/29 - 27s - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.1558 - val_accuracy: 0.9847 - 27s/epoch - 914ms/step
# Epoch 35/100
# 29/29 - 27s - loss: 0.0044 - accuracy: 0.9978 - val_loss: 0.1645 - val_accuracy: 0.9760 - 27s/epoch - 915ms/step
# Epoch 36/100
# 29/29 - 27s - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.1678 - val_accuracy: 0.9739 - 27s/epoch - 916ms/step
# Epoch 37/100
# 29/29 - 26s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1903 - val_accuracy: 0.9717 - 26s/epoch - 912ms/step
# Epoch 38/100
# 29/29 - 27s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9717 - 27s/epoch - 914ms/step
# Epoch 39/100
# 29/29 - 27s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.1887 - val_accuracy: 0.9717 - 27s/epoch - 922ms/step
# Epoch 40/100
# 29/29 - 27s - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.1855 - val_accuracy: 0.9739 - 27s/epoch - 916ms/step
# Epoch 41/100
# 29/29 - 26s - loss: 4.4144e-04 - accuracy: 1.0000 - val_loss: 0.1878 - val_accuracy: 0.9717 - 26s/epoch - 907ms/step
# Epoch 42/100
# 29/29 - 26s - loss: 7.5530e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9826 - 26s/epoch - 912ms/step
# Epoch 43/100
# 29/29 - 26s - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.1909 - val_accuracy: 0.9695 - 26s/epoch - 910ms/step
# Epoch 44/100
# 29/29 - 26s - loss: 5.9150e-04 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9651 - 26s/epoch - 906ms/step
# Epoch 45/100
# 29/29 - 26s - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.2214 - val_accuracy: 0.9717 - 26s/epoch - 901ms/step
# Epoch 46/100
# 29/29 - 26s - loss: 0.0066 - accuracy: 0.9984 - val_loss: 0.2339 - val_accuracy: 0.9651 - 26s/epoch - 901ms/step
# Epoch 47/100
# 29/29 - 26s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.2354 - val_accuracy: 0.9739 - 26s/epoch - 896ms/step
# Epoch 48/100
# 29/29 - 26s - loss: 0.0111 - accuracy: 0.9967 - val_loss: 0.3216 - val_accuracy: 0.9521 - 26s/epoch - 890ms/step
# Epoch 49/100
# 29/29 - 26s - loss: 0.0345 - accuracy: 0.9907 - val_loss: 13.3827 - val_accuracy: 0.7516 - 26s/epoch - 888ms/step
# Epoch 50/100
# 29/29 - 26s - loss: 0.0323 - accuracy: 0.9929 - val_loss: 4.6115 - val_accuracy: 0.8606 - 26s/epoch - 885ms/step
# Epoch 51/100
# 29/29 - 26s - loss: 0.0118 - accuracy: 0.9956 - val_loss: 1.2109 - val_accuracy: 0.9237 - 26s/epoch - 906ms/step
# Epoch 52/100
# 29/29 - 26s - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.2204 - val_accuracy: 0.9804 - 26s/epoch - 892ms/step
# Epoch 53/100
# 29/29 - 26s - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.1602 - val_accuracy: 0.9869 - 26s/epoch - 889ms/step
# Epoch 54/100
# 29/29 - 26s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1871 - val_accuracy: 0.9782 - 26s/epoch - 887ms/step
# Epoch 55/100
# 29/29 - 26s - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.1639 - val_accuracy: 0.9739 - 26s/epoch - 888ms/step
# Epoch 56/100
# 29/29 - 26s - loss: 0.0019 - accuracy: 0.9989 - val_loss: 7.7785 - val_accuracy: 0.8235 - 26s/epoch - 895ms/step
# Epoch 57/100
# 29/29 - 26s - loss: 7.1581e-04 - accuracy: 1.0000 - val_loss: 0.2465 - val_accuracy: 0.9782 - 26s/epoch - 904ms/step
# Epoch 58/100
# 29/29 - 26s - loss: 4.2786e-04 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.9847 - 26s/epoch - 893ms/step
# Epoch 59/100
# 29/29 - 26s - loss: 7.1271e-04 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9739 - 26s/epoch - 899ms/step
# Epoch 60/100
# 29/29 - 26s - loss: 0.0017 - accuracy: 0.9989 - val_loss: 0.4126 - val_accuracy: 0.9695 - 26s/epoch - 897ms/step
# Epoch 61/100
# 29/29 - 26s - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.3662 - val_accuracy: 0.9739 - 26s/epoch - 891ms/step
# Epoch 62/100
# 29/29 - 26s - loss: 3.4283e-04 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9847 - 26s/epoch - 897ms/step
# Epoch 63/100
# 29/29 - 26s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.1928 - val_accuracy: 0.9804 - 26s/epoch - 905ms/step
# Epoch 64/100
# 29/29 - 26s - loss: 0.0057 - accuracy: 0.9973 - val_loss: 0.2992 - val_accuracy: 0.9477 - 26s/epoch - 887ms/step
# Epoch 65/100
# 29/29 - 26s - loss: 0.0209 - accuracy: 0.9956 - val_loss: 0.5352 - val_accuracy: 0.9760 - 26s/epoch - 894ms/step
# Epoch 66/100
# 29/29 - 26s - loss: 0.0435 - accuracy: 0.9913 - val_loss: 0.4255 - val_accuracy: 0.9695 - 26s/epoch - 893ms/step
# Epoch 67/100
# 29/29 - 26s - loss: 0.0422 - accuracy: 0.9935 - val_loss: 0.4902 - val_accuracy: 0.9390 - 26s/epoch - 893ms/step
# Epoch 68/100
# 29/29 - 26s - loss: 0.0231 - accuracy: 0.9907 - val_loss: 0.5938 - val_accuracy: 0.9434 - 26s/epoch - 886ms/step
# Epoch 69/100
# 29/29 - 26s - loss: 0.0123 - accuracy: 0.9956 - val_loss: 0.5456 - val_accuracy: 0.9542 - 26s/epoch - 896ms/step
# Epoch 70/100
# 29/29 - 26s - loss: 0.0259 - accuracy: 0.9951 - val_loss: 0.3619 - val_accuracy: 0.9630 - 26s/epoch - 893ms/step
# Epoch 71/100
# 29/29 - 26s - loss: 0.0106 - accuracy: 0.9956 - val_loss: 0.5735 - val_accuracy: 0.9412 - 26s/epoch - 892ms/step
# Epoch 72/100
# 29/29 - 26s - loss: 0.0107 - accuracy: 0.9978 - val_loss: 0.2957 - val_accuracy: 0.9608 - 26s/epoch - 895ms/step
# Epoch 73/100
# 29/29 - 26s - loss: 0.0107 - accuracy: 0.9967 - val_loss: 0.2687 - val_accuracy: 0.9673 - 26s/epoch - 896ms/step
# Epoch 74/100
# 29/29 - 26s - loss: 0.0068 - accuracy: 0.9984 - val_loss: 0.2372 - val_accuracy: 0.9826 - 26s/epoch - 891ms/step
# Epoch 75/100
# 29/29 - 26s - loss: 0.0036 - accuracy: 0.9984 - val_loss: 8.5495 - val_accuracy: 0.5643 - 26s/epoch - 898ms/step
# Epoch 76/100
# 29/29 - 26s - loss: 0.0416 - accuracy: 0.9935 - val_loss: 0.4313 - val_accuracy: 0.9499 - 26s/epoch - 898ms/step
# Epoch 77/100
# 29/29 - 26s - loss: 0.0197 - accuracy: 0.9951 - val_loss: 0.2957 - val_accuracy: 0.9325 - 26s/epoch - 890ms/step
# Epoch 78/100
# 29/29 - 26s - loss: 0.0237 - accuracy: 0.9946 - val_loss: 0.4134 - val_accuracy: 0.9063 - 26s/epoch - 893ms/step
# Epoch 79/100
# 29/29 - 26s - loss: 0.0373 - accuracy: 0.9935 - val_loss: 0.6543 - val_accuracy: 0.9303 - 26s/epoch - 885ms/step
# Epoch 80/100
# 29/29 - 26s - loss: 0.0088 - accuracy: 0.9973 - val_loss: 1.1039 - val_accuracy: 0.8627 - 26s/epoch - 891ms/step
# Epoch 81/100
# 29/29 - 26s - loss: 0.0195 - accuracy: 0.9962 - val_loss: 1.0689 - val_accuracy: 0.8017 - 26s/epoch - 891ms/step
# Epoch 82/100
# 29/29 - 26s - loss: 0.0284 - accuracy: 0.9951 - val_loss: 8.7258 - val_accuracy: 0.7843 - 26s/epoch - 892ms/step
# Epoch 83/100
# 29/29 - 26s - loss: 0.0056 - accuracy: 0.9989 - val_loss: 0.2853 - val_accuracy: 0.9673 - 26s/epoch - 895ms/step
# Epoch 84/100
# 29/29 - 26s - loss: 0.0987 - accuracy: 0.9962 - val_loss: 8.4572 - val_accuracy: 0.6645 - 26s/epoch - 889ms/step
# Epoch 85/100
# 29/29 - 26s - loss: 0.0403 - accuracy: 0.9935 - val_loss: 0.4700 - val_accuracy: 0.9020 - 26s/epoch - 890ms/step
# Epoch 86/100
# 29/29 - 26s - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.5130 - val_accuracy: 0.9129 - 26s/epoch - 898ms/step
# Epoch 87/100
# 29/29 - 26s - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.2926 - val_accuracy: 0.9586 - 26s/epoch - 894ms/step
# Epoch 88/100
# 29/29 - 26s - loss: 0.0063 - accuracy: 0.9989 - val_loss: 0.4845 - val_accuracy: 0.9325 - 26s/epoch - 892ms/step
# Epoch 89/100
# 29/29 - 26s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.5134 - val_accuracy: 0.9194 - 26s/epoch - 885ms/step
# Epoch 90/100
# 29/29 - 26s - loss: 0.0072 - accuracy: 0.9984 - val_loss: 0.2999 - val_accuracy: 0.9651 - 26s/epoch - 889ms/step
# Epoch 91/100
# 29/29 - 26s - loss: 0.0079 - accuracy: 0.9984 - val_loss: 0.2518 - val_accuracy: 0.9695 - 26s/epoch - 886ms/step
# Epoch 92/100
# 29/29 - 26s - loss: 0.0060 - accuracy: 0.9973 - val_loss: 0.4957 - val_accuracy: 0.9390 - 26s/epoch - 888ms/step
# Epoch 93/100
# 29/29 - 26s - loss: 0.0117 - accuracy: 0.9978 - val_loss: 0.3045 - val_accuracy: 0.9717 - 26s/epoch - 888ms/step
# Epoch 94/100
# 29/29 - 26s - loss: 6.5871e-04 - accuracy: 1.0000 - val_loss: 0.2728 - val_accuracy: 0.9695 - 26s/epoch - 893ms/step
# Epoch 95/100
# 29/29 - 26s - loss: 0.0213 - accuracy: 0.9978 - val_loss: 0.4205 - val_accuracy: 0.9499 - 26s/epoch - 891ms/step
# Epoch 96/100
# 29/29 - 26s - loss: 0.0160 - accuracy: 0.9967 - val_loss: 1.8228 - val_accuracy: 0.8758 - 26s/epoch - 893ms/step
# Epoch 97/100
# 29/29 - 26s - loss: 0.0071 - accuracy: 0.9973 - val_loss: 0.1705 - val_accuracy: 0.9760 - 26s/epoch - 889ms/step
# Epoch 98/100
# 29/29 - 26s - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.1751 - val_accuracy: 0.9760 - 26s/epoch - 897ms/step
# Epoch 99/100
# 29/29 - 26s - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.2017 - val_accuracy: 0.9695 - 26s/epoch - 895ms/step
# Epoch 100/100
# 29/29 - 26s - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.2484 - val_accuracy: 0.9673 - 26s/epoch - 891ms/step
# 0.0376
# ***Performance on Test Data***
# Accuracy  : 0.928395061728395
# Precision : 0.9320149712306576
# f1Score : 0.9274691358024691
# [[130   1   4]
#  [  0 134   1]
#  [  5  18 112]]
# 7/7 [==============================] - 5s 725ms/step - loss: 0.7230 - accuracy: 0.9284
# Results for fold 2
# Found 1836 images belonging to 3 classes.
# Found 459 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.
# Epoch 1/100
# 29/29 - 28s - loss: 0.0684 - accuracy: 0.9880 - val_loss: 0.4927 - val_accuracy: 0.8083 - 28s/epoch - 981ms/step
# Epoch 2/100
# 29/29 - 27s - loss: 0.0180 - accuracy: 0.9951 - val_loss: 0.0280 - val_accuracy: 0.9935 - 27s/epoch - 938ms/step
# Epoch 3/100
# 29/29 - 27s - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.1037 - val_accuracy: 0.9869 - 27s/epoch - 938ms/step
# Epoch 4/100
# 29/29 - 27s - loss: 0.0106 - accuracy: 0.9951 - val_loss: 0.3353 - val_accuracy: 0.9434 - 27s/epoch - 931ms/step
# Epoch 5/100
# 29/29 - 27s - loss: 0.0133 - accuracy: 0.9967 - val_loss: 2.7575e-04 - val_accuracy: 1.0000 - 27s/epoch - 928ms/step
# Epoch 6/100
# 29/29 - 27s - loss: 0.0483 - accuracy: 0.9886 - val_loss: 0.4660 - val_accuracy: 0.9325 - 27s/epoch - 924ms/step
# Epoch 7/100
# 29/29 - 27s - loss: 0.0218 - accuracy: 0.9956 - val_loss: 0.0342 - val_accuracy: 0.9935 - 27s/epoch - 918ms/step
# Epoch 8/100
# 29/29 - 26s - loss: 0.0050 - accuracy: 0.9967 - val_loss: 0.0052 - val_accuracy: 0.9978 - 26s/epoch - 913ms/step
# Epoch 9/100
# 29/29 - 27s - loss: 0.0476 - accuracy: 0.9913 - val_loss: 0.3407 - val_accuracy: 0.9041 - 27s/epoch - 915ms/step
# Epoch 10/100
# 29/29 - 26s - loss: 0.0322 - accuracy: 0.9935 - val_loss: 0.0410 - val_accuracy: 0.9913 - 26s/epoch - 910ms/step
# Epoch 11/100
# 29/29 - 26s - loss: 0.0085 - accuracy: 0.9967 - val_loss: 0.0440 - val_accuracy: 0.9891 - 26s/epoch - 912ms/step
# Epoch 12/100
# 29/29 - 27s - loss: 0.0075 - accuracy: 0.9973 - val_loss: 0.0311 - val_accuracy: 0.9847 - 27s/epoch - 926ms/step
# Epoch 13/100
# 29/29 - 26s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1093 - val_accuracy: 0.9717 - 26s/epoch - 909ms/step
# Epoch 14/100
# 29/29 - 26s - loss: 0.0042 - accuracy: 0.9989 - val_loss: 1.6458 - val_accuracy: 0.9172 - 26s/epoch - 908ms/step
# Epoch 15/100
# 29/29 - 26s - loss: 0.0022 - accuracy: 0.9989 - val_loss: 0.0047 - val_accuracy: 0.9956 - 26s/epoch - 908ms/step
# Epoch 16/100
# 29/29 - 27s - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.1231 - val_accuracy: 0.9651 - 27s/epoch - 915ms/step
# Epoch 17/100
# 29/29 - 26s - loss: 0.0055 - accuracy: 0.9989 - val_loss: 0.0099 - val_accuracy: 0.9956 - 26s/epoch - 913ms/step
# Epoch 18/100
# 29/29 - 26s - loss: 0.0078 - accuracy: 0.9978 - val_loss: 0.3672 - val_accuracy: 0.9390 - 26s/epoch - 912ms/step
# Epoch 19/100
# 29/29 - 26s - loss: 0.0019 - accuracy: 0.9989 - val_loss: 0.0152 - val_accuracy: 0.9913 - 26s/epoch - 911ms/step
# Epoch 20/100
# 29/29 - 26s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0145 - val_accuracy: 0.9978 - 26s/epoch - 910ms/step
# Epoch 21/100
# 29/29 - 26s - loss: 2.4467e-04 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9978 - 26s/epoch - 911ms/step
# Epoch 22/100
# 29/29 - 26s - loss: 0.0015 - accuracy: 0.9989 - val_loss: 0.0038 - val_accuracy: 0.9978 - 26s/epoch - 913ms/step
# Epoch 23/100
# 29/29 - 27s - loss: 0.0014 - accuracy: 0.9989 - val_loss: 0.0030 - val_accuracy: 0.9978 - 27s/epoch - 915ms/step
# Epoch 24/100
# 29/29 - 27s - loss: 0.0024 - accuracy: 0.9989 - val_loss: 0.0330 - val_accuracy: 0.9891 - 27s/epoch - 923ms/step
# Epoch 25/100
# 29/29 - 26s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0103 - val_accuracy: 0.9956 - 26s/epoch - 912ms/step
# Epoch 26/100
# 29/29 - 27s - loss: 9.5922e-05 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 0.9956 - 27s/epoch - 917ms/step
# Epoch 27/100
# 29/29 - 26s - loss: 9.3174e-04 - accuracy: 0.9995 - val_loss: 0.0255 - val_accuracy: 0.9913 - 26s/epoch - 912ms/step
# Epoch 28/100
# 29/29 - 27s - loss: 2.4139e-04 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 0.9956 - 27s/epoch - 923ms/step
# Epoch 29/100
# 29/29 - 26s - loss: 4.3225e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9978 - 26s/epoch - 912ms/step
# Epoch 30/100
# 29/29 - 26s - loss: 1.7591e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000 - 26s/epoch - 908ms/step
# Epoch 31/100
# 29/29 - 26s - loss: 7.5574e-05 - accuracy: 1.0000 - val_loss: 6.7998e-04 - val_accuracy: 1.0000 - 26s/epoch - 914ms/step
# Epoch 32/100
# 29/29 - 26s - loss: 5.2355e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000 - 26s/epoch - 904ms/step
# Epoch 33/100
# 29/29 - 26s - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.2990 - val_accuracy: 0.9717 - 26s/epoch - 910ms/step
# Epoch 34/100
# 29/29 - 26s - loss: 8.2381e-04 - accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 0.9935 - 26s/epoch - 901ms/step
# Epoch 35/100
# 29/29 - 26s - loss: 4.8050e-05 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9956 - 26s/epoch - 907ms/step
# Epoch 36/100
# 29/29 - 26s - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.0373 - val_accuracy: 0.9956 - 26s/epoch - 898ms/step
# Epoch 37/100
# 29/29 - 26s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0204 - val_accuracy: 0.9956 - 26s/epoch - 900ms/step
# Epoch 38/100
# 29/29 - 26s - loss: 3.5244e-04 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 0.9935 - 26s/epoch - 895ms/step
# Epoch 39/100
# 29/29 - 26s - loss: 8.2716e-04 - accuracy: 0.9995 - val_loss: 0.0011 - val_accuracy: 1.0000 - 26s/epoch - 899ms/step
# Epoch 40/100
# 29/29 - 26s - loss: 1.7859e-05 - accuracy: 1.0000 - val_loss: 4.6401e-04 - val_accuracy: 1.0000 - 26s/epoch - 892ms/step
# Epoch 41/100
# 29/29 - 26s - loss: 1.3464e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - 26s/epoch - 891ms/step
# Epoch 42/100
# 29/29 - 26s - loss: 5.4102e-05 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 0.9978 - 26s/epoch - 899ms/step
# Epoch 43/100
# 29/29 - 26s - loss: 1.8774e-05 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - 26s/epoch - 888ms/step
# Epoch 44/100
# 29/29 - 26s - loss: 1.3198e-04 - accuracy: 1.0000 - val_loss: 4.2607e-04 - val_accuracy: 1.0000 - 26s/epoch - 898ms/step
# Epoch 45/100
# 29/29 - 26s - loss: 8.7588e-05 - accuracy: 1.0000 - val_loss: 3.2836e-04 - val_accuracy: 1.0000 - 26s/epoch - 893ms/step
# Epoch 46/100
# 29/29 - 26s - loss: 0.0066 - accuracy: 0.9984 - val_loss: 8.1881 - val_accuracy: 0.6841 - 26s/epoch - 894ms/step
# Epoch 47/100
# 29/29 - 26s - loss: 0.0130 - accuracy: 0.9962 - val_loss: 11.4206 - val_accuracy: 0.6688 - 26s/epoch - 904ms/step
# Epoch 48/100
# 29/29 - 26s - loss: 0.0098 - accuracy: 0.9951 - val_loss: 2.9941 - val_accuracy: 0.8758 - 26s/epoch - 898ms/step
# Epoch 49/100
# 29/29 - 26s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.5666 - val_accuracy: 0.9455 - 26s/epoch - 891ms/step
# Epoch 50/100
# 29/29 - 26s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.2937 - val_accuracy: 0.9760 - 26s/epoch - 891ms/step
# Epoch 51/100
# 29/29 - 26s - loss: 5.1237e-04 - accuracy: 1.0000 - val_loss: 0.2517 - val_accuracy: 0.9695 - 26s/epoch - 887ms/step
# Epoch 52/100
# 29/29 - 26s - loss: 5.8684e-04 - accuracy: 0.9995 - val_loss: 0.0837 - val_accuracy: 0.9847 - 26s/epoch - 895ms/step
# Epoch 53/100
# 29/29 - 26s - loss: 0.0114 - accuracy: 0.9973 - val_loss: 0.1141 - val_accuracy: 0.9826 - 26s/epoch - 888ms/step
# Epoch 54/100
# 29/29 - 26s - loss: 0.1093 - accuracy: 0.9913 - val_loss: 7.0425 - val_accuracy: 0.8344 - 26s/epoch - 888ms/step
# Epoch 55/100
# 29/29 - 26s - loss: 0.0472 - accuracy: 0.9907 - val_loss: 17.1074 - val_accuracy: 0.6972 - 26s/epoch - 890ms/step
# Epoch 56/100
# 29/29 - 26s - loss: 0.1048 - accuracy: 0.9886 - val_loss: 0.1382 - val_accuracy: 0.9782 - 26s/epoch - 886ms/step
# Epoch 57/100
# 29/29 - 26s - loss: 0.0990 - accuracy: 0.9880 - val_loss: 0.5349 - val_accuracy: 0.9760 - 26s/epoch - 893ms/step
# Epoch 58/100
# 29/29 - 26s - loss: 0.0298 - accuracy: 0.9929 - val_loss: 0.4311 - val_accuracy: 0.9586 - 26s/epoch - 893ms/step
# Epoch 59/100
# 29/29 - 26s - loss: 0.0085 - accuracy: 0.9978 - val_loss: 0.1532 - val_accuracy: 0.9826 - 26s/epoch - 904ms/step
# Epoch 60/100
# 29/29 - 26s - loss: 0.0529 - accuracy: 0.9935 - val_loss: 0.1615 - val_accuracy: 0.9826 - 26s/epoch - 890ms/step
# Epoch 61/100
# 29/29 - 26s - loss: 0.0193 - accuracy: 0.9956 - val_loss: 0.4258 - val_accuracy: 0.9695 - 26s/epoch - 892ms/step
# Epoch 62/100
# 29/29 - 26s - loss: 0.0167 - accuracy: 0.9967 - val_loss: 0.2504 - val_accuracy: 0.9782 - 26s/epoch - 893ms/step
# Epoch 63/100
# 29/29 - 26s - loss: 0.0064 - accuracy: 0.9989 - val_loss: 0.1568 - val_accuracy: 0.9891 - 26s/epoch - 897ms/step
# Epoch 64/100
# 29/29 - 26s - loss: 0.0139 - accuracy: 0.9956 - val_loss: 0.3119 - val_accuracy: 0.9630 - 26s/epoch - 892ms/step
# Epoch 65/100
# 29/29 - 26s - loss: 0.0072 - accuracy: 0.9989 - val_loss: 1.3209 - val_accuracy: 0.8627 - 26s/epoch - 887ms/step
# Epoch 66/100
# 29/29 - 26s - loss: 0.0363 - accuracy: 0.9967 - val_loss: 0.1381 - val_accuracy: 0.9804 - 26s/epoch - 891ms/step
# Epoch 67/100
# 29/29 - 26s - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.1394 - val_accuracy: 0.9804 - 26s/epoch - 884ms/step
# Epoch 68/100
# 29/29 - 26s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0899 - val_accuracy: 0.9891 - 26s/epoch - 886ms/step
# Epoch 69/100
# 29/29 - 26s - loss: 1.6177e-04 - accuracy: 1.0000 - val_loss: 0.0710 - val_accuracy: 0.9913 - 26s/epoch - 888ms/step
# Epoch 70/100
# 29/29 - 26s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0763 - val_accuracy: 0.9935 - 26s/epoch - 891ms/step
# Epoch 71/100
# 29/29 - 26s - loss: 1.9136e-04 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 0.9935 - 26s/epoch - 901ms/step
# Epoch 72/100
# 29/29 - 26s - loss: 6.8840e-04 - accuracy: 1.0000 - val_loss: 0.0722 - val_accuracy: 0.9956 - 26s/epoch - 895ms/step
# Epoch 73/100
# 29/29 - 26s - loss: 0.0112 - accuracy: 0.9989 - val_loss: 0.0722 - val_accuracy: 0.9935 - 26s/epoch - 893ms/step
# Epoch 74/100
# 29/29 - 26s - loss: 0.0080 - accuracy: 0.9995 - val_loss: 0.2268 - val_accuracy: 0.9651 - 26s/epoch - 889ms/step
# Epoch 75/100
# 29/29 - 26s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0491 - val_accuracy: 0.9913 - 26s/epoch - 899ms/step
# Epoch 76/100
# 29/29 - 26s - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0719 - val_accuracy: 0.9891 - 26s/epoch - 891ms/step
# Epoch 77/100
# 29/29 - 26s - loss: 3.7550e-04 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9739 - 26s/epoch - 897ms/step
# Epoch 78/100
# 29/29 - 26s - loss: 4.1501e-04 - accuracy: 1.0000 - val_loss: 0.2070 - val_accuracy: 0.9782 - 26s/epoch - 886ms/step
# Epoch 79/100
# 29/29 - 26s - loss: 0.0053 - accuracy: 0.9995 - val_loss: 0.5171 - val_accuracy: 0.9630 - 26s/epoch - 893ms/step
# Epoch 80/100
# 29/29 - 26s - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.2095 - val_accuracy: 0.9739 - 26s/epoch - 886ms/step
# Epoch 81/100
# 29/29 - 26s - loss: 0.0052 - accuracy: 0.9995 - val_loss: 0.2132 - val_accuracy: 0.9717 - 26s/epoch - 896ms/step
# Epoch 82/100
# 29/29 - 26s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.1288 - val_accuracy: 0.9804 - 26s/epoch - 880ms/step
# Epoch 83/100
# 29/29 - 26s - loss: 8.3748e-04 - accuracy: 0.9995 - val_loss: 0.0319 - val_accuracy: 0.9935 - 26s/epoch - 892ms/step
# Epoch 84/100
# 29/29 - 26s - loss: 5.0297e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9956 - 26s/epoch - 884ms/step
# Epoch 85/100
# 29/29 - 26s - loss: 0.0054 - accuracy: 0.9989 - val_loss: 0.0627 - val_accuracy: 0.9935 - 26s/epoch - 886ms/step
# Epoch 86/100
# 29/29 - 26s - loss: 5.5655e-04 - accuracy: 0.9995 - val_loss: 0.1929 - val_accuracy: 0.9760 - 26s/epoch - 891ms/step
# Epoch 87/100
# 29/29 - 26s - loss: 1.7726e-04 - accuracy: 1.0000 - val_loss: 0.1746 - val_accuracy: 0.9782 - 26s/epoch - 882ms/step
# Epoch 88/100
# 29/29 - 26s - loss: 2.8059e-04 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9869 - 26s/epoch - 888ms/step
# Epoch 89/100
# 29/29 - 26s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0577 - val_accuracy: 0.9956 - 26s/epoch - 893ms/step
# Epoch 90/100
# 29/29 - 26s - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.1067 - val_accuracy: 0.9847 - 26s/epoch - 887ms/step
# Epoch 91/100
# 29/29 - 26s - loss: 3.2739e-05 - accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9891 - 26s/epoch - 884ms/step
# Epoch 92/100
# 29/29 - 26s - loss: 9.9656e-04 - accuracy: 0.9995 - val_loss: 0.0144 - val_accuracy: 0.9935 - 26s/epoch - 894ms/step
# Epoch 93/100
# 29/29 - 26s - loss: 7.8000e-05 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 0.9978 - 26s/epoch - 894ms/step
# Epoch 94/100
# 29/29 - 26s - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1047 - val_accuracy: 0.9891 - 26s/epoch - 900ms/step
# Epoch 95/100
# 29/29 - 26s - loss: 2.7841e-04 - accuracy: 1.0000 - val_loss: 0.0303 - val_accuracy: 0.9956 - 26s/epoch - 897ms/step
# Epoch 96/100
# 29/29 - 26s - loss: 8.6265e-05 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 0.9978 - 26s/epoch - 887ms/step
# Epoch 97/100
# 29/29 - 26s - loss: 0.0022 - accuracy: 0.9995 - val_loss: 41.1774 - val_accuracy: 0.5817 - 26s/epoch - 890ms/step
# Epoch 98/100
# 29/29 - 26s - loss: 0.0291 - accuracy: 0.9973 - val_loss: 0.2191 - val_accuracy: 0.9782 - 26s/epoch - 892ms/step
# Epoch 99/100
# 29/29 - 26s - loss: 0.0146 - accuracy: 0.9967 - val_loss: 0.2582 - val_accuracy: 0.9782 - 26s/epoch - 889ms/step
# Epoch 100/100
# 29/29 - 26s - loss: 0.0136 - accuracy: 0.9978 - val_loss: 0.1489 - val_accuracy: 0.9869 - 26s/epoch - 891ms/step
# 0.0386
# ***Performance on Test Data***
# Accuracy  : 0.9530864197530864
# Precision : 0.9538456100135891
# f1Score : 0.9529095976823292
# [[130   1   4]
#  [  2 133   0]
#  [  3   9 123]]
# 7/7 [==============================] - 4s 667ms/step - loss: 0.6215 - accuracy: 0.9531
# Results for fold 3
# Found 1836 images belonging to 3 classes.
# Found 459 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.
# Epoch 1/100
# 29/29 - 27s - loss: 0.0293 - accuracy: 0.9956 - val_loss: 0.1587 - val_accuracy: 0.9477 - 27s/epoch - 924ms/step
# Epoch 2/100
# 29/29 - 26s - loss: 0.0842 - accuracy: 0.9886 - val_loss: 0.3814 - val_accuracy: 0.9434 - 26s/epoch - 887ms/step
# Epoch 3/100
# 29/29 - 26s - loss: 0.0759 - accuracy: 0.9902 - val_loss: 0.1733 - val_accuracy: 0.9826 - 26s/epoch - 885ms/step
# Epoch 4/100
# 29/29 - 26s - loss: 0.0376 - accuracy: 0.9918 - val_loss: 0.3763 - val_accuracy: 0.9695 - 26s/epoch - 890ms/step
# Epoch 5/100
# 29/29 - 26s - loss: 0.0513 - accuracy: 0.9897 - val_loss: 0.6586 - val_accuracy: 0.9455 - 26s/epoch - 883ms/step
# Epoch 6/100
# 29/29 - 26s - loss: 0.0177 - accuracy: 0.9973 - val_loss: 0.0505 - val_accuracy: 0.9891 - 26s/epoch - 888ms/step
# Epoch 7/100
# 29/29 - 26s - loss: 0.0051 - accuracy: 0.9978 - val_loss: 0.0694 - val_accuracy: 0.9935 - 26s/epoch - 896ms/step
# Epoch 8/100
# 29/29 - 26s - loss: 0.0330 - accuracy: 0.9978 - val_loss: 0.2847 - val_accuracy: 0.9651 - 26s/epoch - 884ms/step
# Epoch 9/100
# 29/29 - 26s - loss: 0.0204 - accuracy: 0.9951 - val_loss: 0.0269 - val_accuracy: 0.9978 - 26s/epoch - 888ms/step
# Epoch 10/100
# 29/29 - 26s - loss: 0.0025 - accuracy: 0.9978 - val_loss: 0.0485 - val_accuracy: 0.9869 - 26s/epoch - 886ms/step
# Epoch 11/100
# 29/29 - 26s - loss: 0.0076 - accuracy: 0.9984 - val_loss: 0.0575 - val_accuracy: 0.9826 - 26s/epoch - 887ms/step
# Epoch 12/100
# 29/29 - 26s - loss: 0.0332 - accuracy: 0.9940 - val_loss: 0.0618 - val_accuracy: 0.9782 - 26s/epoch - 887ms/step
# Epoch 13/100
# 29/29 - 26s - loss: 0.0400 - accuracy: 0.9956 - val_loss: 0.9806 - val_accuracy: 0.8453 - 26s/epoch - 887ms/step
# Epoch 14/100
# 29/29 - 26s - loss: 0.0324 - accuracy: 0.9967 - val_loss: 0.0745 - val_accuracy: 0.9760 - 26s/epoch - 887ms/step
# Epoch 15/100
# 29/29 - 26s - loss: 0.0504 - accuracy: 0.9956 - val_loss: 0.5838 - val_accuracy: 0.8540 - 26s/epoch - 881ms/step
# Epoch 16/100
# 29/29 - 26s - loss: 0.0767 - accuracy: 0.9951 - val_loss: 0.0349 - val_accuracy: 0.9935 - 26s/epoch - 887ms/step
# Epoch 17/100
# 29/29 - 26s - loss: 0.0295 - accuracy: 0.9967 - val_loss: 0.0031 - val_accuracy: 0.9978 - 26s/epoch - 887ms/step
# Epoch 18/100
# 29/29 - 26s - loss: 0.0015 - accuracy: 0.9989 - val_loss: 0.0105 - val_accuracy: 0.9935 - 26s/epoch - 891ms/step
# Epoch 19/100
# 29/29 - 26s - loss: 4.4700e-04 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 0.9956 - 26s/epoch - 896ms/step
# Epoch 20/100
# 29/29 - 26s - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.0026 - val_accuracy: 1.0000 - 26s/epoch - 895ms/step
# Epoch 21/100
# 29/29 - 26s - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0068 - val_accuracy: 0.9956 - 26s/epoch - 888ms/step
# Epoch 22/100
# 29/29 - 26s - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0102 - val_accuracy: 0.9978 - 26s/epoch - 893ms/step
# Epoch 23/100
# 29/29 - 26s - loss: 9.0469e-04 - accuracy: 0.9995 - val_loss: 0.0078 - val_accuracy: 0.9978 - 26s/epoch - 881ms/step
# Epoch 24/100
# 29/29 - 26s - loss: 3.1315e-04 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 0.9956 - 26s/epoch - 892ms/step
# Epoch 25/100
# 29/29 - 26s - loss: 4.3151e-04 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 0.9978 - 26s/epoch - 882ms/step
# Epoch 26/100
# 29/29 - 26s - loss: 0.0012 - accuracy: 0.9989 - val_loss: 0.0010 - val_accuracy: 1.0000 - 26s/epoch - 889ms/step
# Epoch 27/100
# 29/29 - 26s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 5.1325e-04 - val_accuracy: 1.0000 - 26s/epoch - 885ms/step
# Epoch 28/100
# 29/29 - 26s - loss: 2.4821e-04 - accuracy: 1.0000 - val_loss: 0.0200 - val_accuracy: 0.9935 - 26s/epoch - 883ms/step
# Epoch 29/100
# 29/29 - 26s - loss: 2.0824e-04 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 0.9956 - 26s/epoch - 886ms/step
# Epoch 30/100
# 29/29 - 26s - loss: 1.0251e-04 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 0.9978 - 26s/epoch - 884ms/step
# Epoch 31/100
# 29/29 - 26s - loss: 1.7445e-04 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9978 - 26s/epoch - 894ms/step
# Epoch 32/100
# 29/29 - 26s - loss: 7.2293e-04 - accuracy: 0.9995 - val_loss: 1.0207e-05 - val_accuracy: 1.0000 - 26s/epoch - 881ms/step
# Epoch 33/100
# 29/29 - 26s - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0266 - val_accuracy: 0.9956 - 26s/epoch - 879ms/step
# Epoch 34/100
# 29/29 - 26s - loss: 9.9459e-05 - accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 0.9956 - 26s/epoch - 882ms/step
# Epoch 35/100
# 29/29 - 26s - loss: 2.8823e-04 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9956 - 26s/epoch - 880ms/step
# Epoch 36/100
# 29/29 - 26s - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.1044 - val_accuracy: 0.9847 - 26s/epoch - 884ms/step
# Epoch 37/100
# 29/29 - 26s - loss: 0.0015 - accuracy: 0.9989 - val_loss: 1.2779e-05 - val_accuracy: 1.0000 - 26s/epoch - 892ms/step
# Epoch 38/100
# 29/29 - 26s - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.1240 - val_accuracy: 0.9717 - 26s/epoch - 880ms/step
# Epoch 39/100
# 29/29 - 26s - loss: 0.0018 - accuracy: 0.9989 - val_loss: 0.0797 - val_accuracy: 0.9739 - 26s/epoch - 882ms/step
# Epoch 40/100
# 29/29 - 26s - loss: 0.0032 - accuracy: 0.9995 - val_loss: 0.0368 - val_accuracy: 0.9913 - 26s/epoch - 880ms/step
# Epoch 41/100
# 29/29 - 26s - loss: 0.0077 - accuracy: 0.9989 - val_loss: 0.2213 - val_accuracy: 0.9542 - 26s/epoch - 885ms/step
# Epoch 42/100
# 29/29 - 25s - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.4101 - val_accuracy: 0.9368 - 25s/epoch - 873ms/step
# Epoch 43/100
# 29/29 - 26s - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.5052 - val_accuracy: 0.9325 - 26s/epoch - 883ms/step
# Epoch 44/100
# 29/29 - 26s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.2194 - val_accuracy: 0.9651 - 26s/epoch - 882ms/step
# Epoch 45/100
# 29/29 - 26s - loss: 0.0098 - accuracy: 0.9989 - val_loss: 0.1143 - val_accuracy: 0.9826 - 26s/epoch - 883ms/step
# Epoch 46/100
# 29/29 - 26s - loss: 0.0399 - accuracy: 0.9973 - val_loss: 0.2844 - val_accuracy: 0.9325 - 26s/epoch - 884ms/step
# Epoch 47/100
# 29/29 - 26s - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.1822 - val_accuracy: 0.9673 - 26s/epoch - 880ms/step
# Epoch 48/100
# 29/29 - 25s - loss: 0.0072 - accuracy: 0.9989 - val_loss: 0.0293 - val_accuracy: 0.9913 - 25s/epoch - 879ms/step
# Epoch 49/100
# 29/29 - 26s - loss: 0.0023 - accuracy: 0.9989 - val_loss: 0.0615 - val_accuracy: 0.9739 - 26s/epoch - 884ms/step
# Epoch 50/100
# 29/29 - 25s - loss: 6.8428e-04 - accuracy: 0.9995 - val_loss: 0.0697 - val_accuracy: 0.9782 - 25s/epoch - 879ms/step
# Epoch 51/100
# 29/29 - 26s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0466 - val_accuracy: 0.9826 - 26s/epoch - 888ms/step
# Epoch 52/100
# 29/29 - 26s - loss: 1.0491e-04 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 0.9739 - 26s/epoch - 884ms/step
# Epoch 53/100
# 29/29 - 26s - loss: 0.0087 - accuracy: 0.9989 - val_loss: 0.0203 - val_accuracy: 0.9956 - 26s/epoch - 884ms/step
# Epoch 54/100
# 29/29 - 26s - loss: 0.0069 - accuracy: 0.9995 - val_loss: 0.0272 - val_accuracy: 0.9935 - 26s/epoch - 886ms/step
# Epoch 55/100
# 29/29 - 26s - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.0166 - val_accuracy: 0.9956 - 26s/epoch - 885ms/step
# Epoch 56/100
# 29/29 - 26s - loss: 0.0057 - accuracy: 0.9995 - val_loss: 0.0131 - val_accuracy: 0.9978 - 26s/epoch - 884ms/step
# Epoch 57/100
# 29/29 - 26s - loss: 0.0016 - accuracy: 0.9989 - val_loss: 0.0195 - val_accuracy: 0.9956 - 26s/epoch - 880ms/step
# Epoch 58/100
# 29/29 - 26s - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.1518 - val_accuracy: 0.9499 - 26s/epoch - 884ms/step
# Epoch 59/100
# 29/29 - 25s - loss: 0.0033 - accuracy: 0.9995 - val_loss: 0.2429 - val_accuracy: 0.9281 - 25s/epoch - 876ms/step
# Epoch 60/100
# 29/29 - 26s - loss: 0.0020 - accuracy: 0.9989 - val_loss: 0.2704 - val_accuracy: 0.9325 - 26s/epoch - 881ms/step
# Epoch 61/100
# 29/29 - 25s - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.2417 - val_accuracy: 0.9303 - 25s/epoch - 874ms/step
# Epoch 62/100
# 29/29 - 26s - loss: 1.6544e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9499 - 26s/epoch - 882ms/step
# Epoch 63/100
# 29/29 - 26s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0413 - val_accuracy: 0.9826 - 26s/epoch - 881ms/step
# Epoch 64/100
# 29/29 - 26s - loss: 0.0092 - accuracy: 0.9984 - val_loss: 0.1730 - val_accuracy: 0.9760 - 26s/epoch - 890ms/step
# Epoch 65/100
# 29/29 - 25s - loss: 0.0048 - accuracy: 0.9995 - val_loss: 0.1015 - val_accuracy: 0.9913 - 25s/epoch - 877ms/step
# Epoch 66/100
# 29/29 - 26s - loss: 0.0087 - accuracy: 0.9978 - val_loss: 0.5903 - val_accuracy: 0.9542 - 26s/epoch - 882ms/step
# Epoch 67/100
# 29/29 - 26s - loss: 0.0080 - accuracy: 0.9989 - val_loss: 0.1136 - val_accuracy: 0.9826 - 26s/epoch - 898ms/step
# Epoch 68/100
# 29/29 - 25s - loss: 0.0143 - accuracy: 0.9984 - val_loss: 0.1442 - val_accuracy: 0.9760 - 25s/epoch - 876ms/step
# Epoch 69/100
# 29/29 - 26s - loss: 0.0245 - accuracy: 0.9956 - val_loss: 28.4943 - val_accuracy: 0.7168 - 26s/epoch - 881ms/step
# Epoch 70/100
# 29/29 - 26s - loss: 0.0426 - accuracy: 0.9956 - val_loss: 0.0024 - val_accuracy: 0.9978 - 26s/epoch - 881ms/step
# Epoch 71/100
# 29/29 - 26s - loss: 0.0152 - accuracy: 0.9973 - val_loss: 0.0470 - val_accuracy: 0.9869 - 26s/epoch - 885ms/step
# Epoch 72/100
# 29/29 - 26s - loss: 0.0110 - accuracy: 0.9956 - val_loss: 0.0255 - val_accuracy: 0.9956 - 26s/epoch - 885ms/step
# Epoch 73/100
# 29/29 - 26s - loss: 7.8670e-04 - accuracy: 0.9995 - val_loss: 0.0611 - val_accuracy: 0.9826 - 26s/epoch - 885ms/step
# Epoch 74/100
# 29/29 - 26s - loss: 9.1178e-04 - accuracy: 0.9995 - val_loss: 0.0763 - val_accuracy: 0.9804 - 26s/epoch - 885ms/step
# Epoch 75/100
# 29/29 - 26s - loss: 2.8473e-05 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 0.9891 - 26s/epoch - 892ms/step
# Epoch 76/100
# 29/29 - 25s - loss: 2.1409e-05 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 0.9913 - 25s/epoch - 878ms/step
# Epoch 77/100
# 29/29 - 25s - loss: 7.3326e-04 - accuracy: 0.9995 - val_loss: 0.0075 - val_accuracy: 0.9978 - 25s/epoch - 877ms/step
# Epoch 78/100
# 29/29 - 26s - loss: 9.5083e-05 - accuracy: 1.0000 - val_loss: 7.2427e-04 - val_accuracy: 1.0000 - 26s/epoch - 881ms/step
# Epoch 79/100
# 29/29 - 26s - loss: 2.3874e-04 - accuracy: 1.0000 - val_loss: 2.6521e-04 - val_accuracy: 1.0000 - 26s/epoch - 894ms/step
# Epoch 80/100
# 29/29 - 26s - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.0198 - val_accuracy: 0.9956 - 26s/epoch - 882ms/step
# Epoch 81/100
# 29/29 - 26s - loss: 0.0024 - accuracy: 0.9989 - val_loss: 0.0191 - val_accuracy: 0.9935 - 26s/epoch - 895ms/step
# Epoch 82/100
# 29/29 - 26s - loss: 0.0256 - accuracy: 0.9962 - val_loss: 56.8147 - val_accuracy: 0.6318 - 26s/epoch - 881ms/step
# Epoch 83/100
# 29/29 - 26s - loss: 0.0044 - accuracy: 0.9995 - val_loss: 0.0033 - val_accuracy: 0.9978 - 26s/epoch - 889ms/step
# Epoch 84/100
# 29/29 - 26s - loss: 0.0070 - accuracy: 0.9984 - val_loss: 0.0186 - val_accuracy: 0.9978 - 26s/epoch - 886ms/step
# Epoch 85/100
# 29/29 - 26s - loss: 0.0074 - accuracy: 0.9995 - val_loss: 0.0109 - val_accuracy: 0.9978 - 26s/epoch - 887ms/step
# Epoch 86/100
# 29/29 - 25s - loss: 0.0032 - accuracy: 0.9995 - val_loss: 0.1755 - val_accuracy: 0.9847 - 25s/epoch - 878ms/step
# Epoch 87/100
# 29/29 - 25s - loss: 0.0100 - accuracy: 0.9984 - val_loss: 2.0849 - val_accuracy: 0.9390 - 25s/epoch - 879ms/step
# Epoch 88/100
# 29/29 - 26s - loss: 0.0017 - accuracy: 0.9989 - val_loss: 0.0190 - val_accuracy: 0.9935 - 26s/epoch - 881ms/step
# Epoch 89/100
# 29/29 - 26s - loss: 2.0652e-04 - accuracy: 1.0000 - val_loss: 1.3871e-04 - val_accuracy: 1.0000 - 26s/epoch - 885ms/step
# Epoch 90/100
# 29/29 - 26s - loss: 9.6183e-04 - accuracy: 0.9995 - val_loss: 0.0169 - val_accuracy: 0.9956 - 26s/epoch - 890ms/step
# Epoch 91/100
# 29/29 - 26s - loss: 0.0048 - accuracy: 0.9995 - val_loss: 0.0102 - val_accuracy: 0.9956 - 26s/epoch - 887ms/step
# Epoch 92/100
# 29/29 - 26s - loss: 1.8277e-04 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9978 - 26s/epoch - 891ms/step
# Epoch 93/100
# 29/29 - 25s - loss: 1.2955e-04 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 0.9978 - 25s/epoch - 877ms/step
# Epoch 94/100
# 29/29 - 26s - loss: 3.6467e-04 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9956 - 26s/epoch - 880ms/step
# Epoch 95/100
# 29/29 - 26s - loss: 0.0208 - accuracy: 0.9984 - val_loss: 1.1201 - val_accuracy: 0.8627 - 26s/epoch - 882ms/step
# Epoch 96/100
# 29/29 - 26s - loss: 0.0257 - accuracy: 0.9978 - val_loss: 2.2551 - val_accuracy: 0.7320 - 26s/epoch - 889ms/step
# Epoch 97/100
# 29/29 - 25s - loss: 0.0505 - accuracy: 0.9989 - val_loss: 20.3065 - val_accuracy: 0.6797 - 25s/epoch - 877ms/step
# Epoch 98/100
# 29/29 - 26s - loss: 0.0018 - accuracy: 0.9989 - val_loss: 6.5654 - val_accuracy: 0.8649 - 26s/epoch - 887ms/step
# Epoch 99/100
# 29/29 - 26s - loss: 3.3491e-04 - accuracy: 1.0000 - val_loss: 2.4223 - val_accuracy: 0.9412 - 26s/epoch - 881ms/step
# Epoch 100/100
# 29/29 - 26s - loss: 9.6207e-04 - accuracy: 0.9995 - val_loss: 0.1456 - val_accuracy: 0.9826 - 26s/epoch - 888ms/step
# 0.0387
# ***Performance on Test Data***
# Accuracy  : 0.9555555555555556
# Precision : 0.9559269644046158
# f1Score : 0.9554286829649148
# [[131   1   3]
#  [  1 132   2]
#  [  3   8 124]]
# 7/7 [==============================] - 4s 660ms/step - loss: 0.7196 - accuracy: 0.9556
# Results for fold 4
# Found 1836 images belonging to 3 classes.
# Found 459 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.
# Epoch 1/100
# 29/29 - 26s - loss: 0.0160 - accuracy: 0.9967 - val_loss: 9.1317 - val_accuracy: 0.8322 - 26s/epoch - 910ms/step
# Epoch 2/100
# 29/29 - 26s - loss: 0.0305 - accuracy: 0.9951 - val_loss: 0.2479 - val_accuracy: 0.9368 - 26s/epoch - 893ms/step
# Epoch 3/100
# 29/29 - 26s - loss: 0.0453 - accuracy: 0.9918 - val_loss: 0.3659 - val_accuracy: 0.9259 - 26s/epoch - 896ms/step
# Epoch 4/100
# 29/29 - 26s - loss: 0.0262 - accuracy: 0.9956 - val_loss: 0.6894 - val_accuracy: 0.8475 - 26s/epoch - 890ms/step
# Epoch 5/100
# 29/29 - 26s - loss: 0.0223 - accuracy: 0.9956 - val_loss: 1.1788 - val_accuracy: 0.8976 - 26s/epoch - 885ms/step
# Epoch 6/100
# 29/29 - 26s - loss: 0.0125 - accuracy: 0.9984 - val_loss: 0.7667 - val_accuracy: 0.9107 - 26s/epoch - 887ms/step
# Epoch 7/100
# 29/29 - 25s - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.2279 - val_accuracy: 0.9586 - 25s/epoch - 876ms/step
# Epoch 8/100
# 29/29 - 25s - loss: 0.0129 - accuracy: 0.9978 - val_loss: 0.0191 - val_accuracy: 0.9978 - 25s/epoch - 878ms/step
# Epoch 9/100
# 29/29 - 26s - loss: 1.4328e-05 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9956 - 26s/epoch - 885ms/step
# Epoch 10/100
# 29/29 - 26s - loss: 3.2749e-04 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9978 - 26s/epoch - 896ms/step
# Epoch 11/100
# 29/29 - 26s - loss: 0.0014 - accuracy: 0.9989 - val_loss: 0.0208 - val_accuracy: 0.9978 - 26s/epoch - 896ms/step
# Epoch 12/100
# 29/29 - 26s - loss: 5.9880e-05 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9978 - 26s/epoch - 892ms/step
# Epoch 13/100
# 29/29 - 26s - loss: 4.9972e-05 - accuracy: 1.0000 - val_loss: 2.4493e-04 - val_accuracy: 1.0000 - 26s/epoch - 897ms/step
# Epoch 14/100
# 29/29 - 26s - loss: 1.9820e-04 - accuracy: 1.0000 - val_loss: 4.3856e-04 - val_accuracy: 1.0000 - 26s/epoch - 893ms/step
# Epoch 15/100
# 29/29 - 26s - loss: 9.5677e-04 - accuracy: 0.9995 - val_loss: 0.0090 - val_accuracy: 0.9978 - 26s/epoch - 901ms/step
# Epoch 16/100
# 29/29 - 26s - loss: 8.9602e-04 - accuracy: 0.9989 - val_loss: 0.0065 - val_accuracy: 0.9978 - 26s/epoch - 898ms/step
# Epoch 17/100
# 29/29 - 26s - loss: 6.3336e-06 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 0.9978 - 26s/epoch - 895ms/step
# Epoch 18/100
# 29/29 - 26s - loss: 8.6228e-05 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 0.9978 - 26s/epoch - 895ms/step
# Epoch 19/100
# 29/29 - 26s - loss: 1.1121e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 0.9978 - 26s/epoch - 895ms/step
# Epoch 20/100
# 29/29 - 26s - loss: 6.0259e-04 - accuracy: 0.9995 - val_loss: 1.4327e-06 - val_accuracy: 1.0000 - 26s/epoch - 899ms/step
# Epoch 21/100
# 29/29 - 26s - loss: 5.6985e-04 - accuracy: 1.0000 - val_loss: 2.3047e-04 - val_accuracy: 1.0000 - 26s/epoch - 887ms/step
# Epoch 22/100
# 29/29 - 26s - loss: 3.4751e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 0.9978 - 26s/epoch - 896ms/step
# Epoch 23/100
# 29/29 - 26s - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0145 - val_accuracy: 0.9956 - 26s/epoch - 896ms/step
# Epoch 24/100
# 29/29 - 26s - loss: 4.5356e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 0.9978 - 26s/epoch - 901ms/step
# Epoch 25/100
# 29/29 - 26s - loss: 4.3444e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 0.9978 - 26s/epoch - 897ms/step
# Epoch 26/100
# 29/29 - 26s - loss: 3.0725e-04 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9978 - 26s/epoch - 893ms/step
# Epoch 27/100
# 29/29 - 26s - loss: 8.6545e-04 - accuracy: 0.9995 - val_loss: 0.0019 - val_accuracy: 0.9978 - 26s/epoch - 902ms/step
# Epoch 28/100
# 29/29 - 26s - loss: 5.2167e-04 - accuracy: 0.9995 - val_loss: 0.0050 - val_accuracy: 0.9978 - 26s/epoch - 894ms/step
# Epoch 29/100
# 29/29 - 26s - loss: 1.8041e-04 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 0.9978 - 26s/epoch - 897ms/step
# Epoch 30/100
# 29/29 - 26s - loss: 9.8649e-06 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9978 - 26s/epoch - 881ms/step
# Epoch 31/100
# 29/29 - 26s - loss: 4.9808e-05 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 0.9978 - 26s/epoch - 884ms/step
# Epoch 32/100
# 29/29 - 26s - loss: 1.7969e-04 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9978 - 26s/epoch - 895ms/step
# Epoch 33/100
# 29/29 - 26s - loss: 1.4424e-06 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 0.9978 - 26s/epoch - 889ms/step
# Epoch 34/100
# 29/29 - 26s - loss: 0.0049 - accuracy: 0.9989 - val_loss: 0.0341 - val_accuracy: 0.9956 - 26s/epoch - 894ms/step
# Epoch 35/100
# 29/29 - 26s - loss: 8.8288e-06 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9935 - 26s/epoch - 898ms/step
# Epoch 36/100
# 29/29 - 26s - loss: 3.9614e-06 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 0.9956 - 26s/epoch - 896ms/step
# Epoch 37/100
# 29/29 - 26s - loss: 7.1857e-06 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9956 - 26s/epoch - 902ms/step
# Epoch 38/100
# 29/29 - 26s - loss: 1.8478e-07 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 0.9978 - 26s/epoch - 894ms/step
# Epoch 39/100
# 29/29 - 26s - loss: 4.4056e-05 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9978 - 26s/epoch - 904ms/step
# Epoch 40/100
# 29/29 - 26s - loss: 0.0029 - accuracy: 0.9995 - val_loss: 5.5119e-04 - val_accuracy: 1.0000 - 26s/epoch - 899ms/step
# Epoch 41/100
# 29/29 - 26s - loss: 4.4024e-04 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 0.9978 - 26s/epoch - 893ms/step
# Epoch 42/100
# 29/29 - 26s - loss: 2.2476e-04 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9978 - 26s/epoch - 890ms/step
# Epoch 43/100
# 29/29 - 26s - loss: 6.2930e-04 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9978 - 26s/epoch - 902ms/step
# Epoch 44/100
# 29/29 - 26s - loss: 9.8385e-05 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 0.9978 - 26s/epoch - 896ms/step
# Epoch 45/100
# 29/29 - 26s - loss: 3.3306e-05 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9978 - 26s/epoch - 899ms/step
# Epoch 46/100
# 29/29 - 26s - loss: 2.9655e-06 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 0.9978 - 26s/epoch - 893ms/step
# Epoch 47/100
# 29/29 - 26s - loss: 3.0895e-04 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9956 - 26s/epoch - 896ms/step
# Epoch 48/100
# 29/29 - 26s - loss: 2.6101e-08 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9956 - 26s/epoch - 895ms/step
# Epoch 49/100
# 29/29 - 26s - loss: 1.1293e-05 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 0.9978 - 26s/epoch - 886ms/step
# Epoch 50/100
# 29/29 - 26s - loss: 8.5519e-06 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9978 - 26s/epoch - 887ms/step
# Epoch 51/100
# 29/29 - 26s - loss: 1.7191e-04 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9978 - 26s/epoch - 903ms/step
# Epoch 52/100
# 29/29 - 26s - loss: 1.8993e-05 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 0.9978 - 26s/epoch - 891ms/step
# Epoch 53/100
# 29/29 - 26s - loss: 5.4245e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000 - 26s/epoch - 898ms/step
# Epoch 54/100
# 29/29 - 26s - loss: 2.9318e-05 - accuracy: 1.0000 - val_loss: 9.4885e-04 - val_accuracy: 1.0000 - 26s/epoch - 888ms/step
# Epoch 55/100
# 29/29 - 26s - loss: 2.0125e-04 - accuracy: 1.0000 - val_loss: 7.3377e-04 - val_accuracy: 1.0000 - 26s/epoch - 892ms/step
# Epoch 56/100
# 29/29 - 26s - loss: 1.7851e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9978 - 26s/epoch - 891ms/step
# Epoch 57/100
# 29/29 - 26s - loss: 4.3414e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 0.9978 - 26s/epoch - 895ms/step
# Epoch 58/100
# 29/29 - 26s - loss: 1.5961e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 0.9978 - 26s/epoch - 896ms/step
# Epoch 59/100
# 29/29 - 26s - loss: 2.1254e-06 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - 26s/epoch - 894ms/step
# Epoch 60/100
# 29/29 - 26s - loss: 6.5393e-06 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000 - 26s/epoch - 893ms/step
# Epoch 61/100
# 29/29 - 26s - loss: 3.8524e-07 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000 - 26s/epoch - 895ms/step
# Epoch 62/100
# 29/29 - 26s - loss: 2.0812e-04 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9956 - 26s/epoch - 893ms/step
# Epoch 63/100
# 29/29 - 26s - loss: 1.5587e-05 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9935 - 26s/epoch - 901ms/step
# Epoch 64/100
# 29/29 - 26s - loss: 6.7371e-05 - accuracy: 1.0000 - val_loss: 0.0159 - val_accuracy: 0.9956 - 26s/epoch - 897ms/step
# Epoch 65/100
# 29/29 - 26s - loss: 1.7460e-05 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 0.9935 - 26s/epoch - 903ms/step
# Epoch 66/100
# ...
# Epoch 83/100
# 29/29 - 26s - loss: 0.0015 - accuracy: 0.9989 - val_loss: 0.1493 - val_accuracy: 0.9935 - 26s/epoch - 894ms/step
# Epoch 84/100
# 29/29 - 26s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1751 - val_accuracy: 0.9891 - 26s/epoch - 892ms/step
# Epoch 85/100
# 29/29 - 26s - loss: 0.0102 - accuracy: 0.9989 - val_loss: 0.2959 - val_accuracy: 0.9695 - 26s/epoch - 892ms/step
# Epoch 86/100
# 29/29 - 26s - loss: 2.4802e-06 - accuracy: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9739 - 26s/epoch - 906ms/step
# Epoch 87/100
# 29/29 - 26s - loss: 1.2993e-06 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9826 - 26s/epoch - 899ms/step
# Epoch 88/100
# 29/29 - 26s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.2212 - val_accuracy: 0.9608 - 26s/epoch - 890ms/step
# Epoch 89/100
# 29/29 - 26s - loss: 5.3040e-05 - accuracy: 1.0000 - val_loss: 0.1296 - val_accuracy: 0.9782 - 26s/epoch - 898ms/step
# Epoch 90/100
# 29/29 - 26s - loss: 3.1614e-04 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9935 - 26s/epoch - 893ms/step
# Epoch 91/100
# 29/29 - 26s - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.0223 - val_accuracy: 0.9956 - 26s/epoch - 894ms/step
# Epoch 92/100
# 29/29 - 26s - loss: 4.8279e-04 - accuracy: 0.9995 - val_loss: 0.2837 - val_accuracy: 0.9695 - 26s/epoch - 893ms/step
# Epoch 93/100
# 29/29 - 26s - loss: 9.8186e-04 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 0.9956 - 26s/epoch - 893ms/step
# Epoch 94/100
# 29/29 - 26s - loss: 6.4554e-04 - accuracy: 0.9995 - val_loss: 0.0272 - val_accuracy: 0.9956 - 26s/epoch - 890ms/step
# Epoch 95/100
# 29/29 - 26s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0126 - val_accuracy: 0.9956 - 26s/epoch - 890ms/step
# Epoch 96/100
# 29/29 - 26s - loss: 1.7953e-06 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9956 - 26s/epoch - 894ms/step
# Epoch 97/100
# 29/29 - 26s - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0666 - val_accuracy: 0.9847 - 26s/epoch - 890ms/step
# Epoch 98/100
# 29/29 - 26s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0109 - val_accuracy: 0.9978 - 26s/epoch - 894ms/step
# Epoch 99/100
# 29/29 - 26s - loss: 1.6309e-04 - accuracy: 1.0000 - val_loss: 0.0154 - val_accuracy: 0.9978 - 26s/epoch - 901ms/step
# Epoch 100/100
# 29/29 - 26s - loss: 2.3290e-05 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 0.9978 - 26s/epoch - 893ms/step
# 0.0386
# ***Performance on Test Data***
# Accuracy  : 0.9530864197530864
# Precision : 0.9540224438834836
# f1Score : 0.952774539148081
# [[131   0   4]
#  [  0 134   1]
#  [  3  11 121]]
# 7/7 [==============================] - 4s 663ms/step - loss: 0.7358 - accuracy: 0.9531
# Results for fold 5
# Found 1836 images belonging to 3 classes.
# Found 459 images belonging to 3 classes.
# Found 405 images belonging to 3 classes.
# Epoch 1/100
# 29/29 - 27s - loss: 6.0469e-04 - accuracy: 0.9995 - val_loss: 8.6035e-06 - val_accuracy: 1.0000 - 27s/epoch - 927ms/step
# Epoch 2/100
# 29/29 - 26s - loss: 0.0112 - accuracy: 0.9984 - val_loss: 0.0809 - val_accuracy: 0.9913 - 26s/epoch - 902ms/step
# Epoch 3/100
# 29/29 - 26s - loss: 0.0099 - accuracy: 0.9984 - val_loss: 4.9589 - val_accuracy: 0.7756 - 26s/epoch - 895ms/step
# Epoch 4/100
# 29/29 - 26s - loss: 1.7184e-04 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9673 - 26s/epoch - 896ms/step
# Epoch 5/100
# 29/29 - 26s - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.0055 - val_accuracy: 0.9978 - 26s/epoch - 896ms/step
# Epoch 6/100
# 29/29 - 26s - loss: 5.1381e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 0.9978 - 26s/epoch - 893ms/step
# Epoch 7/100
# 29/29 - 26s - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.0049 - val_accuracy: 0.9978 - 26s/epoch - 891ms/step
# Epoch 8/100
# 29/29 - 26s - loss: 0.0173 - accuracy: 0.9973 - val_loss: 0.0017 - val_accuracy: 1.0000 - 26s/epoch - 888ms/step
# Epoch 9/100
# 29/29 - 26s - loss: 0.0072 - accuracy: 0.9978 - val_loss: 9.1861 - val_accuracy: 0.8693 - 26s/epoch - 890ms/step
# Epoch 10/100
# 29/29 - 26s - loss: 0.0141 - accuracy: 0.9973 - val_loss: 5.7951e-04 - val_accuracy: 1.0000 - 26s/epoch - 897ms/step
# Epoch 11/100
# 29/29 - 26s - loss: 0.0068 - accuracy: 0.9984 - val_loss: 0.0045 - val_accuracy: 0.9978 - 26s/epoch - 894ms/step
# Epoch 12/100
# 29/29 - 26s - loss: 0.0209 - accuracy: 0.9989 - val_loss: 0.0175 - val_accuracy: 0.9956 - 26s/epoch - 891ms/step
# Epoch 13/100
# 29/29 - 26s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 5.8183e-06 - val_accuracy: 1.0000 - 26s/epoch - 889ms/step
# Epoch 14/100
# 29/29 - 26s - loss: 0.0017 - accuracy: 0.9989 - val_loss: 4.9705e-07 - val_accuracy: 1.0000 - 26s/epoch - 886ms/step
# Epoch 15/100
# 29/29 - 26s - loss: 0.0027 - accuracy: 0.9995 - val_loss: 2.6327e-06 - val_accuracy: 1.0000 - 26s/epoch - 890ms/step
# Epoch 16/100
# 29/29 - 26s - loss: 0.0037 - accuracy: 0.9995 - val_loss: 4.1654e-07 - val_accuracy: 1.0000 - 26s/epoch - 892ms/step
# Epoch 17/100
# 29/29 - 26s - loss: 9.7887e-04 - accuracy: 1.0000 - val_loss: 1.3091e-05 - val_accuracy: 1.0000 - 26s/epoch - 890ms/step
# Epoch 18/100
# 29/29 - 26s - loss: 0.0033 - accuracy: 0.9995 - val_loss: 9.8171e-06 - val_accuracy: 1.0000 - 26s/epoch - 885ms/step
# Epoch 19/100
# 29/29 - 26s - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.1090 - val_accuracy: 0.9869 - 26s/epoch - 896ms/step
# Epoch 20/100
# 29/29 - 26s - loss: 7.0279e-04 - accuracy: 0.9995 - val_loss: 0.0619 - val_accuracy: 0.9913 - 26s/epoch - 889ms/step
# Epoch 21/100
# 29/29 - 26s - loss: 0.0018 - accuracy: 0.9989 - val_loss: 0.0056 - val_accuracy: 0.9978 - 26s/epoch - 890ms/step
# Epoch 22/100
# 29/29 - 26s - loss: 2.0954e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 0.9978 - 26s/epoch - 902ms/step
# Epoch 23/100
# 29/29 - 26s - loss: 1.6656e-04 - accuracy: 1.0000 - val_loss: 1.3140e-04 - val_accuracy: 1.0000 - 26s/epoch - 896ms/step
# Epoch 24/100
# 29/29 - 26s - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0063 - val_accuracy: 0.9978 - 26s/epoch - 892ms/step
# Epoch 25/100
# 29/29 - 26s - loss: 0.0058 - accuracy: 0.9995 - val_loss: 0.0018 - val_accuracy: 0.9978 - 26s/epoch - 889ms/step
# Epoch 26/100
# 29/29 - 26s - loss: 2.9321e-05 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 0.9978 - 26s/epoch - 885ms/step
# Epoch 27/100
# 29/29 - 26s - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.1269 - val_accuracy: 0.9891 - 26s/epoch - 892ms/step
# Epoch 28/100
# 29/29 - 26s - loss: 2.2574e-05 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9891 - 26s/epoch - 890ms/step
# Epoch 29/100
# 29/29 - 26s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0083 - val_accuracy: 0.9956 - 26s/epoch - 893ms/step
# Epoch 30/100
# 29/29 - 26s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0054 - val_accuracy: 0.9956 - 26s/epoch - 889ms/step
# Epoch 31/100
# 29/29 - 26s - loss: 1.1529e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 0.9978 - 26s/epoch - 892ms/step
# Epoch 32/100
# 29/29 - 25s - loss: 5.9858e-04 - accuracy: 0.9995 - val_loss: 0.0100 - val_accuracy: 0.9956 - 25s/epoch - 878ms/step
# Epoch 33/100
# 29/29 - 25s - loss: 0.0032 - accuracy: 0.9995 - val_loss: 1.6858e-04 - val_accuracy: 1.0000 - 25s/epoch - 878ms/step
# Epoch 34/100
# 29/29 - 26s - loss: 3.6831e-05 - accuracy: 1.0000 - val_loss: 7.6229e-04 - val_accuracy: 1.0000 - 26s/epoch - 892ms/step
# Epoch 35/100
# 29/29 - 26s - loss: 1.7486e-04 - accuracy: 1.0000 - val_loss: 2.4433e-04 - val_accuracy: 1.0000 - 26s/epoch - 880ms/step
# Epoch 36/100
# 29/29 - 26s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000 - 26s/epoch - 879ms/step
# Epoch 37/100
# 29/29 - 26s - loss: 4.5621e-04 - accuracy: 0.9995 - val_loss: 0.0021 - val_accuracy: 0.9978 - 26s/epoch - 882ms/step
# Epoch 38/100
# 29/29 - 25s - loss: 8.3227e-04 - accuracy: 0.9995 - val_loss: 0.0031 - val_accuracy: 0.9978 - 25s/epoch - 869ms/step
# Epoch 39/100
# 29/29 - 25s - loss: 2.2449e-04 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9978 - 25s/epoch - 875ms/step
# Epoch 40/100
# 29/29 - 25s - loss: 5.0770e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 0.9978 - 25s/epoch - 877ms/step
# Epoch 41/100
# 29/29 - 25s - loss: 6.9310e-04 - accuracy: 0.9995 - val_loss: 0.0059 - val_accuracy: 0.9978 - 25s/epoch - 872ms/step
# Epoch 42/100
# 29/29 - 25s - loss: 1.2192e-07 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 0.9978 - 25s/epoch - 876ms/step
# Epoch 43/100
# 29/29 - 25s - loss: 1.0131e-05 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 0.9978 - 25s/epoch - 873ms/step
# Epoch 44/100
# 29/29 - 26s - loss: 3.1305e-06 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 0.9978 - 26s/epoch - 884ms/step
# Epoch 45/100
# 29/29 - 26s - loss: 1.3812e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9978 - 26s/epoch - 886ms/step
# Epoch 46/100
# 29/29 - 26s - loss: 6.4516e-04 - accuracy: 0.9995 - val_loss: 0.0020 - val_accuracy: 0.9978 - 26s/epoch - 890ms/step
# Epoch 47/100
# 29/29 - 25s - loss: 1.8393e-06 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 0.9978 - 25s/epoch - 870ms/step
# Epoch 48/100
# 29/29 - 26s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0034 - val_accuracy: 0.9978 - 26s/epoch - 880ms/step
# Epoch 49/100
# 29/29 - 25s - loss: 6.6574e-04 - accuracy: 0.9995 - val_loss: 0.0036 - val_accuracy: 0.9978 - 25s/epoch - 877ms/step
# Epoch 50/100
# 29/29 - 26s - loss: 2.8832e-06 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 0.9978 - 26s/epoch - 882ms/step
# Epoch 51/100
# 29/29 - 25s - loss: 1.4488e-04 - accuracy: 1.0000 - val_loss: 8.7098e-04 - val_accuracy: 1.0000 - 25s/epoch - 875ms/step
# Epoch 52/100
# 29/29 - 26s - loss: 3.8487e-06 - accuracy: 1.0000 - val_loss: 7.8795e-04 - val_accuracy: 1.0000 - 26s/epoch - 883ms/step
# Epoch 53/100
# 29/29 - 25s - loss: 3.6851e-05 - accuracy: 1.0000 - val_loss: 5.1387e-04 - val_accuracy: 1.0000 - 25s/epoch - 872ms/step
# Epoch 54/100
# 29/29 - 25s - loss: 6.3489e-04 - accuracy: 0.9995 - val_loss: 5.5917e-04 - val_accuracy: 1.0000 - 25s/epoch - 873ms/step
# Epoch 55/100
# 29/29 - 26s - loss: 8.8064e-07 - accuracy: 1.0000 - val_loss: 6.6226e-04 - val_accuracy: 1.0000 - 26s/epoch - 882ms/step
# Epoch 56/100
# 29/29 - 25s - loss: 0.0042 - accuracy: 0.9995 - val_loss: 1.5588e-04 - val_accuracy: 1.0000 - 25s/epoch - 871ms/step
# Epoch 57/100
# 29/29 - 25s - loss: 2.6107e-04 - accuracy: 1.0000 - val_loss: 8.7442e-05 - val_accuracy: 1.0000 - 25s/epoch - 874ms/step
# Epoch 58/100
# 29/29 - 26s - loss: 4.5167e-05 - accuracy: 1.0000 - val_loss: 6.3764e-06 - val_accuracy: 1.0000 - 26s/epoch - 888ms/step
# Epoch 59/100
# 29/29 - 26s - loss: 8.0744e-04 - accuracy: 0.9995 - val_loss: 7.4184e-04 - val_accuracy: 1.0000 - 26s/epoch - 884ms/step
# Epoch 60/100
# 29/29 - 25s - loss: 9.1863e-04 - accuracy: 0.9995 - val_loss: 0.0950 - val_accuracy: 0.9913 - 25s/epoch - 874ms/step
# Epoch 61/100
# 29/29 - 26s - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0690 - val_accuracy: 0.9869 - 26s/epoch - 883ms/step
# Epoch 62/100
# 29/29 - 25s - loss: 6.9091e-04 - accuracy: 0.9995 - val_loss: 0.0048 - val_accuracy: 0.9978 - 25s/epoch - 872ms/step
# Epoch 63/100
# 29/29 - 26s - loss: 6.6575e-04 - accuracy: 0.9995 - val_loss: 4.2871e-05 - val_accuracy: 1.0000 - 26s/epoch - 881ms/step
# Epoch 64/100
# 29/29 - 25s - loss: 4.0320e-04 - accuracy: 1.0000 - val_loss: 5.8134e-04 - val_accuracy: 1.0000 - 25s/epoch - 879ms/step
# Epoch 65/100
# 29/29 - 26s - loss: 6.2930e-06 - accuracy: 1.0000 - val_loss: 4.6398e-05 - val_accuracy: 1.0000 - 26s/epoch - 886ms/step
# Epoch 66/100
# 29/29 - 25s - loss: 5.7256e-07 - accuracy: 1.0000 - val_loss: 1.4474e-05 - val_accuracy: 1.0000 - 25s/epoch - 876ms/step
# Epoch 67/100
# 29/29 - 26s - loss: 1.3118e-04 - accuracy: 1.0000 - val_loss: 3.3320e-04 - val_accuracy: 1.0000 - 26s/epoch - 883ms/step
# Epoch 68/100
# 29/29 - 25s - loss: 3.1282e-04 - accuracy: 1.0000 - val_loss: 3.4203e-07 - val_accuracy: 1.0000 - 25s/epoch - 872ms/step
# Epoch 69/100
# 29/29 - 26s - loss: 1.2529e-06 - accuracy: 1.0000 - val_loss: 1.7115e-07 - val_accuracy: 1.0000 - 26s/epoch - 887ms/step
# Epoch 70/100
# 29/29 - 26s - loss: 3.4529e-05 - accuracy: 1.0000 - val_loss: 1.1204e-06 - val_accuracy: 1.0000 - 26s/epoch - 884ms/step
# Epoch 71/100
# 29/29 - 25s - loss: 7.7562e-06 - accuracy: 1.0000 - val_loss: 6.1778e-07 - val_accuracy: 1.0000 - 25s/epoch - 879ms/step
# Epoch 72/100
# 29/29 - 25s - loss: 1.7104e-05 - accuracy: 1.0000 - val_loss: 2.6697e-07 - val_accuracy: 1.0000 - 25s/epoch - 876ms/step
# Epoch 73/100
# 29/29 - 26s - loss: 1.8355e-07 - accuracy: 1.0000 - val_loss: 1.2570e-07 - val_accuracy: 1.0000 - 26s/epoch - 880ms/step
# Epoch 74/100
# 29/29 - 25s - loss: 1.3130e-06 - accuracy: 1.0000 - val_loss: 6.5448e-08 - val_accuracy: 1.0000 - 25s/epoch - 875ms/step
# Epoch 75/100
# 29/29 - 25s - loss: 1.5191e-04 - accuracy: 1.0000 - val_loss: 3.1804e-05 - val_accuracy: 1.0000 - 25s/epoch - 876ms/step
# Epoch 76/100
# 29/29 - 25s - loss: 1.3142e-05 - accuracy: 1.0000 - val_loss: 2.4746e-05 - val_accuracy: 1.0000 - 25s/epoch - 879ms/step
# Epoch 77/100
# 29/29 - 25s - loss: 2.0582e-08 - accuracy: 1.0000 - val_loss: 1.2348e-05 - val_accuracy: 1.0000 - 25s/epoch - 874ms/step
# Epoch 78/100
# 29/29 - 26s - loss: 1.2172e-04 - accuracy: 1.0000 - val_loss: 0.0851 - val_accuracy: 0.9891 - 26s/epoch - 883ms/step
# Epoch 79/100
# 29/29 - 25s - loss: 1.0778e-08 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 0.9891 - 25s/epoch - 871ms/step
# Epoch 80/100
# 29/29 - 25s - loss: 3.0516e-09 - accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9935 - 25s/epoch - 879ms/step
# Epoch 81/100
# 29/29 - 25s - loss: 5.6162e-08 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 0.9956 - 25s/epoch - 874ms/step
# Epoch 82/100
# 29/29 - 26s - loss: 1.9543e-08 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 0.9978 - 26s/epoch - 881ms/step
# Epoch 83/100
# 29/29 - 26s - loss: 1.1680e-06 - accuracy: 1.0000 - val_loss: 4.1663e-04 - val_accuracy: 1.0000 - 26s/epoch - 881ms/step
# Epoch 84/100
# 29/29 - 25s - loss: 2.8269e-06 - accuracy: 1.0000 - val_loss: 6.3929e-05 - val_accuracy: 1.0000 - 25s/epoch - 878ms/step
# Epoch 85/100
# 29/29 - 25s - loss: 9.5051e-08 - accuracy: 1.0000 - val_loss: 1.1169e-05 - val_accuracy: 1.0000 - 25s/epoch - 875ms/step
# Epoch 86/100
# 29/29 - 25s - loss: 0.0055 - accuracy: 0.9995 - val_loss: 0.5314 - val_accuracy: 0.9651 - 25s/epoch - 872ms/step
# Epoch 87/100
# 29/29 - 25s - loss: 0.0091 - accuracy: 0.9984 - val_loss: 54.2940 - val_accuracy: 0.6797 - 25s/epoch - 873ms/step
# Epoch 88/100
# 29/29 - 25s - loss: 0.0129 - accuracy: 0.9978 - val_loss: 0.9947 - val_accuracy: 0.9542 - 25s/epoch - 866ms/step
# Epoch 89/100
# 29/29 - 25s - loss: 0.0281 - accuracy: 0.9973 - val_loss: 9.1398 - val_accuracy: 0.9041 - 25s/epoch - 877ms/step
# Epoch 90/100
# 29/29 - 25s - loss: 0.0442 - accuracy: 0.9962 - val_loss: 1.1300 - val_accuracy: 0.8584 - 25s/epoch - 871ms/step
# Epoch 91/100
# 29/29 - 25s - loss: 0.1303 - accuracy: 0.9918 - val_loss: 0.1207 - val_accuracy: 0.9913 - 25s/epoch - 877ms/step
# Epoch 92/100
# 29/29 - 25s - loss: 0.0531 - accuracy: 0.9897 - val_loss: 0.0775 - val_accuracy: 0.9891 - 25s/epoch - 866ms/step
# Epoch 93/100
# 29/29 - 25s - loss: 0.0313 - accuracy: 0.9940 - val_loss: 0.1047 - val_accuracy: 0.9847 - 25s/epoch - 868ms/step
# Epoch 94/100
# 29/29 - 25s - loss: 0.0239 - accuracy: 0.9951 - val_loss: 0.2367 - val_accuracy: 0.9477 - 25s/epoch - 866ms/step
# Epoch 95/100
# 29/29 - 26s - loss: 0.0150 - accuracy: 0.9973 - val_loss: 0.5180 - val_accuracy: 0.9041 - 26s/epoch - 882ms/step
# Epoch 96/100
# 29/29 - 25s - loss: 0.0064 - accuracy: 0.9989 - val_loss: 0.7110 - val_accuracy: 0.9063 - 25s/epoch - 868ms/step
# Epoch 97/100
# 29/29 - 25s - loss: 0.0112 - accuracy: 0.9967 - val_loss: 0.4198 - val_accuracy: 0.9390 - 25s/epoch - 872ms/step
# Epoch 98/100
# 29/29 - 25s - loss: 0.0554 - accuracy: 0.9956 - val_loss: 0.0533 - val_accuracy: 0.9891 - 25s/epoch - 872ms/step
# Epoch 99/100
# 29/29 - 25s - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0513 - val_accuracy: 0.9956 - 25s/epoch - 872ms/step
# Epoch 100/100
# 29/29 - 25s - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.0011 - val_accuracy: 1.0000 - 25s/epoch - 876ms/step
# 0.0386
# ***Performance on Test Data***
# Accuracy  : 0.9530864197530864
# Precision : 0.9544171122556935
# f1Score : 0.9526545501921699
# [[132   1   2]
#  [  0 134   1]
#  [  5  10 120]]
# 7/7 [==============================] - 4s 639ms/step - loss: 0.8064 - accuracy: 0.9531
# Overall Accuracy:  0.9486419753086419
