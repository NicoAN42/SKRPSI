# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoAN42/SKRPSI/blob/main/cbam_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mount dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.layers import Conv2D, Input, concatenate, Activation, InputLayer, Dense, Reshape, Flatten, Add, multiply, Permute, Lambda, Concatenate
from tensorflow.keras.layers import LeakyReLU,ReLU, MaxPooling2D, BatchNormalization,GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import layers
from tensorflow.keras.activations import softmax,sigmoid
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout,SpatialDropout2D,GaussianDropout
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.regularizers import l1,l2
from tensorflow.keras import backend as K
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow
import tensorflow as tf
import math
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold
import os
import random
import shutil

# %%
#from tensorflow.keras.optimizers import SGD

# %%
CLASS = 3
#sourcepath isi semua data train, folder valid kosongin datanya sisai folder classnya
sourcePath = '/content/drive/MyDrive/Colab Notebooks/Dataset 090'
train_path = '/content/drive/MyDrive/Colab Notebooks/Dataset 090/train'
valid_path = '/content/drive/MyDrive/Colab Notebooks/Dataset 090/valid'
test_path = '/content/drive/MyDrive/Colab Notebooks/Dataset 090/test'
attention_module = 'cbam_block'
#nico

# %%
classLabels =['covid','normal', 'pneumonia']

# %%
def attach_attention_module(net, attention_module):
  #if attention_module == 'se_block': # SE_block
    #net = se_block(net)
  if attention_module == 'cbam_block': # CBAM_block
    net = cbam_block(net)
  else:
    raise Exception("'{}' is not supported attention module!".format(attention_module))

  return net

# %%
def cbam_block(cbam_feature, ratio=8):
	"""Contains the implementation of Convolutional Block Attention Module(CBAM) block.
	As described in https://arxiv.org/abs/1807.06521.
	"""
	
	cbam_feature = channel_attention(cbam_feature, ratio)
	cbam_feature = spatial_attention(cbam_feature)
	return cbam_feature

# %%
def channel_attention(input_feature, ratio=8):
	
	channel_axis = 1 if K.image_data_format() == "channels_first" else -1
	channel = input_feature.shape[channel_axis]
	
	shared_layer_one = Dense(channel//ratio,
							 activation='relu',
							 kernel_initializer='he_normal',
							 use_bias=True,
							 bias_initializer='zeros')
	shared_layer_two = Dense(channel,
							 kernel_initializer='he_normal',
							 use_bias=True,
							 bias_initializer='zeros')
	
	avg_pool = GlobalAveragePooling2D()(input_feature)    
	avg_pool = Reshape((1,1,channel))(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel)
	avg_pool = shared_layer_one(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel//ratio)
	avg_pool = shared_layer_two(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel)
	
	max_pool = GlobalMaxPooling2D()(input_feature)
	max_pool = Reshape((1,1,channel))(max_pool)
	assert max_pool.shape[1:] == (1,1,channel)
	max_pool = shared_layer_one(max_pool)
	assert max_pool.shape[1:] == (1,1,channel//ratio)
	max_pool = shared_layer_two(max_pool)
	assert max_pool.shape[1:] == (1,1,channel)
	
	cbam_feature = Add()([avg_pool,max_pool])
	cbam_feature = Activation('sigmoid')(cbam_feature)
	
	if K.image_data_format() == "channels_first":
		cbam_feature = Permute((3, 1, 2))(cbam_feature)
	
	return multiply([input_feature, cbam_feature])

# %%
def spatial_attention(input_feature):
	kernel_size = 7
	
	if K.image_data_format() == "channels_first":
		channel = input_feature.shape[1]
		cbam_feature = Permute((2,3,1))(input_feature)
	else:
		channel = input_feature.shape[-1]
		cbam_feature = input_feature
	
	avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
	assert avg_pool.shape[-1] == 1
	max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
	assert max_pool.shape[-1] == 1
	concat = Concatenate(axis=3)([avg_pool, max_pool])
	assert concat.shape[-1] == 2
	cbam_feature = Conv2D(filters = 1,
					kernel_size=kernel_size,
					strides=1,
					padding='same',
					activation='sigmoid',
					kernel_initializer='he_normal',
					use_bias=False)(concat)	
	assert cbam_feature.shape[-1] == 1
	
	if K.image_data_format() == "channels_first":
		cbam_feature = Permute((3, 1, 2))(cbam_feature)
		
	return multiply([input_feature, cbam_feature])

# %%
input = Input(shape=(256,256,3))

# %%
#Layer 1
model = layers.Conv2D(32, (3,3), padding='same', name='conv_1', activation = 'relu')(input)
model = layers.BatchNormalization(name='norm_1')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides= 2)(model)
attention_module = 'cbam_block'
y = attach_attention_module(model, attention_module)
model =  tensorflow.keras.layers.add([model, y])

# %%
#Layer 2
model = layers.Conv2D(64, (3,3), padding='same', name='conv_2', activation = 'relu')(model)
model = layers.Dropout(0.1)(model)
model = layers.BatchNormalization(name='norm_2')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

# %%
# Layer 3
model = layers.Conv2D(64, (3,3), padding='same', name='conv_3', activation = 'relu')(model)
model = layers.BatchNormalization(name='norm_3')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

# %%
# Layer 4
model = layers.Conv2D(128, (3,3), padding='same', name='conv_4', activation = 'relu')(model)
model = layers.Dropout(0.2)(model)
model = layers.BatchNormalization(name='norm_4')(model)
model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

# %%
# Layer 5
model = layers.Conv2D(256, (3,3), padding='same', name='conv_5', activation = 'relu')(model)
layer = layers.Conv2D(256, (3,3), padding='same', name='conv_5', activation = 'relu')
batch = layers.BatchNormalization(name='norm_5')
model = layers.Dropout(0.2)(model)
model = layers.BatchNormalization(name='norm_5')(model)
#model = layers.MaxPooling2D(pool_size=(2, 2), strides = 2)(model)

# %%
model = layers.Flatten()(model)
model = layers.Dense(128, activation = 'relu')(model)
model = layers.Dropout(0.2)(model)
output = layers.Dense(3,Activation('softmax'))(model)
model = Model(input, output)

# %%
#output = model.output_shape

# %%
print(input)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")

# %%
initial_learning_rate=0.0001

# %%
lr_schedule = ExponentialDecay(
   initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)

# %%
opt = Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)

# %%
model.compile(optimizer=opt, loss="sparse_categorical_crossentropy", metrics=["accuracy"] )

# %%
print(model.summary())
print(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv_1 (Conv2D)                (None, 256, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  norm_1 (BatchNormalization)    (None, 256, 256, 32  128         ['conv_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['norm_1[0][0]']
#                                 )
#
#  global_average_pooling2d (Glob  (None, 32)          0           ['max_pooling2d[0][0]']
#  alAveragePooling2D)
#
#  global_max_pooling2d (GlobalMa  (None, 32)          0           ['max_pooling2d[0][0]']
#  xPooling2D)
#
#  reshape (Reshape)              (None, 1, 1, 32)     0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  reshape_1 (Reshape)            (None, 1, 1, 32)     0           ['global_max_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 1, 1, 4)      132         ['reshape[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  dense_1 (Dense)                (None, 1, 1, 32)     160         ['dense[0][0]',
#                                                                   'dense[1][0]']
#
#  add (Add)                      (None, 1, 1, 32)     0           ['dense_1[0][0]',
#                                                                   'dense_1[1][0]']
#
#  activation (Activation)        (None, 1, 1, 32)     0           ['add[0][0]']
#
#  multiply (Multiply)            (None, 128, 128, 32  0           ['max_pooling2d[0][0]',
#                                 )                                 'activation[0][0]']
#
#  lambda (Lambda)                (None, 128, 128, 1)  0           ['multiply[0][0]']
#
#  lambda_1 (Lambda)              (None, 128, 128, 1)  0           ['multiply[0][0]']
#
#  concatenate (Concatenate)      (None, 128, 128, 2)  0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  conv2d (Conv2D)                (None, 128, 128, 1)  98          ['concatenate[0][0]']
#
#  multiply_1 (Multiply)          (None, 128, 128, 32  0           ['multiply[0][0]',
#                                 )                                 'conv2d[0][0]']
#
#  add_1 (Add)                    (None, 128, 128, 32  0           ['max_pooling2d[0][0]',
#                                 )                                 'multiply_1[0][0]']
#
#  conv_2 (Conv2D)                (None, 128, 128, 64  18496       ['add_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 64  0           ['conv_2[0][0]']
#                                 )
#
#  norm_2 (BatchNormalization)    (None, 128, 128, 64  256         ['dropout[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['norm_2[0][0]']
#
#  conv_3 (Conv2D)                (None, 64, 64, 64)   36928       ['max_pooling2d_1[0][0]']
#
#  norm_3 (BatchNormalization)    (None, 64, 64, 64)   256         ['conv_3[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)  0           ['norm_3[0][0]']
#
#  conv_4 (Conv2D)                (None, 32, 32, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 128)  0           ['conv_4[0][0]']
#
#  norm_4 (BatchNormalization)    (None, 32, 32, 128)  512         ['dropout_1[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0          ['norm_4[0][0]']
#
#  conv_5 (Conv2D)                (None, 16, 16, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 256)  0           ['conv_5[0][0]']
#
#  norm_5 (BatchNormalization)    (None, 16, 16, 256)  1024        ['dropout_2[0][0]']
#
#  flatten (Flatten)              (None, 65536)        0           ['norm_5[0][0]']
#
#  dense_2 (Dense)                (None, 128)          8388736     ['flatten[0][0]']
#
#  dropout_3 (Dropout)            (None, 128)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 3)            387         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 8,817,033
# Trainable params: 8,815,945
# Non-trainable params: 1,088
# __________________________________________________________________________________________________
# None
# <keras.engine.functional.Functional object at 0x7fa610479c50>

# %%
X = []
Y = []
def transferBetweenFolders(source, dest, splitRate): 
    global sourceFiles
    sourceFiles=os.listdir(source)
    if(len(sourceFiles)!=0):
        transferFileNumbers=int(len(sourceFiles)*splitRate)
        transferIndex=random.sample(range(0, len(sourceFiles)), transferFileNumbers)
        for eachIndex in transferIndex:
            shutil.move(source+str(sourceFiles[eachIndex]), dest+str(sourceFiles[eachIndex]))
    else:
        print("No file moved. Source empty!")

# %%
def transferAllClassBetweenFolders(source, dest, splitRate):
    for label in classLabels:
        transferBetweenFolders(sourcePath+'/'+source+'/'+label+'/', 
                               sourcePath+'/'+dest+'/'+label+'/', 
                               splitRate)
#First cut all images from validation to train (if any exists)
transferAllClassBetweenFolders('valid', 'train', 1.0)
#no valid
transferAllClassBetweenFolders('test', 'train', 1.0)

# %%
def prepareNameWithLabels(folderName):
    sourceFiles=os.listdir(sourcePath+'/train/'+folderName)
    for val in sourceFiles:
        X.append(val)
        for i in range(len(classLabels)):
          if(folderName==classLabels[i]):
              Y.append(i)
# Organize file names and class labels in X and Y variables
for i in range(len(classLabels)):
  prepareNameWithLabels(classLabels[i])

def my_metrics(y_true, y_pred):
    accuracy=accuracy_score(y_true, y_pred)
    precision=precision_score(y_true, y_pred,average='weighted')
    f1Score=f1_score(y_true, y_pred, average='weighted') 
    print("Accuracy  : {}".format(accuracy))
    print("Precision : {}".format(precision))
    print("f1Score : {}".format(f1Score))
    cm=confusion_matrix(y_true, y_pred)
    print(cm)
    return accuracy, precision, f1Score

# %%
transferAllClassBetweenFolders('valid', 'train', 1.0)
transferAllClassBetweenFolders('test', 'train', 1.0)
X=np.asarray(X)
Y=np.asarray(Y)

print(X)
print(Y)

skf = StratifiedKFold(n_splits=5
                      , shuffle=True)
skf.get_n_splits(X, Y)
print(skf)
print(skf.get_n_splits(X,Y))
print(skf.split(X,Y))
foldNum=0
overAllAcc = 0
# Out:
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# ['COVID(78).png' 'COVID(99).png' 'COVID(68).png' ...
#  'person260_bacteria_1224.jpeg' 'person258_bacteria_1210.jpeg'
#  'person259_bacteria_1220.jpeg']
# [0 0 0 ... 2 2 2]
# StratifiedKFold(n_splits=5, random_state=None, shuffle=True)
# 5
# <generator object _BaseKFold.split at 0x7fa610441550>

# %%
for train_index, val_index in skf.split(X, Y):
    print("trn_indx: %s test_indx: %s" % (len(train_index), len(val_index)))
    #First cut all images from validation to train (if any exists)
    transferAllClassBetweenFolders('valid', 'train', 1.0)
    #no valid
    transferAllClassBetweenFolders('test', 'train', 1.0)
    foldNum+=1
    print("Results for fold",foldNum)
    X_train, X_val = X[train_index], X[val_index]
    Y_train, Y_val = Y[train_index], Y[val_index]
    print(len(X_train))
    print(len(X_val))
    # Move validation images of this fold from train folder to the validation folder
    for eachIndex in range(len(X_val)):
        classLabel=''
        for i in range(len(classLabels)):
          if(Y_val[eachIndex]==i):
              classLabel=classLabels[i]
        #Then, copy the validation images to the validation folder
        shutil.move(sourcePath+'/train/'+classLabel+'/'+X_val[eachIndex], 
                    #sourcePath+'/valid/'+classLabel+'/'+X_val[eachIndex])
        #without valid
                    sourcePath+'/test/'+classLabel+'/'+X_val[eachIndex])
        
    train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 32, shuffle=True)
    #without valid
    #valid_batches = ImageDataGenerator().flow_from_directory(valid_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 32, shuffle=True)
    test_batches = ImageDataGenerator().flow_from_directory(test_path, target_size=(256,256), classes=['covid', 'normal', 'pneumonia'], class_mode = 'sparse', batch_size = 32, shuffle=False)

    history = model.fit(train_batches, 
                    #steps_per_epoch=sp_epoch, 
                    #without valid
                    #validation_data=valid_batches, 
                    #validation_steps=10, 
                    epochs=100, 
                    verbose=2)
    
    
    
    plt.plot(history.history['accuracy'])
    #plt.plot(history.history['val_accuracy'])
    plt.title('Final Cbam model accuracy')
    plt.ylim(0,1.1)
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    #plt.legend(['train', 'valid'], loc='upper left')
    #without valid
    plt.legend(['train'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    #plt.plot(history.history['val_loss'])
    plt.title('Final Cbam model loss')
    plt.ylim(0,1.1)
    plt.ylabel('loss')
    plt.xlabel('epoch')
    #plt.legend(['train', 'valid'], loc='upper left')
    #without valid
    plt.legend(['train'], loc='upper left')
    plt.show()
    test_batches.reset()
    Y_pred = model.predict(test_batches)
    classes = test_batches.classes[test_batches.index_array]
    y_pred = np.argmax(Y_pred, axis=-1)
    print(sum(y_pred==classes)/10000)
    confusion_matrix(test_batches.classes[test_batches.index_array],y_pred)
    #predictions = model.predict(test_batches, verbose=1)
    #yPredictions = np.argmax(predictions, axis=1)
    #print(yPredictions)
    #true_classes = test_batches.classes
    # evaluate validation performance
    print("***Performance on Test Data***")    
    #valAcc, valPrec, valFScore = my_metrics(true_classes, yPredictions)
    valAcc, valPrec, valFScore = my_metrics(classes, y_pred)
    #valAcc, valPrec, valFScore = my_metrics(classes, y_pred)
    overAllAcc = overAllAcc+valAcc
    
    model.evaluate(test_batches)
print("Overall Accuracy: ",  overAllAcc/foldNum)
# Out:
# trn_indx: 2160 test_indx: 540
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# Results for fold 1
# 2160
# 540
# Found 2160 images belonging to 3 classes.
# Found 540 images belonging to 3 classes.
# Epoch 1/100
# 68/68 - 741s - loss: 0.7364 - accuracy: 0.8833 - 741s/epoch - 11s/step
# Epoch 2/100
# 68/68 - 22s - loss: 0.5623 - accuracy: 0.9167 - 22s/epoch - 318ms/step
# Epoch 3/100
# 68/68 - 22s - loss: 0.1912 - accuracy: 0.9495 - 22s/epoch - 320ms/step
# Epoch 4/100
# 68/68 - 22s - loss: 0.1065 - accuracy: 0.9620 - 22s/epoch - 316ms/step
# Epoch 5/100
# 68/68 - 22s - loss: 0.0899 - accuracy: 0.9718 - 22s/epoch - 318ms/step
# Epoch 6/100
# 68/68 - 22s - loss: 0.0861 - accuracy: 0.9759 - 22s/epoch - 318ms/step
# Epoch 7/100
# 68/68 - 22s - loss: 0.0375 - accuracy: 0.9866 - 22s/epoch - 318ms/step
# Epoch 8/100
# 68/68 - 22s - loss: 0.1187 - accuracy: 0.9750 - 22s/epoch - 316ms/step
# Epoch 9/100
# 68/68 - 21s - loss: 0.2626 - accuracy: 0.9509 - 21s/epoch - 316ms/step
# Epoch 10/100
# 68/68 - 21s - loss: 0.1180 - accuracy: 0.9648 - 21s/epoch - 316ms/step
# Epoch 11/100
# 68/68 - 22s - loss: 0.0850 - accuracy: 0.9727 - 22s/epoch - 319ms/step
# Epoch 12/100
# 68/68 - 22s - loss: 0.0486 - accuracy: 0.9838 - 22s/epoch - 321ms/step
# Epoch 13/100
# 68/68 - 22s - loss: 0.0531 - accuracy: 0.9833 - 22s/epoch - 318ms/step
# Epoch 14/100
# 68/68 - 22s - loss: 0.0655 - accuracy: 0.9815 - 22s/epoch - 319ms/step
# Epoch 15/100
# 68/68 - 22s - loss: 0.0886 - accuracy: 0.9801 - 22s/epoch - 318ms/step
# Epoch 16/100
# 68/68 - 22s - loss: 0.0779 - accuracy: 0.9773 - 22s/epoch - 317ms/step
# Epoch 17/100
# 68/68 - 22s - loss: 0.0549 - accuracy: 0.9815 - 22s/epoch - 317ms/step
# Epoch 18/100
# 68/68 - 22s - loss: 0.0490 - accuracy: 0.9856 - 22s/epoch - 319ms/step
# Epoch 19/100
# 68/68 - 22s - loss: 0.0380 - accuracy: 0.9866 - 22s/epoch - 319ms/step
# Epoch 20/100
# 68/68 - 22s - loss: 0.0284 - accuracy: 0.9894 - 22s/epoch - 317ms/step
# Epoch 21/100
# 68/68 - 22s - loss: 0.0254 - accuracy: 0.9907 - 22s/epoch - 317ms/step
# Epoch 22/100
# 68/68 - 22s - loss: 0.0226 - accuracy: 0.9926 - 22s/epoch - 320ms/step
# Epoch 23/100
# 68/68 - 22s - loss: 0.0097 - accuracy: 0.9958 - 22s/epoch - 318ms/step
# Epoch 24/100
# 68/68 - 22s - loss: 0.0066 - accuracy: 0.9972 - 22s/epoch - 316ms/step
# Epoch 25/100
# 68/68 - 22s - loss: 0.0417 - accuracy: 0.9931 - 22s/epoch - 318ms/step
# Epoch 26/100
# 68/68 - 22s - loss: 0.0294 - accuracy: 0.9898 - 22s/epoch - 321ms/step
# Epoch 27/100
# 68/68 - 21s - loss: 0.0136 - accuracy: 0.9944 - 21s/epoch - 315ms/step
# Epoch 28/100
# 68/68 - 22s - loss: 0.0353 - accuracy: 0.9903 - 22s/epoch - 317ms/step
# Epoch 29/100
# 68/68 - 22s - loss: 0.0632 - accuracy: 0.9819 - 22s/epoch - 317ms/step
# Epoch 30/100
# 68/68 - 21s - loss: 0.0591 - accuracy: 0.9866 - 21s/epoch - 316ms/step
# Epoch 31/100
# 68/68 - 21s - loss: 0.0340 - accuracy: 0.9889 - 21s/epoch - 316ms/step
# Epoch 32/100
# 68/68 - 22s - loss: 0.0283 - accuracy: 0.9931 - 22s/epoch - 317ms/step
# Epoch 33/100
# 68/68 - 22s - loss: 0.0158 - accuracy: 0.9958 - 22s/epoch - 318ms/step
# Epoch 34/100
# 68/68 - 21s - loss: 0.0065 - accuracy: 0.9963 - 21s/epoch - 316ms/step
# Epoch 35/100
# 68/68 - 22s - loss: 0.0353 - accuracy: 0.9880 - 22s/epoch - 316ms/step
# Epoch 36/100
# 68/68 - 22s - loss: 0.0077 - accuracy: 0.9972 - 22s/epoch - 317ms/step
# Epoch 37/100
# 68/68 - 22s - loss: 0.0117 - accuracy: 0.9954 - 22s/epoch - 317ms/step
# Epoch 38/100
# 68/68 - 22s - loss: 0.0274 - accuracy: 0.9921 - 22s/epoch - 317ms/step
# Epoch 39/100
# 68/68 - 22s - loss: 0.0174 - accuracy: 0.9935 - 22s/epoch - 318ms/step
# Epoch 40/100
# 68/68 - 22s - loss: 0.0167 - accuracy: 0.9958 - 22s/epoch - 321ms/step
# Epoch 41/100
# 68/68 - 22s - loss: 0.0073 - accuracy: 0.9977 - 22s/epoch - 317ms/step
# Epoch 42/100
# 68/68 - 22s - loss: 0.0096 - accuracy: 0.9977 - 22s/epoch - 319ms/step
# Epoch 43/100
# 68/68 - 22s - loss: 0.0042 - accuracy: 0.9977 - 22s/epoch - 318ms/step
# Epoch 44/100
# 68/68 - 22s - loss: 0.0132 - accuracy: 0.9963 - 22s/epoch - 318ms/step
# Epoch 45/100
# 68/68 - 22s - loss: 0.0780 - accuracy: 0.9875 - 22s/epoch - 317ms/step
# Epoch 46/100
# 68/68 - 22s - loss: 0.0277 - accuracy: 0.9921 - 22s/epoch - 316ms/step
# Epoch 47/100
# 68/68 - 21s - loss: 0.0333 - accuracy: 0.9912 - 21s/epoch - 314ms/step
# Epoch 48/100
# 68/68 - 22s - loss: 0.0318 - accuracy: 0.9931 - 22s/epoch - 318ms/step
# Epoch 49/100
# 68/68 - 21s - loss: 0.0089 - accuracy: 0.9972 - 21s/epoch - 316ms/step
# Epoch 50/100
# 68/68 - 22s - loss: 0.0145 - accuracy: 0.9963 - 22s/epoch - 316ms/step
# Epoch 51/100
# 68/68 - 21s - loss: 0.0105 - accuracy: 0.9968 - 21s/epoch - 315ms/step
# Epoch 52/100
# 68/68 - 22s - loss: 0.0052 - accuracy: 0.9981 - 22s/epoch - 319ms/step
# Epoch 53/100
# 68/68 - 22s - loss: 0.0053 - accuracy: 0.9972 - 22s/epoch - 317ms/step
# Epoch 54/100
# 68/68 - 22s - loss: 0.0162 - accuracy: 0.9944 - 22s/epoch - 317ms/step
# Epoch 55/100
# 68/68 - 22s - loss: 0.0409 - accuracy: 0.9917 - 22s/epoch - 320ms/step
# Epoch 56/100
# 68/68 - 22s - loss: 0.0203 - accuracy: 0.9958 - 22s/epoch - 316ms/step
# Epoch 57/100
# 68/68 - 22s - loss: 0.1161 - accuracy: 0.9819 - 22s/epoch - 316ms/step
# Epoch 58/100
# 68/68 - 22s - loss: 0.1875 - accuracy: 0.9778 - 22s/epoch - 316ms/step
# Epoch 59/100
# 68/68 - 21s - loss: 0.2118 - accuracy: 0.9745 - 21s/epoch - 316ms/step
# Epoch 60/100
# 68/68 - 22s - loss: 0.0753 - accuracy: 0.9875 - 22s/epoch - 316ms/step
# Epoch 61/100
# 68/68 - 21s - loss: 0.0187 - accuracy: 0.9921 - 21s/epoch - 314ms/step
# Epoch 62/100
# 68/68 - 22s - loss: 0.0124 - accuracy: 0.9958 - 22s/epoch - 317ms/step
# Epoch 63/100
# 68/68 - 22s - loss: 0.0153 - accuracy: 0.9954 - 22s/epoch - 318ms/step
# Epoch 64/100
# 68/68 - 21s - loss: 0.0146 - accuracy: 0.9968 - 21s/epoch - 315ms/step
# Epoch 65/100
# 68/68 - 22s - loss: 0.0502 - accuracy: 0.9940 - 22s/epoch - 316ms/step
# Epoch 66/100
# 68/68 - 22s - loss: 0.0358 - accuracy: 0.9907 - 22s/epoch - 317ms/step
# Epoch 67/100
# 68/68 - 21s - loss: 0.0168 - accuracy: 0.9949 - 21s/epoch - 315ms/step
# Epoch 68/100
# 68/68 - 21s - loss: 0.0163 - accuracy: 0.9972 - 21s/epoch - 315ms/step
# Epoch 69/100
# 68/68 - 22s - loss: 0.0158 - accuracy: 0.9954 - 22s/epoch - 319ms/step
# Epoch 70/100
# 68/68 - 22s - loss: 0.0168 - accuracy: 0.9944 - 22s/epoch - 317ms/step
# Epoch 71/100
# 68/68 - 21s - loss: 0.0074 - accuracy: 0.9977 - 21s/epoch - 316ms/step
# Epoch 72/100
# 68/68 - 22s - loss: 0.0154 - accuracy: 0.9972 - 22s/epoch - 318ms/step
# Epoch 73/100
# 68/68 - 22s - loss: 0.0064 - accuracy: 0.9981 - 22s/epoch - 318ms/step
# Epoch 74/100
# 68/68 - 22s - loss: 0.0029 - accuracy: 0.9991 - 22s/epoch - 317ms/step
# Epoch 75/100
# 68/68 - 22s - loss: 0.0046 - accuracy: 0.9972 - 22s/epoch - 316ms/step
# Epoch 76/100
# 68/68 - 22s - loss: 0.0076 - accuracy: 0.9972 - 22s/epoch - 317ms/step
# Epoch 77/100
# 68/68 - 22s - loss: 0.0218 - accuracy: 0.9958 - 22s/epoch - 317ms/step
# Epoch 78/100
# 68/68 - 22s - loss: 0.0021 - accuracy: 0.9995 - 22s/epoch - 318ms/step
# Epoch 79/100
# 68/68 - 22s - loss: 0.0041 - accuracy: 0.9981 - 22s/epoch - 318ms/step
# Epoch 80/100
# 68/68 - 22s - loss: 0.0073 - accuracy: 0.9981 - 22s/epoch - 317ms/step
# Epoch 81/100
# 68/68 - 22s - loss: 0.0126 - accuracy: 0.9968 - 22s/epoch - 317ms/step
# Epoch 82/100
# 68/68 - 22s - loss: 0.0132 - accuracy: 0.9977 - 22s/epoch - 318ms/step
# Epoch 83/100
# 68/68 - 22s - loss: 0.0084 - accuracy: 0.9977 - 22s/epoch - 320ms/step
# Epoch 84/100
# 68/68 - 22s - loss: 0.0138 - accuracy: 0.9977 - 22s/epoch - 318ms/step
# Epoch 85/100
# 68/68 - 22s - loss: 0.0033 - accuracy: 0.9986 - 22s/epoch - 318ms/step
# Epoch 86/100
# 68/68 - 22s - loss: 0.0059 - accuracy: 0.9981 - 22s/epoch - 318ms/step
# Epoch 87/100
# 68/68 - 22s - loss: 0.0062 - accuracy: 0.9991 - 22s/epoch - 320ms/step
# Epoch 88/100
# 68/68 - 22s - loss: 3.8070e-04 - accuracy: 1.0000 - 22s/epoch - 320ms/step
# Epoch 89/100
# 68/68 - 22s - loss: 7.0606e-04 - accuracy: 1.0000 - 22s/epoch - 318ms/step
# Epoch 90/100
# 68/68 - 22s - loss: 9.2795e-04 - accuracy: 1.0000 - 22s/epoch - 320ms/step
# Epoch 91/100
# 68/68 - 22s - loss: 6.2217e-04 - accuracy: 1.0000 - 22s/epoch - 318ms/step
# Epoch 92/100
# 68/68 - 22s - loss: 0.0013 - accuracy: 0.9991 - 22s/epoch - 319ms/step
# Epoch 93/100
# 68/68 - 22s - loss: 0.0118 - accuracy: 0.9963 - 22s/epoch - 317ms/step
# Epoch 94/100
# 68/68 - 22s - loss: 9.0369e-04 - accuracy: 1.0000 - 22s/epoch - 319ms/step
# Epoch 95/100
# 68/68 - 22s - loss: 0.0054 - accuracy: 0.9972 - 22s/epoch - 317ms/step
# Epoch 96/100
# 68/68 - 22s - loss: 0.0012 - accuracy: 1.0000 - 22s/epoch - 319ms/step
# Epoch 97/100
# 68/68 - 22s - loss: 0.0029 - accuracy: 0.9986 - 22s/epoch - 319ms/step
# Epoch 98/100
# 68/68 - 22s - loss: 0.0167 - accuracy: 0.9968 - 22s/epoch - 320ms/step
# Epoch 99/100
# 68/68 - 22s - loss: 0.0180 - accuracy: 0.9968 - 22s/epoch - 318ms/step
# Epoch 100/100
# 68/68 - 22s - loss: 0.0059 - accuracy: 0.9981 - 22s/epoch - 318ms/step
# 0.0529
# ***Performance on Test Data***
# Accuracy  : 0.9796296296296296
# Precision : 0.9797391277205352
# f1Score : 0.9796494092638652
# [[176   2   2]
#  [  0 176   4]
#  [  2   1 177]]
# 17/17 [==============================] - 6s 344ms/step - loss: 0.2438 - accuracy: 0.9796
# trn_indx: 2160 test_indx: 540
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# Results for fold 2
# 2160
# 540
# Found 2160 images belonging to 3 classes.
# Found 540 images belonging to 3 classes.
# Epoch 1/100
# 68/68 - 22s - loss: 0.1157 - accuracy: 0.9875 - 22s/epoch - 322ms/step
# Epoch 2/100
# 68/68 - 22s - loss: 0.1357 - accuracy: 0.9764 - 22s/epoch - 321ms/step
# Epoch 3/100
# 68/68 - 22s - loss: 0.0358 - accuracy: 0.9889 - 22s/epoch - 321ms/step
# Epoch 4/100
# 68/68 - 22s - loss: 0.0353 - accuracy: 0.9903 - 22s/epoch - 319ms/step
# Epoch 5/100
# 68/68 - 22s - loss: 0.0094 - accuracy: 0.9963 - 22s/epoch - 319ms/step
# Epoch 6/100
# 68/68 - 22s - loss: 0.0171 - accuracy: 0.9940 - 22s/epoch - 319ms/step
# Epoch 7/100
# 68/68 - 22s - loss: 0.0080 - accuracy: 0.9968 - 22s/epoch - 316ms/step
# Epoch 8/100
# 68/68 - 21s - loss: 0.0143 - accuracy: 0.9981 - 21s/epoch - 316ms/step
# Epoch 9/100
# 68/68 - 22s - loss: 0.0048 - accuracy: 0.9981 - 22s/epoch - 317ms/step
# Epoch 10/100
# 68/68 - 22s - loss: 0.0033 - accuracy: 0.9991 - 22s/epoch - 317ms/step
# Epoch 11/100
# 68/68 - 22s - loss: 0.0068 - accuracy: 0.9977 - 22s/epoch - 317ms/step
# Epoch 12/100
# 68/68 - 21s - loss: 0.0097 - accuracy: 0.9972 - 21s/epoch - 315ms/step
# Epoch 13/100
# 68/68 - 22s - loss: 0.0087 - accuracy: 0.9977 - 22s/epoch - 319ms/step
# Epoch 14/100
# 68/68 - 22s - loss: 0.0042 - accuracy: 0.9986 - 22s/epoch - 320ms/step
# Epoch 15/100
# 68/68 - 21s - loss: 0.0017 - accuracy: 0.9995 - 21s/epoch - 314ms/step
# Epoch 16/100
# 68/68 - 21s - loss: 0.0096 - accuracy: 0.9981 - 21s/epoch - 316ms/step
# Epoch 17/100
# 68/68 - 22s - loss: 0.0069 - accuracy: 0.9986 - 22s/epoch - 318ms/step
# Epoch 18/100
# 68/68 - 22s - loss: 0.0284 - accuracy: 0.9931 - 22s/epoch - 317ms/step
# Epoch 19/100
# 68/68 - 22s - loss: 0.0133 - accuracy: 0.9972 - 22s/epoch - 319ms/step
# Epoch 20/100
# 68/68 - 22s - loss: 0.0157 - accuracy: 0.9963 - 22s/epoch - 319ms/step
# Epoch 21/100
# 68/68 - 22s - loss: 0.0201 - accuracy: 0.9968 - 22s/epoch - 320ms/step
# Epoch 22/100
# 68/68 - 22s - loss: 0.0136 - accuracy: 0.9958 - 22s/epoch - 316ms/step
# Epoch 23/100
# 68/68 - 21s - loss: 0.0240 - accuracy: 0.9968 - 21s/epoch - 315ms/step
# Epoch 24/100
# 68/68 - 21s - loss: 0.0569 - accuracy: 0.9921 - 21s/epoch - 316ms/step
# Epoch 25/100
# 68/68 - 22s - loss: 0.0138 - accuracy: 0.9954 - 22s/epoch - 317ms/step
# Epoch 26/100
# 68/68 - 22s - loss: 0.0167 - accuracy: 0.9963 - 22s/epoch - 319ms/step
# Epoch 27/100
# 68/68 - 22s - loss: 0.0335 - accuracy: 0.9949 - 22s/epoch - 318ms/step
# Epoch 28/100
# 68/68 - 22s - loss: 0.0226 - accuracy: 0.9944 - 22s/epoch - 320ms/step
# Epoch 29/100
# 68/68 - 22s - loss: 0.0289 - accuracy: 0.9944 - 22s/epoch - 319ms/step
# Epoch 30/100
# 68/68 - 22s - loss: 0.0191 - accuracy: 0.9949 - 22s/epoch - 322ms/step
# Epoch 31/100
# 68/68 - 22s - loss: 0.0124 - accuracy: 0.9963 - 22s/epoch - 319ms/step
# Epoch 32/100
# 68/68 - 22s - loss: 0.0183 - accuracy: 0.9968 - 22s/epoch - 321ms/step
# Epoch 33/100
# 68/68 - 22s - loss: 0.0050 - accuracy: 0.9977 - 22s/epoch - 317ms/step
# Epoch 34/100
# 68/68 - 22s - loss: 0.0068 - accuracy: 0.9977 - 22s/epoch - 319ms/step
# Epoch 35/100
# 68/68 - 22s - loss: 0.0162 - accuracy: 0.9968 - 22s/epoch - 317ms/step
# Epoch 36/100
# 68/68 - 22s - loss: 0.0165 - accuracy: 0.9958 - 22s/epoch - 318ms/step
# Epoch 37/100
# 68/68 - 22s - loss: 0.0231 - accuracy: 0.9963 - 22s/epoch - 317ms/step
# Epoch 38/100
# 68/68 - 22s - loss: 0.0517 - accuracy: 0.9935 - 22s/epoch - 318ms/step
# Epoch 39/100
# 68/68 - 22s - loss: 0.0186 - accuracy: 0.9963 - 22s/epoch - 318ms/step
# Epoch 40/100
# 68/68 - 22s - loss: 0.0239 - accuracy: 0.9940 - 22s/epoch - 318ms/step
# Epoch 41/100
# 68/68 - 22s - loss: 0.0470 - accuracy: 0.9944 - 22s/epoch - 317ms/step
# Epoch 42/100
# 68/68 - 22s - loss: 0.0411 - accuracy: 0.9940 - 22s/epoch - 321ms/step
# Epoch 43/100
# 68/68 - 22s - loss: 0.0079 - accuracy: 0.9972 - 22s/epoch - 319ms/step
# Epoch 44/100
# 68/68 - 22s - loss: 0.0062 - accuracy: 0.9977 - 22s/epoch - 320ms/step
# Epoch 45/100
# 68/68 - 22s - loss: 0.0147 - accuracy: 0.9968 - 22s/epoch - 318ms/step
# Epoch 46/100
# 68/68 - 22s - loss: 0.0172 - accuracy: 0.9981 - 22s/epoch - 318ms/step
# Epoch 47/100
# 68/68 - 22s - loss: 0.0091 - accuracy: 0.9986 - 22s/epoch - 320ms/step
# Epoch 48/100
# 68/68 - 22s - loss: 0.0025 - accuracy: 0.9995 - 22s/epoch - 320ms/step
# Epoch 49/100
# 68/68 - 22s - loss: 0.0011 - accuracy: 1.0000 - 22s/epoch - 319ms/step
# Epoch 50/100
# 68/68 - 22s - loss: 0.0025 - accuracy: 0.9995 - 22s/epoch - 322ms/step
# Epoch 51/100
# 68/68 - 22s - loss: 0.0033 - accuracy: 0.9991 - 22s/epoch - 319ms/step
# Epoch 52/100
# 68/68 - 22s - loss: 0.0024 - accuracy: 0.9991 - 22s/epoch - 319ms/step
# Epoch 53/100
# 68/68 - 22s - loss: 0.0024 - accuracy: 0.9986 - 22s/epoch - 320ms/step
# Epoch 54/100
# 68/68 - 22s - loss: 0.0017 - accuracy: 0.9995 - 22s/epoch - 319ms/step
# Epoch 55/100
# 68/68 - 22s - loss: 0.0127 - accuracy: 0.9977 - 22s/epoch - 317ms/step
# Epoch 56/100
# 68/68 - 22s - loss: 0.0040 - accuracy: 0.9991 - 22s/epoch - 319ms/step
# Epoch 57/100
# 68/68 - 22s - loss: 0.0075 - accuracy: 0.9977 - 22s/epoch - 319ms/step
# Epoch 58/100
# 68/68 - 22s - loss: 0.0328 - accuracy: 0.9958 - 22s/epoch - 320ms/step
# Epoch 59/100
# 68/68 - 22s - loss: 0.0046 - accuracy: 0.9995 - 22s/epoch - 323ms/step
# Epoch 60/100
# 68/68 - 22s - loss: 0.1344 - accuracy: 0.9935 - 22s/epoch - 323ms/step
# Epoch 61/100
# 68/68 - 22s - loss: 0.0201 - accuracy: 0.9963 - 22s/epoch - 321ms/step
# Epoch 62/100
# 68/68 - 22s - loss: 0.0153 - accuracy: 0.9958 - 22s/epoch - 322ms/step
# Epoch 63/100
# 68/68 - 22s - loss: 0.0061 - accuracy: 0.9981 - 22s/epoch - 320ms/step
# Epoch 64/100
# 68/68 - 22s - loss: 0.0201 - accuracy: 0.9963 - 22s/epoch - 320ms/step
# Epoch 65/100
# 68/68 - 22s - loss: 0.0159 - accuracy: 0.9963 - 22s/epoch - 319ms/step
# Epoch 66/100
# 68/68 - 22s - loss: 0.0098 - accuracy: 0.9977 - 22s/epoch - 318ms/step
# Epoch 67/100
# 68/68 - 22s - loss: 0.0036 - accuracy: 0.9986 - 22s/epoch - 320ms/step
# Epoch 68/100
# 68/68 - 22s - loss: 0.0165 - accuracy: 0.9972 - 22s/epoch - 319ms/step
# Epoch 69/100
# 68/68 - 22s - loss: 0.0010 - accuracy: 1.0000 - 22s/epoch - 318ms/step
# Epoch 70/100
# 68/68 - 22s - loss: 0.0055 - accuracy: 0.9981 - 22s/epoch - 319ms/step
# Epoch 71/100
# 68/68 - 22s - loss: 0.0035 - accuracy: 0.9986 - 22s/epoch - 322ms/step
# Epoch 72/100
# 68/68 - 22s - loss: 0.0029 - accuracy: 0.9991 - 22s/epoch - 318ms/step
# Epoch 73/100
# 68/68 - 22s - loss: 0.0012 - accuracy: 0.9995 - 22s/epoch - 318ms/step
# Epoch 74/100
# 68/68 - 22s - loss: 0.0037 - accuracy: 0.9986 - 22s/epoch - 319ms/step
# Epoch 75/100
# 68/68 - 22s - loss: 0.0094 - accuracy: 0.9986 - 22s/epoch - 319ms/step
# Epoch 76/100
# 68/68 - 22s - loss: 0.0020 - accuracy: 0.9991 - 22s/epoch - 319ms/step
# Epoch 77/100
# 68/68 - 22s - loss: 0.0097 - accuracy: 0.9981 - 22s/epoch - 318ms/step
# Epoch 78/100
# 68/68 - 22s - loss: 0.0054 - accuracy: 0.9981 - 22s/epoch - 322ms/step
# Epoch 79/100
# 68/68 - 22s - loss: 0.0013 - accuracy: 0.9995 - 22s/epoch - 319ms/step
# Epoch 80/100
# 68/68 - 22s - loss: 2.3540e-04 - accuracy: 1.0000 - 22s/epoch - 322ms/step
# Epoch 81/100
# 68/68 - 22s - loss: 0.0013 - accuracy: 0.9995 - 22s/epoch - 320ms/step
# Epoch 82/100
# 68/68 - 22s - loss: 5.2484e-04 - accuracy: 1.0000 - 22s/epoch - 320ms/step
# Epoch 83/100
# 68/68 - 22s - loss: 0.0012 - accuracy: 0.9995 - 22s/epoch - 319ms/step
# Epoch 84/100
# 68/68 - 22s - loss: 7.9507e-04 - accuracy: 0.9995 - 22s/epoch - 321ms/step
# Epoch 85/100
# 68/68 - 22s - loss: 4.3536e-04 - accuracy: 1.0000 - 22s/epoch - 322ms/step
# Epoch 86/100
# 68/68 - 22s - loss: 0.0013 - accuracy: 0.9995 - 22s/epoch - 319ms/step
# Epoch 87/100
# 68/68 - 22s - loss: 6.0650e-04 - accuracy: 1.0000 - 22s/epoch - 318ms/step
# Epoch 88/100
# 68/68 - 22s - loss: 0.0012 - accuracy: 0.9995 - 22s/epoch - 320ms/step
# Epoch 89/100
# 68/68 - 22s - loss: 3.8286e-04 - accuracy: 1.0000 - 22s/epoch - 322ms/step
# Epoch 90/100
# 68/68 - 22s - loss: 0.0019 - accuracy: 0.9991 - 22s/epoch - 319ms/step
# Epoch 91/100
# 68/68 - 22s - loss: 0.0032 - accuracy: 0.9986 - 22s/epoch - 319ms/step
# Epoch 92/100
# 68/68 - 22s - loss: 7.8857e-04 - accuracy: 1.0000 - 22s/epoch - 321ms/step
# Epoch 93/100
# 68/68 - 22s - loss: 0.0011 - accuracy: 0.9995 - 22s/epoch - 317ms/step
# Epoch 94/100
# 68/68 - 22s - loss: 6.7083e-04 - accuracy: 0.9995 - 22s/epoch - 319ms/step
# Epoch 95/100
# 68/68 - 22s - loss: 0.0011 - accuracy: 0.9995 - 22s/epoch - 321ms/step
# Epoch 96/100
# 68/68 - 22s - loss: 4.1162e-04 - accuracy: 1.0000 - 22s/epoch - 321ms/step
# Epoch 97/100
# 68/68 - 22s - loss: 6.6857e-04 - accuracy: 1.0000 - 22s/epoch - 320ms/step
# Epoch 98/100
# 68/68 - 22s - loss: 1.0635e-04 - accuracy: 1.0000 - 22s/epoch - 321ms/step
# Epoch 99/100
# 68/68 - 22s - loss: 3.2994e-04 - accuracy: 1.0000 - 22s/epoch - 324ms/step
# Epoch 100/100
# 68/68 - 22s - loss: 5.4024e-04 - accuracy: 1.0000 - 22s/epoch - 320ms/step
# 0.0537
# ***Performance on Test Data***
# Accuracy  : 0.9944444444444445
# Precision : 0.9944545613547744
# f1Score : 0.9944444015771725
# [[180   0   0]
#  [  0 179   1]
#  [  0   2 178]]
# 17/17 [==============================] - 5s 324ms/step - loss: 0.0238 - accuracy: 0.9944
# trn_indx: 2160 test_indx: 540
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# Results for fold 3
# 2160
# 540
# Found 2160 images belonging to 3 classes.
# Found 540 images belonging to 3 classes.
# Epoch 1/100
# 68/68 - 22s - loss: 0.0755 - accuracy: 0.9907 - 22s/epoch - 322ms/step
# Epoch 2/100
# 68/68 - 22s - loss: 0.0758 - accuracy: 0.9926 - 22s/epoch - 324ms/step
# Epoch 3/100
# 68/68 - 22s - loss: 0.0632 - accuracy: 0.9880 - 22s/epoch - 323ms/step
# Epoch 4/100
# 68/68 - 22s - loss: 0.0231 - accuracy: 0.9931 - 22s/epoch - 324ms/step
# Epoch 5/100
# 68/68 - 22s - loss: 0.0126 - accuracy: 0.9972 - 22s/epoch - 325ms/step
# Epoch 6/100
# 68/68 - 22s - loss: 0.0079 - accuracy: 0.9972 - 22s/epoch - 322ms/step
# Epoch 7/100
# 68/68 - 22s - loss: 0.0144 - accuracy: 0.9977 - 22s/epoch - 324ms/step
# Epoch 8/100
# 68/68 - 22s - loss: 0.0019 - accuracy: 1.0000 - 22s/epoch - 323ms/step
# Epoch 9/100
# 68/68 - 22s - loss: 0.0131 - accuracy: 0.9972 - 22s/epoch - 321ms/step
# Epoch 10/100
# 68/68 - 22s - loss: 0.0125 - accuracy: 0.9977 - 22s/epoch - 323ms/step
# Epoch 11/100
# 68/68 - 22s - loss: 0.0050 - accuracy: 0.9981 - 22s/epoch - 322ms/step
# Epoch 12/100
# 68/68 - 22s - loss: 0.0029 - accuracy: 0.9991 - 22s/epoch - 323ms/step
# Epoch 13/100
# 68/68 - 22s - loss: 0.0031 - accuracy: 0.9986 - 22s/epoch - 327ms/step
# Epoch 14/100
# 68/68 - 22s - loss: 0.0074 - accuracy: 0.9977 - 22s/epoch - 324ms/step
# Epoch 15/100
# 68/68 - 22s - loss: 0.0025 - accuracy: 0.9995 - 22s/epoch - 324ms/step
# Epoch 16/100
# 68/68 - 22s - loss: 5.1539e-04 - accuracy: 1.0000 - 22s/epoch - 326ms/step
# Epoch 17/100
# 68/68 - 22s - loss: 0.0033 - accuracy: 0.9977 - 22s/epoch - 323ms/step
# Epoch 18/100
# 68/68 - 22s - loss: 0.0048 - accuracy: 0.9981 - 22s/epoch - 322ms/step
# Epoch 19/100
# 68/68 - 22s - loss: 0.0220 - accuracy: 0.9958 - 22s/epoch - 321ms/step
# Epoch 20/100
# 68/68 - 22s - loss: 0.0808 - accuracy: 0.9931 - 22s/epoch - 322ms/step
# Epoch 21/100
# 68/68 - 22s - loss: 0.0509 - accuracy: 0.9926 - 22s/epoch - 321ms/step
# Epoch 22/100
# 68/68 - 22s - loss: 0.0186 - accuracy: 0.9958 - 22s/epoch - 325ms/step
# Epoch 23/100
# 68/68 - 22s - loss: 0.0341 - accuracy: 0.9963 - 22s/epoch - 321ms/step
# Epoch 24/100
# 68/68 - 22s - loss: 0.0031 - accuracy: 0.9986 - 22s/epoch - 322ms/step
# Epoch 25/100
# 68/68 - 22s - loss: 0.0205 - accuracy: 0.9972 - 22s/epoch - 323ms/step
# Epoch 26/100
# 68/68 - 22s - loss: 0.0131 - accuracy: 0.9977 - 22s/epoch - 322ms/step
# Epoch 27/100
# 68/68 - 22s - loss: 0.0041 - accuracy: 0.9991 - 22s/epoch - 327ms/step
# Epoch 28/100
# 68/68 - 22s - loss: 0.0034 - accuracy: 0.9995 - 22s/epoch - 322ms/step
# Epoch 29/100
# 68/68 - 22s - loss: 0.0016 - accuracy: 0.9995 - 22s/epoch - 324ms/step
# Epoch 30/100
# 68/68 - 22s - loss: 0.0051 - accuracy: 0.9981 - 22s/epoch - 328ms/step
# Epoch 31/100
# 68/68 - 22s - loss: 4.5925e-04 - accuracy: 1.0000 - 22s/epoch - 323ms/step
# Epoch 32/100
# 68/68 - 22s - loss: 0.0011 - accuracy: 0.9995 - 22s/epoch - 321ms/step
# Epoch 33/100
# 68/68 - 22s - loss: 0.0069 - accuracy: 0.9977 - 22s/epoch - 321ms/step
# Epoch 34/100
# 68/68 - 22s - loss: 0.0072 - accuracy: 0.9986 - 22s/epoch - 323ms/step
# Epoch 35/100
# 68/68 - 22s - loss: 0.0072 - accuracy: 0.9981 - 22s/epoch - 322ms/step
# Epoch 36/100
# 68/68 - 22s - loss: 0.0083 - accuracy: 0.9972 - 22s/epoch - 324ms/step
# Epoch 37/100
# 68/68 - 22s - loss: 0.0019 - accuracy: 1.0000 - 22s/epoch - 322ms/step
# Epoch 38/100
# 68/68 - 22s - loss: 0.0401 - accuracy: 0.9972 - 22s/epoch - 324ms/step
# Epoch 39/100
# 68/68 - 22s - loss: 0.0600 - accuracy: 0.9921 - 22s/epoch - 322ms/step
# Epoch 40/100
# 68/68 - 22s - loss: 0.0140 - accuracy: 0.9963 - 22s/epoch - 322ms/step
# Epoch 41/100
# 68/68 - 22s - loss: 0.0304 - accuracy: 0.9977 - 22s/epoch - 328ms/step
# Epoch 42/100
# 68/68 - 22s - loss: 0.0294 - accuracy: 0.9935 - 22s/epoch - 325ms/step
# Epoch 43/100
# 68/68 - 22s - loss: 0.0075 - accuracy: 0.9981 - 22s/epoch - 323ms/step
# Epoch 44/100
# 68/68 - 22s - loss: 4.2672e-04 - accuracy: 1.0000 - 22s/epoch - 323ms/step
# Epoch 45/100
# 68/68 - 22s - loss: 0.0018 - accuracy: 0.9995 - 22s/epoch - 323ms/step
# Epoch 46/100
# 68/68 - 22s - loss: 0.0027 - accuracy: 0.9986 - 22s/epoch - 325ms/step
# Epoch 47/100
# 68/68 - 22s - loss: 6.6838e-04 - accuracy: 1.0000 - 22s/epoch - 330ms/step
# Epoch 48/100
# 68/68 - 23s - loss: 0.0015 - accuracy: 0.9991 - 23s/epoch - 332ms/step
# Epoch 49/100
# 68/68 - 23s - loss: 0.0762 - accuracy: 0.9940 - 23s/epoch - 339ms/step
# Epoch 50/100
# 68/68 - 22s - loss: 0.0618 - accuracy: 0.9968 - 22s/epoch - 327ms/step
# Epoch 51/100
# 68/68 - 22s - loss: 0.0458 - accuracy: 0.9940 - 22s/epoch - 329ms/step
# Epoch 52/100
# 68/68 - 22s - loss: 0.0123 - accuracy: 0.9963 - 22s/epoch - 329ms/step
# Epoch 53/100
# 68/68 - 22s - loss: 0.0314 - accuracy: 0.9931 - 22s/epoch - 329ms/step
# Epoch 54/100
# 68/68 - 22s - loss: 0.0199 - accuracy: 0.9944 - 22s/epoch - 322ms/step
# Epoch 55/100
# 68/68 - 22s - loss: 0.0090 - accuracy: 0.9981 - 22s/epoch - 326ms/step
# Epoch 56/100
# 68/68 - 22s - loss: 0.0030 - accuracy: 0.9986 - 22s/epoch - 325ms/step
# Epoch 57/100
# 68/68 - 22s - loss: 0.0056 - accuracy: 0.9981 - 22s/epoch - 326ms/step
# Epoch 58/100
# 68/68 - 22s - loss: 0.0135 - accuracy: 0.9981 - 22s/epoch - 323ms/step
# Epoch 59/100
# 68/68 - 22s - loss: 0.0080 - accuracy: 0.9991 - 22s/epoch - 322ms/step
# Epoch 60/100
# 68/68 - 22s - loss: 0.0110 - accuracy: 0.9981 - 22s/epoch - 328ms/step
# Epoch 61/100
# 68/68 - 22s - loss: 9.2885e-04 - accuracy: 1.0000 - 22s/epoch - 323ms/step
# Epoch 62/100
# 68/68 - 22s - loss: 1.5299e-04 - accuracy: 1.0000 - 22s/epoch - 324ms/step
# Epoch 63/100
# 68/68 - 22s - loss: 0.0042 - accuracy: 0.9995 - 22s/epoch - 326ms/step
# Epoch 64/100
# 68/68 - 22s - loss: 0.0170 - accuracy: 0.9991 - 22s/epoch - 328ms/step
# Epoch 65/100
# 68/68 - 22s - loss: 0.0046 - accuracy: 0.9991 - 22s/epoch - 325ms/step
# Epoch 66/100
# 68/68 - 22s - loss: 0.0112 - accuracy: 0.9986 - 22s/epoch - 326ms/step
# Epoch 67/100
# 68/68 - 22s - loss: 0.0018 - accuracy: 0.9991 - 22s/epoch - 328ms/step
# Epoch 68/100
# 68/68 - 22s - loss: 0.0136 - accuracy: 0.9977 - 22s/epoch - 326ms/step
# Epoch 69/100
# 68/68 - 23s - loss: 0.0024 - accuracy: 0.9981 - 23s/epoch - 331ms/step
# Epoch 70/100
# 68/68 - 22s - loss: 0.0013 - accuracy: 0.9991 - 22s/epoch - 324ms/step
# Epoch 71/100
# 68/68 - 22s - loss: 0.0018 - accuracy: 0.9995 - 22s/epoch - 323ms/step
# Epoch 72/100
# 68/68 - 22s - loss: 0.0014 - accuracy: 0.9995 - 22s/epoch - 324ms/step
# Epoch 73/100
# 68/68 - 22s - loss: 0.0324 - accuracy: 0.9972 - 22s/epoch - 322ms/step
# Epoch 74/100
# 68/68 - 22s - loss: 0.0082 - accuracy: 0.9977 - 22s/epoch - 323ms/step
# Epoch 75/100
# 68/68 - 22s - loss: 0.0090 - accuracy: 0.9986 - 22s/epoch - 322ms/step
# Epoch 76/100
# 68/68 - 22s - loss: 0.0053 - accuracy: 0.9981 - 22s/epoch - 324ms/step
# Epoch 77/100
# 68/68 - 22s - loss: 0.0071 - accuracy: 0.9986 - 22s/epoch - 323ms/step
# Epoch 78/100
# 68/68 - 22s - loss: 0.0017 - accuracy: 0.9995 - 22s/epoch - 328ms/step
# Epoch 79/100
# 68/68 - 22s - loss: 0.0071 - accuracy: 0.9981 - 22s/epoch - 325ms/step
# Epoch 80/100
# 68/68 - 22s - loss: 0.0070 - accuracy: 0.9991 - 22s/epoch - 326ms/step
# Epoch 81/100
# 68/68 - 22s - loss: 0.0308 - accuracy: 0.9972 - 22s/epoch - 325ms/step
# Epoch 82/100
# 68/68 - 22s - loss: 0.0398 - accuracy: 0.9949 - 22s/epoch - 325ms/step
# Epoch 83/100
# 68/68 - 22s - loss: 0.0097 - accuracy: 0.9972 - 22s/epoch - 326ms/step
# Epoch 84/100
# 68/68 - 22s - loss: 0.0038 - accuracy: 0.9991 - 22s/epoch - 321ms/step
# Epoch 85/100
# 68/68 - 22s - loss: 0.0014 - accuracy: 0.9995 - 22s/epoch - 324ms/step
# Epoch 86/100
# 68/68 - 22s - loss: 0.0025 - accuracy: 0.9995 - 22s/epoch - 322ms/step
# Epoch 87/100
# 68/68 - 22s - loss: 0.0012 - accuracy: 0.9995 - 22s/epoch - 323ms/step
# Epoch 88/100
# 68/68 - 22s - loss: 0.0015 - accuracy: 0.9995 - 22s/epoch - 322ms/step
# Epoch 89/100
# 68/68 - 22s - loss: 5.3341e-04 - accuracy: 1.0000 - 22s/epoch - 329ms/step
# Epoch 90/100
# 68/68 - 22s - loss: 5.5186e-04 - accuracy: 1.0000 - 22s/epoch - 327ms/step
# Epoch 91/100
# 68/68 - 22s - loss: 0.0018 - accuracy: 0.9991 - 22s/epoch - 327ms/step
# Epoch 92/100
# 68/68 - 22s - loss: 4.3995e-04 - accuracy: 0.9995 - 22s/epoch - 325ms/step
# Epoch 93/100
# 68/68 - 22s - loss: 6.6174e-04 - accuracy: 1.0000 - 22s/epoch - 325ms/step
# Epoch 94/100
# 68/68 - 22s - loss: 9.0297e-04 - accuracy: 0.9995 - 22s/epoch - 320ms/step
# Epoch 95/100
# 68/68 - 22s - loss: 9.3651e-06 - accuracy: 1.0000 - 22s/epoch - 323ms/step
# Epoch 96/100
# 68/68 - 22s - loss: 2.9729e-04 - accuracy: 1.0000 - 22s/epoch - 324ms/step
# Epoch 97/100
# 68/68 - 22s - loss: 7.3470e-05 - accuracy: 1.0000 - 22s/epoch - 327ms/step
# Epoch 98/100
# 68/68 - 22s - loss: 0.0027 - accuracy: 0.9991 - 22s/epoch - 324ms/step
# Epoch 99/100
# 68/68 - 22s - loss: 0.0020 - accuracy: 0.9995 - 22s/epoch - 324ms/step
# Epoch 100/100
# 68/68 - 22s - loss: 0.0011 - accuracy: 0.9995 - 22s/epoch - 326ms/step
# 0.0538
# ***Performance on Test Data***
# Accuracy  : 0.9962962962962963
# Precision : 0.9963065275219972
# f1Score : 0.9962962820072057
# [[180   0   0]
#  [  0 179   1]
#  [  1   0 179]]
# 17/17 [==============================] - 5s 323ms/step - loss: 0.0320 - accuracy: 0.9963
# trn_indx: 2160 test_indx: 540
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# Results for fold 4
# 2160
# 540
# Found 2160 images belonging to 3 classes.
# Found 540 images belonging to 3 classes.
# Epoch 1/100
# 68/68 - 22s - loss: 0.0736 - accuracy: 0.9949 - 22s/epoch - 325ms/step
# Epoch 2/100
# 68/68 - 22s - loss: 0.0227 - accuracy: 0.9935 - 22s/epoch - 327ms/step
# Epoch 3/100
# 68/68 - 22s - loss: 0.0259 - accuracy: 0.9977 - 22s/epoch - 325ms/step
# Epoch 4/100
# 68/68 - 22s - loss: 0.0073 - accuracy: 0.9981 - 22s/epoch - 324ms/step
# Epoch 5/100
# 68/68 - 22s - loss: 0.0219 - accuracy: 0.9958 - 22s/epoch - 324ms/step
# Epoch 6/100
# 68/68 - 22s - loss: 0.0088 - accuracy: 0.9986 - 22s/epoch - 323ms/step
# Epoch 7/100
# 68/68 - 22s - loss: 0.0016 - accuracy: 0.9995 - 22s/epoch - 323ms/step
# Epoch 8/100
# 68/68 - 22s - loss: 0.0028 - accuracy: 0.9995 - 22s/epoch - 323ms/step
# Epoch 9/100
# 68/68 - 22s - loss: 0.0030 - accuracy: 0.9986 - 22s/epoch - 324ms/step
# Epoch 10/100
# 68/68 - 22s - loss: 0.0020 - accuracy: 0.9991 - 22s/epoch - 322ms/step
# Epoch 11/100
# 68/68 - 22s - loss: 0.0017 - accuracy: 0.9995 - 22s/epoch - 325ms/step
# Epoch 12/100
# 68/68 - 22s - loss: 0.0059 - accuracy: 0.9986 - 22s/epoch - 322ms/step
# Epoch 13/100
# 68/68 - 22s - loss: 6.4873e-04 - accuracy: 1.0000 - 22s/epoch - 322ms/step
# Epoch 14/100
# 68/68 - 22s - loss: 0.0057 - accuracy: 0.9991 - 22s/epoch - 325ms/step
# Epoch 15/100
# 68/68 - 22s - loss: 0.0018 - accuracy: 0.9991 - 22s/epoch - 319ms/step
# Epoch 16/100
# 68/68 - 22s - loss: 0.0438 - accuracy: 0.9968 - 22s/epoch - 322ms/step
# Epoch 17/100
# 68/68 - 22s - loss: 0.0454 - accuracy: 0.9949 - 22s/epoch - 324ms/step
# Epoch 18/100
# 68/68 - 22s - loss: 0.0243 - accuracy: 0.9968 - 22s/epoch - 325ms/step
# Epoch 19/100
# 68/68 - 22s - loss: 0.0086 - accuracy: 0.9972 - 22s/epoch - 322ms/step
# Epoch 20/100
# 68/68 - 22s - loss: 0.0020 - accuracy: 0.9986 - 22s/epoch - 322ms/step
# Epoch 21/100
# 68/68 - 22s - loss: 0.0022 - accuracy: 0.9991 - 22s/epoch - 324ms/step
# Epoch 22/100
# 68/68 - 22s - loss: 0.0014 - accuracy: 0.9995 - 22s/epoch - 323ms/step
# Epoch 23/100
# 68/68 - 22s - loss: 0.0014 - accuracy: 0.9991 - 22s/epoch - 323ms/step
# Epoch 24/100
# 68/68 - 22s - loss: 0.0050 - accuracy: 0.9995 - 22s/epoch - 326ms/step
# Epoch 25/100
# 68/68 - 22s - loss: 1.0936e-04 - accuracy: 1.0000 - 22s/epoch - 326ms/step
# Epoch 26/100
# 68/68 - 22s - loss: 0.0029 - accuracy: 0.9991 - 22s/epoch - 322ms/step
# Epoch 27/100
# 68/68 - 22s - loss: 0.0019 - accuracy: 0.9991 - 22s/epoch - 323ms/step
# Epoch 28/100
# 68/68 - 22s - loss: 0.0146 - accuracy: 0.9991 - 22s/epoch - 323ms/step
# Epoch 29/100
# 68/68 - 22s - loss: 0.0028 - accuracy: 0.9986 - 22s/epoch - 325ms/step
# Epoch 30/100
# 68/68 - 22s - loss: 0.0024 - accuracy: 0.9986 - 22s/epoch - 321ms/step
# Epoch 31/100
# 68/68 - 22s - loss: 0.0011 - accuracy: 1.0000 - 22s/epoch - 325ms/step
# Epoch 32/100
# 68/68 - 22s - loss: 7.0886e-05 - accuracy: 1.0000 - 22s/epoch - 322ms/step
# Epoch 33/100
# 68/68 - 22s - loss: 7.0882e-04 - accuracy: 0.9995 - 22s/epoch - 325ms/step
# Epoch 34/100
# 68/68 - 22s - loss: 5.7190e-04 - accuracy: 0.9995 - 22s/epoch - 321ms/step
# Epoch 35/100
# 68/68 - 22s - loss: 8.2190e-04 - accuracy: 0.9995 - 22s/epoch - 325ms/step
# Epoch 36/100
# 68/68 - 22s - loss: 0.0024 - accuracy: 0.9995 - 22s/epoch - 324ms/step
# Epoch 37/100
# 68/68 - 22s - loss: 4.0145e-04 - accuracy: 1.0000 - 22s/epoch - 324ms/step
# Epoch 38/100
# 68/68 - 22s - loss: 4.9488e-04 - accuracy: 1.0000 - 22s/epoch - 324ms/step
# Epoch 39/100
# 68/68 - 22s - loss: 5.2163e-04 - accuracy: 1.0000 - 22s/epoch - 328ms/step
# Epoch 40/100
# 68/68 - 22s - loss: 1.6308e-04 - accuracy: 1.0000 - 22s/epoch - 322ms/step
# Epoch 41/100
# 68/68 - 22s - loss: 1.6505e-07 - accuracy: 1.0000 - 22s/epoch - 322ms/step
# Epoch 42/100
# 68/68 - 22s - loss: 3.5616e-07 - accuracy: 1.0000 - 22s/epoch - 325ms/step
# Epoch 43/100
# 68/68 - 22s - loss: 5.7800e-04 - accuracy: 1.0000 - 22s/epoch - 324ms/step
# Epoch 44/100
# 68/68 - 22s - loss: 0.0049 - accuracy: 0.9995 - 22s/epoch - 328ms/step
# Epoch 45/100
# 68/68 - 22s - loss: 1.4763e-04 - accuracy: 1.0000 - 22s/epoch - 321ms/step
# Epoch 46/100
# 68/68 - 22s - loss: 6.3118e-05 - accuracy: 1.0000 - 22s/epoch - 325ms/step
# Epoch 47/100
# 68/68 - 22s - loss: 1.7239e-05 - accuracy: 1.0000 - 22s/epoch - 322ms/step
# Epoch 48/100
# 68/68 - 22s - loss: 0.0026 - accuracy: 0.9995 - 22s/epoch - 322ms/step
# Epoch 49/100
# 68/68 - 22s - loss: 5.9122e-04 - accuracy: 1.0000 - 22s/epoch - 326ms/step
# Epoch 50/100
# 68/68 - 22s - loss: 2.9560e-04 - accuracy: 1.0000 - 22s/epoch - 323ms/step
# Epoch 51/100
# 68/68 - 22s - loss: 1.5571e-04 - accuracy: 1.0000 - 22s/epoch - 323ms/step
# Epoch 52/100
# 68/68 - 22s - loss: 0.0014 - accuracy: 0.9995 - 22s/epoch - 322ms/step
# Epoch 53/100
# 68/68 - 22s - loss: 0.0039 - accuracy: 0.9986 - 22s/epoch - 326ms/step
# Epoch 54/100
# 68/68 - 22s - loss: 9.5929e-05 - accuracy: 1.0000 - 22s/epoch - 323ms/step
# Epoch 55/100
# 68/68 - 22s - loss: 0.0035 - accuracy: 0.9986 - 22s/epoch - 325ms/step
# Epoch 56/100
# 68/68 - 22s - loss: 0.0148 - accuracy: 0.9968 - 22s/epoch - 327ms/step
# Epoch 57/100
# 68/68 - 22s - loss: 0.0088 - accuracy: 0.9977 - 22s/epoch - 322ms/step
# Epoch 58/100
# 68/68 - 22s - loss: 0.0150 - accuracy: 0.9986 - 22s/epoch - 326ms/step
# Epoch 59/100
# 68/68 - 22s - loss: 0.0050 - accuracy: 0.9991 - 22s/epoch - 321ms/step
# Epoch 60/100
# 68/68 - 22s - loss: 0.0025 - accuracy: 0.9991 - 22s/epoch - 325ms/step
# Epoch 61/100
# 68/68 - 22s - loss: 0.0116 - accuracy: 0.9991 - 22s/epoch - 325ms/step
# Epoch 62/100
# 68/68 - 22s - loss: 0.0065 - accuracy: 0.9991 - 22s/epoch - 330ms/step
# Epoch 63/100
# 68/68 - 22s - loss: 0.0025 - accuracy: 0.9995 - 22s/epoch - 322ms/step
# Epoch 64/100
# 68/68 - 22s - loss: 0.0263 - accuracy: 0.9963 - 22s/epoch - 327ms/step
# Epoch 65/100
# 68/68 - 22s - loss: 0.0153 - accuracy: 0.9968 - 22s/epoch - 321ms/step
# Epoch 66/100
# 68/68 - 22s - loss: 0.0011 - accuracy: 1.0000 - 22s/epoch - 325ms/step
# Epoch 67/100
# 68/68 - 22s - loss: 0.0403 - accuracy: 0.9954 - 22s/epoch - 326ms/step
# Epoch 68/100
# 68/68 - 22s - loss: 0.0367 - accuracy: 0.9981 - 22s/epoch - 321ms/step
# Epoch 69/100
# 68/68 - 22s - loss: 0.0116 - accuracy: 0.9981 - 22s/epoch - 321ms/step
# Epoch 70/100
# 68/68 - 22s - loss: 0.0020 - accuracy: 0.9986 - 22s/epoch - 319ms/step
# Epoch 71/100
# 68/68 - 22s - loss: 0.0082 - accuracy: 0.9981 - 22s/epoch - 326ms/step
# Epoch 72/100
# 68/68 - 22s - loss: 6.2123e-04 - accuracy: 0.9995 - 22s/epoch - 323ms/step
# Epoch 73/100
# 68/68 - 22s - loss: 0.0025 - accuracy: 0.9991 - 22s/epoch - 323ms/step
# Epoch 74/100
# 68/68 - 22s - loss: 0.0075 - accuracy: 0.9991 - 22s/epoch - 323ms/step
# Epoch 75/100
# 68/68 - 22s - loss: 0.0221 - accuracy: 0.9986 - 22s/epoch - 324ms/step
# Epoch 76/100
# 68/68 - 22s - loss: 0.0348 - accuracy: 0.9968 - 22s/epoch - 322ms/step
# Epoch 77/100
# 68/68 - 22s - loss: 0.0242 - accuracy: 0.9981 - 22s/epoch - 327ms/step
# Epoch 78/100
# 68/68 - 22s - loss: 0.0064 - accuracy: 0.9981 - 22s/epoch - 322ms/step
# Epoch 79/100
# 68/68 - 22s - loss: 0.0189 - accuracy: 0.9981 - 22s/epoch - 322ms/step
# Epoch 80/100
# 68/68 - 22s - loss: 0.0084 - accuracy: 0.9991 - 22s/epoch - 322ms/step
# Epoch 81/100
# 68/68 - 22s - loss: 0.0024 - accuracy: 0.9986 - 22s/epoch - 325ms/step
# Epoch 82/100
# 68/68 - 22s - loss: 0.0023 - accuracy: 0.9986 - 22s/epoch - 322ms/step
# Epoch 83/100
# 68/68 - 22s - loss: 0.0010 - accuracy: 1.0000 - 22s/epoch - 324ms/step
# Epoch 84/100
# 68/68 - 22s - loss: 0.0014 - accuracy: 0.9995 - 22s/epoch - 326ms/step
# Epoch 85/100
# 68/68 - 22s - loss: 0.0019 - accuracy: 0.9991 - 22s/epoch - 324ms/step
# Epoch 86/100
# 68/68 - 22s - loss: 2.2401e-04 - accuracy: 1.0000 - 22s/epoch - 325ms/step
# Epoch 87/100
# 68/68 - 22s - loss: 0.0085 - accuracy: 0.9977 - 22s/epoch - 320ms/step
# Epoch 88/100
# 68/68 - 22s - loss: 8.1820e-04 - accuracy: 1.0000 - 22s/epoch - 322ms/step
# Epoch 89/100
# 68/68 - 22s - loss: 3.0023e-04 - accuracy: 1.0000 - 22s/epoch - 320ms/step
# Epoch 90/100
# 68/68 - 22s - loss: 8.5749e-04 - accuracy: 0.9995 - 22s/epoch - 321ms/step
# Epoch 91/100
# 68/68 - 22s - loss: 4.7166e-05 - accuracy: 1.0000 - 22s/epoch - 322ms/step
# Epoch 92/100
# 68/68 - 22s - loss: 4.6262e-04 - accuracy: 1.0000 - 22s/epoch - 323ms/step
# Epoch 93/100
# 68/68 - 22s - loss: 9.2036e-04 - accuracy: 0.9995 - 22s/epoch - 321ms/step
# Epoch 94/100
# 68/68 - 22s - loss: 0.0015 - accuracy: 0.9991 - 22s/epoch - 323ms/step
# Epoch 95/100
# 68/68 - 22s - loss: 0.0030 - accuracy: 0.9991 - 22s/epoch - 326ms/step
# Epoch 96/100
# 68/68 - 22s - loss: 0.0018 - accuracy: 0.9991 - 22s/epoch - 322ms/step
# Epoch 97/100
# 68/68 - 22s - loss: 2.0208e-04 - accuracy: 1.0000 - 22s/epoch - 322ms/step
# Epoch 98/100
# 68/68 - 22s - loss: 0.0013 - accuracy: 0.9991 - 22s/epoch - 322ms/step
# Epoch 99/100
# 68/68 - 22s - loss: 6.7510e-07 - accuracy: 1.0000 - 22s/epoch - 325ms/step
# Epoch 100/100
# 68/68 - 22s - loss: 0.0059 - accuracy: 0.9995 - 22s/epoch - 322ms/step
# 0.0457
# ***Performance on Test Data***
# Accuracy  : 0.8462962962962963
# Precision : 0.8919540229885058
# f1Score : 0.8499432384418736
# [[143  37   0]
#  [  0 180   0]
#  [  2  44 134]]
# 17/17 [==============================] - 5s 327ms/step - loss: 3.8277 - accuracy: 0.8463
# trn_indx: 2160 test_indx: 540
# No file moved. Source empty!
# No file moved. Source empty!
# No file moved. Source empty!
# Results for fold 5
# 2160
# 540
# Found 2160 images belonging to 3 classes.
# Found 540 images belonging to 3 classes.
# Epoch 1/100
# 68/68 - 22s - loss: 0.0119 - accuracy: 0.9981 - 22s/epoch - 321ms/step
# Epoch 2/100
# 68/68 - 22s - loss: 0.0263 - accuracy: 0.9968 - 22s/epoch - 321ms/step
# Epoch 3/100
# 68/68 - 22s - loss: 0.0968 - accuracy: 0.9875 - 22s/epoch - 320ms/step
# Epoch 4/100
# 68/68 - 22s - loss: 0.0039 - accuracy: 0.9986 - 22s/epoch - 322ms/step
# Epoch 5/100
# 68/68 - 22s - loss: 0.0101 - accuracy: 0.9972 - 22s/epoch - 320ms/step
# Epoch 6/100
# 68/68 - 22s - loss: 0.0028 - accuracy: 0.9986 - 22s/epoch - 316ms/step
# Epoch 7/100
# 68/68 - 22s - loss: 0.0042 - accuracy: 0.9986 - 22s/epoch - 321ms/step
# Epoch 8/100
# 68/68 - 22s - loss: 0.0011 - accuracy: 0.9995 - 22s/epoch - 320ms/step
# Epoch 9/100
# 68/68 - 22s - loss: 0.0103 - accuracy: 0.9981 - 22s/epoch - 321ms/step
# Epoch 10/100
# 68/68 - 21s - loss: 0.0089 - accuracy: 0.9986 - 21s/epoch - 315ms/step
# Epoch 11/100
# 68/68 - 22s - loss: 0.0039 - accuracy: 0.9995 - 22s/epoch - 321ms/step
# Epoch 12/100
# 68/68 - 22s - loss: 0.0019 - accuracy: 0.9995 - 22s/epoch - 319ms/step
# Epoch 13/100
# 68/68 - 22s - loss: 0.0010 - accuracy: 1.0000 - 22s/epoch - 322ms/step
# Epoch 14/100
# 68/68 - 22s - loss: 0.0011 - accuracy: 0.9995 - 22s/epoch - 318ms/step
# Epoch 15/100
# 68/68 - 22s - loss: 0.0054 - accuracy: 0.9977 - 22s/epoch - 320ms/step
# Epoch 16/100
# 68/68 - 22s - loss: 0.0040 - accuracy: 0.9986 - 22s/epoch - 317ms/step
# Epoch 17/100
# 68/68 - 22s - loss: 0.0013 - accuracy: 0.9995 - 22s/epoch - 322ms/step
# Epoch 18/100
# 68/68 - 22s - loss: 6.6751e-04 - accuracy: 1.0000 - 22s/epoch - 317ms/step
# Epoch 19/100
# 68/68 - 21s - loss: 2.5874e-04 - accuracy: 1.0000 - 21s/epoch - 316ms/step
# Epoch 20/100
# 68/68 - 22s - loss: 2.2146e-04 - accuracy: 1.0000 - 22s/epoch - 318ms/step
# Epoch 21/100
# 68/68 - 21s - loss: 1.7765e-04 - accuracy: 1.0000 - 21s/epoch - 316ms/step
# Epoch 22/100
# 68/68 - 22s - loss: 4.3243e-04 - accuracy: 1.0000 - 22s/epoch - 319ms/step
# Epoch 23/100
# 68/68 - 22s - loss: 3.6763e-04 - accuracy: 0.9995 - 22s/epoch - 318ms/step
# Epoch 24/100
# 68/68 - 22s - loss: 0.0016 - accuracy: 0.9995 - 22s/epoch - 317ms/step
# Epoch 25/100
# 68/68 - 21s - loss: 5.5159e-04 - accuracy: 1.0000 - 21s/epoch - 313ms/step
# Epoch 26/100
# 68/68 - 22s - loss: 4.1219e-04 - accuracy: 1.0000 - 22s/epoch - 317ms/step
# Epoch 27/100
# 68/68 - 21s - loss: 4.1248e-04 - accuracy: 1.0000 - 21s/epoch - 314ms/step
# Epoch 28/100
# 68/68 - 21s - loss: 0.0015 - accuracy: 0.9995 - 21s/epoch - 315ms/step
# Epoch 29/100
# 68/68 - 22s - loss: 2.1895e-04 - accuracy: 1.0000 - 22s/epoch - 317ms/step
# Epoch 30/100
# 68/68 - 22s - loss: 5.3579e-04 - accuracy: 1.0000 - 22s/epoch - 317ms/step
# Epoch 31/100
# 68/68 - 21s - loss: 5.0579e-04 - accuracy: 1.0000 - 21s/epoch - 316ms/step
# Epoch 32/100
# 68/68 - 22s - loss: 4.0591e-04 - accuracy: 1.0000 - 22s/epoch - 316ms/step
# Epoch 33/100
# 68/68 - 22s - loss: 2.6617e-04 - accuracy: 1.0000 - 22s/epoch - 316ms/step
# Epoch 34/100
# 68/68 - 22s - loss: 8.1539e-04 - accuracy: 1.0000 - 22s/epoch - 317ms/step
# Epoch 35/100
# 68/68 - 22s - loss: 0.0049 - accuracy: 0.9991 - 22s/epoch - 320ms/step
# Epoch 36/100
# 68/68 - 21s - loss: 0.0152 - accuracy: 0.9972 - 21s/epoch - 314ms/step
# Epoch 37/100
# 68/68 - 22s - loss: 0.0245 - accuracy: 0.9972 - 22s/epoch - 319ms/step
# Epoch 38/100
# 68/68 - 22s - loss: 0.0031 - accuracy: 0.9986 - 22s/epoch - 318ms/step
# Epoch 39/100
# 68/68 - 22s - loss: 0.0081 - accuracy: 0.9991 - 22s/epoch - 322ms/step
# Epoch 40/100
# 68/68 - 21s - loss: 0.0015 - accuracy: 0.9995 - 21s/epoch - 315ms/step
# Epoch 41/100
# 68/68 - 22s - loss: 7.3040e-04 - accuracy: 1.0000 - 22s/epoch - 319ms/step
# Epoch 42/100
# 68/68 - 22s - loss: 3.3418e-04 - accuracy: 1.0000 - 22s/epoch - 316ms/step
# Epoch 43/100
# 68/68 - 22s - loss: 0.0074 - accuracy: 0.9986 - 22s/epoch - 317ms/step
# Epoch 44/100
# 68/68 - 21s - loss: 0.0041 - accuracy: 0.9981 - 21s/epoch - 316ms/step
# Epoch 45/100
# 68/68 - 22s - loss: 5.5143e-04 - accuracy: 1.0000 - 22s/epoch - 318ms/step
# Epoch 46/100
# 68/68 - 21s - loss: 7.6057e-04 - accuracy: 1.0000 - 21s/epoch - 316ms/step
# Epoch 47/100
# 68/68 - 22s - loss: 4.3257e-04 - accuracy: 1.0000 - 22s/epoch - 319ms/step
# Epoch 48/100
# 68/68 - 22s - loss: 9.7961e-04 - accuracy: 0.9995 - 22s/epoch - 316ms/step
# Epoch 49/100
# 68/68 - 22s - loss: 0.0013 - accuracy: 0.9995 - 22s/epoch - 319ms/step
# Epoch 50/100
# 68/68 - 22s - loss: 0.0016 - accuracy: 0.9995 - 22s/epoch - 318ms/step
# Epoch 51/100
# 68/68 - 22s - loss: 0.0026 - accuracy: 0.9995 - 22s/epoch - 317ms/step
# Epoch 52/100
# 68/68 - 22s - loss: 0.0010 - accuracy: 0.9995 - 22s/epoch - 322ms/step
# Epoch 53/100
# 68/68 - 22s - loss: 0.0069 - accuracy: 0.9986 - 22s/epoch - 317ms/step
# Epoch 54/100
# 68/68 - 22s - loss: 0.0410 - accuracy: 0.9977 - 22s/epoch - 320ms/step
# Epoch 55/100
# 68/68 - 22s - loss: 0.0277 - accuracy: 0.9944 - 22s/epoch - 316ms/step
# Epoch 56/100
# 68/68 - 22s - loss: 0.0278 - accuracy: 0.9954 - 22s/epoch - 318ms/step
# Epoch 57/100
# 68/68 - 22s - loss: 0.0761 - accuracy: 0.9958 - 22s/epoch - 318ms/step
# Epoch 58/100
# 68/68 - 22s - loss: 0.0036 - accuracy: 0.9977 - 22s/epoch - 320ms/step
# Epoch 59/100
# 68/68 - 21s - loss: 0.0221 - accuracy: 0.9963 - 21s/epoch - 316ms/step
# Epoch 60/100
# 68/68 - 22s - loss: 0.0029 - accuracy: 0.9991 - 22s/epoch - 320ms/step
# Epoch 61/100
# 68/68 - 22s - loss: 0.0093 - accuracy: 0.9991 - 22s/epoch - 320ms/step
# Epoch 62/100
# 68/68 - 22s - loss: 9.3793e-05 - accuracy: 1.0000 - 22s/epoch - 318ms/step
# Epoch 63/100
# 68/68 - 22s - loss: 2.3131e-04 - accuracy: 1.0000 - 22s/epoch - 317ms/step
# Epoch 64/100
# 68/68 - 22s - loss: 0.0054 - accuracy: 0.9991 - 22s/epoch - 318ms/step
# Epoch 65/100
# 68/68 - 22s - loss: 0.0022 - accuracy: 0.9995 - 22s/epoch - 319ms/step
# Epoch 66/100
# 68/68 - 22s - loss: 0.0066 - accuracy: 0.9991 - 22s/epoch - 320ms/step
# Epoch 67/100
# 68/68 - 22s - loss: 0.0057 - accuracy: 0.9986 - 22s/epoch - 321ms/step
# Epoch 68/100
# 68/68 - 22s - loss: 0.0011 - accuracy: 0.9995 - 22s/epoch - 318ms/step
# Epoch 69/100
# 68/68 - 22s - loss: 6.8904e-06 - accuracy: 1.0000 - 22s/epoch - 317ms/step
# Epoch 70/100
# 68/68 - 22s - loss: 2.2460e-04 - accuracy: 1.0000 - 22s/epoch - 317ms/step
# Epoch 71/100
# 68/68 - 22s - loss: 0.0162 - accuracy: 0.9991 - 22s/epoch - 318ms/step
# Epoch 72/100
# 68/68 - 22s - loss: 0.0125 - accuracy: 0.9986 - 22s/epoch - 318ms/step
# Epoch 73/100
# 68/68 - 22s - loss: 0.0079 - accuracy: 0.9986 - 22s/epoch - 318ms/step
# Epoch 74/100
# 68/68 - 21s - loss: 0.0038 - accuracy: 0.9991 - 21s/epoch - 315ms/step
# Epoch 75/100
# 68/68 - 22s - loss: 4.1978e-04 - accuracy: 1.0000 - 22s/epoch - 318ms/step
# Epoch 76/100
# 68/68 - 22s - loss: 0.0017 - accuracy: 0.9991 - 22s/epoch - 320ms/step
# Epoch 77/100
# 68/68 - 21s - loss: 0.0096 - accuracy: 0.9991 - 21s/epoch - 315ms/step
# Epoch 78/100
# 68/68 - 22s - loss: 0.0081 - accuracy: 0.9981 - 22s/epoch - 316ms/step
# Epoch 79/100
# 68/68 - 22s - loss: 0.0092 - accuracy: 0.9991 - 22s/epoch - 317ms/step
# Epoch 80/100
# 68/68 - 22s - loss: 5.4799e-04 - accuracy: 1.0000 - 22s/epoch - 321ms/step
# Epoch 81/100
# 68/68 - 21s - loss: 1.8006e-04 - accuracy: 1.0000 - 21s/epoch - 316ms/step
# Epoch 82/100
# 68/68 - 22s - loss: 0.0027 - accuracy: 0.9991 - 22s/epoch - 316ms/step
# Epoch 83/100
# 68/68 - 22s - loss: 0.0429 - accuracy: 0.9972 - 22s/epoch - 318ms/step
# Epoch 84/100
# 68/68 - 22s - loss: 0.0015 - accuracy: 0.9995 - 22s/epoch - 319ms/step
# Epoch 85/100
# 68/68 - 21s - loss: 6.3251e-04 - accuracy: 1.0000 - 21s/epoch - 314ms/step
# Epoch 86/100
# 68/68 - 22s - loss: 0.0052 - accuracy: 0.9991 - 22s/epoch - 318ms/step
# Epoch 87/100
# 68/68 - 22s - loss: 9.1896e-04 - accuracy: 1.0000 - 22s/epoch - 317ms/step
# Epoch 88/100
# 68/68 - 22s - loss: 6.9627e-05 - accuracy: 1.0000 - 22s/epoch - 319ms/step
# Epoch 89/100
# 68/68 - 21s - loss: 3.6694e-04 - accuracy: 1.0000 - 21s/epoch - 314ms/step
# Epoch 90/100
# 68/68 - 22s - loss: 1.1635e-04 - accuracy: 1.0000 - 22s/epoch - 319ms/step
# Epoch 91/100
# 68/68 - 21s - loss: 3.1023e-04 - accuracy: 1.0000 - 21s/epoch - 316ms/step
# Epoch 92/100
# 68/68 - 21s - loss: 7.3461e-04 - accuracy: 1.0000 - 21s/epoch - 316ms/step
# Epoch 93/100
# 68/68 - 21s - loss: 2.9147e-04 - accuracy: 1.0000 - 21s/epoch - 315ms/step
# Epoch 94/100
# 68/68 - 22s - loss: 7.3544e-04 - accuracy: 0.9995 - 22s/epoch - 316ms/step
# Epoch 95/100
# 68/68 - 22s - loss: 6.0910e-04 - accuracy: 1.0000 - 22s/epoch - 319ms/step
# Epoch 96/100
# 68/68 - 21s - loss: 0.0021 - accuracy: 0.9986 - 21s/epoch - 316ms/step
# Epoch 97/100
# 68/68 - 21s - loss: 0.0012 - accuracy: 0.9995 - 21s/epoch - 315ms/step
# Epoch 98/100
# 68/68 - 21s - loss: 2.3377e-04 - accuracy: 1.0000 - 21s/epoch - 316ms/step
# Epoch 99/100
# 68/68 - 22s - loss: 1.0797e-05 - accuracy: 1.0000 - 22s/epoch - 317ms/step
# Epoch 100/100
# 68/68 - 21s - loss: 1.8561e-04 - accuracy: 1.0000 - 21s/epoch - 313ms/step
# 0.0538
# ***Performance on Test Data***
# Accuracy  : 0.9962962962962963
# Precision : 0.9963369963369964
# f1Score : 0.9962961819809253
# [[180   0   0]
#  [  0 178   2]
#  [  0   0 180]]
# 17/17 [==============================] - 5s 334ms/step - loss: 0.0052 - accuracy: 0.9963
# Overall Accuracy:  0.9625925925925924
